# %% [markdown]
# ## Dependencies

# %%
import random, os, warnings, math
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import tensorflow as tf
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
from tensorflow.keras import optimizers, losses, metrics, Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from transformers import TFAutoModelForSequenceClassification, TFAutoModel, AutoTokenizer


def seed_everything(seed=0):
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'

seed = 0
seed_everything(seed)
sns.set(style='whitegrid')
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 150)

# %% [markdown]
# ### Hardware configuration

# %%
# TPU or GPU detection
# Detect hardware, return appropriate distribution strategy
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print(f'Running on TPU {tpu.master()}')
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy()

AUTO = tf.data.experimental.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
print(f'REPLICAS: {REPLICAS}')
# Out:
# Running on TPU grpc://10.0.0.2:8470
# REPLICAS: 8

# %% [markdown]
# # Load data

# %%
train_filepath = '/kaggle/input/commonlitreadabilityprize/train.csv'
train = pd.read_csv(train_filepath)
print(f'Train samples: {len(train)}')
display(train.head())
# removing unused columns
train.drop(['url_legal', 'license'], axis=1, inplace=True)
# Out:
# Train samples: 2834
#           id url_legal license  \
# 0  c12129c31       NaN     NaN
# 1  85aa80a4c       NaN     NaN
# 2  b69ac6792       NaN     NaN
# 3  dd1000b26       NaN     NaN
# 4  37c1b32fb       NaN     NaN
#
#                                                                                                                                                  excerpt  \
# 0  When the young people returned to the ballroom, it presented a decidedly changed appearance. Instead of an interior scene, it was a winter landsca...
# 1  All through dinner time, Mrs. Fayre was somewhat silent, her eyes resting on Dolly with a wistful, uncertain expression. She wanted to give the ch...
# 2  As Roger had predicted, the snow departed as quickly as it came, and two days after their sleigh ride there was scarcely a vestige of white on the...
# 3  And outside before the palace a great garden was walled round, filled full of stately fruit-trees, gray olives and sweet figs, and pomegranates, p...
# 4  Once upon a time there were Three Bears who lived together in a house of their own in a wood. One of them was a Little, Small, Wee Bear; and one w...
#
#      target  standard_error
# 0 -0.340259        0.464009
# 1 -0.315372        0.480805
# 2 -0.580118        0.476676
# 3 -1.054013        0.450007
# 4  0.247197        0.510845

# %% [markdown]
# # Model parameters

# %%
BATCH_SIZE = 8 * REPLICAS
LEARNING_RATE = 1e-5 * REPLICAS
EPOCHS = 35
ES_PATIENCE = 10
PATIENCE = 2
N_FOLDS = 5
SEQ_LEN = 256
BASE_MODEL = '/kaggle/input/huggingface-roberta/roberta-large/'

# %% [markdown]
# ## Auxiliary functions

# %%
# Datasets utility functions
def custom_standardization(text):
    text = text.lower() # if encoder is uncased
    text = text.strip()
    return text


def sample_target(features, target):
    mean, stddev = target
    sampled_target = tf.random.normal([], mean=tf.cast(mean, dtype=tf.float32), 
                                      stddev=tf.cast(stddev, dtype=tf.float32), dtype=tf.float32)
    
    return (features, sampled_target)
    

def get_dataset(pandas_df, tokenizer, labeled=True, ordered=False, repeated=False, 
                is_sampled=False, batch_size=32, seq_len=128):
    """
        Return a Tensorflow dataset ready for training or inference.
    """
    text = [custom_standardization(text) for text in pandas_df['excerpt']]
    
    # Tokenize inputs
    tokenized_inputs = tokenizer(text, max_length=seq_len, truncation=True, 
                                 padding='max_length', return_tensors='tf')
    
    if labeled:
        dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': tokenized_inputs['input_ids'], 
                                                      'attention_mask': tokenized_inputs['attention_mask']}, 
                                                      (pandas_df['target'], pandas_df['standard_error'])))
        if is_sampled:
            dataset = dataset.map(sample_target, num_parallel_calls=tf.data.AUTOTUNE)
    else:
        dataset = tf.data.Dataset.from_tensor_slices({'input_ids': tokenized_inputs['input_ids'], 
                                                      'attention_mask': tokenized_inputs['attention_mask']})
        
    if repeated:
        dataset = dataset.repeat()
    if not ordered:
        dataset = dataset.shuffle(1024)
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    
    return dataset


def plot_metrics(history):
    metric_list = list(history.keys())
    size = len(metric_list)//2
    fig, axes = plt.subplots(size, 1, sharex='col', figsize=(20, size * 5))
    axes = axes.flatten()
    
    for index in range(len(metric_list)//2):
        metric_name = metric_list[index]
        val_metric_name = metric_list[index+size]
        axes[index].plot(history[metric_name], label='Train %s' % metric_name)
        axes[index].plot(history[val_metric_name], label='Validation %s' % metric_name)
        axes[index].legend(loc='best', fontsize=16)
        axes[index].set_title(metric_name)

    plt.xlabel('Epochs', fontsize=16)
    sns.despine()
    plt.show()

# %% [markdown]
# # Model

# %%
def model_fn(encoder, seq_len=256):
    input_ids = L.Input(shape=(seq_len,), dtype=tf.int32, name='input_ids')
    input_attention_mask = L.Input(shape=(seq_len,), dtype=tf.int32, name='attention_mask')
    
    outputs = encoder({'input_ids': input_ids, 
                       'attention_mask': input_attention_mask})
    last_hidden_state = outputs['last_hidden_state']
    
    x = L.GlobalAveragePooling1D()(last_hidden_state)
#     x = L.Dropout(.5)(x)
    output = L.Dense(1, name='output')(x)
    
    model = Model(inputs=[input_ids, input_attention_mask], outputs=output)

    optimizer = optimizers.Adam(lr=LEARNING_RATE)
    model.compile(optimizer=optimizer, 
                  loss=losses.MeanSquaredError(), 
                  metrics=[metrics.RootMeanSquaredError()])
    
    return model


with strategy.scope():
#     encoder = TFAutoModelForSequenceClassification.from_pretrained(BASE_MODEL, num_labels=1)
    encoder = TFAutoModel.from_pretrained(BASE_MODEL)
    model = model_fn(encoder, SEQ_LEN)
    
model.summary()
# Out:
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-large/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-large/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# attention_mask (InputLayer)     [(None, 256)]        0
# __________________________________________________________________________________________________
# input_ids (InputLayer)          [(None, 256)]        0
# __________________________________________________________________________________________________
# tf_roberta_model (TFRobertaMode TFBaseModelOutputWit 355359744   attention_mask[0][0]
#                                                                  input_ids[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 1024)         0           tf_roberta_model[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            1025        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 355,360,769
# Trainable params: 355,360,769
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL)
skf = KFold(n_splits=N_FOLDS, shuffle=True, random_state=seed)
oof_pred = []; oof_labels = []; history_list = []

for fold,(idxT, idxV) in enumerate(skf.split(train)):
    if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    print(f'\nFOLD: {fold+1}')
    print(f'TRAIN: {len(idxT)} VALID: {len(idxV)}')

    # Model
    K.clear_session()
    with strategy.scope():
#         encoder = TFAutoModelForSequenceClassification.from_pretrained(BASE_MODEL, num_labels=1)
        encoder = TFAutoModel.from_pretrained(BASE_MODEL)
        model = model_fn(encoder, SEQ_LEN)
        
    model_path = f'model_{fold}.h5'
    es = EarlyStopping(monitor='val_root_mean_squared_error', mode='min', 
                       patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_root_mean_squared_error', mode='min', 
                                 save_best_only=True, save_weights_only=True)

    # Train
    history = model.fit(x=get_dataset(train.loc[idxT], tokenizer, repeated=True, is_sampled=True, 
                                      batch_size=BATCH_SIZE, seq_len=SEQ_LEN), 
                        validation_data=get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                                                    batch_size=BATCH_SIZE, seq_len=SEQ_LEN), 
                        steps_per_epoch=50, 
                        callbacks=[es, checkpoint], 
                        epochs=EPOCHS,  
                        verbose=2).history
      
    history_list.append(history)
    # Save last model weights
    model.load_weights(model_path)
    
    # Results
    print(f"#### FOLD {fold+1} OOF RMSE = {np.min(history['val_root_mean_squared_error']):.4f}")

    # OOF predictions
    valid_ds = get_dataset(train.loc[idxV], tokenizer, ordered=True, batch_size=BATCH_SIZE, seq_len=SEQ_LEN)
    oof_labels.append([target[0].numpy() for sample, target in iter(valid_ds.unbatch())])
    x_oof = valid_ds.map(lambda sample, target: sample)
    oof_pred.append(model.predict(x_oof))
# Out:
# FOLD: 1
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-large/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-large/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/35
# 50/50 - 185s - loss: 1.1369 - root_mean_squared_error: 1.0663 - val_loss: 0.4014 - val_root_mean_squared_error: 0.6335
# Epoch 2/35
# 50/50 - 13s - loss: 0.6125 - root_mean_squared_error: 0.7826 - val_loss: 0.4312 - val_root_mean_squared_error: 0.6567
# Epoch 3/35
# 50/50 - 12s - loss: 0.5368 - root_mean_squared_error: 0.7327 - val_loss: 0.4279 - val_root_mean_squared_error: 0.6541
# Epoch 4/35
# 50/50 - 12s - loss: 0.4415 - root_mean_squared_error: 0.6644 - val_loss: 0.4597 - val_root_mean_squared_error: 0.6780
# Epoch 5/35
# 50/50 - 13s - loss: 0.3930 - root_mean_squared_error: 0.6269 - val_loss: 0.4015 - val_root_mean_squared_error: 0.6337
# Epoch 6/35
# 50/50 - 12s - loss: 0.3428 - root_mean_squared_error: 0.5855 - val_loss: 0.4134 - val_root_mean_squared_error: 0.6430
# Epoch 7/35
# 50/50 - 12s - loss: 0.3417 - root_mean_squared_error: 0.5845 - val_loss: 0.3569 - val_root_mean_squared_error: 0.5974
# Epoch 8/35
# 50/50 - 13s - loss: 0.3306 - root_mean_squared_error: 0.5750 - val_loss: 0.3882 - val_root_mean_squared_error: 0.6230
# Epoch 9/35
# 50/50 - 12s - loss: 0.3109 - root_mean_squared_error: 0.5576 - val_loss: 0.4129 - val_root_mean_squared_error: 0.6426
# Epoch 10/35
# 50/50 - 13s - loss: 0.3453 - root_mean_squared_error: 0.5877 - val_loss: 0.3441 - val_root_mean_squared_error: 0.5866
# Epoch 11/35
# 50/50 - 12s - loss: 1.0156 - root_mean_squared_error: 1.0078 - val_loss: 1.0869 - val_root_mean_squared_error: 1.0426
# Epoch 12/35
# 50/50 - 12s - loss: 1.2912 - root_mean_squared_error: 1.1363 - val_loss: 1.0863 - val_root_mean_squared_error: 1.0423
# Epoch 13/35
# 50/50 - 12s - loss: 1.3477 - root_mean_squared_error: 1.1609 - val_loss: 1.0989 - val_root_mean_squared_error: 1.0483
# Epoch 14/35
# 50/50 - 13s - loss: 1.3423 - root_mean_squared_error: 1.1586 - val_loss: 1.1112 - val_root_mean_squared_error: 1.0542
# Epoch 15/35
# 50/50 - 13s - loss: 1.3332 - root_mean_squared_error: 1.1547 - val_loss: 1.0907 - val_root_mean_squared_error: 1.0444
# Epoch 16/35
# 50/50 - 13s - loss: 1.3319 - root_mean_squared_error: 1.1541 - val_loss: 1.0861 - val_root_mean_squared_error: 1.0422
# Epoch 17/35
# 50/50 - 13s - loss: 1.3446 - root_mean_squared_error: 1.1596 - val_loss: 1.0991 - val_root_mean_squared_error: 1.0484
# Epoch 18/35
# 50/50 - 12s - loss: 1.3280 - root_mean_squared_error: 1.1524 - val_loss: 1.1316 - val_root_mean_squared_error: 1.0638
# Epoch 19/35
# 50/50 - 12s - loss: 1.2982 - root_mean_squared_error: 1.1394 - val_loss: 1.0938 - val_root_mean_squared_error: 1.0459
# Epoch 20/35
# 50/50 - 13s - loss: 1.3325 - root_mean_squared_error: 1.1543 - val_loss: 1.3987 - val_root_mean_squared_error: 1.1827
# Restoring model weights from the end of the best epoch.
# Epoch 00020: early stopping
# #### FOLD 1 OOF RMSE = 0.5866
#
# FOLD: 2
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-large/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-large/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/35
# 50/50 - 190s - loss: 1.4274 - root_mean_squared_error: 1.1947 - val_loss: 0.7696 - val_root_mean_squared_error: 0.8772
# Epoch 2/35
# 50/50 - 13s - loss: 0.7387 - root_mean_squared_error: 0.8595 - val_loss: 0.5311 - val_root_mean_squared_error: 0.7288
# Epoch 3/35
# 50/50 - 13s - loss: 0.5628 - root_mean_squared_error: 0.7502 - val_loss: 0.4872 - val_root_mean_squared_error: 0.6980
# Epoch 4/35
# 50/50 - 13s - loss: 0.7654 - root_mean_squared_error: 0.8749 - val_loss: 0.4513 - val_root_mean_squared_error: 0.6718
# Epoch 5/35
# 50/50 - 13s - loss: 0.5347 - root_mean_squared_error: 0.7312 - val_loss: 0.8491 - val_root_mean_squared_error: 0.9215
# Epoch 6/35
# 50/50 - 13s - loss: 1.1971 - root_mean_squared_error: 1.0941 - val_loss: 1.1747 - val_root_mean_squared_error: 1.0839
# Epoch 7/35
# 50/50 - 13s - loss: 1.2982 - root_mean_squared_error: 1.1394 - val_loss: 1.0964 - val_root_mean_squared_error: 1.0471
# Epoch 8/35
# 50/50 - 14s - loss: 1.3275 - root_mean_squared_error: 1.1522 - val_loss: 1.0829 - val_root_mean_squared_error: 1.0406
# Epoch 9/35
# 50/50 - 13s - loss: 1.3773 - root_mean_squared_error: 1.1736 - val_loss: 1.0842 - val_root_mean_squared_error: 1.0412
# Epoch 10/35
# 50/50 - 13s - loss: 1.2673 - root_mean_squared_error: 1.1257 - val_loss: 1.1177 - val_root_mean_squared_error: 1.0572
# Epoch 11/35
# 50/50 - 13s - loss: 1.3563 - root_mean_squared_error: 1.1646 - val_loss: 1.1595 - val_root_mean_squared_error: 1.0768
# Epoch 12/35
# 50/50 - 13s - loss: 1.2854 - root_mean_squared_error: 1.1338 - val_loss: 1.1369 - val_root_mean_squared_error: 1.0662
# Epoch 13/35
# 50/50 - 13s - loss: 1.3840 - root_mean_squared_error: 1.1764 - val_loss: 1.0990 - val_root_mean_squared_error: 1.0484
# Epoch 14/35
# 50/50 - 13s - loss: 1.2857 - root_mean_squared_error: 1.1339 - val_loss: 1.1532 - val_root_mean_squared_error: 1.0739
# Restoring model weights from the end of the best epoch.
# Epoch 00014: early stopping
# #### FOLD 2 OOF RMSE = 0.6718
#
# FOLD: 3
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-large/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-large/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/35
# 50/50 - 191s - loss: 1.9701 - root_mean_squared_error: 1.4036 - val_loss: 0.4958 - val_root_mean_squared_error: 0.7041
# Epoch 2/35
# 50/50 - 13s - loss: 0.6366 - root_mean_squared_error: 0.7979 - val_loss: 0.3559 - val_root_mean_squared_error: 0.5966
# Epoch 3/35
# 50/50 - 13s - loss: 0.5136 - root_mean_squared_error: 0.7167 - val_loss: 0.3673 - val_root_mean_squared_error: 0.6061
# Epoch 4/35
# 50/50 - 13s - loss: 0.4764 - root_mean_squared_error: 0.6902 - val_loss: 0.4478 - val_root_mean_squared_error: 0.6692
# Epoch 5/35
# 50/50 - 13s - loss: 0.3576 - root_mean_squared_error: 0.5980 - val_loss: 0.4397 - val_root_mean_squared_error: 0.6631
# Epoch 6/35
# 50/50 - 13s - loss: 0.3762 - root_mean_squared_error: 0.6133 - val_loss: 0.3559 - val_root_mean_squared_error: 0.5966
# Epoch 7/35
# 50/50 - 13s - loss: 0.3278 - root_mean_squared_error: 0.5725 - val_loss: 0.3667 - val_root_mean_squared_error: 0.6056
# Epoch 8/35
# 50/50 - 13s - loss: 0.3544 - root_mean_squared_error: 0.5953 - val_loss: 0.3213 - val_root_mean_squared_error: 0.5668
# Epoch 9/35
# 50/50 - 13s - loss: 0.3537 - root_mean_squared_error: 0.5947 - val_loss: 0.4853 - val_root_mean_squared_error: 0.6966
# Epoch 10/35
# 50/50 - 13s - loss: 0.3767 - root_mean_squared_error: 0.6137 - val_loss: 0.4540 - val_root_mean_squared_error: 0.6738
# Epoch 11/35
# 50/50 - 13s - loss: 0.3380 - root_mean_squared_error: 0.5814 - val_loss: 0.3569 - val_root_mean_squared_error: 0.5974
# Epoch 12/35
# 50/50 - 13s - loss: 0.3353 - root_mean_squared_error: 0.5791 - val_loss: 0.4100 - val_root_mean_squared_error: 0.6403
# Epoch 13/35
# 50/50 - 13s - loss: 0.3621 - root_mean_squared_error: 0.6018 - val_loss: 0.3780 - val_root_mean_squared_error: 0.6148
# Epoch 14/35
# 50/50 - 13s - loss: 0.3464 - root_mean_squared_error: 0.5886 - val_loss: 0.4013 - val_root_mean_squared_error: 0.6335
# Epoch 15/35
# 50/50 - 14s - loss: 0.3018 - root_mean_squared_error: 0.5494 - val_loss: 0.3527 - val_root_mean_squared_error: 0.5939
# Epoch 16/35
# 50/50 - 13s - loss: 0.3133 - root_mean_squared_error: 0.5597 - val_loss: 0.3815 - val_root_mean_squared_error: 0.6177
# Epoch 17/35
# 50/50 - 13s - loss: 0.3103 - root_mean_squared_error: 0.5570 - val_loss: 0.3624 - val_root_mean_squared_error: 0.6020
# Epoch 18/35
# 50/50 - 13s - loss: 0.3113 - root_mean_squared_error: 0.5580 - val_loss: 0.3555 - val_root_mean_squared_error: 0.5963
# Restoring model weights from the end of the best epoch.
# Epoch 00018: early stopping
# #### FOLD 3 OOF RMSE = 0.5668
#
# FOLD: 4
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-large/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-large/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/35
# 50/50 - 195s - loss: 2.1732 - root_mean_squared_error: 1.4742 - val_loss: 0.9863 - val_root_mean_squared_error: 0.9931
# Epoch 2/35
# 50/50 - 13s - loss: 1.3255 - root_mean_squared_error: 1.1513 - val_loss: 1.0803 - val_root_mean_squared_error: 1.0394
# Epoch 3/35
# 50/50 - 13s - loss: 1.2927 - root_mean_squared_error: 1.1370 - val_loss: 1.1056 - val_root_mean_squared_error: 1.0515
# Epoch 4/35
# 50/50 - 13s - loss: 1.3591 - root_mean_squared_error: 1.1658 - val_loss: 1.0927 - val_root_mean_squared_error: 1.0453
# Epoch 5/35
# 50/50 - 13s - loss: 1.2971 - root_mean_squared_error: 1.1389 - val_loss: 1.0962 - val_root_mean_squared_error: 1.0470
# Epoch 6/35
# 50/50 - 13s - loss: 1.3243 - root_mean_squared_error: 1.1508 - val_loss: 1.1115 - val_root_mean_squared_error: 1.0543
# Epoch 7/35
# 50/50 - 13s - loss: 1.2938 - root_mean_squared_error: 1.1375 - val_loss: 1.0910 - val_root_mean_squared_error: 1.0445
# Epoch 8/35
# 50/50 - 13s - loss: 1.3243 - root_mean_squared_error: 1.1508 - val_loss: 1.1522 - val_root_mean_squared_error: 1.0734
# Epoch 9/35
# 50/50 - 13s - loss: 1.3266 - root_mean_squared_error: 1.1518 - val_loss: 1.0841 - val_root_mean_squared_error: 1.0412
# Epoch 10/35
# 50/50 - 13s - loss: 1.3222 - root_mean_squared_error: 1.1499 - val_loss: 1.0975 - val_root_mean_squared_error: 1.0476
# Epoch 11/35
# 50/50 - 13s - loss: 1.2940 - root_mean_squared_error: 1.1375 - val_loss: 1.1170 - val_root_mean_squared_error: 1.0569
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping
# #### FOLD 4 OOF RMSE = 0.9931
#
# FOLD: 5
# TRAIN: 2268 VALID: 566
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-large/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-large/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/35
# 50/50 - 194s - loss: 1.4758 - root_mean_squared_error: 1.2148 - val_loss: 0.8862 - val_root_mean_squared_error: 0.9414
# Epoch 2/35
# 50/50 - 13s - loss: 0.6581 - root_mean_squared_error: 0.8113 - val_loss: 0.7008 - val_root_mean_squared_error: 0.8371
# Epoch 3/35
# 50/50 - 13s - loss: 0.5214 - root_mean_squared_error: 0.7221 - val_loss: 0.7614 - val_root_mean_squared_error: 0.8726
# Epoch 4/35
# 50/50 - 13s - loss: 0.4113 - root_mean_squared_error: 0.6414 - val_loss: 0.4474 - val_root_mean_squared_error: 0.6689
# Epoch 5/35
# 50/50 - 12s - loss: 0.3996 - root_mean_squared_error: 0.6321 - val_loss: 0.5169 - val_root_mean_squared_error: 0.7190
# Epoch 6/35
# 50/50 - 13s - loss: 0.4151 - root_mean_squared_error: 0.6443 - val_loss: 0.8551 - val_root_mean_squared_error: 0.9247
# Epoch 7/35
# 50/50 - 13s - loss: 0.3810 - root_mean_squared_error: 0.6172 - val_loss: 0.5014 - val_root_mean_squared_error: 0.7081
# Epoch 8/35
# 50/50 - 13s - loss: 0.3751 - root_mean_squared_error: 0.6125 - val_loss: 0.5576 - val_root_mean_squared_error: 0.7467
# Epoch 9/35
# 50/50 - 13s - loss: 0.3293 - root_mean_squared_error: 0.5739 - val_loss: 0.6477 - val_root_mean_squared_error: 0.8048
# Epoch 10/35
# 50/50 - 13s - loss: 0.3179 - root_mean_squared_error: 0.5639 - val_loss: 0.4768 - val_root_mean_squared_error: 0.6905
# Epoch 11/35
# 50/50 - 13s - loss: 0.3193 - root_mean_squared_error: 0.5650 - val_loss: 0.4926 - val_root_mean_squared_error: 0.7019
# Epoch 12/35
# 50/50 - 13s - loss: 0.3336 - root_mean_squared_error: 0.5775 - val_loss: 0.6212 - val_root_mean_squared_error: 0.7882
# Epoch 13/35
# 50/50 - 13s - loss: 0.2858 - root_mean_squared_error: 0.5346 - val_loss: 0.5173 - val_root_mean_squared_error: 0.7192
# Epoch 14/35
# 50/50 - 13s - loss: 0.3260 - root_mean_squared_error: 0.5710 - val_loss: 0.4953 - val_root_mean_squared_error: 0.7038
# Restoring model weights from the end of the best epoch.
# Epoch 00014: early stopping
# #### FOLD 5 OOF RMSE = 0.6689

# %% [markdown]
# ## Model loss and metrics graph

# %%
for fold, history in enumerate(history_list):
    print(f'\nFOLD: {fold+1}')
    plot_metrics(history)
# Out:
# FOLD: 1
# FOLD: 2
# FOLD: 3
# FOLD: 4
# FOLD: 5

# %% [markdown]
# # Model evaluation
#
# We are evaluating the model on the `OOF` predictions, it stands for `Out Of Fold`, since we are training using `K-Fold` our model will see all the data, and the correct way to evaluate each fold is by looking at the predictions that are not from that fold.
#
# ## OOF metrics

# %%
y_true = np.concatenate(oof_labels)
y_preds = np.concatenate(oof_pred)


for fold, history in enumerate(history_list):
    print(f"FOLD {fold+1} RMSE: {np.min(history['val_root_mean_squared_error']):.4f}")
    
print(f'OOF RMSE: {mean_squared_error(y_true, y_preds, squared=False):.4f}')
# Out:
# FOLD 1 RMSE: 0.5866
# FOLD 2 RMSE: 0.6718
# FOLD 3 RMSE: 0.5668
# FOLD 4 RMSE: 0.9931
# FOLD 5 RMSE: 0.6689
# OOF RMSE: 0.7142

# %% [markdown]
# ### **Error analysis**, label x prediction distribution
#
# Here we can compare the distribution from the labels and the predicted values, in a perfect scenario they should align.

# %%
preds_df = pd.DataFrame({'Label': y_true, 'Prediction': y_preds[:,0]})

fig, ax = plt.subplots(1, 1, figsize=(20, 6))
sns.distplot(preds_df['Label'], ax=ax, label='Label')
sns.distplot(preds_df['Prediction'], ax=ax, label='Prediction')
ax.legend()
plt.show()

# %%
sns.jointplot(data=preds_df, x='Label', y='Prediction', kind='reg', height=10)
plt.show()
