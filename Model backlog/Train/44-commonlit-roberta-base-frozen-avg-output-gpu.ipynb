# %% [markdown]
# ## Dependencies

# %%
import warnings, math, json
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import tensorflow_addons as tfa
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
from tensorflow.keras import optimizers, losses, metrics, Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from transformers import TFAutoModelForSequenceClassification, TFAutoModel, AutoTokenizer
from commonlit_scripts import *


seed = 0
seed_everything(seed)
sns.set(style='whitegrid')
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 150)

# %% [markdown]
# ### Hardware configuration

# %%
strategy, tpu = get_strategy()
AUTO = tf.data.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
print(f'REPLICAS: {REPLICAS}')
# Out:
# REPLICAS: 1

# %% [markdown]
# # Load data

# %%
train_filepath = '/kaggle/input/commonlitreadabilityprize/train.csv'
train = pd.read_csv(train_filepath)
print(f'Train samples: {len(train)}')
# removing unused columns
train.drop(['url_legal', 'license'], axis=1, inplace=True)

train['standard_error'] = train['standard_error'] / 2
display(train.head())
# Out:
# Train samples: 2834
#           id  \
# 0  c12129c31
# 1  85aa80a4c
# 2  b69ac6792
# 3  dd1000b26
# 4  37c1b32fb
#
#                                                                                                                                                  excerpt  \
# 0  When the young people returned to the ballroom, it presented a decidedly changed appearance. Instead of an interior scene, it was a winter landsca...
# 1  All through dinner time, Mrs. Fayre was somewhat silent, her eyes resting on Dolly with a wistful, uncertain expression. She wanted to give the ch...
# 2  As Roger had predicted, the snow departed as quickly as it came, and two days after their sleigh ride there was scarcely a vestige of white on the...
# 3  And outside before the palace a great garden was walled round, filled full of stately fruit-trees, gray olives and sweet figs, and pomegranates, p...
# 4  Once upon a time there were Three Bears who lived together in a house of their own in a wood. One of them was a Little, Small, Wee Bear; and one w...
#
#      target  standard_error
# 0 -0.340259        0.232005
# 1 -0.315372        0.240402
# 2 -0.580118        0.238338
# 3 -1.054013        0.225004
# 4  0.247197        0.255422

# %% [markdown]
# # Model parameters

# %%
config = {
  "BATCH_SIZE": 8 * REPLICAS,
  "LEARNING_RATE": 1e-5 * REPLICAS,
  "EPOCHS": 100,
  "ES_PATIENCE": 30,
  "N_FOLDS": 5,
  "N_USED_FOLDS": 1,
  "SEQ_LEN": 256,
  "BASE_MODEL": '/kaggle/input/huggingface-roberta/roberta-base/',
  "SEED": seed,
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# ## Auxiliary functions

# %%
# Datasets utility functions
def custom_standardization(text, is_lower=True):
    if is_lower:
        text = text.lower() # if encoder is uncased
    text = text.strip()
    return text

def sample_target(features, target):
    mean, _, _, stddev = target
    mean = tf.cast(mean, dtype=tf.float32)
    stddev = tf.cast(stddev, dtype=tf.float32)
    sampled_target = tf.random.normal([], mean=mean, stddev=stddev, dtype=tf.float32)
    return (features, (mean, sampled_target, mean))

def conf_output(features, target):
    mean, _, _, stddev = target
#     mean = tf.cast(mean, dtype=tf.float32)
#     stddev = tf.cast(stddev, dtype=tf.float32)
#     sampled_target = tf.random.normal([], mean=mean, stddev=stddev, dtype=tf.float32)
    return (features, (mean, mean, mean))

def get_dataset(pandas_df, tokenizer, labeled=True, ordered=False, repeated=False, 
                is_sampled=False, batch_size=32, seq_len=128, is_lower=True):
    """
        Return a Tensorflow dataset ready for training or inference.
    """
    text = [custom_standardization(text, is_lower) for text in pandas_df['excerpt']]
    
    # Tokenize inputs
    tokenized_inputs = tokenizer(text, max_length=seq_len, truncation=True, 
                                 padding='max_length', return_tensors='tf')
    
    if labeled:
        dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': tokenized_inputs['input_ids'], 
                                                       'attention_mask': tokenized_inputs['attention_mask']}, 
                                                      (pandas_df['target'], pandas_df['target'], 
                                                       pandas_df['target'], pandas_df['standard_error'])))
        
        if is_sampled:
            dataset = dataset.map(sample_target, num_parallel_calls=tf.data.AUTOTUNE)
        else:
            dataset = dataset.map(conf_output, num_parallel_calls=tf.data.AUTOTUNE)
    else:
        dataset = tf.data.Dataset.from_tensor_slices({'input_ids': tokenized_inputs['input_ids'], 
                                                      'attention_mask': tokenized_inputs['attention_mask']})
        
    if repeated:
        dataset = dataset.repeat()
    if not ordered:
        dataset = dataset.shuffle(2048)
    dataset = dataset.batch(batch_size)
    dataset = dataset.cache()
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# %% [markdown]
# # Model

# %%
def model_fn(encoder, seq_len=256):
    input_ids = L.Input(shape=(seq_len,), dtype=tf.int32, name='input_ids')
    input_attention_mask = L.Input(shape=(seq_len,), dtype=tf.int32, name='attention_mask')
    
    outputs = encoder({'input_ids': input_ids,  
                       'attention_mask': input_attention_mask})
    last_hidden_state = outputs['last_hidden_state']
    
    cls_token = last_hidden_state[:, 0, :]
    
    output_mean = L.Dense(1, name='output_mean')(cls_token)
    output_samp = L.Dense(1, name='output_samp')(cls_token)
    output = L.Average(name='output')([output_mean, output_samp])
    
    model = Model(inputs=[input_ids, input_attention_mask], 
                  outputs=[output, output_samp, output_mean])

    optimizer = optimizers.Adam(lr=config['LEARNING_RATE'])
    model.compile(optimizer=optimizer, 
                  loss={'output': losses.MeanSquaredError(),
                        'output_samp': losses.MeanSquaredError(),
                        'output_mean': losses.MeanSquaredError()}, 
                  loss_weights={'output': 1.,
                                'output_samp': 1.,
                                'output_mean': 1.}, 
                  metrics={'output': metrics.RootMeanSquaredError(name='rmse'), 
                           'output_samp': metrics.RootMeanSquaredError(name='rmse_samp'), 
                           'output_mean': metrics.RootMeanSquaredError(name='rmse_mean')})
    return model


with strategy.scope():
    encoder = TFAutoModel.from_pretrained(config['BASE_MODEL'])
    # Freeze embeddings
    encoder.layers[0].embeddings.trainable = False
    model = model_fn(encoder, config['SEQ_LEN'])
    
model.summary()
# Out:
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# attention_mask (InputLayer)     [(None, 256)]        0
# __________________________________________________________________________________________________
# input_ids (InputLayer)          [(None, 256)]        0
# __________________________________________________________________________________________________
# tf_roberta_model (TFRobertaMode TFBaseModelOutputWit 124645632   attention_mask[0][0]
#                                                                  input_ids[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici (None, 768)          0           tf_roberta_model[0][0]
# __________________________________________________________________________________________________
# output_mean (Dense)             (None, 1)            769         tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# output_samp (Dense)             (None, 1)            769         tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# output (Average)                (None, 1)            0           output_mean[0][0]
#                                                                  output_samp[0][0]
# ==================================================================================================
# Total params: 124,647,170
# Trainable params: 85,646,594
# Non-trainable params: 39,000,576
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
tokenizer = AutoTokenizer.from_pretrained(config['BASE_MODEL'])
skf = KFold(n_splits=config['N_FOLDS'], shuffle=True, random_state=seed)
oof_pred = []; oof_labels = []; history_list = []


for fold,(idxT, idxV) in enumerate(skf.split(train)):
    if fold >= config['N_USED_FOLDS']:
        break
    if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    print(f'\nFOLD: {fold+1}')
    print(f'TRAIN: {len(idxT)} VALID: {len(idxV)}')
    
    # Model
    K.clear_session()
    with strategy.scope():
        encoder = TFAutoModel.from_pretrained(config['BASE_MODEL'])
        # Freeze embeddings
        encoder.layers[0].embeddings.trainable = False
        model = model_fn(encoder, seq_len=config['SEQ_LEN'])

    model_path = f'model_{fold}.h5'
    es = EarlyStopping(monitor='val_output_rmse', mode='min', 
                       patience=config['ES_PATIENCE'], restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_output_rmse', mode='min', 
                                 save_best_only=True, save_weights_only=True)

    # Train
    history = model.fit(x=get_dataset(train.loc[idxT], tokenizer, repeated=True, is_sampled=True, 
                                      batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN']), 
                        validation_data=get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                                                    batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN']), 
                        steps_per_epoch=10, 
                        callbacks=[es, checkpoint], 
                        epochs=config['EPOCHS'],  
                        verbose=2).history

    history_list.append(history)
    # Save last model weights
    model.load_weights(model_path)

    # Results
    print(f"#### FOLD {fold+1} OOF RMSE = {np.min(history['val_output_rmse']):.4f}")
    print(f"#### FOLD {fold+1} OOF RMSE = {np.min(history['val_output_samp_rmse_samp']):.4f}")
    print(f"#### FOLD {fold+1} OOF RMSE = {np.min(history['val_output_mean_rmse_mean']):.4f}")

    # OOF predictions
    valid_ds = get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                           batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN'])
    oof_labels.append([target[0].numpy() for sample, target in iter(valid_ds.unbatch())])
    x_oof = valid_ds.map(lambda sample, target: sample)
    preds = model.predict(x_oof)
    oof_pred.append(preds[0])
# Out:
# FOLD: 1
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/100
# 10/10 - 34s - loss: 3.8356 - output_loss: 1.2499 - output_samp_loss: 1.4226 - output_mean_loss: 1.1630 - output_rmse: 1.1180 - output_samp_rmse_samp: 1.1927 - output_mean_rmse_mean: 1.0784 - val_loss: 3.4001 - val_output_loss: 1.1326 - val_output_samp_loss: 1.1113 - val_output_mean_loss: 1.1561 - val_output_rmse: 1.0642 - val_output_samp_rmse_samp: 1.0542 - val_output_mean_rmse_mean: 1.0752
# Epoch 2/100
# 10/10 - 10s - loss: 3.3555 - output_loss: 1.0797 - output_samp_loss: 1.1609 - output_mean_loss: 1.1149 - output_rmse: 1.0391 - output_samp_rmse_samp: 1.0774 - output_mean_rmse_mean: 1.0559 - val_loss: 2.9509 - val_output_loss: 0.9829 - val_output_samp_loss: 0.9609 - val_output_mean_loss: 1.0071 - val_output_rmse: 0.9914 - val_output_samp_rmse_samp: 0.9802 - val_output_mean_rmse_mean: 1.0035
# Epoch 3/100
# 10/10 - 10s - loss: 3.6304 - output_loss: 1.1768 - output_samp_loss: 1.2783 - output_mean_loss: 1.1753 - output_rmse: 1.0848 - output_samp_rmse_samp: 1.1306 - output_mean_rmse_mean: 1.0841 - val_loss: 2.7837 - val_output_loss: 0.9249 - val_output_samp_loss: 0.9421 - val_output_mean_loss: 0.9167 - val_output_rmse: 0.9617 - val_output_samp_rmse_samp: 0.9706 - val_output_mean_rmse_mean: 0.9575
# Epoch 4/100
# 10/10 - 10s - loss: 2.9044 - output_loss: 0.9430 - output_samp_loss: 0.9809 - output_mean_loss: 0.9805 - output_rmse: 0.9711 - output_samp_rmse_samp: 0.9904 - output_mean_rmse_mean: 0.9902 - val_loss: 2.6881 - val_output_loss: 0.8943 - val_output_samp_loss: 0.9080 - val_output_mean_loss: 0.8858 - val_output_rmse: 0.9457 - val_output_samp_rmse_samp: 0.9529 - val_output_mean_rmse_mean: 0.9412
# Epoch 5/100
# 10/10 - 10s - loss: 2.3069 - output_loss: 0.7285 - output_samp_loss: 0.8108 - output_mean_loss: 0.7675 - output_rmse: 0.8535 - output_samp_rmse_samp: 0.9005 - output_mean_rmse_mean: 0.8761 - val_loss: 1.8622 - val_output_loss: 0.6186 - val_output_samp_loss: 0.5988 - val_output_mean_loss: 0.6448 - val_output_rmse: 0.7865 - val_output_samp_rmse_samp: 0.7738 - val_output_mean_rmse_mean: 0.8030
# Epoch 6/100
# 10/10 - 10s - loss: 1.8083 - output_loss: 0.5604 - output_samp_loss: 0.6610 - output_mean_loss: 0.5869 - output_rmse: 0.7486 - output_samp_rmse_samp: 0.8130 - output_mean_rmse_mean: 0.7661 - val_loss: 1.9773 - val_output_loss: 0.6571 - val_output_samp_loss: 0.6727 - val_output_mean_loss: 0.6475 - val_output_rmse: 0.8106 - val_output_samp_rmse_samp: 0.8202 - val_output_mean_rmse_mean: 0.8046
# Epoch 7/100
# 10/10 - 10s - loss: 1.6395 - output_loss: 0.5182 - output_samp_loss: 0.6042 - output_mean_loss: 0.5171 - output_rmse: 0.7199 - output_samp_rmse_samp: 0.7773 - output_mean_rmse_mean: 0.7191 - val_loss: 1.5646 - val_output_loss: 0.5164 - val_output_samp_loss: 0.5555 - val_output_mean_loss: 0.4927 - val_output_rmse: 0.7186 - val_output_samp_rmse_samp: 0.7453 - val_output_mean_rmse_mean: 0.7019
# Epoch 8/100
# 10/10 - 10s - loss: 1.8295 - output_loss: 0.5454 - output_samp_loss: 0.7680 - output_mean_loss: 0.5161 - output_rmse: 0.7385 - output_samp_rmse_samp: 0.8764 - output_mean_rmse_mean: 0.7184 - val_loss: 1.5376 - val_output_loss: 0.5105 - val_output_samp_loss: 0.5138 - val_output_mean_loss: 0.5133 - val_output_rmse: 0.7145 - val_output_samp_rmse_samp: 0.7168 - val_output_mean_rmse_mean: 0.7165
# Epoch 9/100
# 10/10 - 10s - loss: 1.7808 - output_loss: 0.5755 - output_samp_loss: 0.6070 - output_mean_loss: 0.5983 - output_rmse: 0.7586 - output_samp_rmse_samp: 0.7791 - output_mean_rmse_mean: 0.7735 - val_loss: 2.0125 - val_output_loss: 0.6627 - val_output_samp_loss: 0.7654 - val_output_mean_loss: 0.5844 - val_output_rmse: 0.8141 - val_output_samp_rmse_samp: 0.8749 - val_output_mean_rmse_mean: 0.7644
# Epoch 10/100
# 10/10 - 10s - loss: 1.7552 - output_loss: 0.5750 - output_samp_loss: 0.6170 - output_mean_loss: 0.5631 - output_rmse: 0.7583 - output_samp_rmse_samp: 0.7855 - output_mean_rmse_mean: 0.7504 - val_loss: 1.1691 - val_output_loss: 0.3857 - val_output_samp_loss: 0.4017 - val_output_mean_loss: 0.3817 - val_output_rmse: 0.6210 - val_output_samp_rmse_samp: 0.6338 - val_output_mean_rmse_mean: 0.6178
# Epoch 11/100
# 10/10 - 10s - loss: 1.3801 - output_loss: 0.4279 - output_samp_loss: 0.5253 - output_mean_loss: 0.4269 - output_rmse: 0.6542 - output_samp_rmse_samp: 0.7248 - output_mean_rmse_mean: 0.6533 - val_loss: 1.3028 - val_output_loss: 0.4316 - val_output_samp_loss: 0.4380 - val_output_mean_loss: 0.4333 - val_output_rmse: 0.6570 - val_output_samp_rmse_samp: 0.6618 - val_output_mean_rmse_mean: 0.6582
# Epoch 12/100
# 10/10 - 10s - loss: 1.8912 - output_loss: 0.6119 - output_samp_loss: 0.6962 - output_mean_loss: 0.5831 - output_rmse: 0.7822 - output_samp_rmse_samp: 0.8344 - output_mean_rmse_mean: 0.7636 - val_loss: 1.2128 - val_output_loss: 0.4015 - val_output_samp_loss: 0.4134 - val_output_mean_loss: 0.3979 - val_output_rmse: 0.6336 - val_output_samp_rmse_samp: 0.6430 - val_output_mean_rmse_mean: 0.6308
# Epoch 13/100
# 10/10 - 10s - loss: 1.3383 - output_loss: 0.3970 - output_samp_loss: 0.5077 - output_mean_loss: 0.4336 - output_rmse: 0.6301 - output_samp_rmse_samp: 0.7125 - output_mean_rmse_mean: 0.6585 - val_loss: 1.3981 - val_output_loss: 0.4609 - val_output_samp_loss: 0.4886 - val_output_mean_loss: 0.4486 - val_output_rmse: 0.6789 - val_output_samp_rmse_samp: 0.6990 - val_output_mean_rmse_mean: 0.6698
# Epoch 14/100
# 10/10 - 10s - loss: 1.3512 - output_loss: 0.4028 - output_samp_loss: 0.5260 - output_mean_loss: 0.4223 - output_rmse: 0.6347 - output_samp_rmse_samp: 0.7253 - output_mean_rmse_mean: 0.6498 - val_loss: 1.5319 - val_output_loss: 0.5082 - val_output_samp_loss: 0.5236 - val_output_mean_loss: 0.5000 - val_output_rmse: 0.7129 - val_output_samp_rmse_samp: 0.7236 - val_output_mean_rmse_mean: 0.7071
# Epoch 15/100
# 10/10 - 10s - loss: 1.4043 - output_loss: 0.4246 - output_samp_loss: 0.5381 - output_mean_loss: 0.4416 - output_rmse: 0.6516 - output_samp_rmse_samp: 0.7335 - output_mean_rmse_mean: 0.6645 - val_loss: 1.5135 - val_output_loss: 0.5005 - val_output_samp_loss: 0.5332 - val_output_mean_loss: 0.4799 - val_output_rmse: 0.7074 - val_output_samp_rmse_samp: 0.7302 - val_output_mean_rmse_mean: 0.6927
# Epoch 16/100
# 10/10 - 10s - loss: 1.5079 - output_loss: 0.4648 - output_samp_loss: 0.5913 - output_mean_loss: 0.4519 - output_rmse: 0.6817 - output_samp_rmse_samp: 0.7689 - output_mean_rmse_mean: 0.6722 - val_loss: 1.3733 - val_output_loss: 0.4547 - val_output_samp_loss: 0.4409 - val_output_mean_loss: 0.4777 - val_output_rmse: 0.6743 - val_output_samp_rmse_samp: 0.6640 - val_output_mean_rmse_mean: 0.6912
# Epoch 17/100
# 10/10 - 10s - loss: 1.7939 - output_loss: 0.5494 - output_samp_loss: 0.6832 - output_mean_loss: 0.5612 - output_rmse: 0.7412 - output_samp_rmse_samp: 0.8266 - output_mean_rmse_mean: 0.7492 - val_loss: 1.1336 - val_output_loss: 0.3747 - val_output_samp_loss: 0.3785 - val_output_mean_loss: 0.3804 - val_output_rmse: 0.6121 - val_output_samp_rmse_samp: 0.6152 - val_output_mean_rmse_mean: 0.6168
# Epoch 18/100
# 10/10 - 10s - loss: 1.7275 - output_loss: 0.5613 - output_samp_loss: 0.5832 - output_mean_loss: 0.5830 - output_rmse: 0.7492 - output_samp_rmse_samp: 0.7637 - output_mean_rmse_mean: 0.7635 - val_loss: 1.4335 - val_output_loss: 0.4733 - val_output_samp_loss: 0.5157 - val_output_mean_loss: 0.4445 - val_output_rmse: 0.6880 - val_output_samp_rmse_samp: 0.7181 - val_output_mean_rmse_mean: 0.6667
# Epoch 19/100
# 10/10 - 10s - loss: 1.1292 - output_loss: 0.3345 - output_samp_loss: 0.4527 - output_mean_loss: 0.3420 - output_rmse: 0.5783 - output_samp_rmse_samp: 0.6728 - output_mean_rmse_mean: 0.5848 - val_loss: 1.5374 - val_output_loss: 0.5086 - val_output_samp_loss: 0.5491 - val_output_mean_loss: 0.4796 - val_output_rmse: 0.7132 - val_output_samp_rmse_samp: 0.7410 - val_output_mean_rmse_mean: 0.6925
# Epoch 20/100
# 10/10 - 10s - loss: 1.0347 - output_loss: 0.3252 - output_samp_loss: 0.3913 - output_mean_loss: 0.3182 - output_rmse: 0.5702 - output_samp_rmse_samp: 0.6255 - output_mean_rmse_mean: 0.5641 - val_loss: 1.1745 - val_output_loss: 0.3870 - val_output_samp_loss: 0.3750 - val_output_mean_loss: 0.4125 - val_output_rmse: 0.6221 - val_output_samp_rmse_samp: 0.6124 - val_output_mean_rmse_mean: 0.6422
# Epoch 21/100
# 10/10 - 10s - loss: 1.2386 - output_loss: 0.3704 - output_samp_loss: 0.4814 - output_mean_loss: 0.3868 - output_rmse: 0.6086 - output_samp_rmse_samp: 0.6938 - output_mean_rmse_mean: 0.6219 - val_loss: 1.1453 - val_output_loss: 0.3768 - val_output_samp_loss: 0.3646 - val_output_mean_loss: 0.4039 - val_output_rmse: 0.6139 - val_output_samp_rmse_samp: 0.6039 - val_output_mean_rmse_mean: 0.6355
# Epoch 22/100
# 10/10 - 10s - loss: 1.0808 - output_loss: 0.3395 - output_samp_loss: 0.4017 - output_mean_loss: 0.3396 - output_rmse: 0.5827 - output_samp_rmse_samp: 0.6338 - output_mean_rmse_mean: 0.5828 - val_loss: 1.0435 - val_output_loss: 0.3421 - val_output_samp_loss: 0.3656 - val_output_mean_loss: 0.3358 - val_output_rmse: 0.5849 - val_output_samp_rmse_samp: 0.6046 - val_output_mean_rmse_mean: 0.5795
# Epoch 23/100
# 10/10 - 10s - loss: 0.9994 - output_loss: 0.2931 - output_samp_loss: 0.3887 - output_mean_loss: 0.3175 - output_rmse: 0.5414 - output_samp_rmse_samp: 0.6235 - output_mean_rmse_mean: 0.5635 - val_loss: 1.0108 - val_output_loss: 0.3284 - val_output_samp_loss: 0.3329 - val_output_mean_loss: 0.3494 - val_output_rmse: 0.5731 - val_output_samp_rmse_samp: 0.5770 - val_output_mean_rmse_mean: 0.5911
# Epoch 24/100
# 10/10 - 10s - loss: 1.0625 - output_loss: 0.3181 - output_samp_loss: 0.4523 - output_mean_loss: 0.2920 - output_rmse: 0.5640 - output_samp_rmse_samp: 0.6726 - output_mean_rmse_mean: 0.5404 - val_loss: 1.0199 - val_output_loss: 0.3313 - val_output_samp_loss: 0.3689 - val_output_mean_loss: 0.3197 - val_output_rmse: 0.5755 - val_output_samp_rmse_samp: 0.6074 - val_output_mean_rmse_mean: 0.5654
# Epoch 25/100
# 10/10 - 10s - loss: 0.8485 - output_loss: 0.2597 - output_samp_loss: 0.2988 - output_mean_loss: 0.2900 - output_rmse: 0.5096 - output_samp_rmse_samp: 0.5466 - output_mean_rmse_mean: 0.5386 - val_loss: 1.0862 - val_output_loss: 0.3563 - val_output_samp_loss: 0.3393 - val_output_mean_loss: 0.3905 - val_output_rmse: 0.5969 - val_output_samp_rmse_samp: 0.5825 - val_output_mean_rmse_mean: 0.6249
# Epoch 26/100
# 10/10 - 10s - loss: 1.2422 - output_loss: 0.3882 - output_samp_loss: 0.4528 - output_mean_loss: 0.4011 - output_rmse: 0.6231 - output_samp_rmse_samp: 0.6729 - output_mean_rmse_mean: 0.6333 - val_loss: 1.6176 - val_output_loss: 0.5364 - val_output_samp_loss: 0.5594 - val_output_mean_loss: 0.5218 - val_output_rmse: 0.7324 - val_output_samp_rmse_samp: 0.7480 - val_output_mean_rmse_mean: 0.7224
# Epoch 27/100
# 10/10 - 10s - loss: 1.2791 - output_loss: 0.3947 - output_samp_loss: 0.4866 - output_mean_loss: 0.3978 - output_rmse: 0.6282 - output_samp_rmse_samp: 0.6976 - output_mean_rmse_mean: 0.6307 - val_loss: 1.1335 - val_output_loss: 0.3752 - val_output_samp_loss: 0.3732 - val_output_mean_loss: 0.3851 - val_output_rmse: 0.6125 - val_output_samp_rmse_samp: 0.6109 - val_output_mean_rmse_mean: 0.6206
# Epoch 28/100
# 10/10 - 10s - loss: 1.3821 - output_loss: 0.4270 - output_samp_loss: 0.4977 - output_mean_loss: 0.4574 - output_rmse: 0.6534 - output_samp_rmse_samp: 0.7055 - output_mean_rmse_mean: 0.6763 - val_loss: 1.1369 - val_output_loss: 0.3764 - val_output_samp_loss: 0.3935 - val_output_mean_loss: 0.3669 - val_output_rmse: 0.6136 - val_output_samp_rmse_samp: 0.6273 - val_output_mean_rmse_mean: 0.6057
# Epoch 29/100
# 10/10 - 10s - loss: 1.1476 - output_loss: 0.3377 - output_samp_loss: 0.4601 - output_mean_loss: 0.3497 - output_rmse: 0.5812 - output_samp_rmse_samp: 0.6783 - output_mean_rmse_mean: 0.5914 - val_loss: 1.1647 - val_output_loss: 0.3859 - val_output_samp_loss: 0.3749 - val_output_mean_loss: 0.4039 - val_output_rmse: 0.6212 - val_output_samp_rmse_samp: 0.6123 - val_output_mean_rmse_mean: 0.6356
# Epoch 30/100
# 10/10 - 10s - loss: 1.0994 - output_loss: 0.3429 - output_samp_loss: 0.4291 - output_mean_loss: 0.3273 - output_rmse: 0.5856 - output_samp_rmse_samp: 0.6551 - output_mean_rmse_mean: 0.5721 - val_loss: 1.5242 - val_output_loss: 0.5057 - val_output_samp_loss: 0.5332 - val_output_mean_loss: 0.4853 - val_output_rmse: 0.7112 - val_output_samp_rmse_samp: 0.7302 - val_output_mean_rmse_mean: 0.6967
# Epoch 31/100
# 10/10 - 10s - loss: 0.9127 - output_loss: 0.2947 - output_samp_loss: 0.3187 - output_mean_loss: 0.2993 - output_rmse: 0.5428 - output_samp_rmse_samp: 0.5645 - output_mean_rmse_mean: 0.5471 - val_loss: 1.1076 - val_output_loss: 0.3675 - val_output_samp_loss: 0.3741 - val_output_mean_loss: 0.3659 - val_output_rmse: 0.6062 - val_output_samp_rmse_samp: 0.6117 - val_output_mean_rmse_mean: 0.6049
# Epoch 32/100
# 10/10 - 10s - loss: 0.9754 - output_loss: 0.3028 - output_samp_loss: 0.3555 - output_mean_loss: 0.3171 - output_rmse: 0.5503 - output_samp_rmse_samp: 0.5963 - output_mean_rmse_mean: 0.5631 - val_loss: 1.4452 - val_output_loss: 0.4788 - val_output_samp_loss: 0.5203 - val_output_mean_loss: 0.4461 - val_output_rmse: 0.6919 - val_output_samp_rmse_samp: 0.7213 - val_output_mean_rmse_mean: 0.6679
# Epoch 33/100
# 10/10 - 10s - loss: 0.8858 - output_loss: 0.2530 - output_samp_loss: 0.3891 - output_mean_loss: 0.2437 - output_rmse: 0.5030 - output_samp_rmse_samp: 0.6238 - output_mean_rmse_mean: 0.4936 - val_loss: 1.0961 - val_output_loss: 0.3622 - val_output_samp_loss: 0.3470 - val_output_mean_loss: 0.3870 - val_output_rmse: 0.6018 - val_output_samp_rmse_samp: 0.5890 - val_output_mean_rmse_mean: 0.6221
# Epoch 34/100
# 10/10 - 10s - loss: 1.1098 - output_loss: 0.3472 - output_samp_loss: 0.3876 - output_mean_loss: 0.3749 - output_rmse: 0.5893 - output_samp_rmse_samp: 0.6226 - output_mean_rmse_mean: 0.6123 - val_loss: 1.1424 - val_output_loss: 0.3790 - val_output_samp_loss: 0.3911 - val_output_mean_loss: 0.3723 - val_output_rmse: 0.6156 - val_output_samp_rmse_samp: 0.6254 - val_output_mean_rmse_mean: 0.6102
# Epoch 35/100
# 10/10 - 10s - loss: 0.7717 - output_loss: 0.2251 - output_samp_loss: 0.2931 - output_mean_loss: 0.2536 - output_rmse: 0.4744 - output_samp_rmse_samp: 0.5413 - output_mean_rmse_mean: 0.5035 - val_loss: 1.6089 - val_output_loss: 0.5347 - val_output_samp_loss: 0.5419 - val_output_mean_loss: 0.5322 - val_output_rmse: 0.7312 - val_output_samp_rmse_samp: 0.7362 - val_output_mean_rmse_mean: 0.7295
# Epoch 36/100
# 10/10 - 10s - loss: 1.0864 - output_loss: 0.3387 - output_samp_loss: 0.3773 - output_mean_loss: 0.3704 - output_rmse: 0.5820 - output_samp_rmse_samp: 0.6143 - output_mean_rmse_mean: 0.6086 - val_loss: 1.4869 - val_output_loss: 0.4930 - val_output_samp_loss: 0.5299 - val_output_mean_loss: 0.4640 - val_output_rmse: 0.7021 - val_output_samp_rmse_samp: 0.7279 - val_output_mean_rmse_mean: 0.6812
# Epoch 37/100
# 10/10 - 10s - loss: 0.9426 - output_loss: 0.2841 - output_samp_loss: 0.3727 - output_mean_loss: 0.2858 - output_rmse: 0.5330 - output_samp_rmse_samp: 0.6105 - output_mean_rmse_mean: 0.5346 - val_loss: 1.1240 - val_output_loss: 0.3729 - val_output_samp_loss: 0.3644 - val_output_mean_loss: 0.3866 - val_output_rmse: 0.6107 - val_output_samp_rmse_samp: 0.6037 - val_output_mean_rmse_mean: 0.6218
# Epoch 38/100
# 10/10 - 10s - loss: 0.6886 - output_loss: 0.1861 - output_samp_loss: 0.3198 - output_mean_loss: 0.1826 - output_rmse: 0.4314 - output_samp_rmse_samp: 0.5655 - output_mean_rmse_mean: 0.4273 - val_loss: 2.6753 - val_output_loss: 0.8903 - val_output_samp_loss: 0.9368 - val_output_mean_loss: 0.8482 - val_output_rmse: 0.9435 - val_output_samp_rmse_samp: 0.9679 - val_output_mean_rmse_mean: 0.9210
# Epoch 39/100
# 10/10 - 10s - loss: 1.4829 - output_loss: 0.4736 - output_samp_loss: 0.5347 - output_mean_loss: 0.4746 - output_rmse: 0.6882 - output_samp_rmse_samp: 0.7312 - output_mean_rmse_mean: 0.6889 - val_loss: 0.9955 - val_output_loss: 0.3298 - val_output_samp_loss: 0.3394 - val_output_mean_loss: 0.3263 - val_output_rmse: 0.5743 - val_output_samp_rmse_samp: 0.5826 - val_output_mean_rmse_mean: 0.5712
# Epoch 40/100
# 10/10 - 10s - loss: 0.9612 - output_loss: 0.2799 - output_samp_loss: 0.3763 - output_mean_loss: 0.3051 - output_rmse: 0.5290 - output_samp_rmse_samp: 0.6134 - output_mean_rmse_mean: 0.5523 - val_loss: 0.9627 - val_output_loss: 0.3194 - val_output_samp_loss: 0.3193 - val_output_mean_loss: 0.3239 - val_output_rmse: 0.5652 - val_output_samp_rmse_samp: 0.5651 - val_output_mean_rmse_mean: 0.5692
# Epoch 41/100
# 10/10 - 10s - loss: 1.4639 - output_loss: 0.4571 - output_samp_loss: 0.5329 - output_mean_loss: 0.4739 - output_rmse: 0.6761 - output_samp_rmse_samp: 0.7300 - output_mean_rmse_mean: 0.6884 - val_loss: 1.4230 - val_output_loss: 0.4728 - val_output_samp_loss: 0.4949 - val_output_mean_loss: 0.4553 - val_output_rmse: 0.6876 - val_output_samp_rmse_samp: 0.7035 - val_output_mean_rmse_mean: 0.6748
# Epoch 42/100
# 10/10 - 10s - loss: 0.9961 - output_loss: 0.3081 - output_samp_loss: 0.3694 - output_mean_loss: 0.3185 - output_rmse: 0.5551 - output_samp_rmse_samp: 0.6078 - output_mean_rmse_mean: 0.5644 - val_loss: 1.5008 - val_output_loss: 0.4991 - val_output_samp_loss: 0.5001 - val_output_mean_loss: 0.5015 - val_output_rmse: 0.7065 - val_output_samp_rmse_samp: 0.7072 - val_output_mean_rmse_mean: 0.7082
# Epoch 43/100
# 10/10 - 10s - loss: 0.9805 - output_loss: 0.3121 - output_samp_loss: 0.3369 - output_mean_loss: 0.3315 - output_rmse: 0.5587 - output_samp_rmse_samp: 0.5804 - output_mean_rmse_mean: 0.5758 - val_loss: 1.1227 - val_output_loss: 0.3716 - val_output_samp_loss: 0.3975 - val_output_mean_loss: 0.3536 - val_output_rmse: 0.6096 - val_output_samp_rmse_samp: 0.6305 - val_output_mean_rmse_mean: 0.5946
# Epoch 44/100
# 10/10 - 10s - loss: 0.8034 - output_loss: 0.2582 - output_samp_loss: 0.2909 - output_mean_loss: 0.2543 - output_rmse: 0.5081 - output_samp_rmse_samp: 0.5394 - output_mean_rmse_mean: 0.5043 - val_loss: 1.0506 - val_output_loss: 0.3492 - val_output_samp_loss: 0.3486 - val_output_mean_loss: 0.3528 - val_output_rmse: 0.5909 - val_output_samp_rmse_samp: 0.5904 - val_output_mean_rmse_mean: 0.5940
# Epoch 45/100
# 10/10 - 10s - loss: 0.9249 - output_loss: 0.2717 - output_samp_loss: 0.3804 - output_mean_loss: 0.2728 - output_rmse: 0.5213 - output_samp_rmse_samp: 0.6168 - output_mean_rmse_mean: 0.5223 - val_loss: 1.2435 - val_output_loss: 0.4135 - val_output_samp_loss: 0.4132 - val_output_mean_loss: 0.4167 - val_output_rmse: 0.6431 - val_output_samp_rmse_samp: 0.6428 - val_output_mean_rmse_mean: 0.6455
# Epoch 46/100
# 10/10 - 10s - loss: 0.9015 - output_loss: 0.2934 - output_samp_loss: 0.3385 - output_mean_loss: 0.2696 - output_rmse: 0.5417 - output_samp_rmse_samp: 0.5818 - output_mean_rmse_mean: 0.5192 - val_loss: 1.1607 - val_output_loss: 0.3856 - val_output_samp_loss: 0.3934 - val_output_mean_loss: 0.3817 - val_output_rmse: 0.6210 - val_output_samp_rmse_samp: 0.6272 - val_output_mean_rmse_mean: 0.6178
# Epoch 47/100
# 10/10 - 10s - loss: 0.9847 - output_loss: 0.2993 - output_samp_loss: 0.3743 - output_mean_loss: 0.3110 - output_rmse: 0.5471 - output_samp_rmse_samp: 0.6118 - output_mean_rmse_mean: 0.5577 - val_loss: 1.7692 - val_output_loss: 0.5886 - val_output_samp_loss: 0.5963 - val_output_mean_loss: 0.5843 - val_output_rmse: 0.7672 - val_output_samp_rmse_samp: 0.7722 - val_output_mean_rmse_mean: 0.7644
# Epoch 48/100
# 10/10 - 10s - loss: 1.1713 - output_loss: 0.3616 - output_samp_loss: 0.4615 - output_mean_loss: 0.3482 - output_rmse: 0.6014 - output_samp_rmse_samp: 0.6793 - output_mean_rmse_mean: 0.5901 - val_loss: 2.1717 - val_output_loss: 0.7226 - val_output_samp_loss: 0.7358 - val_output_mean_loss: 0.7133 - val_output_rmse: 0.8500 - val_output_samp_rmse_samp: 0.8578 - val_output_mean_rmse_mean: 0.8446
# Epoch 49/100
# 10/10 - 10s - loss: 0.9389 - output_loss: 0.2898 - output_samp_loss: 0.3388 - output_mean_loss: 0.3103 - output_rmse: 0.5384 - output_samp_rmse_samp: 0.5821 - output_mean_rmse_mean: 0.5570 - val_loss: 0.9393 - val_output_loss: 0.3118 - val_output_samp_loss: 0.3077 - val_output_mean_loss: 0.3198 - val_output_rmse: 0.5584 - val_output_samp_rmse_samp: 0.5547 - val_output_mean_rmse_mean: 0.5655
# Epoch 50/100
# 10/10 - 10s - loss: 1.1468 - output_loss: 0.3623 - output_samp_loss: 0.4189 - output_mean_loss: 0.3656 - output_rmse: 0.6019 - output_samp_rmse_samp: 0.6473 - output_mean_rmse_mean: 0.6047 - val_loss: 1.3400 - val_output_loss: 0.4425 - val_output_samp_loss: 0.5012 - val_output_mean_loss: 0.3963 - val_output_rmse: 0.6652 - val_output_samp_rmse_samp: 0.7079 - val_output_mean_rmse_mean: 0.6295
# Epoch 51/100
# 10/10 - 10s - loss: 0.6293 - output_loss: 0.1771 - output_samp_loss: 0.2780 - output_mean_loss: 0.1742 - output_rmse: 0.4208 - output_samp_rmse_samp: 0.5273 - output_mean_rmse_mean: 0.4173 - val_loss: 1.0211 - val_output_loss: 0.3389 - val_output_samp_loss: 0.3391 - val_output_mean_loss: 0.3431 - val_output_rmse: 0.5821 - val_output_samp_rmse_samp: 0.5823 - val_output_mean_rmse_mean: 0.5858
# Epoch 52/100
# 10/10 - 10s - loss: 1.1323 - output_loss: 0.3308 - output_samp_loss: 0.4474 - output_mean_loss: 0.3541 - output_rmse: 0.5751 - output_samp_rmse_samp: 0.6689 - output_mean_rmse_mean: 0.5951 - val_loss: 0.9809 - val_output_loss: 0.3232 - val_output_samp_loss: 0.3461 - val_output_mean_loss: 0.3117 - val_output_rmse: 0.5685 - val_output_samp_rmse_samp: 0.5883 - val_output_mean_rmse_mean: 0.5583
# Epoch 53/100
# 10/10 - 10s - loss: 0.8153 - output_loss: 0.2531 - output_samp_loss: 0.3025 - output_mean_loss: 0.2597 - output_rmse: 0.5031 - output_samp_rmse_samp: 0.5500 - output_mean_rmse_mean: 0.5096 - val_loss: 1.0555 - val_output_loss: 0.3487 - val_output_samp_loss: 0.3297 - val_output_mean_loss: 0.3771 - val_output_rmse: 0.5905 - val_output_samp_rmse_samp: 0.5742 - val_output_mean_rmse_mean: 0.6141
# Epoch 54/100
# 10/10 - 10s - loss: 0.8093 - output_loss: 0.2241 - output_samp_loss: 0.3589 - output_mean_loss: 0.2263 - output_rmse: 0.4734 - output_samp_rmse_samp: 0.5991 - output_mean_rmse_mean: 0.4757 - val_loss: 1.5233 - val_output_loss: 0.5060 - val_output_samp_loss: 0.5300 - val_output_mean_loss: 0.4873 - val_output_rmse: 0.7113 - val_output_samp_rmse_samp: 0.7280 - val_output_mean_rmse_mean: 0.6981
# Epoch 55/100
# 10/10 - 10s - loss: 0.8196 - output_loss: 0.2578 - output_samp_loss: 0.3066 - output_mean_loss: 0.2551 - output_rmse: 0.5077 - output_samp_rmse_samp: 0.5538 - output_mean_rmse_mean: 0.5051 - val_loss: 1.4316 - val_output_loss: 0.4749 - val_output_samp_loss: 0.4526 - val_output_mean_loss: 0.5040 - val_output_rmse: 0.6892 - val_output_samp_rmse_samp: 0.6728 - val_output_mean_rmse_mean: 0.7099
# Epoch 56/100
# 10/10 - 10s - loss: 0.7000 - output_loss: 0.2178 - output_samp_loss: 0.2323 - output_mean_loss: 0.2499 - output_rmse: 0.4667 - output_samp_rmse_samp: 0.4820 - output_mean_rmse_mean: 0.4999 - val_loss: 1.2495 - val_output_loss: 0.4148 - val_output_samp_loss: 0.4076 - val_output_mean_loss: 0.4271 - val_output_rmse: 0.6440 - val_output_samp_rmse_samp: 0.6384 - val_output_mean_rmse_mean: 0.6535
# Epoch 57/100
# 10/10 - 10s - loss: 0.7010 - output_loss: 0.2022 - output_samp_loss: 0.2869 - output_mean_loss: 0.2118 - output_rmse: 0.4497 - output_samp_rmse_samp: 0.5357 - output_mean_rmse_mean: 0.4602 - val_loss: 1.4317 - val_output_loss: 0.4718 - val_output_samp_loss: 0.5437 - val_output_mean_loss: 0.4161 - val_output_rmse: 0.6869 - val_output_samp_rmse_samp: 0.7374 - val_output_mean_rmse_mean: 0.6451
# Epoch 58/100
# 10/10 - 10s - loss: 1.0783 - output_loss: 0.3344 - output_samp_loss: 0.4156 - output_mean_loss: 0.3283 - output_rmse: 0.5783 - output_samp_rmse_samp: 0.6447 - output_mean_rmse_mean: 0.5730 - val_loss: 1.8103 - val_output_loss: 0.5999 - val_output_samp_loss: 0.5475 - val_output_mean_loss: 0.6629 - val_output_rmse: 0.7745 - val_output_samp_rmse_samp: 0.7399 - val_output_mean_rmse_mean: 0.8142
# Epoch 59/100
# 10/10 - 10s - loss: 0.9549 - output_loss: 0.2863 - output_samp_loss: 0.3610 - output_mean_loss: 0.3076 - output_rmse: 0.5351 - output_samp_rmse_samp: 0.6008 - output_mean_rmse_mean: 0.5546 - val_loss: 1.0409 - val_output_loss: 0.3365 - val_output_samp_loss: 0.3942 - val_output_mean_loss: 0.3102 - val_output_rmse: 0.5801 - val_output_samp_rmse_samp: 0.6278 - val_output_mean_rmse_mean: 0.5570
# Epoch 60/100
# 10/10 - 10s - loss: 0.8926 - output_loss: 0.2479 - output_samp_loss: 0.3560 - output_mean_loss: 0.2888 - output_rmse: 0.4979 - output_samp_rmse_samp: 0.5966 - output_mean_rmse_mean: 0.5374 - val_loss: 1.1011 - val_output_loss: 0.3633 - val_output_samp_loss: 0.3403 - val_output_mean_loss: 0.3975 - val_output_rmse: 0.6027 - val_output_samp_rmse_samp: 0.5833 - val_output_mean_rmse_mean: 0.6305
# Epoch 61/100
# 10/10 - 10s - loss: 0.7481 - output_loss: 0.2452 - output_samp_loss: 0.2560 - output_mean_loss: 0.2469 - output_rmse: 0.4951 - output_samp_rmse_samp: 0.5060 - output_mean_rmse_mean: 0.4969 - val_loss: 1.2818 - val_output_loss: 0.4258 - val_output_samp_loss: 0.4302 - val_output_mean_loss: 0.4258 - val_output_rmse: 0.6525 - val_output_samp_rmse_samp: 0.6559 - val_output_mean_rmse_mean: 0.6525
# Epoch 62/100
# 10/10 - 10s - loss: 0.9105 - output_loss: 0.2931 - output_samp_loss: 0.3119 - output_mean_loss: 0.3054 - output_rmse: 0.5414 - output_samp_rmse_samp: 0.5585 - output_mean_rmse_mean: 0.5527 - val_loss: 1.0083 - val_output_loss: 0.3337 - val_output_samp_loss: 0.3504 - val_output_mean_loss: 0.3241 - val_output_rmse: 0.5777 - val_output_samp_rmse_samp: 0.5920 - val_output_mean_rmse_mean: 0.5693
# Epoch 63/100
# 10/10 - 10s - loss: 0.9011 - output_loss: 0.2792 - output_samp_loss: 0.3408 - output_mean_loss: 0.2811 - output_rmse: 0.5283 - output_samp_rmse_samp: 0.5837 - output_mean_rmse_mean: 0.5302 - val_loss: 1.0496 - val_output_loss: 0.3480 - val_output_samp_loss: 0.3406 - val_output_mean_loss: 0.3610 - val_output_rmse: 0.5899 - val_output_samp_rmse_samp: 0.5836 - val_output_mean_rmse_mean: 0.6009
# Epoch 64/100
# 10/10 - 10s - loss: 0.6747 - output_loss: 0.1889 - output_samp_loss: 0.2848 - output_mean_loss: 0.2010 - output_rmse: 0.4347 - output_samp_rmse_samp: 0.5337 - output_mean_rmse_mean: 0.4483 - val_loss: 1.9719 - val_output_loss: 0.6561 - val_output_samp_loss: 0.6507 - val_output_mean_loss: 0.6651 - val_output_rmse: 0.8100 - val_output_samp_rmse_samp: 0.8067 - val_output_mean_rmse_mean: 0.8155
# Epoch 65/100
# 10/10 - 10s - loss: 0.8289 - output_loss: 0.2543 - output_samp_loss: 0.3065 - output_mean_loss: 0.2681 - output_rmse: 0.5043 - output_samp_rmse_samp: 0.5536 - output_mean_rmse_mean: 0.5178 - val_loss: 1.0994 - val_output_loss: 0.3653 - val_output_samp_loss: 0.3618 - val_output_mean_loss: 0.3723 - val_output_rmse: 0.6044 - val_output_samp_rmse_samp: 0.6015 - val_output_mean_rmse_mean: 0.6101
# Epoch 66/100
# 10/10 - 10s - loss: 1.1438 - output_loss: 0.3622 - output_samp_loss: 0.4118 - output_mean_loss: 0.3698 - output_rmse: 0.6019 - output_samp_rmse_samp: 0.6417 - output_mean_rmse_mean: 0.6081 - val_loss: 0.9325 - val_output_loss: 0.3097 - val_output_samp_loss: 0.3138 - val_output_mean_loss: 0.3090 - val_output_rmse: 0.5565 - val_output_samp_rmse_samp: 0.5602 - val_output_mean_rmse_mean: 0.5559
# Epoch 67/100
# 10/10 - 10s - loss: 0.9389 - output_loss: 0.2961 - output_samp_loss: 0.3369 - output_mean_loss: 0.3059 - output_rmse: 0.5442 - output_samp_rmse_samp: 0.5804 - output_mean_rmse_mean: 0.5530 - val_loss: 1.8921 - val_output_loss: 0.6297 - val_output_samp_loss: 0.6510 - val_output_mean_loss: 0.6114 - val_output_rmse: 0.7936 - val_output_samp_rmse_samp: 0.8069 - val_output_mean_rmse_mean: 0.7819
# Epoch 68/100
# 10/10 - 10s - loss: 1.0802 - output_loss: 0.3314 - output_samp_loss: 0.4272 - output_mean_loss: 0.3216 - output_rmse: 0.5757 - output_samp_rmse_samp: 0.6536 - output_mean_rmse_mean: 0.5671 - val_loss: 1.4295 - val_output_loss: 0.4756 - val_output_samp_loss: 0.4742 - val_output_mean_loss: 0.4798 - val_output_rmse: 0.6896 - val_output_samp_rmse_samp: 0.6886 - val_output_mean_rmse_mean: 0.6926
# Epoch 69/100
# 10/10 - 10s - loss: 0.9515 - output_loss: 0.2936 - output_samp_loss: 0.3627 - output_mean_loss: 0.2952 - output_rmse: 0.5418 - output_samp_rmse_samp: 0.6023 - output_mean_rmse_mean: 0.5433 - val_loss: 1.0694 - val_output_loss: 0.3546 - val_output_samp_loss: 0.3501 - val_output_mean_loss: 0.3647 - val_output_rmse: 0.5955 - val_output_samp_rmse_samp: 0.5917 - val_output_mean_rmse_mean: 0.6039
# Epoch 70/100
# 10/10 - 10s - loss: 0.7838 - output_loss: 0.2176 - output_samp_loss: 0.3655 - output_mean_loss: 0.2006 - output_rmse: 0.4665 - output_samp_rmse_samp: 0.6046 - output_mean_rmse_mean: 0.4479 - val_loss: 1.1771 - val_output_loss: 0.3895 - val_output_samp_loss: 0.4273 - val_output_mean_loss: 0.3603 - val_output_rmse: 0.6241 - val_output_samp_rmse_samp: 0.6537 - val_output_mean_rmse_mean: 0.6002
# Epoch 71/100
# 10/10 - 10s - loss: 0.7534 - output_loss: 0.2347 - output_samp_loss: 0.2768 - output_mean_loss: 0.2418 - output_rmse: 0.4845 - output_samp_rmse_samp: 0.5262 - output_mean_rmse_mean: 0.4917 - val_loss: 1.4991 - val_output_loss: 0.4985 - val_output_samp_loss: 0.4915 - val_output_mean_loss: 0.5092 - val_output_rmse: 0.7061 - val_output_samp_rmse_samp: 0.7010 - val_output_mean_rmse_mean: 0.7135
# Epoch 72/100
# 10/10 - 10s - loss: 0.7434 - output_loss: 0.2361 - output_samp_loss: 0.2644 - output_mean_loss: 0.2430 - output_rmse: 0.4859 - output_samp_rmse_samp: 0.5142 - output_mean_rmse_mean: 0.4929 - val_loss: 1.3465 - val_output_loss: 0.4474 - val_output_samp_loss: 0.4636 - val_output_mean_loss: 0.4356 - val_output_rmse: 0.6689 - val_output_samp_rmse_samp: 0.6809 - val_output_mean_rmse_mean: 0.6600
# Epoch 73/100
# 10/10 - 10s - loss: 0.8120 - output_loss: 0.2435 - output_samp_loss: 0.3213 - output_mean_loss: 0.2473 - output_rmse: 0.4934 - output_samp_rmse_samp: 0.5668 - output_mean_rmse_mean: 0.4973 - val_loss: 0.8337 - val_output_loss: 0.2764 - val_output_samp_loss: 0.2726 - val_output_mean_loss: 0.2848 - val_output_rmse: 0.5257 - val_output_samp_rmse_samp: 0.5221 - val_output_mean_rmse_mean: 0.5337
# Epoch 74/100
# 10/10 - 10s - loss: 1.0626 - output_loss: 0.3234 - output_samp_loss: 0.4010 - output_mean_loss: 0.3382 - output_rmse: 0.5687 - output_samp_rmse_samp: 0.6332 - output_mean_rmse_mean: 0.5815 - val_loss: 1.0308 - val_output_loss: 0.3426 - val_output_samp_loss: 0.3471 - val_output_mean_loss: 0.3411 - val_output_rmse: 0.5853 - val_output_samp_rmse_samp: 0.5892 - val_output_mean_rmse_mean: 0.5841
# Epoch 75/100
# 10/10 - 10s - loss: 0.7874 - output_loss: 0.2393 - output_samp_loss: 0.3094 - output_mean_loss: 0.2387 - output_rmse: 0.4892 - output_samp_rmse_samp: 0.5562 - output_mean_rmse_mean: 0.4885 - val_loss: 1.2933 - val_output_loss: 0.4288 - val_output_samp_loss: 0.4633 - val_output_mean_loss: 0.4012 - val_output_rmse: 0.6548 - val_output_samp_rmse_samp: 0.6806 - val_output_mean_rmse_mean: 0.6334
# Epoch 76/100
# 10/10 - 10s - loss: 0.9371 - output_loss: 0.2990 - output_samp_loss: 0.3461 - output_mean_loss: 0.2920 - output_rmse: 0.5468 - output_samp_rmse_samp: 0.5883 - output_mean_rmse_mean: 0.5404 - val_loss: 1.0607 - val_output_loss: 0.3525 - val_output_samp_loss: 0.3449 - val_output_mean_loss: 0.3634 - val_output_rmse: 0.5937 - val_output_samp_rmse_samp: 0.5872 - val_output_mean_rmse_mean: 0.6028
# Epoch 77/100
# 10/10 - 10s - loss: 0.8309 - output_loss: 0.2511 - output_samp_loss: 0.3247 - output_mean_loss: 0.2550 - output_rmse: 0.5011 - output_samp_rmse_samp: 0.5698 - output_mean_rmse_mean: 0.5050 - val_loss: 1.4400 - val_output_loss: 0.4785 - val_output_samp_loss: 0.4998 - val_output_mean_loss: 0.4617 - val_output_rmse: 0.6918 - val_output_samp_rmse_samp: 0.7069 - val_output_mean_rmse_mean: 0.6795
# Epoch 78/100
# 10/10 - 10s - loss: 0.5353 - output_loss: 0.1576 - output_samp_loss: 0.2157 - output_mean_loss: 0.1621 - output_rmse: 0.3969 - output_samp_rmse_samp: 0.4644 - output_mean_rmse_mean: 0.4026 - val_loss: 1.2430 - val_output_loss: 0.4113 - val_output_samp_loss: 0.4506 - val_output_mean_loss: 0.3811 - val_output_rmse: 0.6413 - val_output_samp_rmse_samp: 0.6713 - val_output_mean_rmse_mean: 0.6174
# Epoch 79/100
# 10/10 - 10s - loss: 0.6765 - output_loss: 0.2089 - output_samp_loss: 0.2525 - output_mean_loss: 0.2151 - output_rmse: 0.4571 - output_samp_rmse_samp: 0.5025 - output_mean_rmse_mean: 0.4638 - val_loss: 1.5752 - val_output_loss: 0.5237 - val_output_samp_loss: 0.5294 - val_output_mean_loss: 0.5221 - val_output_rmse: 0.7237 - val_output_samp_rmse_samp: 0.7276 - val_output_mean_rmse_mean: 0.7226
# Epoch 80/100
# 10/10 - 10s - loss: 0.7358 - output_loss: 0.2100 - output_samp_loss: 0.3183 - output_mean_loss: 0.2075 - output_rmse: 0.4583 - output_samp_rmse_samp: 0.5642 - output_mean_rmse_mean: 0.4556 - val_loss: 2.1529 - val_output_loss: 0.7151 - val_output_samp_loss: 0.7597 - val_output_mean_loss: 0.6781 - val_output_rmse: 0.8456 - val_output_samp_rmse_samp: 0.8716 - val_output_mean_rmse_mean: 0.8235
# Epoch 81/100
# 10/10 - 10s - loss: 0.8585 - output_loss: 0.2519 - output_samp_loss: 0.3510 - output_mean_loss: 0.2556 - output_rmse: 0.5019 - output_samp_rmse_samp: 0.5924 - output_mean_rmse_mean: 0.5056 - val_loss: 1.2545 - val_output_loss: 0.4166 - val_output_samp_loss: 0.4233 - val_output_mean_loss: 0.4146 - val_output_rmse: 0.6454 - val_output_samp_rmse_samp: 0.6506 - val_output_mean_rmse_mean: 0.6439
# Epoch 82/100
# 10/10 - 10s - loss: 0.8473 - output_loss: 0.2529 - output_samp_loss: 0.3139 - output_mean_loss: 0.2806 - output_rmse: 0.5029 - output_samp_rmse_samp: 0.5602 - output_mean_rmse_mean: 0.5297 - val_loss: 0.9259 - val_output_loss: 0.3067 - val_output_samp_loss: 0.3167 - val_output_mean_loss: 0.3025 - val_output_rmse: 0.5538 - val_output_samp_rmse_samp: 0.5628 - val_output_mean_rmse_mean: 0.5500
# Epoch 83/100
# 10/10 - 10s - loss: 0.7408 - output_loss: 0.2124 - output_samp_loss: 0.3085 - output_mean_loss: 0.2198 - output_rmse: 0.4609 - output_samp_rmse_samp: 0.5554 - output_mean_rmse_mean: 0.4688 - val_loss: 1.1218 - val_output_loss: 0.3716 - val_output_samp_loss: 0.3505 - val_output_mean_loss: 0.3997 - val_output_rmse: 0.6096 - val_output_samp_rmse_samp: 0.5921 - val_output_mean_rmse_mean: 0.6322
# Epoch 84/100
# 10/10 - 10s - loss: 0.5361 - output_loss: 0.1600 - output_samp_loss: 0.2088 - output_mean_loss: 0.1672 - output_rmse: 0.4000 - output_samp_rmse_samp: 0.4570 - output_mean_rmse_mean: 0.4089 - val_loss: 1.2816 - val_output_loss: 0.4259 - val_output_samp_loss: 0.4245 - val_output_mean_loss: 0.4313 - val_output_rmse: 0.6526 - val_output_samp_rmse_samp: 0.6515 - val_output_mean_rmse_mean: 0.6568
# Epoch 85/100
# 10/10 - 10s - loss: 0.6410 - output_loss: 0.1905 - output_samp_loss: 0.2553 - output_mean_loss: 0.1952 - output_rmse: 0.4365 - output_samp_rmse_samp: 0.5053 - output_mean_rmse_mean: 0.4419 - val_loss: 1.4159 - val_output_loss: 0.4708 - val_output_samp_loss: 0.4721 - val_output_mean_loss: 0.4730 - val_output_rmse: 0.6861 - val_output_samp_rmse_samp: 0.6871 - val_output_mean_rmse_mean: 0.6877
# Epoch 86/100
# 10/10 - 10s - loss: 0.5849 - output_loss: 0.1685 - output_samp_loss: 0.2369 - output_mean_loss: 0.1795 - output_rmse: 0.4105 - output_samp_rmse_samp: 0.4868 - output_mean_rmse_mean: 0.4237 - val_loss: 1.0478 - val_output_loss: 0.3469 - val_output_samp_loss: 0.3733 - val_output_mean_loss: 0.3277 - val_output_rmse: 0.5890 - val_output_samp_rmse_samp: 0.6109 - val_output_mean_rmse_mean: 0.5725
# Epoch 87/100
# 10/10 - 10s - loss: 0.7434 - output_loss: 0.2389 - output_samp_loss: 0.2467 - output_mean_loss: 0.2578 - output_rmse: 0.4887 - output_samp_rmse_samp: 0.4967 - output_mean_rmse_mean: 0.5078 - val_loss: 1.0669 - val_output_loss: 0.3527 - val_output_samp_loss: 0.3308 - val_output_mean_loss: 0.3835 - val_output_rmse: 0.5939 - val_output_samp_rmse_samp: 0.5751 - val_output_mean_rmse_mean: 0.6192
# Epoch 88/100
# 10/10 - 10s - loss: 0.5662 - output_loss: 0.1558 - output_samp_loss: 0.2516 - output_mean_loss: 0.1587 - output_rmse: 0.3947 - output_samp_rmse_samp: 0.5016 - output_mean_rmse_mean: 0.3984 - val_loss: 1.2611 - val_output_loss: 0.4182 - val_output_samp_loss: 0.4474 - val_output_mean_loss: 0.3955 - val_output_rmse: 0.6467 - val_output_samp_rmse_samp: 0.6689 - val_output_mean_rmse_mean: 0.6289
# Epoch 89/100
# 10/10 - 10s - loss: 0.6145 - output_loss: 0.1709 - output_samp_loss: 0.2679 - output_mean_loss: 0.1756 - output_rmse: 0.4134 - output_samp_rmse_samp: 0.5176 - output_mean_rmse_mean: 0.4191 - val_loss: 0.9105 - val_output_loss: 0.3018 - val_output_samp_loss: 0.2965 - val_output_mean_loss: 0.3122 - val_output_rmse: 0.5493 - val_output_samp_rmse_samp: 0.5445 - val_output_mean_rmse_mean: 0.5588
# Epoch 90/100
# 10/10 - 10s - loss: 0.6149 - output_loss: 0.1789 - output_samp_loss: 0.2380 - output_mean_loss: 0.1981 - output_rmse: 0.4229 - output_samp_rmse_samp: 0.4878 - output_mean_rmse_mean: 0.4450 - val_loss: 1.1431 - val_output_loss: 0.3796 - val_output_samp_loss: 0.3720 - val_output_mean_loss: 0.3914 - val_output_rmse: 0.6162 - val_output_samp_rmse_samp: 0.6099 - val_output_mean_rmse_mean: 0.6256
# Epoch 91/100
# 10/10 - 10s - loss: 0.6426 - output_loss: 0.1997 - output_samp_loss: 0.2290 - output_mean_loss: 0.2139 - output_rmse: 0.4469 - output_samp_rmse_samp: 0.4786 - output_mean_rmse_mean: 0.4625 - val_loss: 1.8791 - val_output_loss: 0.6251 - val_output_samp_loss: 0.6300 - val_output_mean_loss: 0.6240 - val_output_rmse: 0.7907 - val_output_samp_rmse_samp: 0.7937 - val_output_mean_rmse_mean: 0.7899
# Epoch 92/100
# 10/10 - 10s - loss: 1.0148 - output_loss: 0.3201 - output_samp_loss: 0.3775 - output_mean_loss: 0.3172 - output_rmse: 0.5657 - output_samp_rmse_samp: 0.6144 - output_mean_rmse_mean: 0.5632 - val_loss: 1.4143 - val_output_loss: 0.4696 - val_output_samp_loss: 0.4947 - val_output_mean_loss: 0.4500 - val_output_rmse: 0.6853 - val_output_samp_rmse_samp: 0.7033 - val_output_mean_rmse_mean: 0.6708
# Epoch 93/100
# 10/10 - 10s - loss: 0.7228 - output_loss: 0.2235 - output_samp_loss: 0.2660 - output_mean_loss: 0.2333 - output_rmse: 0.4728 - output_samp_rmse_samp: 0.5158 - output_mean_rmse_mean: 0.4830 - val_loss: 1.0423 - val_output_loss: 0.3456 - val_output_samp_loss: 0.3336 - val_output_mean_loss: 0.3631 - val_output_rmse: 0.5879 - val_output_samp_rmse_samp: 0.5776 - val_output_mean_rmse_mean: 0.6025
# Epoch 94/100
# 10/10 - 10s - loss: 0.8443 - output_loss: 0.2525 - output_samp_loss: 0.3304 - output_mean_loss: 0.2613 - output_rmse: 0.5025 - output_samp_rmse_samp: 0.5748 - output_mean_rmse_mean: 0.5112 - val_loss: 1.0407 - val_output_loss: 0.3453 - val_output_samp_loss: 0.3591 - val_output_mean_loss: 0.3364 - val_output_rmse: 0.5876 - val_output_samp_rmse_samp: 0.5992 - val_output_mean_rmse_mean: 0.5800
# Epoch 95/100
# 10/10 - 10s - loss: 0.7835 - output_loss: 0.2317 - output_samp_loss: 0.3176 - output_mean_loss: 0.2342 - output_rmse: 0.4813 - output_samp_rmse_samp: 0.5636 - output_mean_rmse_mean: 0.4839 - val_loss: 1.2464 - val_output_loss: 0.4127 - val_output_samp_loss: 0.4497 - val_output_mean_loss: 0.3840 - val_output_rmse: 0.6424 - val_output_samp_rmse_samp: 0.6706 - val_output_mean_rmse_mean: 0.6197
# Epoch 96/100
# 10/10 - 10s - loss: 0.5451 - output_loss: 0.1535 - output_samp_loss: 0.2234 - output_mean_loss: 0.1683 - output_rmse: 0.3918 - output_samp_rmse_samp: 0.4726 - output_mean_rmse_mean: 0.4102 - val_loss: 0.9412 - val_output_loss: 0.3120 - val_output_samp_loss: 0.3010 - val_output_mean_loss: 0.3282 - val_output_rmse: 0.5585 - val_output_samp_rmse_samp: 0.5486 - val_output_mean_rmse_mean: 0.5729
# Epoch 97/100
# 10/10 - 10s - loss: 0.7073 - output_loss: 0.2126 - output_samp_loss: 0.2808 - output_mean_loss: 0.2140 - output_rmse: 0.4611 - output_samp_rmse_samp: 0.5299 - output_mean_rmse_mean: 0.4626 - val_loss: 1.3479 - val_output_loss: 0.4477 - val_output_samp_loss: 0.4731 - val_output_mean_loss: 0.4271 - val_output_rmse: 0.6691 - val_output_samp_rmse_samp: 0.6878 - val_output_mean_rmse_mean: 0.6535
# Epoch 98/100
# 10/10 - 10s - loss: 0.6352 - output_loss: 0.1837 - output_samp_loss: 0.2539 - output_mean_loss: 0.1976 - output_rmse: 0.4285 - output_samp_rmse_samp: 0.5039 - output_mean_rmse_mean: 0.4446 - val_loss: 1.1133 - val_output_loss: 0.3697 - val_output_samp_loss: 0.3700 - val_output_mean_loss: 0.3735 - val_output_rmse: 0.6080 - val_output_samp_rmse_samp: 0.6083 - val_output_mean_rmse_mean: 0.6112
# Epoch 99/100
# 10/10 - 10s - loss: 0.6183 - output_loss: 0.1736 - output_samp_loss: 0.2625 - output_mean_loss: 0.1823 - output_rmse: 0.4166 - output_samp_rmse_samp: 0.5123 - output_mean_rmse_mean: 0.4269 - val_loss: 1.2328 - val_output_loss: 0.4083 - val_output_samp_loss: 0.3748 - val_output_mean_loss: 0.4497 - val_output_rmse: 0.6390 - val_output_samp_rmse_samp: 0.6122 - val_output_mean_rmse_mean: 0.6706
# Epoch 100/100
# 10/10 - 10s - loss: 0.5514 - output_loss: 0.1513 - output_samp_loss: 0.2368 - output_mean_loss: 0.1632 - output_rmse: 0.3890 - output_samp_rmse_samp: 0.4867 - output_mean_rmse_mean: 0.4040 - val_loss: 1.0050 - val_output_loss: 0.3335 - val_output_samp_loss: 0.3478 - val_output_mean_loss: 0.3237 - val_output_rmse: 0.5775 - val_output_samp_rmse_samp: 0.5897 - val_output_mean_rmse_mean: 0.5689
# #### FOLD 1 OOF RMSE = 0.5257
# #### FOLD 1 OOF RMSE = 0.5221
# #### FOLD 1 OOF RMSE = 0.5337

# %% [markdown]
# ## Model loss and metrics graph

# %%
for fold, history in enumerate(history_list):
    print(f'\nFOLD: {fold+1}')
    plot_metrics(history)
# Out:
# FOLD: 1

# %% [markdown]
# # Model evaluation
#
# ## OOF metrics

# %%
y_true = np.concatenate(oof_labels)
y_preds = np.concatenate(oof_pred)

for fold, history in enumerate(history_list):
    print(f"#### FOLD {fold+1} OOF RMSE = {np.min(history['val_output_rmse']):.4f}")
    print(f"#### FOLD {fold+1} OOF RMSE = {np.min(history['val_output_samp_rmse_samp']):.4f}")
    print(f"#### FOLD {fold+1} OOF RMSE = {np.min(history['val_output_mean_rmse_mean']):.4f}")
    
print(f'OOF RMSE: {mean_squared_error(y_true, y_preds, squared=False):.4f}')
# Out:
# #### FOLD 1 OOF RMSE = 0.5257
# #### FOLD 1 OOF RMSE = 0.5221
# #### FOLD 1 OOF RMSE = 0.5337
# OOF RMSE: 0.5257

# %% [markdown]
# ### **Error analysis**, label x prediction distribution
#
# Here we can compare the distribution from the labels and the predicted values, in a perfect scenario they should align.

# %%
preds_df = pd.DataFrame({'Label': y_true, 'Pred': y_preds[:,0]})

fig, ax = plt.subplots(1, 1, figsize=(20, 6))
sns.distplot(preds_df['Label'], ax=ax, label='Label')
sns.distplot(preds_df['Pred'], ax=ax, label='Prediction')
ax.legend()
plt.show()

# %%
sns.jointplot(data=preds_df, x='Label', y='Pred', kind='reg', height=8)
plt.show()
