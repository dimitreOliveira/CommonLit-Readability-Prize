# %% [markdown]
# ## Dependencies

# %%
import warnings, math, json
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
from tensorflow.keras import optimizers, losses, metrics, Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from transformers import TFAutoModelForSequenceClassification, TFAutoModel, AutoTokenizer
from commonlit_scripts import *


seed = 0
seed_everything(seed)
sns.set(style='whitegrid')
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 150)

# %% [markdown]
# ### Hardware configuration

# %%
strategy, tpu = get_strategy()
AUTO = tf.data.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
print(f'REPLICAS: {REPLICAS}')
# Out:
# Running on TPU grpc://10.0.0.2:8470
# REPLICAS: 8

# %% [markdown]
# # Load data

# %%
train_filepath = '/kaggle/input/commonlitreadabilityprize/train.csv'
train = pd.read_csv(train_filepath)
print(f'Train samples: {len(train)}')
# removing unused columns
train.drop(['url_legal', 'license'], axis=1, inplace=True)
display(train.head())
# Out:
# Train samples: 2834
#           id  \
# 0  c12129c31
# 1  85aa80a4c
# 2  b69ac6792
# 3  dd1000b26
# 4  37c1b32fb
#
#                                                                                                                                                  excerpt  \
# 0  When the young people returned to the ballroom, it presented a decidedly changed appearance. Instead of an interior scene, it was a winter landsca...
# 1  All through dinner time, Mrs. Fayre was somewhat silent, her eyes resting on Dolly with a wistful, uncertain expression. She wanted to give the ch...
# 2  As Roger had predicted, the snow departed as quickly as it came, and two days after their sleigh ride there was scarcely a vestige of white on the...
# 3  And outside before the palace a great garden was walled round, filled full of stately fruit-trees, gray olives and sweet figs, and pomegranates, p...
# 4  Once upon a time there were Three Bears who lived together in a house of their own in a wood. One of them was a Little, Small, Wee Bear; and one w...
#
#      target  standard_error
# 0 -0.340259        0.464009
# 1 -0.315372        0.480805
# 2 -0.580118        0.476676
# 3 -1.054013        0.450007
# 4  0.247197        0.510845

# %% [markdown]
# # Model parameters

# %%
config = {
  "BATCH_SIZE": 8 * REPLICAS,
  "LEARNING_RATE": 1e-5 * REPLICAS,
  "EPOCHS": 100,
  "ES_PATIENCE": 30,
  "N_FOLDS": 5,
  "N_USED_FOLDS": 1,
  "SEQ_LEN": 256,
  "BASE_MODEL": '/kaggle/input/huggingface-bert/bert-base-uncased',
  "SEED": seed,
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# ## Auxiliary functions

# %%
# Datasets utility functions
def custom_standardization(text, is_lower=True):
    if is_lower:
        text = text.lower() # if encoder is uncased
    text = text.strip()
    return text


def sample_target(features, target):
    mean, stddev = target
    sampled_target = tf.random.normal([], mean=tf.cast(mean, dtype=tf.float32), 
                                      stddev=tf.cast(stddev, dtype=tf.float32), dtype=tf.float32)
    
    return (features, sampled_target)
    

def get_dataset(pandas_df, tokenizer, labeled=True, ordered=False, repeated=False, 
                is_sampled=False, batch_size=32, seq_len=128, is_lower=True):
    """
        Return a Tensorflow dataset ready for training or inference.
    """
    text = [custom_standardization(text, is_lower) for text in pandas_df['excerpt']]
    
    # Tokenize inputs
    tokenized_inputs = tokenizer(text, max_length=seq_len, truncation=True, 
                                 padding='max_length', return_tensors='tf')
    
    if labeled:
        dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': tokenized_inputs['input_ids'], 
                                                       'token_type_ids': tokenized_inputs['token_type_ids'], 
                                                       'attention_mask': tokenized_inputs['attention_mask']}, 
                                                      (pandas_df['target'], pandas_df['standard_error'])))
        if is_sampled:
            dataset = dataset.map(sample_target, num_parallel_calls=tf.data.AUTOTUNE)
    else:
        dataset = tf.data.Dataset.from_tensor_slices({'input_ids': tokenized_inputs['input_ids'], 
                                                      'token_type_ids': tokenized_inputs['token_type_ids'], 
                                                      'attention_mask': tokenized_inputs['attention_mask']})
        
    if repeated:
        dataset = dataset.repeat()
    if not ordered:
        dataset = dataset.shuffle(2048)
    dataset = dataset.batch(batch_size)
    dataset = dataset.cache()
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    
    return dataset

# %% [markdown]
# # Model

# %%
def model_fn(encoder, seq_len=256):
    input_ids = L.Input(shape=(seq_len,), dtype=tf.int32, name='input_ids')
    input_token_type_ids = L.Input(shape=(seq_len,), dtype=tf.int32, name='token_type_ids')
    input_attention_mask = L.Input(shape=(seq_len,), dtype=tf.int32, name='attention_mask')
    
    outputs = encoder({'input_ids': input_ids,  
                       'token_type_ids': input_token_type_ids, 
                       'attention_mask': input_attention_mask})
    last_hidden_state = outputs['last_hidden_state']
    
    x = L.GlobalAveragePooling1D()(last_hidden_state)
#     x = L.Dropout(.5)(x)
    output = L.Dense(1, name='output')(x)
    
    model = Model(inputs=[input_ids, input_token_type_ids, input_attention_mask], outputs=output)

    optimizer = optimizers.Adam(lr=config['LEARNING_RATE'])
    model.compile(optimizer=optimizer, 
                  loss=losses.MeanSquaredError(), 
                  metrics=[metrics.RootMeanSquaredError()])
    
    return model


with strategy.scope():
    encoder = TFAutoModel.from_pretrained(config['BASE_MODEL'])
    model = model_fn(encoder, config['SEQ_LEN'])
    
model.summary()
# Out:
# Some layers from the model checkpoint at /kaggle/input/huggingface-bert/bert-base-uncased were not used when initializing TFBertModel: ['mlm___cls', 'nsp___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at /kaggle/input/huggingface-bert/bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# attention_mask (InputLayer)     [(None, 256)]        0
# __________________________________________________________________________________________________
# input_ids (InputLayer)          [(None, 256)]        0
# __________________________________________________________________________________________________
# token_type_ids (InputLayer)     [(None, 256)]        0
# __________________________________________________________________________________________________
# tf_bert_model (TFBertModel)     TFBaseModelOutputWit 109482240   attention_mask[0][0]
#                                                                  input_ids[0][0]
#                                                                  token_type_ids[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 768)          0           tf_bert_model[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            769         global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 109,483,009
# Trainable params: 109,483,009
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
tokenizer = AutoTokenizer.from_pretrained(config['BASE_MODEL'])
skf = KFold(n_splits=config['N_FOLDS'], shuffle=True, random_state=seed)
oof_pred = []; oof_labels = []; history_list = []

for fold,(idxT, idxV) in enumerate(skf.split(train)):
    if fold >= config['N_USED_FOLDS']:
        break
    if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    print(f'\nFOLD: {fold+1}')
    print(f'TRAIN: {len(idxT)} VALID: {len(idxV)}')

    # Model
    K.clear_session()
    with strategy.scope():
        encoder = TFAutoModel.from_pretrained(config['BASE_MODEL'])
        model = model_fn(encoder, config['SEQ_LEN'])
        
    model_path = f'model_{fold}.h5'
    es = EarlyStopping(monitor='val_root_mean_squared_error', mode='min', 
                       patience=config['ES_PATIENCE'], restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_root_mean_squared_error', mode='min', 
                                 save_best_only=True, save_weights_only=True)

    # Train
    history = model.fit(x=get_dataset(train.loc[idxT], tokenizer, repeated=True, is_sampled=True, 
                                      batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN']), 
                        validation_data=get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                                                    batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN']), 
                        steps_per_epoch=10, 
                        callbacks=[es, checkpoint], 
                        epochs=config['EPOCHS'],  
                        verbose=2).history
      
    history_list.append(history)
    # Save last model weights
    model.load_weights(model_path)
    
    # Results
    print(f"#### FOLD {fold+1} OOF RMSE = {np.min(history['val_root_mean_squared_error']):.4f}")

    # OOF predictions
    valid_ds = get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                           batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN'])
    oof_labels.append([target[0].numpy() for sample, target in iter(valid_ds.unbatch())])
    x_oof = valid_ds.map(lambda sample, target: sample)
    oof_pred.append(model.predict(x_oof))
# Out:
# FOLD: 1
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-bert/bert-base-uncased were not used when initializing TFBertModel: ['mlm___cls', 'nsp___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at /kaggle/input/huggingface-bert/bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Epoch 1/100
# 10/10 - 86s - loss: 1.7097 - root_mean_squared_error: 1.3076 - val_loss: 0.9479 - val_root_mean_squared_error: 0.9736
# Epoch 2/100
# 10/10 - 2s - loss: 0.9720 - root_mean_squared_error: 0.9859 - val_loss: 0.4969 - val_root_mean_squared_error: 0.7049
# Epoch 3/100
# 10/10 - 2s - loss: 0.7012 - root_mean_squared_error: 0.8374 - val_loss: 0.3554 - val_root_mean_squared_error: 0.5962
# Epoch 4/100
# 10/10 - 2s - loss: 0.6073 - root_mean_squared_error: 0.7793 - val_loss: 0.3459 - val_root_mean_squared_error: 0.5881
# Epoch 5/100
# 10/10 - 2s - loss: 0.5601 - root_mean_squared_error: 0.7484 - val_loss: 0.4132 - val_root_mean_squared_error: 0.6428
# Epoch 6/100
# 10/10 - 2s - loss: 0.4441 - root_mean_squared_error: 0.6664 - val_loss: 0.3536 - val_root_mean_squared_error: 0.5947
# Epoch 7/100
# 10/10 - 2s - loss: 0.4930 - root_mean_squared_error: 0.7022 - val_loss: 0.6659 - val_root_mean_squared_error: 0.8160
# Epoch 8/100
# 10/10 - 2s - loss: 0.5009 - root_mean_squared_error: 0.7078 - val_loss: 0.3163 - val_root_mean_squared_error: 0.5624
# Epoch 9/100
# 10/10 - 2s - loss: 0.4869 - root_mean_squared_error: 0.6978 - val_loss: 0.2887 - val_root_mean_squared_error: 0.5373
# Epoch 10/100
# 10/10 - 2s - loss: 0.4644 - root_mean_squared_error: 0.6815 - val_loss: 0.5564 - val_root_mean_squared_error: 0.7460
# Epoch 11/100
# 10/10 - 2s - loss: 0.4226 - root_mean_squared_error: 0.6501 - val_loss: 0.3017 - val_root_mean_squared_error: 0.5493
# Epoch 12/100
# 10/10 - 2s - loss: 0.3844 - root_mean_squared_error: 0.6200 - val_loss: 0.3324 - val_root_mean_squared_error: 0.5765
# Epoch 13/100
# 10/10 - 2s - loss: 0.3545 - root_mean_squared_error: 0.5954 - val_loss: 0.3782 - val_root_mean_squared_error: 0.6150
# Epoch 14/100
# 10/10 - 2s - loss: 0.3578 - root_mean_squared_error: 0.5982 - val_loss: 0.2873 - val_root_mean_squared_error: 0.5360
# Epoch 15/100
# 10/10 - 2s - loss: 0.3285 - root_mean_squared_error: 0.5731 - val_loss: 0.3131 - val_root_mean_squared_error: 0.5596
# Epoch 16/100
# 10/10 - 2s - loss: 0.3215 - root_mean_squared_error: 0.5670 - val_loss: 0.3336 - val_root_mean_squared_error: 0.5776
# Epoch 17/100
# 10/10 - 2s - loss: 0.3237 - root_mean_squared_error: 0.5690 - val_loss: 0.3589 - val_root_mean_squared_error: 0.5991
# Epoch 18/100
# 10/10 - 2s - loss: 0.3198 - root_mean_squared_error: 0.5655 - val_loss: 0.3007 - val_root_mean_squared_error: 0.5484
# Epoch 19/100
# 10/10 - 2s - loss: 0.3571 - root_mean_squared_error: 0.5976 - val_loss: 0.3790 - val_root_mean_squared_error: 0.6156
# Epoch 20/100
# 10/10 - 2s - loss: 0.2945 - root_mean_squared_error: 0.5427 - val_loss: 0.3354 - val_root_mean_squared_error: 0.5791
# Epoch 21/100
# 10/10 - 2s - loss: 0.3358 - root_mean_squared_error: 0.5795 - val_loss: 0.3056 - val_root_mean_squared_error: 0.5528
# Epoch 22/100
# 10/10 - 2s - loss: 0.3069 - root_mean_squared_error: 0.5540 - val_loss: 0.4110 - val_root_mean_squared_error: 0.6411
# Epoch 23/100
# 10/10 - 3s - loss: 0.3685 - root_mean_squared_error: 0.6071 - val_loss: 0.3409 - val_root_mean_squared_error: 0.5839
# Epoch 24/100
# 10/10 - 2s - loss: 0.2991 - root_mean_squared_error: 0.5469 - val_loss: 0.4122 - val_root_mean_squared_error: 0.6420
# Epoch 25/100
# 10/10 - 2s - loss: 0.3394 - root_mean_squared_error: 0.5826 - val_loss: 0.2864 - val_root_mean_squared_error: 0.5352
# Epoch 26/100
# 10/10 - 2s - loss: 0.3792 - root_mean_squared_error: 0.6158 - val_loss: 0.5255 - val_root_mean_squared_error: 0.7249
# Epoch 27/100
# 10/10 - 2s - loss: 0.3175 - root_mean_squared_error: 0.5634 - val_loss: 0.3256 - val_root_mean_squared_error: 0.5706
# Epoch 28/100
# 10/10 - 2s - loss: 0.2913 - root_mean_squared_error: 0.5398 - val_loss: 0.3047 - val_root_mean_squared_error: 0.5520
# Epoch 29/100
# 10/10 - 2s - loss: 0.2816 - root_mean_squared_error: 0.5307 - val_loss: 0.4489 - val_root_mean_squared_error: 0.6700
# Epoch 30/100
# 10/10 - 2s - loss: 0.2570 - root_mean_squared_error: 0.5070 - val_loss: 0.2933 - val_root_mean_squared_error: 0.5416
# Epoch 31/100
# 10/10 - 2s - loss: 0.2729 - root_mean_squared_error: 0.5224 - val_loss: 0.3727 - val_root_mean_squared_error: 0.6105
# Epoch 32/100
# 10/10 - 2s - loss: 0.2487 - root_mean_squared_error: 0.4987 - val_loss: 0.4538 - val_root_mean_squared_error: 0.6737
# Epoch 33/100
# 10/10 - 2s - loss: 0.2736 - root_mean_squared_error: 0.5231 - val_loss: 0.2865 - val_root_mean_squared_error: 0.5353
# Epoch 34/100
# 10/10 - 2s - loss: 0.2728 - root_mean_squared_error: 0.5223 - val_loss: 0.3310 - val_root_mean_squared_error: 0.5754
# Epoch 35/100
# 10/10 - 2s - loss: 0.2907 - root_mean_squared_error: 0.5392 - val_loss: 0.4085 - val_root_mean_squared_error: 0.6391
# Epoch 36/100
# 10/10 - 2s - loss: 0.2732 - root_mean_squared_error: 0.5227 - val_loss: 0.3617 - val_root_mean_squared_error: 0.6014
# Epoch 37/100
# 10/10 - 2s - loss: 0.2960 - root_mean_squared_error: 0.5441 - val_loss: 0.3283 - val_root_mean_squared_error: 0.5730
# Epoch 38/100
# 10/10 - 2s - loss: 0.2813 - root_mean_squared_error: 0.5304 - val_loss: 0.2847 - val_root_mean_squared_error: 0.5336
# Epoch 39/100
# 10/10 - 2s - loss: 0.2651 - root_mean_squared_error: 0.5149 - val_loss: 0.4496 - val_root_mean_squared_error: 0.6706
# Epoch 40/100
# 10/10 - 2s - loss: 0.2572 - root_mean_squared_error: 0.5071 - val_loss: 0.2746 - val_root_mean_squared_error: 0.5241
# Epoch 41/100
# 10/10 - 2s - loss: 0.3018 - root_mean_squared_error: 0.5494 - val_loss: 0.3476 - val_root_mean_squared_error: 0.5896
# Epoch 42/100
# 10/10 - 2s - loss: 0.2853 - root_mean_squared_error: 0.5341 - val_loss: 0.3395 - val_root_mean_squared_error: 0.5827
# Epoch 43/100
# 10/10 - 2s - loss: 0.3243 - root_mean_squared_error: 0.5694 - val_loss: 0.2771 - val_root_mean_squared_error: 0.5264
# Epoch 44/100
# 10/10 - 3s - loss: 0.3230 - root_mean_squared_error: 0.5684 - val_loss: 0.4857 - val_root_mean_squared_error: 0.6969
# Epoch 45/100
# 10/10 - 2s - loss: 0.3604 - root_mean_squared_error: 0.6003 - val_loss: 0.3383 - val_root_mean_squared_error: 0.5817
# Epoch 46/100
# 10/10 - 2s - loss: 0.3205 - root_mean_squared_error: 0.5661 - val_loss: 0.3504 - val_root_mean_squared_error: 0.5920
# Epoch 47/100
# 10/10 - 2s - loss: 0.3476 - root_mean_squared_error: 0.5896 - val_loss: 0.4939 - val_root_mean_squared_error: 0.7027
# Epoch 48/100
# 10/10 - 2s - loss: 0.3235 - root_mean_squared_error: 0.5688 - val_loss: 0.2886 - val_root_mean_squared_error: 0.5372
# Epoch 49/100
# 10/10 - 2s - loss: 0.3299 - root_mean_squared_error: 0.5744 - val_loss: 0.3688 - val_root_mean_squared_error: 0.6073
# Epoch 50/100
# 10/10 - 2s - loss: 0.2619 - root_mean_squared_error: 0.5118 - val_loss: 0.3590 - val_root_mean_squared_error: 0.5991
# Epoch 51/100
# 10/10 - 2s - loss: 0.2764 - root_mean_squared_error: 0.5257 - val_loss: 0.3249 - val_root_mean_squared_error: 0.5700
# Epoch 52/100
# 10/10 - 2s - loss: 0.3025 - root_mean_squared_error: 0.5500 - val_loss: 0.4524 - val_root_mean_squared_error: 0.6726
# Epoch 53/100
# 10/10 - 2s - loss: 0.2690 - root_mean_squared_error: 0.5186 - val_loss: 0.2904 - val_root_mean_squared_error: 0.5389
# Epoch 54/100
# 10/10 - 2s - loss: 0.2801 - root_mean_squared_error: 0.5292 - val_loss: 0.4671 - val_root_mean_squared_error: 0.6834
# Epoch 55/100
# 10/10 - 2s - loss: 0.2760 - root_mean_squared_error: 0.5254 - val_loss: 0.3812 - val_root_mean_squared_error: 0.6174
# Epoch 56/100
# 10/10 - 2s - loss: 0.2625 - root_mean_squared_error: 0.5124 - val_loss: 0.3309 - val_root_mean_squared_error: 0.5752
# Epoch 57/100
# 10/10 - 2s - loss: 0.2969 - root_mean_squared_error: 0.5449 - val_loss: 0.3301 - val_root_mean_squared_error: 0.5746
# Epoch 58/100
# 10/10 - 2s - loss: 0.3109 - root_mean_squared_error: 0.5576 - val_loss: 0.3019 - val_root_mean_squared_error: 0.5495
# Epoch 59/100
# 10/10 - 2s - loss: 0.2602 - root_mean_squared_error: 0.5101 - val_loss: 0.3866 - val_root_mean_squared_error: 0.6217
# Epoch 60/100
# 10/10 - 2s - loss: 0.2733 - root_mean_squared_error: 0.5228 - val_loss: 0.3026 - val_root_mean_squared_error: 0.5501
# Epoch 61/100
# 10/10 - 2s - loss: 0.2585 - root_mean_squared_error: 0.5085 - val_loss: 0.4305 - val_root_mean_squared_error: 0.6561
# Epoch 62/100
# 10/10 - 2s - loss: 0.2411 - root_mean_squared_error: 0.4910 - val_loss: 0.2975 - val_root_mean_squared_error: 0.5454
# Epoch 63/100
# 10/10 - 2s - loss: 0.2682 - root_mean_squared_error: 0.5179 - val_loss: 0.2817 - val_root_mean_squared_error: 0.5307
# Epoch 64/100
# 10/10 - 2s - loss: 0.3242 - root_mean_squared_error: 0.5694 - val_loss: 0.2993 - val_root_mean_squared_error: 0.5471
# Epoch 65/100
# 10/10 - 3s - loss: 0.2940 - root_mean_squared_error: 0.5422 - val_loss: 0.4200 - val_root_mean_squared_error: 0.6481
# Epoch 66/100
# 10/10 - 2s - loss: 0.3087 - root_mean_squared_error: 0.5556 - val_loss: 0.3266 - val_root_mean_squared_error: 0.5715
# Epoch 67/100
# 10/10 - 2s - loss: 0.3027 - root_mean_squared_error: 0.5501 - val_loss: 0.3204 - val_root_mean_squared_error: 0.5660
# Epoch 68/100
# 10/10 - 2s - loss: 0.3413 - root_mean_squared_error: 0.5842 - val_loss: 0.3246 - val_root_mean_squared_error: 0.5697
# Epoch 69/100
# 10/10 - 2s - loss: 0.3006 - root_mean_squared_error: 0.5483 - val_loss: 0.3987 - val_root_mean_squared_error: 0.6314
# Epoch 70/100
# 10/10 - 2s - loss: 0.3218 - root_mean_squared_error: 0.5673 - val_loss: 0.3665 - val_root_mean_squared_error: 0.6054
# Restoring model weights from the end of the best epoch.
# Epoch 00070: early stopping
# #### FOLD 1 OOF RMSE = 0.5241

# %% [markdown]
# ## Model loss and metrics graph

# %%
for fold, history in enumerate(history_list):
    print(f'\nFOLD: {fold+1}')
    plot_metrics(history)
# Out:
# FOLD: 1

# %% [markdown]
# # Model evaluation
#
# We are evaluating the model on the `OOF` predictions, it stands for `Out Of Fold`, since we are training using `K-Fold` our model will see all the data, and the correct way to evaluate each fold is by looking at the predictions that are not from that fold.
#
# ## OOF metrics

# %%
y_true = np.concatenate(oof_labels)
y_preds = np.concatenate(oof_pred)


for fold, history in enumerate(history_list):
    print(f"FOLD {fold+1} RMSE: {np.min(history['val_root_mean_squared_error']):.4f}")
    
print(f'OOF RMSE: {mean_squared_error(y_true, y_preds, squared=False):.4f}')
# Out:
# FOLD 1 RMSE: 0.5241
# OOF RMSE: 0.5241

# %% [markdown]
# ### **Error analysis**, label x prediction distribution
#
# Here we can compare the distribution from the labels and the predicted values, in a perfect scenario they should align.

# %%
preds_df = pd.DataFrame({'Label': y_true, 'Prediction': y_preds[:,0]})

fig, ax = plt.subplots(1, 1, figsize=(20, 6))
sns.distplot(preds_df['Label'], ax=ax, label='Label')
sns.distplot(preds_df['Prediction'], ax=ax, label='Prediction')
ax.legend()
plt.show()

# %%
sns.jointplot(data=preds_df, x='Label', y='Prediction', kind='reg', height=10)
plt.show()
