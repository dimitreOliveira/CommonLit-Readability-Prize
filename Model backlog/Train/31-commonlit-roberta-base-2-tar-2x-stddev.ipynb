# %% [markdown]
# ## Dependencies

# %%
import warnings, math, json
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import tensorflow_addons as tfa
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
from tensorflow.keras import optimizers, losses, metrics, Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from transformers import TFAutoModelForSequenceClassification, TFAutoModel, AutoTokenizer
from commonlit_scripts import *


seed = 0
seed_everything(seed)
sns.set(style='whitegrid')
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 150)

# %% [markdown]
# ### Hardware configuration

# %%
strategy, tpu = get_strategy()
AUTO = tf.data.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
print(f'REPLICAS: {REPLICAS}')
# Out:
# Running on TPU grpc://10.0.0.2:8470
# REPLICAS: 8

# %% [markdown]
# # Load data

# %%
train_filepath = '/kaggle/input/commonlitreadabilityprize/train.csv'
train = pd.read_csv(train_filepath)
print(f'Train samples: {len(train)}')
# removing unused columns
train.drop(['url_legal', 'license'], axis=1, inplace=True)

train['standard_error'] = train['standard_error'] * 2
display(train.head())
# Out:
# Train samples: 2834
#           id  \
# 0  c12129c31
# 1  85aa80a4c
# 2  b69ac6792
# 3  dd1000b26
# 4  37c1b32fb
#
#                                                                                                                                                  excerpt  \
# 0  When the young people returned to the ballroom, it presented a decidedly changed appearance. Instead of an interior scene, it was a winter landsca...
# 1  All through dinner time, Mrs. Fayre was somewhat silent, her eyes resting on Dolly with a wistful, uncertain expression. She wanted to give the ch...
# 2  As Roger had predicted, the snow departed as quickly as it came, and two days after their sleigh ride there was scarcely a vestige of white on the...
# 3  And outside before the palace a great garden was walled round, filled full of stately fruit-trees, gray olives and sweet figs, and pomegranates, p...
# 4  Once upon a time there were Three Bears who lived together in a house of their own in a wood. One of them was a Little, Small, Wee Bear; and one w...
#
#      target  standard_error
# 0 -0.340259        0.928018
# 1 -0.315372        0.961610
# 2 -0.580118        0.953352
# 3 -1.054013        0.900014
# 4  0.247197        1.021690

# %% [markdown]
# # Model parameters

# %%
config = {
  "BATCH_SIZE": 8 * REPLICAS,
  "LEARNING_RATE": 1e-5 * REPLICAS,
  "EPOCHS": 100,
  "ES_PATIENCE": 30,
  "N_FOLDS": 5,
  "N_USED_FOLDS": 1,
  "SEQ_LEN": 256,
  "BASE_MODEL": '/kaggle/input/huggingface-roberta/roberta-base/',
  "SEED": seed,
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# ## Auxiliary functions

# %%
# Datasets utility functions
def custom_standardization(text, is_lower=True):
    if is_lower:
        text = text.lower() # if encoder is uncased
    text = text.strip()
    return text

def sample_target(features, target):
    mean, _, stddev = target
    sampled_target = tf.random.normal([], mean=tf.cast(mean, dtype=tf.float32), 
                                      stddev=tf.cast(stddev, dtype=tf.float32), dtype=tf.float32)
    return (features, (mean, sampled_target))
    
def get_dataset(pandas_df, tokenizer, labeled=True, ordered=False, repeated=False, 
                is_sampled=False, batch_size=32, seq_len=128, is_lower=True):
    """
        Return a Tensorflow dataset ready for training or inference.
    """
    text = [custom_standardization(text, is_lower) for text in pandas_df['excerpt']]
    
    # Tokenize inputs
    tokenized_inputs = tokenizer(text, max_length=seq_len, truncation=True, 
                                 padding='max_length', return_tensors='tf')
    
    if labeled:
        dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': tokenized_inputs['input_ids'], 
                                                       'attention_mask': tokenized_inputs['attention_mask']}, 
                                                      (pandas_df['target'], pandas_df['target'], pandas_df['standard_error'])))
        if is_sampled:
            dataset = dataset.map(sample_target, num_parallel_calls=tf.data.AUTOTUNE)
    else:
        dataset = tf.data.Dataset.from_tensor_slices({'input_ids': tokenized_inputs['input_ids'], 
                                                      'attention_mask': tokenized_inputs['attention_mask']})
        
    if repeated:
        dataset = dataset.repeat()
    if not ordered:
        dataset = dataset.shuffle(2048)
    dataset = dataset.batch(batch_size)
    dataset = dataset.cache()
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# %% [markdown]
# # Model

# %%
def model_fn(encoder, seq_len=256):
    input_ids = L.Input(shape=(seq_len,), dtype=tf.int32, name='input_ids')
    input_attention_mask = L.Input(shape=(seq_len,), dtype=tf.int32, name='attention_mask')
    
    outputs = encoder({'input_ids': input_ids,  
                       'attention_mask': input_attention_mask})
    last_hidden_state = outputs['last_hidden_state']
    
    cls_token = last_hidden_state[:, 0, :]
    output = L.Dense(1, name='output')(cls_token)
    output_sample = L.Dense(1, name='output_sample')(cls_token)
    
    model = Model(inputs=[input_ids, input_attention_mask], 
                  outputs=[output, output_sample])

    optimizer = optimizers.Adam(lr=config['LEARNING_RATE'])
    model.compile(optimizer=optimizer, 
                  loss=losses.MeanSquaredError(), 
                  metrics=[metrics.RootMeanSquaredError()])
    return model


with strategy.scope():
    encoder = TFAutoModel.from_pretrained(config['BASE_MODEL'])
    # Freeze embeddings
    encoder.layers[0].embeddings.trainable = False
    model = model_fn(encoder, config['SEQ_LEN'])
    
model.summary()
# Out:
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# attention_mask (InputLayer)     [(None, 256)]        0
# __________________________________________________________________________________________________
# input_ids (InputLayer)          [(None, 256)]        0
# __________________________________________________________________________________________________
# tf_roberta_model (TFRobertaMode TFBaseModelOutputWit 124645632   attention_mask[0][0]
#                                                                  input_ids[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici (None, 768)          0           tf_roberta_model[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            769         tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# output_sample (Dense)           (None, 1)            769         tf.__operators__.getitem[0][0]
# ==================================================================================================
# Total params: 124,647,170
# Trainable params: 85,646,594
# Non-trainable params: 39,000,576
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
tokenizer = AutoTokenizer.from_pretrained(config['BASE_MODEL'])
skf = KFold(n_splits=config['N_FOLDS'], shuffle=True, random_state=seed)
oof_pred = []; oof_labels = []; history_list = []; oof_pred2 = []


for fold,(idxT, idxV) in enumerate(skf.split(train)):
    if fold >= config['N_USED_FOLDS']:
        break
    if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    print(f'\nFOLD: {fold+1}')
    print(f'TRAIN: {len(idxT)} VALID: {len(idxV)}')
    
    # Model
    K.clear_session()
    with strategy.scope():
        encoder = TFAutoModel.from_pretrained(config['BASE_MODEL'])
        # Freeze embeddings
        encoder.layers[0].embeddings.trainable = False
        model = model_fn(encoder, seq_len=config['SEQ_LEN'])

    model_path = f'model_{fold}.h5'
    es = EarlyStopping(monitor='val_output_root_mean_squared_error', mode='min', 
                       patience=config['ES_PATIENCE'], restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_output_root_mean_squared_error', mode='min', 
                                 save_best_only=True, save_weights_only=True)

    # Train
    history = model.fit(x=get_dataset(train.loc[idxT], tokenizer, repeated=True, is_sampled=True, 
                                      batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN']), 
                        validation_data=get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                                                    batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN']), 
                        steps_per_epoch=10, 
                        callbacks=[es, checkpoint], 
                        epochs=config['EPOCHS'],  
                        verbose=2).history

    history_list.append(history)
    # Save last model weights
    model.load_weights(model_path)

    # Results
    print(f"#### FOLD {fold+1} OOF RMSE = {np.min(history['val_output_root_mean_squared_error']):.4f}")
    print(f"#### FOLD {fold+1} OOF RMSE = {np.min(history['val_output_sample_root_mean_squared_error']):.4f}")

    # OOF predictions
    valid_ds = get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                           batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN'])
    oof_labels.append([target[0].numpy() for sample, target in iter(valid_ds.unbatch())])
    x_oof = valid_ds.map(lambda sample, target: sample)
    preds = model.predict(x_oof)
    oof_pred.append(preds[0])
    oof_pred2.append(preds[1])
# Out:
# FOLD: 1
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/100
# 10/10 - 84s - loss: 3.8929 - output_loss: 1.5241 - output_sample_loss: 2.3688 - output_root_mean_squared_error: 1.2345 - output_sample_root_mean_squared_error: 1.5391 - val_loss: 1.9805 - val_output_loss: 1.0177 - val_output_sample_loss: 0.9628 - val_output_root_mean_squared_error: 1.0088 - val_output_sample_root_mean_squared_error: 0.9812
# Epoch 2/100
# 10/10 - 2s - loss: 3.1517 - output_loss: 1.0503 - output_sample_loss: 2.1014 - output_root_mean_squared_error: 1.0248 - output_sample_root_mean_squared_error: 1.4496 - val_loss: 1.2115 - val_output_loss: 0.6087 - val_output_sample_loss: 0.6029 - val_output_root_mean_squared_error: 0.7802 - val_output_sample_root_mean_squared_error: 0.7764
# Epoch 3/100
# 10/10 - 2s - loss: 2.3988 - output_loss: 0.7334 - output_sample_loss: 1.6653 - output_root_mean_squared_error: 0.8564 - output_sample_root_mean_squared_error: 1.2905 - val_loss: 0.9385 - val_output_loss: 0.4834 - val_output_sample_loss: 0.4551 - val_output_root_mean_squared_error: 0.6953 - val_output_sample_root_mean_squared_error: 0.6746
# Epoch 4/100
# 10/10 - 2s - loss: 1.9797 - output_loss: 0.4757 - output_sample_loss: 1.5040 - output_root_mean_squared_error: 0.6897 - output_sample_root_mean_squared_error: 1.2264 - val_loss: 1.2216 - val_output_loss: 0.5203 - val_output_sample_loss: 0.7014 - val_output_root_mean_squared_error: 0.7213 - val_output_sample_root_mean_squared_error: 0.8375
# Epoch 5/100
# 10/10 - 2s - loss: 2.0375 - output_loss: 0.5427 - output_sample_loss: 1.4948 - output_root_mean_squared_error: 0.7367 - output_sample_root_mean_squared_error: 1.2226 - val_loss: 0.9603 - val_output_loss: 0.3953 - val_output_sample_loss: 0.5650 - val_output_root_mean_squared_error: 0.6287 - val_output_sample_root_mean_squared_error: 0.7517
# Epoch 6/100
# 10/10 - 2s - loss: 1.8070 - output_loss: 0.4949 - output_sample_loss: 1.3122 - output_root_mean_squared_error: 0.7035 - output_sample_root_mean_squared_error: 1.1455 - val_loss: 1.3268 - val_output_loss: 0.7498 - val_output_sample_loss: 0.5770 - val_output_root_mean_squared_error: 0.8659 - val_output_sample_root_mean_squared_error: 0.7596
# Epoch 7/100
# 10/10 - 2s - loss: 1.5950 - output_loss: 0.3913 - output_sample_loss: 1.2037 - output_root_mean_squared_error: 0.6255 - output_sample_root_mean_squared_error: 1.0971 - val_loss: 1.0014 - val_output_loss: 0.5329 - val_output_sample_loss: 0.4685 - val_output_root_mean_squared_error: 0.7300 - val_output_sample_root_mean_squared_error: 0.6845
# Epoch 8/100
# 10/10 - 2s - loss: 2.0554 - output_loss: 0.5170 - output_sample_loss: 1.5384 - output_root_mean_squared_error: 0.7190 - output_sample_root_mean_squared_error: 1.2403 - val_loss: 1.0399 - val_output_loss: 0.5098 - val_output_sample_loss: 0.5301 - val_output_root_mean_squared_error: 0.7140 - val_output_sample_root_mean_squared_error: 0.7281
# Epoch 9/100
# 10/10 - 2s - loss: 1.8737 - output_loss: 0.4791 - output_sample_loss: 1.3946 - output_root_mean_squared_error: 0.6922 - output_sample_root_mean_squared_error: 1.1809 - val_loss: 0.9319 - val_output_loss: 0.4037 - val_output_sample_loss: 0.5282 - val_output_root_mean_squared_error: 0.6353 - val_output_sample_root_mean_squared_error: 0.7268
# Epoch 10/100
# 10/10 - 2s - loss: 1.8240 - output_loss: 0.5128 - output_sample_loss: 1.3113 - output_root_mean_squared_error: 0.7161 - output_sample_root_mean_squared_error: 1.1451 - val_loss: 0.9192 - val_output_loss: 0.4046 - val_output_sample_loss: 0.5147 - val_output_root_mean_squared_error: 0.6360 - val_output_sample_root_mean_squared_error: 0.7174
# Epoch 11/100
# 10/10 - 2s - loss: 1.8769 - output_loss: 0.3475 - output_sample_loss: 1.5294 - output_root_mean_squared_error: 0.5895 - output_sample_root_mean_squared_error: 1.2367 - val_loss: 1.2456 - val_output_loss: 0.5796 - val_output_sample_loss: 0.6659 - val_output_root_mean_squared_error: 0.7613 - val_output_sample_root_mean_squared_error: 0.8161
# Epoch 12/100
# 10/10 - 2s - loss: 1.8019 - output_loss: 0.3553 - output_sample_loss: 1.4467 - output_root_mean_squared_error: 0.5961 - output_sample_root_mean_squared_error: 1.2028 - val_loss: 0.6613 - val_output_loss: 0.3218 - val_output_sample_loss: 0.3395 - val_output_root_mean_squared_error: 0.5673 - val_output_sample_root_mean_squared_error: 0.5827
# Epoch 13/100
# 10/10 - 2s - loss: 1.5900 - output_loss: 0.2990 - output_sample_loss: 1.2910 - output_root_mean_squared_error: 0.5468 - output_sample_root_mean_squared_error: 1.1362 - val_loss: 0.7056 - val_output_loss: 0.3501 - val_output_sample_loss: 0.3555 - val_output_root_mean_squared_error: 0.5917 - val_output_sample_root_mean_squared_error: 0.5962
# Epoch 14/100
# 10/10 - 2s - loss: 1.3756 - output_loss: 0.2747 - output_sample_loss: 1.1009 - output_root_mean_squared_error: 0.5241 - output_sample_root_mean_squared_error: 1.0493 - val_loss: 1.2393 - val_output_loss: 0.5374 - val_output_sample_loss: 0.7019 - val_output_root_mean_squared_error: 0.7331 - val_output_sample_root_mean_squared_error: 0.8378
# Epoch 15/100
# 10/10 - 2s - loss: 1.5286 - output_loss: 0.2809 - output_sample_loss: 1.2477 - output_root_mean_squared_error: 0.5300 - output_sample_root_mean_squared_error: 1.1170 - val_loss: 0.7610 - val_output_loss: 0.3602 - val_output_sample_loss: 0.4008 - val_output_root_mean_squared_error: 0.6002 - val_output_sample_root_mean_squared_error: 0.6331
# Epoch 16/100
# 10/10 - 2s - loss: 1.6357 - output_loss: 0.2970 - output_sample_loss: 1.3387 - output_root_mean_squared_error: 0.5450 - output_sample_root_mean_squared_error: 1.1570 - val_loss: 0.7411 - val_output_loss: 0.3364 - val_output_sample_loss: 0.4047 - val_output_root_mean_squared_error: 0.5800 - val_output_sample_root_mean_squared_error: 0.6362
# Epoch 17/100
# 10/10 - 2s - loss: 1.5018 - output_loss: 0.2412 - output_sample_loss: 1.2605 - output_root_mean_squared_error: 0.4912 - output_sample_root_mean_squared_error: 1.1227 - val_loss: 0.8518 - val_output_loss: 0.3469 - val_output_sample_loss: 0.5049 - val_output_root_mean_squared_error: 0.5890 - val_output_sample_root_mean_squared_error: 0.7106
# Epoch 18/100
# 10/10 - 2s - loss: 1.4912 - output_loss: 0.2308 - output_sample_loss: 1.2604 - output_root_mean_squared_error: 0.4804 - output_sample_root_mean_squared_error: 1.1227 - val_loss: 0.7912 - val_output_loss: 0.3327 - val_output_sample_loss: 0.4585 - val_output_root_mean_squared_error: 0.5768 - val_output_sample_root_mean_squared_error: 0.6771
# Epoch 19/100
# 10/10 - 2s - loss: 1.3418 - output_loss: 0.2483 - output_sample_loss: 1.0935 - output_root_mean_squared_error: 0.4983 - output_sample_root_mean_squared_error: 1.0457 - val_loss: 0.7902 - val_output_loss: 0.3269 - val_output_sample_loss: 0.4633 - val_output_root_mean_squared_error: 0.5717 - val_output_sample_root_mean_squared_error: 0.6807
# Epoch 20/100
# 10/10 - 2s - loss: 1.5653 - output_loss: 0.2733 - output_sample_loss: 1.2920 - output_root_mean_squared_error: 0.5228 - output_sample_root_mean_squared_error: 1.1367 - val_loss: 0.7166 - val_output_loss: 0.3383 - val_output_sample_loss: 0.3783 - val_output_root_mean_squared_error: 0.5816 - val_output_sample_root_mean_squared_error: 0.6151
# Epoch 21/100
# 10/10 - 2s - loss: 1.3755 - output_loss: 0.2590 - output_sample_loss: 1.1165 - output_root_mean_squared_error: 0.5089 - output_sample_root_mean_squared_error: 1.0566 - val_loss: 1.0379 - val_output_loss: 0.5421 - val_output_sample_loss: 0.4958 - val_output_root_mean_squared_error: 0.7363 - val_output_sample_root_mean_squared_error: 0.7041
# Epoch 22/100
# 10/10 - 2s - loss: 1.3978 - output_loss: 0.2139 - output_sample_loss: 1.1839 - output_root_mean_squared_error: 0.4625 - output_sample_root_mean_squared_error: 1.0881 - val_loss: 0.6766 - val_output_loss: 0.3192 - val_output_sample_loss: 0.3574 - val_output_root_mean_squared_error: 0.5650 - val_output_sample_root_mean_squared_error: 0.5978
# Epoch 23/100
# 10/10 - 2s - loss: 1.4284 - output_loss: 0.2183 - output_sample_loss: 1.2101 - output_root_mean_squared_error: 0.4672 - output_sample_root_mean_squared_error: 1.1000 - val_loss: 0.7242 - val_output_loss: 0.3632 - val_output_sample_loss: 0.3611 - val_output_root_mean_squared_error: 0.6026 - val_output_sample_root_mean_squared_error: 0.6009
# Epoch 24/100
# 10/10 - 2s - loss: 1.3862 - output_loss: 0.2330 - output_sample_loss: 1.1533 - output_root_mean_squared_error: 0.4827 - output_sample_root_mean_squared_error: 1.0739 - val_loss: 0.6096 - val_output_loss: 0.2922 - val_output_sample_loss: 0.3173 - val_output_root_mean_squared_error: 0.5406 - val_output_sample_root_mean_squared_error: 0.5633
# Epoch 25/100
# 10/10 - 2s - loss: 1.4322 - output_loss: 0.1992 - output_sample_loss: 1.2330 - output_root_mean_squared_error: 0.4464 - output_sample_root_mean_squared_error: 1.1104 - val_loss: 0.6324 - val_output_loss: 0.3222 - val_output_sample_loss: 0.3102 - val_output_root_mean_squared_error: 0.5676 - val_output_sample_root_mean_squared_error: 0.5570
# Epoch 26/100
# 10/10 - 3s - loss: 1.2865 - output_loss: 0.1945 - output_sample_loss: 1.0921 - output_root_mean_squared_error: 0.4410 - output_sample_root_mean_squared_error: 1.0450 - val_loss: 0.7885 - val_output_loss: 0.3477 - val_output_sample_loss: 0.4408 - val_output_root_mean_squared_error: 0.5896 - val_output_sample_root_mean_squared_error: 0.6639
# Epoch 27/100
# 10/10 - 2s - loss: 1.3029 - output_loss: 0.1807 - output_sample_loss: 1.1222 - output_root_mean_squared_error: 0.4250 - output_sample_root_mean_squared_error: 1.0593 - val_loss: 0.6204 - val_output_loss: 0.3052 - val_output_sample_loss: 0.3152 - val_output_root_mean_squared_error: 0.5524 - val_output_sample_root_mean_squared_error: 0.5615
# Epoch 28/100
# 10/10 - 2s - loss: 1.3284 - output_loss: 0.2510 - output_sample_loss: 1.0774 - output_root_mean_squared_error: 0.5010 - output_sample_root_mean_squared_error: 1.0380 - val_loss: 0.5674 - val_output_loss: 0.2879 - val_output_sample_loss: 0.2794 - val_output_root_mean_squared_error: 0.5366 - val_output_sample_root_mean_squared_error: 0.5286
# Epoch 29/100
# 10/10 - 2s - loss: 1.4328 - output_loss: 0.2752 - output_sample_loss: 1.1577 - output_root_mean_squared_error: 0.5246 - output_sample_root_mean_squared_error: 1.0759 - val_loss: 1.7094 - val_output_loss: 0.8383 - val_output_sample_loss: 0.8711 - val_output_root_mean_squared_error: 0.9156 - val_output_sample_root_mean_squared_error: 0.9333
# Epoch 30/100
# 10/10 - 2s - loss: 1.6928 - output_loss: 0.2898 - output_sample_loss: 1.4030 - output_root_mean_squared_error: 0.5383 - output_sample_root_mean_squared_error: 1.1845 - val_loss: 0.7640 - val_output_loss: 0.3485 - val_output_sample_loss: 0.4155 - val_output_root_mean_squared_error: 0.5903 - val_output_sample_root_mean_squared_error: 0.6446
# Epoch 31/100
# 10/10 - 2s - loss: 1.3994 - output_loss: 0.2836 - output_sample_loss: 1.1158 - output_root_mean_squared_error: 0.5325 - output_sample_root_mean_squared_error: 1.0563 - val_loss: 0.6500 - val_output_loss: 0.3084 - val_output_sample_loss: 0.3416 - val_output_root_mean_squared_error: 0.5554 - val_output_sample_root_mean_squared_error: 0.5844
# Epoch 32/100
# 10/10 - 2s - loss: 1.2378 - output_loss: 0.1676 - output_sample_loss: 1.0702 - output_root_mean_squared_error: 0.4094 - output_sample_root_mean_squared_error: 1.0345 - val_loss: 0.7091 - val_output_loss: 0.3110 - val_output_sample_loss: 0.3980 - val_output_root_mean_squared_error: 0.5577 - val_output_sample_root_mean_squared_error: 0.6309
# Epoch 33/100
# 10/10 - 2s - loss: 1.4057 - output_loss: 0.1442 - output_sample_loss: 1.2614 - output_root_mean_squared_error: 0.3798 - output_sample_root_mean_squared_error: 1.1231 - val_loss: 1.2750 - val_output_loss: 0.5845 - val_output_sample_loss: 0.6905 - val_output_root_mean_squared_error: 0.7645 - val_output_sample_root_mean_squared_error: 0.8310
# Epoch 34/100
# 10/10 - 2s - loss: 1.2553 - output_loss: 0.1710 - output_sample_loss: 1.0843 - output_root_mean_squared_error: 0.4136 - output_sample_root_mean_squared_error: 1.0413 - val_loss: 0.6259 - val_output_loss: 0.3429 - val_output_sample_loss: 0.2830 - val_output_root_mean_squared_error: 0.5856 - val_output_sample_root_mean_squared_error: 0.5320
# Epoch 35/100
# 10/10 - 2s - loss: 1.2265 - output_loss: 0.1577 - output_sample_loss: 1.0688 - output_root_mean_squared_error: 0.3971 - output_sample_root_mean_squared_error: 1.0338 - val_loss: 0.9542 - val_output_loss: 0.5913 - val_output_sample_loss: 0.3629 - val_output_root_mean_squared_error: 0.7690 - val_output_sample_root_mean_squared_error: 0.6024
# Epoch 36/100
# 10/10 - 2s - loss: 1.1517 - output_loss: 0.1516 - output_sample_loss: 1.0001 - output_root_mean_squared_error: 0.3893 - output_sample_root_mean_squared_error: 1.0000 - val_loss: 1.2934 - val_output_loss: 0.6892 - val_output_sample_loss: 0.6042 - val_output_root_mean_squared_error: 0.8302 - val_output_sample_root_mean_squared_error: 0.7773
# Epoch 37/100
# 10/10 - 2s - loss: 1.3558 - output_loss: 0.1756 - output_sample_loss: 1.1802 - output_root_mean_squared_error: 0.4190 - output_sample_root_mean_squared_error: 1.0864 - val_loss: 0.7783 - val_output_loss: 0.4154 - val_output_sample_loss: 0.3629 - val_output_root_mean_squared_error: 0.6445 - val_output_sample_root_mean_squared_error: 0.6024
# Epoch 38/100
# 10/10 - 2s - loss: 1.2016 - output_loss: 0.1273 - output_sample_loss: 1.0743 - output_root_mean_squared_error: 0.3568 - output_sample_root_mean_squared_error: 1.0365 - val_loss: 0.7642 - val_output_loss: 0.3701 - val_output_sample_loss: 0.3941 - val_output_root_mean_squared_error: 0.6084 - val_output_sample_root_mean_squared_error: 0.6278
# Epoch 39/100
# 10/10 - 2s - loss: 1.1691 - output_loss: 0.1250 - output_sample_loss: 1.0441 - output_root_mean_squared_error: 0.3535 - output_sample_root_mean_squared_error: 1.0218 - val_loss: 0.6706 - val_output_loss: 0.3186 - val_output_sample_loss: 0.3520 - val_output_root_mean_squared_error: 0.5644 - val_output_sample_root_mean_squared_error: 0.5933
# Epoch 40/100
# 10/10 - 2s - loss: 1.2500 - output_loss: 0.1700 - output_sample_loss: 1.0801 - output_root_mean_squared_error: 0.4123 - output_sample_root_mean_squared_error: 1.0393 - val_loss: 1.0965 - val_output_loss: 0.5418 - val_output_sample_loss: 0.5547 - val_output_root_mean_squared_error: 0.7361 - val_output_sample_root_mean_squared_error: 0.7448
# Epoch 41/100
# 10/10 - 2s - loss: 1.2916 - output_loss: 0.1373 - output_sample_loss: 1.1544 - output_root_mean_squared_error: 0.3705 - output_sample_root_mean_squared_error: 1.0744 - val_loss: 0.6908 - val_output_loss: 0.3114 - val_output_sample_loss: 0.3793 - val_output_root_mean_squared_error: 0.5581 - val_output_sample_root_mean_squared_error: 0.6159
# Epoch 42/100
# 10/10 - 2s - loss: 1.2801 - output_loss: 0.1394 - output_sample_loss: 1.1406 - output_root_mean_squared_error: 0.3734 - output_sample_root_mean_squared_error: 1.0680 - val_loss: 0.7560 - val_output_loss: 0.3634 - val_output_sample_loss: 0.3925 - val_output_root_mean_squared_error: 0.6029 - val_output_sample_root_mean_squared_error: 0.6265
# Epoch 43/100
# 10/10 - 2s - loss: 1.4533 - output_loss: 0.1964 - output_sample_loss: 1.2569 - output_root_mean_squared_error: 0.4431 - output_sample_root_mean_squared_error: 1.1211 - val_loss: 1.2883 - val_output_loss: 0.6694 - val_output_sample_loss: 0.6189 - val_output_root_mean_squared_error: 0.8182 - val_output_sample_root_mean_squared_error: 0.7867
# Epoch 44/100
# 10/10 - 2s - loss: 1.4621 - output_loss: 0.1983 - output_sample_loss: 1.2638 - output_root_mean_squared_error: 0.4453 - output_sample_root_mean_squared_error: 1.1242 - val_loss: 0.8425 - val_output_loss: 0.3895 - val_output_sample_loss: 0.4530 - val_output_root_mean_squared_error: 0.6241 - val_output_sample_root_mean_squared_error: 0.6730
# Epoch 45/100
# 10/10 - 2s - loss: 1.1534 - output_loss: 0.1495 - output_sample_loss: 1.0039 - output_root_mean_squared_error: 0.3867 - output_sample_root_mean_squared_error: 1.0020 - val_loss: 0.7023 - val_output_loss: 0.3304 - val_output_sample_loss: 0.3719 - val_output_root_mean_squared_error: 0.5748 - val_output_sample_root_mean_squared_error: 0.6098
# Epoch 46/100
# 10/10 - 2s - loss: 1.2838 - output_loss: 0.1199 - output_sample_loss: 1.1639 - output_root_mean_squared_error: 0.3462 - output_sample_root_mean_squared_error: 1.0788 - val_loss: 0.9945 - val_output_loss: 0.3742 - val_output_sample_loss: 0.6202 - val_output_root_mean_squared_error: 0.6118 - val_output_sample_root_mean_squared_error: 0.7875
# Epoch 47/100
# 10/10 - 3s - loss: 1.2131 - output_loss: 0.1487 - output_sample_loss: 1.0643 - output_root_mean_squared_error: 0.3857 - output_sample_root_mean_squared_error: 1.0317 - val_loss: 0.9301 - val_output_loss: 0.4749 - val_output_sample_loss: 0.4551 - val_output_root_mean_squared_error: 0.6892 - val_output_sample_root_mean_squared_error: 0.6746
# Epoch 48/100
# 10/10 - 2s - loss: 1.1805 - output_loss: 0.1454 - output_sample_loss: 1.0351 - output_root_mean_squared_error: 0.3812 - output_sample_root_mean_squared_error: 1.0174 - val_loss: 0.8797 - val_output_loss: 0.5029 - val_output_sample_loss: 0.3768 - val_output_root_mean_squared_error: 0.7091 - val_output_sample_root_mean_squared_error: 0.6139
# Epoch 49/100
# 10/10 - 2s - loss: 1.5168 - output_loss: 0.2841 - output_sample_loss: 1.2327 - output_root_mean_squared_error: 0.5330 - output_sample_root_mean_squared_error: 1.1103 - val_loss: 0.6495 - val_output_loss: 0.3305 - val_output_sample_loss: 0.3190 - val_output_root_mean_squared_error: 0.5749 - val_output_sample_root_mean_squared_error: 0.5648
# Epoch 50/100
# 10/10 - 2s - loss: 1.3596 - output_loss: 0.2325 - output_sample_loss: 1.1271 - output_root_mean_squared_error: 0.4822 - output_sample_root_mean_squared_error: 1.0616 - val_loss: 0.8139 - val_output_loss: 0.4346 - val_output_sample_loss: 0.3793 - val_output_root_mean_squared_error: 0.6593 - val_output_sample_root_mean_squared_error: 0.6159
# Epoch 51/100
# 10/10 - 2s - loss: 1.4091 - output_loss: 0.1536 - output_sample_loss: 1.2555 - output_root_mean_squared_error: 0.3919 - output_sample_root_mean_squared_error: 1.1205 - val_loss: 0.8028 - val_output_loss: 0.4022 - val_output_sample_loss: 0.4006 - val_output_root_mean_squared_error: 0.6342 - val_output_sample_root_mean_squared_error: 0.6329
# Epoch 52/100
# 10/10 - 2s - loss: 1.1885 - output_loss: 0.1719 - output_sample_loss: 1.0167 - output_root_mean_squared_error: 0.4146 - output_sample_root_mean_squared_error: 1.0083 - val_loss: 1.0879 - val_output_loss: 0.6434 - val_output_sample_loss: 0.4446 - val_output_root_mean_squared_error: 0.8021 - val_output_sample_root_mean_squared_error: 0.6667
# Epoch 53/100
# 10/10 - 2s - loss: 1.2539 - output_loss: 0.1387 - output_sample_loss: 1.1152 - output_root_mean_squared_error: 0.3724 - output_sample_root_mean_squared_error: 1.0560 - val_loss: 0.9886 - val_output_loss: 0.5444 - val_output_sample_loss: 0.4443 - val_output_root_mean_squared_error: 0.7378 - val_output_sample_root_mean_squared_error: 0.6665
# Epoch 54/100
# 10/10 - 2s - loss: 1.3192 - output_loss: 0.1166 - output_sample_loss: 1.2027 - output_root_mean_squared_error: 0.3414 - output_sample_root_mean_squared_error: 1.0967 - val_loss: 1.1118 - val_output_loss: 0.6608 - val_output_sample_loss: 0.4510 - val_output_root_mean_squared_error: 0.8129 - val_output_sample_root_mean_squared_error: 0.6716
# Epoch 55/100
# 10/10 - 2s - loss: 1.0427 - output_loss: 0.1049 - output_sample_loss: 0.9378 - output_root_mean_squared_error: 0.3239 - output_sample_root_mean_squared_error: 0.9684 - val_loss: 0.6895 - val_output_loss: 0.3366 - val_output_sample_loss: 0.3529 - val_output_root_mean_squared_error: 0.5801 - val_output_sample_root_mean_squared_error: 0.5941
# Epoch 56/100
# 10/10 - 2s - loss: 1.4011 - output_loss: 0.1838 - output_sample_loss: 1.2173 - output_root_mean_squared_error: 0.4287 - output_sample_root_mean_squared_error: 1.1033 - val_loss: 1.4875 - val_output_loss: 0.7180 - val_output_sample_loss: 0.7695 - val_output_root_mean_squared_error: 0.8474 - val_output_sample_root_mean_squared_error: 0.8772
# Epoch 57/100
# 10/10 - 2s - loss: 1.1074 - output_loss: 0.1365 - output_sample_loss: 0.9709 - output_root_mean_squared_error: 0.3695 - output_sample_root_mean_squared_error: 0.9853 - val_loss: 1.0315 - val_output_loss: 0.5232 - val_output_sample_loss: 0.5083 - val_output_root_mean_squared_error: 0.7233 - val_output_sample_root_mean_squared_error: 0.7129
# Epoch 58/100
# 10/10 - 2s - loss: 1.1669 - output_loss: 0.1012 - output_sample_loss: 1.0657 - output_root_mean_squared_error: 0.3182 - output_sample_root_mean_squared_error: 1.0323 - val_loss: 0.7258 - val_output_loss: 0.3617 - val_output_sample_loss: 0.3640 - val_output_root_mean_squared_error: 0.6014 - val_output_sample_root_mean_squared_error: 0.6034
# Restoring model weights from the end of the best epoch.
# Epoch 00058: early stopping
# #### FOLD 1 OOF RMSE = 0.5366
# #### FOLD 1 OOF RMSE = 0.5286

# %% [markdown]
# ## Model loss and metrics graph

# %%
for fold, history in enumerate(history_list):
    print(f'\nFOLD: {fold+1}')
    plot_metrics(history)
# Out:
# FOLD: 1

# %% [markdown]
# # Model evaluation
#
# We are evaluating the model on the `OOF` predictions, it stands for `Out Of Fold`, since we are training using `K-Fold` our model will see all the data, and the correct way to evaluate each fold is by looking at the predictions that are not from that fold.
#
# ## OOF metrics

# %%
y_true = np.concatenate(oof_labels)
y_preds = np.concatenate(oof_pred)
y_preds2 = np.concatenate(oof_pred2)

for fold, history in enumerate(history_list):
    print(f"FOLD {fold+1} RMSE: {np.min(history['val_output_root_mean_squared_error']):.4f}")
    print(f"FOLD {fold+1} RMSE: {np.min(history['val_output_sample_root_mean_squared_error']):.4f}")
    
print(f'OOF RMSE: {mean_squared_error(y_true, y_preds, squared=False):.4f}')
print(f'OOF RMSE: {mean_squared_error(y_true, y_preds2, squared=False):.4f}')
# Out:
# FOLD 1 RMSE: 0.5366
# FOLD 1 RMSE: 0.5286
# OOF RMSE: 0.5366
# OOF RMSE: 0.5286

# %% [markdown]
# ### **Error analysis**, label x prediction distribution
#
# Here we can compare the distribution from the labels and the predicted values, in a perfect scenario they should align.

# %%
preds_df = pd.DataFrame({'Label': y_true, 'Prediction': y_preds[:,0], 'Prediction2': y_preds2[:,0]})

fig, ax = plt.subplots(1, 1, figsize=(20, 6))
sns.distplot(preds_df['Label'], ax=ax, label='Label')
sns.distplot(preds_df['Prediction'], ax=ax, label='Prediction')
ax.legend()
plt.show()

fig, ax = plt.subplots(1, 1, figsize=(20, 6))
sns.distplot(preds_df['Label'], ax=ax, label='Label')
sns.distplot(preds_df['Prediction'], ax=ax, label='Prediction')
ax.legend()
plt.show()

# %%
sns.jointplot(data=preds_df, x='Label', y='Prediction', kind='reg', height=10)
plt.show()
sns.jointplot(data=preds_df, x='Label', y='Prediction2', kind='reg', height=10)
plt.show()
