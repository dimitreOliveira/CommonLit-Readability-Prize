# %% [markdown]
# ## Dependencies

# %%
import random, os, warnings, math
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import tensorflow as tf
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
from tensorflow.keras import optimizers, losses, metrics, Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from transformers import TFAutoModelForSequenceClassification, TFAutoModel, AutoTokenizer


def seed_everything(seed=0):
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'

seed = 0
seed_everything(seed)
sns.set(style='whitegrid')
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 150)

# %% [markdown]
# ### Hardware configuration

# %%
# TPU or GPU detection
# Detect hardware, return appropriate distribution strategy
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print(f'Running on TPU {tpu.master()}')
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy()

AUTO = tf.data.experimental.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
print(f'REPLICAS: {REPLICAS}')
# Out:
# Running on TPU grpc://10.0.0.2:8470
# REPLICAS: 8

# %% [markdown]
# # Load data

# %%
train_filepath = '/kaggle/input/commonlitreadabilityprize/train.csv'
train = pd.read_csv(train_filepath)
print(f'Train samples: {len(train)}')
display(train.head())
# removing unused columns
train.drop(['url_legal', 'license'], axis=1, inplace=True)
# Out:
# Train samples: 2834
#           id url_legal license  \
# 0  c12129c31       NaN     NaN
# 1  85aa80a4c       NaN     NaN
# 2  b69ac6792       NaN     NaN
# 3  dd1000b26       NaN     NaN
# 4  37c1b32fb       NaN     NaN
#
#                                                                                                                                                  excerpt  \
# 0  When the young people returned to the ballroom, it presented a decidedly changed appearance. Instead of an interior scene, it was a winter landsca...
# 1  All through dinner time, Mrs. Fayre was somewhat silent, her eyes resting on Dolly with a wistful, uncertain expression. She wanted to give the ch...
# 2  As Roger had predicted, the snow departed as quickly as it came, and two days after their sleigh ride there was scarcely a vestige of white on the...
# 3  And outside before the palace a great garden was walled round, filled full of stately fruit-trees, gray olives and sweet figs, and pomegranates, p...
# 4  Once upon a time there were Three Bears who lived together in a house of their own in a wood. One of them was a Little, Small, Wee Bear; and one w...
#
#      target  standard_error
# 0 -0.340259        0.464009
# 1 -0.315372        0.480805
# 2 -0.580118        0.476676
# 3 -1.054013        0.450007
# 4  0.247197        0.510845

# %% [markdown]
# # Model parameters

# %%
BATCH_SIZE = 8 * REPLICAS
LEARNING_RATE = 1e-5 * REPLICAS
EPOCHS = 35
ES_PATIENCE = 10
PATIENCE = 2
N_FOLDS = 5
SEQ_LEN = 300
BASE_MODEL = '/kaggle/input/huggingface-roberta/roberta-base/'

# %% [markdown]
# ## Auxiliary functions

# %%
# Datasets utility functions
def custom_standardization(text):
    text = text.lower() # if encoder is uncased
    text = text.strip()
    return text


def sample_target(features, target):
    mean, stddev = target
    sampled_target = tf.random.normal([], mean=tf.cast(mean, dtype=tf.float32), 
                                      stddev=tf.cast(stddev, dtype=tf.float32), dtype=tf.float32)
    
    return (features, sampled_target)
    

def get_dataset(pandas_df, tokenizer, labeled=True, ordered=False, repeated=False, 
                is_sampled=False, batch_size=32, seq_len=128):
    """
        Return a Tensorflow dataset ready for training or inference.
    """
    text = [custom_standardization(text) for text in pandas_df['excerpt']]
    
    # Tokenize inputs
    tokenized_inputs = tokenizer(text, max_length=seq_len, truncation=True, 
                                 padding='max_length', return_tensors='tf')
    
    if labeled:
        dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': tokenized_inputs['input_ids'], 
                                                      'attention_mask': tokenized_inputs['attention_mask']}, 
                                                      (pandas_df['target'], pandas_df['standard_error'])))
        if is_sampled:
            dataset = dataset.map(sample_target, num_parallel_calls=tf.data.AUTOTUNE)
    else:
        dataset = tf.data.Dataset.from_tensor_slices({'input_ids': tokenized_inputs['input_ids'], 
                                                      'attention_mask': tokenized_inputs['attention_mask']})
        
    if repeated:
        dataset = dataset.repeat()
    if not ordered:
        dataset = dataset.shuffle(1024)
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    
    return dataset


def plot_metrics(history):
    metric_list = list(history.keys())
    size = len(metric_list)//2
    fig, axes = plt.subplots(size, 1, sharex='col', figsize=(20, size * 5))
    axes = axes.flatten()
    
    for index in range(len(metric_list)//2):
        metric_name = metric_list[index]
        val_metric_name = metric_list[index+size]
        axes[index].plot(history[metric_name], label='Train %s' % metric_name)
        axes[index].plot(history[val_metric_name], label='Validation %s' % metric_name)
        axes[index].legend(loc='best', fontsize=16)
        axes[index].set_title(metric_name)

    plt.xlabel('Epochs', fontsize=16)
    sns.despine()
    plt.show()

# %% [markdown]
# # Model

# %%
def model_fn(encoder, seq_len=256):
    input_ids = L.Input(shape=(seq_len,), dtype=tf.int32, name='input_ids')
    input_attention_mask = L.Input(shape=(seq_len,), dtype=tf.int32, name='attention_mask')
    
    outputs = encoder({'input_ids': input_ids, 
                       'attention_mask': input_attention_mask})
    last_hidden_state = outputs['last_hidden_state']
    
    x = L.GlobalAveragePooling1D()(last_hidden_state)
#     x = L.Dropout(.5)(x)
    output = L.Dense(1, name='output')(x)
    
    model = Model(inputs=[input_ids, input_attention_mask], outputs=output)

    optimizer = optimizers.Adam(lr=LEARNING_RATE)
    model.compile(optimizer=optimizer, 
                  loss=losses.MeanSquaredError(), 
                  metrics=[metrics.RootMeanSquaredError()])
    
    return model


with strategy.scope():
#     encoder = TFAutoModelForSequenceClassification.from_pretrained(BASE_MODEL, num_labels=1)
    encoder = TFAutoModel.from_pretrained(BASE_MODEL)
    model = model_fn(encoder, SEQ_LEN)
    
model.summary()
# Out:
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# attention_mask (InputLayer)     [(None, 300)]        0
# __________________________________________________________________________________________________
# input_ids (InputLayer)          [(None, 300)]        0
# __________________________________________________________________________________________________
# tf_roberta_model (TFRobertaMode TFBaseModelOutputWit 124645632   attention_mask[0][0]
#                                                                  input_ids[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 768)          0           tf_roberta_model[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            769         global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 124,646,401
# Trainable params: 124,646,401
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL)
skf = KFold(n_splits=N_FOLDS, shuffle=True, random_state=seed)
oof_pred = []; oof_labels = []; history_list = []

for fold,(idxT, idxV) in enumerate(skf.split(train)):
    if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    print(f'\nFOLD: {fold+1}')
    print(f'TRAIN: {len(idxT)} VALID: {len(idxV)}')

    # Model
    K.clear_session()
    with strategy.scope():
#         encoder = TFAutoModelForSequenceClassification.from_pretrained(BASE_MODEL, num_labels=1)
        encoder = TFAutoModel.from_pretrained(BASE_MODEL)
        model = model_fn(encoder, SEQ_LEN)
        
    model_path = f'model_{fold}.h5'
    es = EarlyStopping(monitor='val_root_mean_squared_error', mode='min', 
                       patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_root_mean_squared_error', mode='min', 
                                 save_best_only=True, save_weights_only=True)

    # Train
    history = model.fit(x=get_dataset(train.loc[idxT], tokenizer, repeated=True, is_sampled=True, 
                                      batch_size=BATCH_SIZE, seq_len=SEQ_LEN), 
                        validation_data=get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                                                    batch_size=BATCH_SIZE, seq_len=SEQ_LEN), 
                        steps_per_epoch=50, 
                        callbacks=[es, checkpoint], 
                        epochs=EPOCHS,  
                        verbose=2).history
      
    history_list.append(history)
    # Save last model weights
    model.load_weights(model_path)
    
    # Results
    print(f"#### FOLD {fold+1} OOF RMSE = {np.min(history['val_root_mean_squared_error']):.4f}")

    # OOF predictions
    valid_ds = get_dataset(train.loc[idxV], tokenizer, ordered=True, batch_size=BATCH_SIZE, seq_len=SEQ_LEN)
    oof_labels.append([target[0].numpy() for sample, target in iter(valid_ds.unbatch())])
    x_oof = valid_ds.map(lambda sample, target: sample)
    oof_pred.append(model.predict(x_oof))
# Out:
# FOLD: 1
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/35
# 50/50 - 93s - loss: 0.9684 - root_mean_squared_error: 0.9840 - val_loss: 0.4412 - val_root_mean_squared_error: 0.6642
# Epoch 2/35
# 50/50 - 7s - loss: 0.5472 - root_mean_squared_error: 0.7397 - val_loss: 0.3787 - val_root_mean_squared_error: 0.6154
# Epoch 3/35
# 50/50 - 6s - loss: 0.4477 - root_mean_squared_error: 0.6691 - val_loss: 0.3106 - val_root_mean_squared_error: 0.5573
# Epoch 4/35
# 50/50 - 6s - loss: 0.3985 - root_mean_squared_error: 0.6312 - val_loss: 0.3374 - val_root_mean_squared_error: 0.5809
# Epoch 5/35
# 50/50 - 6s - loss: 0.3640 - root_mean_squared_error: 0.6033 - val_loss: 0.4941 - val_root_mean_squared_error: 0.7029
# Epoch 6/35
# 50/50 - 6s - loss: 0.3607 - root_mean_squared_error: 0.6006 - val_loss: 0.4560 - val_root_mean_squared_error: 0.6752
# Epoch 7/35
# 50/50 - 6s - loss: 0.3505 - root_mean_squared_error: 0.5920 - val_loss: 0.3874 - val_root_mean_squared_error: 0.6224
# Epoch 8/35
# 50/50 - 6s - loss: 0.3430 - root_mean_squared_error: 0.5856 - val_loss: 0.4018 - val_root_mean_squared_error: 0.6339
# Epoch 9/35
# 50/50 - 6s - loss: 0.3590 - root_mean_squared_error: 0.5992 - val_loss: 0.3591 - val_root_mean_squared_error: 0.5993
# Epoch 10/35
# 50/50 - 6s - loss: 0.3177 - root_mean_squared_error: 0.5636 - val_loss: 0.3261 - val_root_mean_squared_error: 0.5711
# Epoch 11/35
# 50/50 - 6s - loss: 0.3274 - root_mean_squared_error: 0.5722 - val_loss: 0.5944 - val_root_mean_squared_error: 0.7710
# Epoch 12/35
# 50/50 - 6s - loss: 0.3152 - root_mean_squared_error: 0.5614 - val_loss: 0.3811 - val_root_mean_squared_error: 0.6174
# Epoch 13/35
# 50/50 - 6s - loss: 0.3123 - root_mean_squared_error: 0.5588 - val_loss: 0.6528 - val_root_mean_squared_error: 0.8080
# Restoring model weights from the end of the best epoch.
# Epoch 00013: early stopping
# #### FOLD 1 OOF RMSE = 0.5573
#
# FOLD: 2
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/35
# 50/50 - 102s - loss: 1.1089 - root_mean_squared_error: 1.0530 - val_loss: 0.4586 - val_root_mean_squared_error: 0.6772
# Epoch 2/35
# 50/50 - 6s - loss: 0.6012 - root_mean_squared_error: 0.7754 - val_loss: 0.4952 - val_root_mean_squared_error: 0.7037
# Epoch 3/35
# 50/50 - 6s - loss: 0.5239 - root_mean_squared_error: 0.7238 - val_loss: 0.3877 - val_root_mean_squared_error: 0.6227
# Epoch 4/35
# 50/50 - 6s - loss: 0.4811 - root_mean_squared_error: 0.6936 - val_loss: 0.3163 - val_root_mean_squared_error: 0.5624
# Epoch 5/35
# 50/50 - 6s - loss: 0.4696 - root_mean_squared_error: 0.6853 - val_loss: 0.3916 - val_root_mean_squared_error: 0.6258
# Epoch 6/35
# 50/50 - 6s - loss: 0.4256 - root_mean_squared_error: 0.6524 - val_loss: 0.3595 - val_root_mean_squared_error: 0.5996
# Epoch 7/35
# 50/50 - 6s - loss: 0.4008 - root_mean_squared_error: 0.6331 - val_loss: 0.3693 - val_root_mean_squared_error: 0.6077
# Epoch 8/35
# 50/50 - 6s - loss: 0.3559 - root_mean_squared_error: 0.5966 - val_loss: 0.4957 - val_root_mean_squared_error: 0.7040
# Epoch 9/35
# 50/50 - 6s - loss: 0.3795 - root_mean_squared_error: 0.6160 - val_loss: 0.3739 - val_root_mean_squared_error: 0.6115
# Epoch 10/35
# 50/50 - 6s - loss: 0.3575 - root_mean_squared_error: 0.5979 - val_loss: 0.5913 - val_root_mean_squared_error: 0.7690
# Epoch 11/35
# 50/50 - 6s - loss: 0.3363 - root_mean_squared_error: 0.5799 - val_loss: 0.3756 - val_root_mean_squared_error: 0.6128
# Epoch 12/35
# 50/50 - 6s - loss: 0.3057 - root_mean_squared_error: 0.5529 - val_loss: 0.4674 - val_root_mean_squared_error: 0.6837
# Epoch 13/35
# 50/50 - 6s - loss: 0.3181 - root_mean_squared_error: 0.5640 - val_loss: 0.4356 - val_root_mean_squared_error: 0.6600
# Epoch 14/35
# 50/50 - 6s - loss: 0.2971 - root_mean_squared_error: 0.5451 - val_loss: 0.3075 - val_root_mean_squared_error: 0.5546
# Epoch 15/35
# 50/50 - 6s - loss: 0.3310 - root_mean_squared_error: 0.5753 - val_loss: 0.6345 - val_root_mean_squared_error: 0.7965
# Epoch 16/35
# 50/50 - 6s - loss: 0.3946 - root_mean_squared_error: 0.6282 - val_loss: 0.3344 - val_root_mean_squared_error: 0.5783
# Epoch 17/35
# 50/50 - 6s - loss: 0.4364 - root_mean_squared_error: 0.6606 - val_loss: 0.3859 - val_root_mean_squared_error: 0.6212
# Epoch 18/35
# 50/50 - 6s - loss: 0.3559 - root_mean_squared_error: 0.5966 - val_loss: 0.4250 - val_root_mean_squared_error: 0.6519
# Epoch 19/35
# 50/50 - 6s - loss: 0.3700 - root_mean_squared_error: 0.6083 - val_loss: 0.3680 - val_root_mean_squared_error: 0.6067
# Epoch 20/35
# 50/50 - 6s - loss: 0.3218 - root_mean_squared_error: 0.5673 - val_loss: 0.5122 - val_root_mean_squared_error: 0.7157
# Epoch 21/35
# 50/50 - 6s - loss: 0.3298 - root_mean_squared_error: 0.5743 - val_loss: 0.4178 - val_root_mean_squared_error: 0.6464
# Epoch 22/35
# 50/50 - 6s - loss: 0.2940 - root_mean_squared_error: 0.5423 - val_loss: 0.3881 - val_root_mean_squared_error: 0.6230
# Epoch 23/35
# 50/50 - 6s - loss: 0.3172 - root_mean_squared_error: 0.5632 - val_loss: 0.3506 - val_root_mean_squared_error: 0.5921
# Epoch 24/35
# 50/50 - 6s - loss: 0.3425 - root_mean_squared_error: 0.5852 - val_loss: 0.6085 - val_root_mean_squared_error: 0.7800
# Restoring model weights from the end of the best epoch.
# Epoch 00024: early stopping
# #### FOLD 2 OOF RMSE = 0.5546
#
# FOLD: 3
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/35
# 50/50 - 96s - loss: 0.9954 - root_mean_squared_error: 0.9977 - val_loss: 0.3913 - val_root_mean_squared_error: 0.6255
# Epoch 2/35
# 50/50 - 6s - loss: 0.5724 - root_mean_squared_error: 0.7566 - val_loss: 0.4849 - val_root_mean_squared_error: 0.6964
# Epoch 3/35
# 50/50 - 6s - loss: 0.4606 - root_mean_squared_error: 0.6787 - val_loss: 0.5131 - val_root_mean_squared_error: 0.7163
# Epoch 4/35
# 50/50 - 6s - loss: 0.3872 - root_mean_squared_error: 0.6223 - val_loss: 0.4013 - val_root_mean_squared_error: 0.6335
# Epoch 5/35
# 50/50 - 6s - loss: 0.3594 - root_mean_squared_error: 0.5995 - val_loss: 0.3831 - val_root_mean_squared_error: 0.6190
# Epoch 6/35
# 50/50 - 6s - loss: 0.3438 - root_mean_squared_error: 0.5864 - val_loss: 0.3392 - val_root_mean_squared_error: 0.5824
# Epoch 7/35
# 50/50 - 6s - loss: 0.3462 - root_mean_squared_error: 0.5884 - val_loss: 0.3310 - val_root_mean_squared_error: 0.5753
# Epoch 8/35
# 50/50 - 6s - loss: 0.3289 - root_mean_squared_error: 0.5735 - val_loss: 0.3786 - val_root_mean_squared_error: 0.6153
# Epoch 9/35
# 50/50 - 6s - loss: 0.3342 - root_mean_squared_error: 0.5781 - val_loss: 0.3348 - val_root_mean_squared_error: 0.5786
# Epoch 10/35
# 50/50 - 6s - loss: 0.2989 - root_mean_squared_error: 0.5467 - val_loss: 0.3597 - val_root_mean_squared_error: 0.5997
# Epoch 11/35
# 50/50 - 7s - loss: 0.3297 - root_mean_squared_error: 0.5742 - val_loss: 0.3937 - val_root_mean_squared_error: 0.6275
# Epoch 12/35
# 50/50 - 6s - loss: 0.3398 - root_mean_squared_error: 0.5829 - val_loss: 0.4330 - val_root_mean_squared_error: 0.6580
# Epoch 13/35
# 50/50 - 6s - loss: 0.3157 - root_mean_squared_error: 0.5619 - val_loss: 0.3941 - val_root_mean_squared_error: 0.6278
# Epoch 14/35
# 50/50 - 6s - loss: 0.2972 - root_mean_squared_error: 0.5451 - val_loss: 0.3590 - val_root_mean_squared_error: 0.5991
# Epoch 15/35
# 50/50 - 6s - loss: 0.3230 - root_mean_squared_error: 0.5683 - val_loss: 0.4149 - val_root_mean_squared_error: 0.6441
# Epoch 16/35
# 50/50 - 6s - loss: 0.3039 - root_mean_squared_error: 0.5513 - val_loss: 0.3280 - val_root_mean_squared_error: 0.5727
# Epoch 17/35
# 50/50 - 6s - loss: 0.3033 - root_mean_squared_error: 0.5507 - val_loss: 0.2827 - val_root_mean_squared_error: 0.5317
# Epoch 18/35
# 50/50 - 6s - loss: 0.3042 - root_mean_squared_error: 0.5516 - val_loss: 0.5853 - val_root_mean_squared_error: 0.7651
# Epoch 19/35
# 50/50 - 6s - loss: 0.3046 - root_mean_squared_error: 0.5519 - val_loss: 0.4905 - val_root_mean_squared_error: 0.7004
# Epoch 20/35
# 50/50 - 6s - loss: 0.2956 - root_mean_squared_error: 0.5437 - val_loss: 0.3209 - val_root_mean_squared_error: 0.5665
# Epoch 21/35
# 50/50 - 6s - loss: 0.2910 - root_mean_squared_error: 0.5395 - val_loss: 0.3353 - val_root_mean_squared_error: 0.5790
# Epoch 22/35
# 50/50 - 6s - loss: 0.2890 - root_mean_squared_error: 0.5376 - val_loss: 0.3841 - val_root_mean_squared_error: 0.6198
# Epoch 23/35
# 50/50 - 7s - loss: 0.3081 - root_mean_squared_error: 0.5551 - val_loss: 0.3733 - val_root_mean_squared_error: 0.6110
# Epoch 24/35
# 50/50 - 6s - loss: 0.3028 - root_mean_squared_error: 0.5502 - val_loss: 0.2908 - val_root_mean_squared_error: 0.5393
# Epoch 25/35
# 50/50 - 6s - loss: 0.2763 - root_mean_squared_error: 0.5256 - val_loss: 0.3525 - val_root_mean_squared_error: 0.5937
# Epoch 26/35
# 50/50 - 6s - loss: 0.3014 - root_mean_squared_error: 0.5490 - val_loss: 0.2919 - val_root_mean_squared_error: 0.5403
# Epoch 27/35
# 50/50 - 6s - loss: 0.2820 - root_mean_squared_error: 0.5311 - val_loss: 0.3223 - val_root_mean_squared_error: 0.5677
# Restoring model weights from the end of the best epoch.
# Epoch 00027: early stopping
# #### FOLD 3 OOF RMSE = 0.5317
#
# FOLD: 4
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/35
# 50/50 - 96s - loss: 0.8367 - root_mean_squared_error: 0.9147 - val_loss: 0.3603 - val_root_mean_squared_error: 0.6002
# Epoch 2/35
# 50/50 - 6s - loss: 0.5380 - root_mean_squared_error: 0.7335 - val_loss: 0.3866 - val_root_mean_squared_error: 0.6218
# Epoch 3/35
# 50/50 - 6s - loss: 0.4692 - root_mean_squared_error: 0.6850 - val_loss: 0.5736 - val_root_mean_squared_error: 0.7573
# Epoch 4/35
# 50/50 - 6s - loss: 0.3724 - root_mean_squared_error: 0.6103 - val_loss: 0.4995 - val_root_mean_squared_error: 0.7068
# Epoch 5/35
# 50/50 - 6s - loss: 0.3623 - root_mean_squared_error: 0.6019 - val_loss: 0.3138 - val_root_mean_squared_error: 0.5601
# Epoch 6/35
# 50/50 - 6s - loss: 0.3715 - root_mean_squared_error: 0.6095 - val_loss: 0.4255 - val_root_mean_squared_error: 0.6523
# Epoch 7/35
# 50/50 - 6s - loss: 0.3525 - root_mean_squared_error: 0.5937 - val_loss: 0.3388 - val_root_mean_squared_error: 0.5821
# Epoch 8/35
# 50/50 - 6s - loss: 0.3658 - root_mean_squared_error: 0.6048 - val_loss: 0.5482 - val_root_mean_squared_error: 0.7404
# Epoch 9/35
# 50/50 - 6s - loss: 0.3118 - root_mean_squared_error: 0.5584 - val_loss: 0.3643 - val_root_mean_squared_error: 0.6035
# Epoch 10/35
# 50/50 - 6s - loss: 0.3047 - root_mean_squared_error: 0.5520 - val_loss: 0.3164 - val_root_mean_squared_error: 0.5625
# Epoch 11/35
# 50/50 - 6s - loss: 0.3228 - root_mean_squared_error: 0.5681 - val_loss: 0.5089 - val_root_mean_squared_error: 0.7134
# Epoch 12/35
# 50/50 - 6s - loss: 0.3223 - root_mean_squared_error: 0.5677 - val_loss: 0.4656 - val_root_mean_squared_error: 0.6824
# Epoch 13/35
# 50/50 - 6s - loss: 0.3356 - root_mean_squared_error: 0.5793 - val_loss: 0.6315 - val_root_mean_squared_error: 0.7947
# Epoch 14/35
# 50/50 - 6s - loss: 0.3440 - root_mean_squared_error: 0.5865 - val_loss: 0.4121 - val_root_mean_squared_error: 0.6420
# Epoch 15/35
# 50/50 - 6s - loss: 0.2784 - root_mean_squared_error: 0.5277 - val_loss: 0.4104 - val_root_mean_squared_error: 0.6407
# Restoring model weights from the end of the best epoch.
# Epoch 00015: early stopping
# #### FOLD 4 OOF RMSE = 0.5601
#
# FOLD: 5
# TRAIN: 2268 VALID: 566
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/35
# 50/50 - 98s - loss: 1.0933 - root_mean_squared_error: 1.0456 - val_loss: 0.6014 - val_root_mean_squared_error: 0.7755
# Epoch 2/35
# 50/50 - 6s - loss: 0.5682 - root_mean_squared_error: 0.7538 - val_loss: 0.3092 - val_root_mean_squared_error: 0.5560
# Epoch 3/35
# 50/50 - 6s - loss: 0.4788 - root_mean_squared_error: 0.6920 - val_loss: 0.3542 - val_root_mean_squared_error: 0.5952
# Epoch 4/35
# 50/50 - 6s - loss: 0.3880 - root_mean_squared_error: 0.6229 - val_loss: 0.4835 - val_root_mean_squared_error: 0.6953
# Epoch 5/35
# 50/50 - 6s - loss: 0.3634 - root_mean_squared_error: 0.6028 - val_loss: 0.2847 - val_root_mean_squared_error: 0.5335
# Epoch 6/35
# 50/50 - 6s - loss: 0.3367 - root_mean_squared_error: 0.5803 - val_loss: 0.3194 - val_root_mean_squared_error: 0.5652
# Epoch 7/35
# 50/50 - 6s - loss: 0.3418 - root_mean_squared_error: 0.5847 - val_loss: 0.3159 - val_root_mean_squared_error: 0.5620
# Epoch 8/35
# 50/50 - 7s - loss: 0.3449 - root_mean_squared_error: 0.5873 - val_loss: 0.5637 - val_root_mean_squared_error: 0.7508
# Epoch 9/35
# 50/50 - 6s - loss: 0.3182 - root_mean_squared_error: 0.5641 - val_loss: 0.4030 - val_root_mean_squared_error: 0.6348
# Epoch 10/35
# 50/50 - 6s - loss: 0.3530 - root_mean_squared_error: 0.5941 - val_loss: 0.4279 - val_root_mean_squared_error: 0.6541
# Epoch 11/35
# 50/50 - 6s - loss: 0.2954 - root_mean_squared_error: 0.5435 - val_loss: 0.3807 - val_root_mean_squared_error: 0.6170
# Epoch 12/35
# 50/50 - 6s - loss: 0.2986 - root_mean_squared_error: 0.5464 - val_loss: 0.3063 - val_root_mean_squared_error: 0.5534
# Epoch 13/35
# 50/50 - 6s - loss: 0.2790 - root_mean_squared_error: 0.5282 - val_loss: 0.4907 - val_root_mean_squared_error: 0.7005
# Epoch 14/35
# 50/50 - 6s - loss: 0.2755 - root_mean_squared_error: 0.5249 - val_loss: 0.4055 - val_root_mean_squared_error: 0.6368
# Epoch 15/35
# 50/50 - 6s - loss: 0.2912 - root_mean_squared_error: 0.5396 - val_loss: 0.3357 - val_root_mean_squared_error: 0.5794
# Restoring model weights from the end of the best epoch.
# Epoch 00015: early stopping
# #### FOLD 5 OOF RMSE = 0.5335

# %% [markdown]
# ## Model loss and metrics graph

# %%
for fold, history in enumerate(history_list):
    print(f'\nFOLD: {fold+1}')
    plot_metrics(history)
# Out:
# FOLD: 1
# FOLD: 2
# FOLD: 3
# FOLD: 4
# FOLD: 5

# %% [markdown]
# # Model evaluation
#
# We are evaluating the model on the `OOF` predictions, it stands for `Out Of Fold`, since we are training using `K-Fold` our model will see all the data, and the correct way to evaluate each fold is by looking at the predictions that are not from that fold.
#
# ## OOF metrics

# %%
y_true = np.concatenate(oof_labels)
y_preds = np.concatenate(oof_pred)


for fold, history in enumerate(history_list):
    print(f"FOLD {fold+1} RMSE: {np.min(history['val_root_mean_squared_error']):.4f}")
    
print(f'OOF RMSE: {mean_squared_error(y_true, y_preds, squared=False):.4f}')
# Out:
# FOLD 1 RMSE: 0.5573
# FOLD 2 RMSE: 0.5546
# FOLD 3 RMSE: 0.5317
# FOLD 4 RMSE: 0.5601
# FOLD 5 RMSE: 0.5335
# OOF RMSE: 0.5476

# %% [markdown]
# ### **Error analysis**, label x prediction distribution
#
# Here we can compare the distribution from the labels and the predicted values, in a perfect scenario they should align.

# %%
preds_df = pd.DataFrame({'Label': y_true, 'Prediction': y_preds[:,0]})

fig, ax = plt.subplots(1, 1, figsize=(20, 6))
sns.distplot(preds_df['Label'], ax=ax, label='Label')
sns.distplot(preds_df['Prediction'], ax=ax, label='Prediction')
ax.legend()
plt.show()

# %%
sns.jointplot(data=preds_df, x='Label', y='Prediction', kind='reg', height=10)
plt.show()
