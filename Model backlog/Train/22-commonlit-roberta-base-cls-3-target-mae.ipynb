# %% [markdown]
# ## Dependencies

# %%
import warnings, math, json
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import tensorflow_addons as tfa
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
from tensorflow.keras import optimizers, losses, metrics, Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from transformers import TFAutoModelForSequenceClassification, TFAutoModel, AutoTokenizer
from commonlit_scripts import *


seed = 0
seed_everything(seed)
sns.set(style='whitegrid')
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 150)

# %% [markdown]
# ### Hardware configuration

# %%
strategy, tpu = get_strategy()
AUTO = tf.data.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
print(f'REPLICAS: {REPLICAS}')
# Out:
# Running on TPU grpc://10.0.0.2:8470
# REPLICAS: 8

# %% [markdown]
# # Load data

# %%
train_filepath = '/kaggle/input/commonlitreadabilityprize/train.csv'
train = pd.read_csv(train_filepath)
print(f'Train samples: {len(train)}')
# removing unused columns
train.drop(['url_legal', 'license'], axis=1, inplace=True)
display(train.head())
# Out:
# Train samples: 2834
#           id  \
# 0  c12129c31
# 1  85aa80a4c
# 2  b69ac6792
# 3  dd1000b26
# 4  37c1b32fb
#
#                                                                                                                                                  excerpt  \
# 0  When the young people returned to the ballroom, it presented a decidedly changed appearance. Instead of an interior scene, it was a winter landsca...
# 1  All through dinner time, Mrs. Fayre was somewhat silent, her eyes resting on Dolly with a wistful, uncertain expression. She wanted to give the ch...
# 2  As Roger had predicted, the snow departed as quickly as it came, and two days after their sleigh ride there was scarcely a vestige of white on the...
# 3  And outside before the palace a great garden was walled round, filled full of stately fruit-trees, gray olives and sweet figs, and pomegranates, p...
# 4  Once upon a time there were Three Bears who lived together in a house of their own in a wood. One of them was a Little, Small, Wee Bear; and one w...
#
#      target  standard_error
# 0 -0.340259        0.464009
# 1 -0.315372        0.480805
# 2 -0.580118        0.476676
# 3 -1.054013        0.450007
# 4  0.247197        0.510845

# %% [markdown]
# # Model parameters

# %%
config = {
  "BATCH_SIZE": 8 * REPLICAS,
  "LEARNING_RATE": 1e-5 * REPLICAS,
  "EPOCHS": 100,
  "ES_PATIENCE": 30,
  "N_FOLDS": 5,
  "N_USED_FOLDS": 1,
  "SEQ_LEN": 256,
  "BASE_MODEL": '/kaggle/input/huggingface-roberta/roberta-base/',
  "SEED": seed,
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# ## Auxiliary functions

# %%
# Datasets utility functions
def custom_standardization(text, is_lower=True):
    if is_lower:
        text = text.lower() # if encoder is uncased
    text = text.strip()
    return text

def sample_target(features, target):
    mean, stddev, _ = target
    sampled_target = tf.random.normal([], mean=tf.cast(mean, dtype=tf.float32), 
                                      stddev=tf.cast(stddev, dtype=tf.float32), dtype=tf.float32)
    return (features, (mean, stddev, sampled_target))
    
def get_dataset(pandas_df, tokenizer, labeled=True, ordered=False, repeated=False, 
                is_sampled=False, batch_size=32, seq_len=128, is_lower=True):
    """
        Return a Tensorflow dataset ready for training or inference.
    """
    text = [custom_standardization(text, is_lower) for text in pandas_df['excerpt']]
    
    # Tokenize inputs
    tokenized_inputs = tokenizer(text, max_length=seq_len, truncation=True, 
                                 padding='max_length', return_tensors='tf')
    
    if labeled:
        dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': tokenized_inputs['input_ids'], 
                                                       'attention_mask': tokenized_inputs['attention_mask']}, 
                                                      (pandas_df['target'], pandas_df['standard_error'], pandas_df['target'])))
        if is_sampled:
            dataset = dataset.map(sample_target, num_parallel_calls=tf.data.AUTOTUNE)
    else:
        dataset = tf.data.Dataset.from_tensor_slices({'input_ids': tokenized_inputs['input_ids'], 
                                                      'attention_mask': tokenized_inputs['attention_mask']})
        
    if repeated:
        dataset = dataset.repeat()
    if not ordered:
        dataset = dataset.shuffle(2048)
    dataset = dataset.batch(batch_size)
    dataset = dataset.cache()
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# %% [markdown]
# # Model

# %%
def model_fn(encoder, seq_len=256):
    input_ids = L.Input(shape=(seq_len,), dtype=tf.int32, name='input_ids')
    input_attention_mask = L.Input(shape=(seq_len,), dtype=tf.int32, name='attention_mask')
    
    outputs = encoder({'input_ids': input_ids,  
                       'attention_mask': input_attention_mask})
    last_hidden_state = outputs['last_hidden_state']
    
    cls_token = last_hidden_state[:, 0, :]
#     x = L.GlobalAveragePooling1D()(last_hidden_state)
    output = L.Dense(1, name='output')(cls_token)
    output_stddev = L.Dense(1, name='output_stddev')(cls_token)
    output_samp = L.Dense(1, name='output_samp')(cls_token)
    
    model = Model(inputs=[input_ids, input_attention_mask], 
                  outputs=[output, output_stddev, output_samp])

    optimizer = optimizers.Adam(lr=config['LEARNING_RATE'])
    model.compile(optimizer=optimizer, 
                  loss=losses.MeanAbsoluteError(), 
                  metrics=[metrics.RootMeanSquaredError()])
    return model


with strategy.scope():
    encoder = TFAutoModel.from_pretrained(config['BASE_MODEL'])
    model = model_fn(encoder, config['SEQ_LEN'])
    
model.summary()
# Out:
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# attention_mask (InputLayer)     [(None, 256)]        0
# __________________________________________________________________________________________________
# input_ids (InputLayer)          [(None, 256)]        0
# __________________________________________________________________________________________________
# tf_roberta_model (TFRobertaMode TFBaseModelOutputWit 124645632   attention_mask[0][0]
#                                                                  input_ids[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici (None, 768)          0           tf_roberta_model[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            769         tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# output_stddev (Dense)           (None, 1)            769         tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# output_samp (Dense)             (None, 1)            769         tf.__operators__.getitem[0][0]
# ==================================================================================================
# Total params: 124,647,939
# Trainable params: 124,647,939
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
tokenizer = AutoTokenizer.from_pretrained(config['BASE_MODEL'])
skf = KFold(n_splits=config['N_FOLDS'], shuffle=True, random_state=seed)
oof_pred = []; oof_labels = []; history_list = []


for fold,(idxT, idxV) in enumerate(skf.split(train)):
    if fold >= config['N_USED_FOLDS']:
        break
    if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    print(f'\nFOLD: {fold+1}')
    print(f'TRAIN: {len(idxT)} VALID: {len(idxV)}')
    
    # Model
    K.clear_session()
    with strategy.scope():
        encoder = TFAutoModel.from_pretrained(config['BASE_MODEL'])
        model = model_fn(encoder, seq_len=config['SEQ_LEN'])

    model_path = f'model_{fold}.h5'
    es = EarlyStopping(monitor='val_output_root_mean_squared_error', mode='min', 
                       patience=config['ES_PATIENCE'], restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_output_root_mean_squared_error', mode='min', 
                                 save_best_only=True, save_weights_only=True)

    # Train
    history = model.fit(x=get_dataset(train.loc[idxT], tokenizer, repeated=True, is_sampled=True, 
                                      batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN']), 
                        validation_data=get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                                                    batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN']), 
                        steps_per_epoch=10, 
                        callbacks=[es, checkpoint], 
                        epochs=config['EPOCHS'],  
                        verbose=2).history

    history_list.append(history)
    # Save last model weights
    model.load_weights(model_path)

    # Results
    print(f"#### FOLD {fold+1} OOF RMSE = {np.min(history['val_output_root_mean_squared_error']):.4f}")
    print(f"#### FOLD {fold+1} OOF RMSE = {np.min(history['val_output_samp_root_mean_squared_error']):.4f}")

    # OOF predictions
    valid_ds = get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                           batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN'])
    oof_labels.append([target[0].numpy() for sample, target in iter(valid_ds.unbatch())])
    x_oof = valid_ds.map(lambda sample, target: sample)
    oof_pred.append(model.predict(x_oof)[0])
# Out:
# FOLD: 1
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/100
# 10/10 - 88s - loss: 2.2034 - output_loss: 0.9247 - output_stddev_loss: 0.2150 - output_samp_loss: 1.0637 - output_root_mean_squared_error: 1.1699 - output_stddev_root_mean_squared_error: 0.3172 - output_samp_root_mean_squared_error: 1.3623 - val_loss: 1.7006 - val_output_loss: 0.7985 - val_output_stddev_loss: 0.0667 - val_output_samp_loss: 0.8353 - val_output_root_mean_squared_error: 0.9791 - val_output_stddev_root_mean_squared_error: 0.0773 - val_output_samp_root_mean_squared_error: 1.0296
# Epoch 2/100
# 10/10 - 2s - loss: 1.7322 - output_loss: 0.7447 - output_stddev_loss: 0.1170 - output_samp_loss: 0.8706 - output_root_mean_squared_error: 0.9428 - output_stddev_root_mean_squared_error: 0.1865 - output_samp_root_mean_squared_error: 1.0727 - val_loss: 1.5215 - val_output_loss: 0.6777 - val_output_stddev_loss: 0.1393 - val_output_samp_loss: 0.7045 - val_output_root_mean_squared_error: 0.8393 - val_output_stddev_root_mean_squared_error: 0.1451 - val_output_samp_root_mean_squared_error: 0.8627
# Epoch 3/100
# 10/10 - 2s - loss: 1.5655 - output_loss: 0.6405 - output_stddev_loss: 0.1641 - output_samp_loss: 0.7609 - output_root_mean_squared_error: 0.8115 - output_stddev_root_mean_squared_error: 0.2342 - output_samp_root_mean_squared_error: 0.9608 - val_loss: 1.2467 - val_output_loss: 0.5225 - val_output_stddev_loss: 0.1823 - val_output_samp_loss: 0.5419 - val_output_root_mean_squared_error: 0.6626 - val_output_stddev_root_mean_squared_error: 0.1887 - val_output_samp_root_mean_squared_error: 0.6839
# Epoch 4/100
# 10/10 - 2s - loss: 1.4597 - output_loss: 0.5775 - output_stddev_loss: 0.1658 - output_samp_loss: 0.7165 - output_root_mean_squared_error: 0.7243 - output_stddev_root_mean_squared_error: 0.2171 - output_samp_root_mean_squared_error: 0.8965 - val_loss: 1.1019 - val_output_loss: 0.4974 - val_output_stddev_loss: 0.0751 - val_output_samp_loss: 0.5294 - val_output_root_mean_squared_error: 0.6237 - val_output_stddev_root_mean_squared_error: 0.0809 - val_output_samp_root_mean_squared_error: 0.6633
# Epoch 5/100
# 10/10 - 2s - loss: 1.3010 - output_loss: 0.5201 - output_stddev_loss: 0.1134 - output_samp_loss: 0.6676 - output_root_mean_squared_error: 0.6647 - output_stddev_root_mean_squared_error: 0.1667 - output_samp_root_mean_squared_error: 0.8588 - val_loss: 1.1122 - val_output_loss: 0.5114 - val_output_stddev_loss: 0.0765 - val_output_samp_loss: 0.5243 - val_output_root_mean_squared_error: 0.6535 - val_output_stddev_root_mean_squared_error: 0.0933 - val_output_samp_root_mean_squared_error: 0.6639
# Epoch 6/100
# 10/10 - 2s - loss: 1.2329 - output_loss: 0.4933 - output_stddev_loss: 0.1023 - output_samp_loss: 0.6373 - output_root_mean_squared_error: 0.6385 - output_stddev_root_mean_squared_error: 0.1457 - output_samp_root_mean_squared_error: 0.7971 - val_loss: 1.1454 - val_output_loss: 0.5696 - val_output_stddev_loss: 0.0542 - val_output_samp_loss: 0.5216 - val_output_root_mean_squared_error: 0.7156 - val_output_stddev_root_mean_squared_error: 0.0739 - val_output_samp_root_mean_squared_error: 0.6523
# Epoch 7/100
# 10/10 - 2s - loss: 1.2525 - output_loss: 0.5057 - output_stddev_loss: 0.1012 - output_samp_loss: 0.6457 - output_root_mean_squared_error: 0.6379 - output_stddev_root_mean_squared_error: 0.1504 - output_samp_root_mean_squared_error: 0.8229 - val_loss: 1.1965 - val_output_loss: 0.5870 - val_output_stddev_loss: 0.0797 - val_output_samp_loss: 0.5299 - val_output_root_mean_squared_error: 0.7320 - val_output_stddev_root_mean_squared_error: 0.0884 - val_output_samp_root_mean_squared_error: 0.6580
# Epoch 8/100
# 10/10 - 2s - loss: 1.2279 - output_loss: 0.4961 - output_stddev_loss: 0.1155 - output_samp_loss: 0.6163 - output_root_mean_squared_error: 0.6227 - output_stddev_root_mean_squared_error: 0.1707 - output_samp_root_mean_squared_error: 0.7718 - val_loss: 1.3139 - val_output_loss: 0.6448 - val_output_stddev_loss: 0.0613 - val_output_samp_loss: 0.6078 - val_output_root_mean_squared_error: 0.7909 - val_output_stddev_root_mean_squared_error: 0.0869 - val_output_samp_root_mean_squared_error: 0.7511
# Epoch 9/100
# 10/10 - 2s - loss: 1.2496 - output_loss: 0.5125 - output_stddev_loss: 0.1106 - output_samp_loss: 0.6266 - output_root_mean_squared_error: 0.6413 - output_stddev_root_mean_squared_error: 0.1560 - output_samp_root_mean_squared_error: 0.7957 - val_loss: 1.1047 - val_output_loss: 0.4695 - val_output_stddev_loss: 0.1303 - val_output_samp_loss: 0.5049 - val_output_root_mean_squared_error: 0.5885 - val_output_stddev_root_mean_squared_error: 0.1431 - val_output_samp_root_mean_squared_error: 0.6352
# Epoch 10/100
# 10/10 - 2s - loss: 1.1901 - output_loss: 0.4388 - output_stddev_loss: 0.1119 - output_samp_loss: 0.6394 - output_root_mean_squared_error: 0.5676 - output_stddev_root_mean_squared_error: 0.1580 - output_samp_root_mean_squared_error: 0.8058 - val_loss: 1.0510 - val_output_loss: 0.5088 - val_output_stddev_loss: 0.0288 - val_output_samp_loss: 0.5134 - val_output_root_mean_squared_error: 0.6383 - val_output_stddev_root_mean_squared_error: 0.0397 - val_output_samp_root_mean_squared_error: 0.6429
# Epoch 11/100
# 10/10 - 2s - loss: 1.1603 - output_loss: 0.4641 - output_stddev_loss: 0.0852 - output_samp_loss: 0.6110 - output_root_mean_squared_error: 0.5933 - output_stddev_root_mean_squared_error: 0.1194 - output_samp_root_mean_squared_error: 0.7639 - val_loss: 0.9823 - val_output_loss: 0.4719 - val_output_stddev_loss: 0.0305 - val_output_samp_loss: 0.4799 - val_output_root_mean_squared_error: 0.5920 - val_output_stddev_root_mean_squared_error: 0.0408 - val_output_samp_root_mean_squared_error: 0.5989
# Epoch 12/100
# 10/10 - 2s - loss: 1.1028 - output_loss: 0.4410 - output_stddev_loss: 0.0814 - output_samp_loss: 0.5804 - output_root_mean_squared_error: 0.5550 - output_stddev_root_mean_squared_error: 0.1165 - output_samp_root_mean_squared_error: 0.7328 - val_loss: 1.2958 - val_output_loss: 0.6364 - val_output_stddev_loss: 0.0507 - val_output_samp_loss: 0.6088 - val_output_root_mean_squared_error: 0.7825 - val_output_stddev_root_mean_squared_error: 0.0651 - val_output_samp_root_mean_squared_error: 0.7507
# Epoch 13/100
# 10/10 - 2s - loss: 1.1602 - output_loss: 0.4505 - output_stddev_loss: 0.0824 - output_samp_loss: 0.6274 - output_root_mean_squared_error: 0.5651 - output_stddev_root_mean_squared_error: 0.1243 - output_samp_root_mean_squared_error: 0.7783 - val_loss: 1.2505 - val_output_loss: 0.6443 - val_output_stddev_loss: 0.0493 - val_output_samp_loss: 0.5568 - val_output_root_mean_squared_error: 0.7839 - val_output_stddev_root_mean_squared_error: 0.0603 - val_output_samp_root_mean_squared_error: 0.6869
# Epoch 14/100
# 10/10 - 2s - loss: 1.1418 - output_loss: 0.4601 - output_stddev_loss: 0.0828 - output_samp_loss: 0.5990 - output_root_mean_squared_error: 0.5897 - output_stddev_root_mean_squared_error: 0.1279 - output_samp_root_mean_squared_error: 0.7462 - val_loss: 0.9972 - val_output_loss: 0.4916 - val_output_stddev_loss: 0.0631 - val_output_samp_loss: 0.4425 - val_output_root_mean_squared_error: 0.6198 - val_output_stddev_root_mean_squared_error: 0.0713 - val_output_samp_root_mean_squared_error: 0.5584
# Epoch 15/100
# 10/10 - 2s - loss: 1.0323 - output_loss: 0.3991 - output_stddev_loss: 0.0862 - output_samp_loss: 0.5470 - output_root_mean_squared_error: 0.5102 - output_stddev_root_mean_squared_error: 0.1324 - output_samp_root_mean_squared_error: 0.6879 - val_loss: 1.0639 - val_output_loss: 0.4829 - val_output_stddev_loss: 0.0289 - val_output_samp_loss: 0.5521 - val_output_root_mean_squared_error: 0.6027 - val_output_stddev_root_mean_squared_error: 0.0368 - val_output_samp_root_mean_squared_error: 0.6807
# Epoch 16/100
# 10/10 - 2s - loss: 1.0552 - output_loss: 0.4000 - output_stddev_loss: 0.0919 - output_samp_loss: 0.5633 - output_root_mean_squared_error: 0.5060 - output_stddev_root_mean_squared_error: 0.1329 - output_samp_root_mean_squared_error: 0.7026 - val_loss: 1.0525 - val_output_loss: 0.4935 - val_output_stddev_loss: 0.0962 - val_output_samp_loss: 0.4628 - val_output_root_mean_squared_error: 0.6254 - val_output_stddev_root_mean_squared_error: 0.1179 - val_output_samp_root_mean_squared_error: 0.5813
# Epoch 17/100
# 10/10 - 2s - loss: 1.0703 - output_loss: 0.4013 - output_stddev_loss: 0.1026 - output_samp_loss: 0.5663 - output_root_mean_squared_error: 0.5137 - output_stddev_root_mean_squared_error: 0.1398 - output_samp_root_mean_squared_error: 0.7132 - val_loss: 0.9236 - val_output_loss: 0.4303 - val_output_stddev_loss: 0.0492 - val_output_samp_loss: 0.4441 - val_output_root_mean_squared_error: 0.5411 - val_output_stddev_root_mean_squared_error: 0.0575 - val_output_samp_root_mean_squared_error: 0.5581
# Epoch 18/100
# 10/10 - 2s - loss: 1.0126 - output_loss: 0.3839 - output_stddev_loss: 0.0806 - output_samp_loss: 0.5480 - output_root_mean_squared_error: 0.4761 - output_stddev_root_mean_squared_error: 0.1199 - output_samp_root_mean_squared_error: 0.6901 - val_loss: 0.9115 - val_output_loss: 0.4329 - val_output_stddev_loss: 0.0378 - val_output_samp_loss: 0.4408 - val_output_root_mean_squared_error: 0.5487 - val_output_stddev_root_mean_squared_error: 0.0499 - val_output_samp_root_mean_squared_error: 0.5576
# Epoch 19/100
# 10/10 - 2s - loss: 0.9157 - output_loss: 0.3245 - output_stddev_loss: 0.0731 - output_samp_loss: 0.5182 - output_root_mean_squared_error: 0.4165 - output_stddev_root_mean_squared_error: 0.1088 - output_samp_root_mean_squared_error: 0.6524 - val_loss: 0.9471 - val_output_loss: 0.4777 - val_output_stddev_loss: 0.0237 - val_output_samp_loss: 0.4457 - val_output_root_mean_squared_error: 0.5994 - val_output_stddev_root_mean_squared_error: 0.0318 - val_output_samp_root_mean_squared_error: 0.5597
# Epoch 20/100
# 10/10 - 2s - loss: 0.8956 - output_loss: 0.3006 - output_stddev_loss: 0.0779 - output_samp_loss: 0.5172 - output_root_mean_squared_error: 0.3889 - output_stddev_root_mean_squared_error: 0.1072 - output_samp_root_mean_squared_error: 0.6481 - val_loss: 0.9653 - val_output_loss: 0.4298 - val_output_stddev_loss: 0.0469 - val_output_samp_loss: 0.4887 - val_output_root_mean_squared_error: 0.5386 - val_output_stddev_root_mean_squared_error: 0.0529 - val_output_samp_root_mean_squared_error: 0.6095
# Epoch 21/100
# 10/10 - 3s - loss: 0.9192 - output_loss: 0.3125 - output_stddev_loss: 0.0748 - output_samp_loss: 0.5319 - output_root_mean_squared_error: 0.4056 - output_stddev_root_mean_squared_error: 0.0999 - output_samp_root_mean_squared_error: 0.6781 - val_loss: 1.0269 - val_output_loss: 0.4552 - val_output_stddev_loss: 0.0436 - val_output_samp_loss: 0.5280 - val_output_root_mean_squared_error: 0.5676 - val_output_stddev_root_mean_squared_error: 0.0534 - val_output_samp_root_mean_squared_error: 0.6565
# Epoch 22/100
# 10/10 - 2s - loss: 0.8909 - output_loss: 0.3227 - output_stddev_loss: 0.0708 - output_samp_loss: 0.4974 - output_root_mean_squared_error: 0.4123 - output_stddev_root_mean_squared_error: 0.0986 - output_samp_root_mean_squared_error: 0.6311 - val_loss: 1.2209 - val_output_loss: 0.6450 - val_output_stddev_loss: 0.0416 - val_output_samp_loss: 0.5342 - val_output_root_mean_squared_error: 0.7944 - val_output_stddev_root_mean_squared_error: 0.0485 - val_output_samp_root_mean_squared_error: 0.6698
# Epoch 23/100
# 10/10 - 2s - loss: 0.9146 - output_loss: 0.3439 - output_stddev_loss: 0.0642 - output_samp_loss: 0.5064 - output_root_mean_squared_error: 0.4394 - output_stddev_root_mean_squared_error: 0.1004 - output_samp_root_mean_squared_error: 0.6442 - val_loss: 1.0698 - val_output_loss: 0.5708 - val_output_stddev_loss: 0.0345 - val_output_samp_loss: 0.4645 - val_output_root_mean_squared_error: 0.7069 - val_output_stddev_root_mean_squared_error: 0.0444 - val_output_samp_root_mean_squared_error: 0.5846
# Epoch 24/100
# 10/10 - 2s - loss: 0.8816 - output_loss: 0.3099 - output_stddev_loss: 0.0687 - output_samp_loss: 0.5030 - output_root_mean_squared_error: 0.3978 - output_stddev_root_mean_squared_error: 0.0977 - output_samp_root_mean_squared_error: 0.6486 - val_loss: 0.9282 - val_output_loss: 0.4361 - val_output_stddev_loss: 0.0661 - val_output_samp_loss: 0.4260 - val_output_root_mean_squared_error: 0.5503 - val_output_stddev_root_mean_squared_error: 0.0827 - val_output_samp_root_mean_squared_error: 0.5388
# Epoch 25/100
# 10/10 - 2s - loss: 0.8268 - output_loss: 0.2803 - output_stddev_loss: 0.0664 - output_samp_loss: 0.4801 - output_root_mean_squared_error: 0.3602 - output_stddev_root_mean_squared_error: 0.0917 - output_samp_root_mean_squared_error: 0.6128 - val_loss: 0.9699 - val_output_loss: 0.4556 - val_output_stddev_loss: 0.0625 - val_output_samp_loss: 0.4518 - val_output_root_mean_squared_error: 0.5672 - val_output_stddev_root_mean_squared_error: 0.0714 - val_output_samp_root_mean_squared_error: 0.5620
# Epoch 26/100
# 10/10 - 2s - loss: 0.9023 - output_loss: 0.3154 - output_stddev_loss: 0.0768 - output_samp_loss: 0.5102 - output_root_mean_squared_error: 0.4000 - output_stddev_root_mean_squared_error: 0.1023 - output_samp_root_mean_squared_error: 0.6453 - val_loss: 1.1207 - val_output_loss: 0.4976 - val_output_stddev_loss: 0.0799 - val_output_samp_loss: 0.5432 - val_output_root_mean_squared_error: 0.6185 - val_output_stddev_root_mean_squared_error: 0.0847 - val_output_samp_root_mean_squared_error: 0.6703
# Epoch 27/100
# 10/10 - 2s - loss: 0.8198 - output_loss: 0.2727 - output_stddev_loss: 0.1003 - output_samp_loss: 0.4467 - output_root_mean_squared_error: 0.3444 - output_stddev_root_mean_squared_error: 0.1236 - output_samp_root_mean_squared_error: 0.5774 - val_loss: 1.1019 - val_output_loss: 0.4933 - val_output_stddev_loss: 0.1021 - val_output_samp_loss: 0.5064 - val_output_root_mean_squared_error: 0.6140 - val_output_stddev_root_mean_squared_error: 0.1103 - val_output_samp_root_mean_squared_error: 0.6278
# Epoch 28/100
# 10/10 - 2s - loss: 0.8535 - output_loss: 0.2682 - output_stddev_loss: 0.1080 - output_samp_loss: 0.4773 - output_root_mean_squared_error: 0.3450 - output_stddev_root_mean_squared_error: 0.1342 - output_samp_root_mean_squared_error: 0.6024 - val_loss: 0.9081 - val_output_loss: 0.4346 - val_output_stddev_loss: 0.0465 - val_output_samp_loss: 0.4270 - val_output_root_mean_squared_error: 0.5492 - val_output_stddev_root_mean_squared_error: 0.0591 - val_output_samp_root_mean_squared_error: 0.5444
# Epoch 29/100
# 10/10 - 2s - loss: 0.8574 - output_loss: 0.2955 - output_stddev_loss: 0.0798 - output_samp_loss: 0.4821 - output_root_mean_squared_error: 0.3782 - output_stddev_root_mean_squared_error: 0.1091 - output_samp_root_mean_squared_error: 0.6059 - val_loss: 0.9057 - val_output_loss: 0.4353 - val_output_stddev_loss: 0.0342 - val_output_samp_loss: 0.4361 - val_output_root_mean_squared_error: 0.5511 - val_output_stddev_root_mean_squared_error: 0.0407 - val_output_samp_root_mean_squared_error: 0.5526
# Epoch 30/100
# 10/10 - 2s - loss: 0.8965 - output_loss: 0.3068 - output_stddev_loss: 0.0625 - output_samp_loss: 0.5272 - output_root_mean_squared_error: 0.3922 - output_stddev_root_mean_squared_error: 0.0871 - output_samp_root_mean_squared_error: 0.6587 - val_loss: 0.9481 - val_output_loss: 0.4520 - val_output_stddev_loss: 0.0424 - val_output_samp_loss: 0.4537 - val_output_root_mean_squared_error: 0.5694 - val_output_stddev_root_mean_squared_error: 0.0507 - val_output_samp_root_mean_squared_error: 0.5722
# Epoch 31/100
# 10/10 - 2s - loss: 0.8290 - output_loss: 0.2772 - output_stddev_loss: 0.0635 - output_samp_loss: 0.4882 - output_root_mean_squared_error: 0.3487 - output_stddev_root_mean_squared_error: 0.0901 - output_samp_root_mean_squared_error: 0.6118 - val_loss: 0.9116 - val_output_loss: 0.4396 - val_output_stddev_loss: 0.0271 - val_output_samp_loss: 0.4449 - val_output_root_mean_squared_error: 0.5509 - val_output_stddev_root_mean_squared_error: 0.0345 - val_output_samp_root_mean_squared_error: 0.5559
# Epoch 32/100
# 10/10 - 2s - loss: 0.9483 - output_loss: 0.3642 - output_stddev_loss: 0.0635 - output_samp_loss: 0.5206 - output_root_mean_squared_error: 0.4499 - output_stddev_root_mean_squared_error: 0.0884 - output_samp_root_mean_squared_error: 0.6492 - val_loss: 1.1882 - val_output_loss: 0.6281 - val_output_stddev_loss: 0.0628 - val_output_samp_loss: 0.4973 - val_output_root_mean_squared_error: 0.7593 - val_output_stddev_root_mean_squared_error: 0.0689 - val_output_samp_root_mean_squared_error: 0.6211
# Epoch 33/100
# 10/10 - 2s - loss: 0.9256 - output_loss: 0.3492 - output_stddev_loss: 0.0632 - output_samp_loss: 0.5133 - output_root_mean_squared_error: 0.4304 - output_stddev_root_mean_squared_error: 0.0961 - output_samp_root_mean_squared_error: 0.6501 - val_loss: 0.9152 - val_output_loss: 0.4339 - val_output_stddev_loss: 0.0370 - val_output_samp_loss: 0.4443 - val_output_root_mean_squared_error: 0.5495 - val_output_stddev_root_mean_squared_error: 0.0502 - val_output_samp_root_mean_squared_error: 0.5618
# Epoch 34/100
# 10/10 - 2s - loss: 0.8106 - output_loss: 0.2784 - output_stddev_loss: 0.0593 - output_samp_loss: 0.4728 - output_root_mean_squared_error: 0.3552 - output_stddev_root_mean_squared_error: 0.0881 - output_samp_root_mean_squared_error: 0.5980 - val_loss: 1.0942 - val_output_loss: 0.5462 - val_output_stddev_loss: 0.0434 - val_output_samp_loss: 0.5045 - val_output_root_mean_squared_error: 0.6785 - val_output_stddev_root_mean_squared_error: 0.0564 - val_output_samp_root_mean_squared_error: 0.6266
# Epoch 35/100
# 10/10 - 2s - loss: 0.7946 - output_loss: 0.2391 - output_stddev_loss: 0.0619 - output_samp_loss: 0.4936 - output_root_mean_squared_error: 0.3011 - output_stddev_root_mean_squared_error: 0.0835 - output_samp_root_mean_squared_error: 0.6198 - val_loss: 0.9490 - val_output_loss: 0.4798 - val_output_stddev_loss: 0.0287 - val_output_samp_loss: 0.4404 - val_output_root_mean_squared_error: 0.5986 - val_output_stddev_root_mean_squared_error: 0.0355 - val_output_samp_root_mean_squared_error: 0.5509
# Epoch 36/100
# 10/10 - 2s - loss: 0.7737 - output_loss: 0.2443 - output_stddev_loss: 0.0631 - output_samp_loss: 0.4662 - output_root_mean_squared_error: 0.3161 - output_stddev_root_mean_squared_error: 0.0878 - output_samp_root_mean_squared_error: 0.5744 - val_loss: 0.9056 - val_output_loss: 0.4337 - val_output_stddev_loss: 0.0452 - val_output_samp_loss: 0.4267 - val_output_root_mean_squared_error: 0.5492 - val_output_stddev_root_mean_squared_error: 0.0580 - val_output_samp_root_mean_squared_error: 0.5391
# Epoch 37/100
# 10/10 - 2s - loss: 0.7610 - output_loss: 0.2384 - output_stddev_loss: 0.0576 - output_samp_loss: 0.4650 - output_root_mean_squared_error: 0.3064 - output_stddev_root_mean_squared_error: 0.0786 - output_samp_root_mean_squared_error: 0.5843 - val_loss: 0.9126 - val_output_loss: 0.4488 - val_output_stddev_loss: 0.0310 - val_output_samp_loss: 0.4327 - val_output_root_mean_squared_error: 0.5668 - val_output_stddev_root_mean_squared_error: 0.0377 - val_output_samp_root_mean_squared_error: 0.5482
# Epoch 38/100
# 10/10 - 2s - loss: 0.7640 - output_loss: 0.2339 - output_stddev_loss: 0.0547 - output_samp_loss: 0.4755 - output_root_mean_squared_error: 0.3032 - output_stddev_root_mean_squared_error: 0.0746 - output_samp_root_mean_squared_error: 0.5980 - val_loss: 0.8974 - val_output_loss: 0.4396 - val_output_stddev_loss: 0.0263 - val_output_samp_loss: 0.4315 - val_output_root_mean_squared_error: 0.5525 - val_output_stddev_root_mean_squared_error: 0.0349 - val_output_samp_root_mean_squared_error: 0.5431
# Epoch 39/100
# 10/10 - 2s - loss: 0.7789 - output_loss: 0.2535 - output_stddev_loss: 0.0518 - output_samp_loss: 0.4736 - output_root_mean_squared_error: 0.3234 - output_stddev_root_mean_squared_error: 0.0718 - output_samp_root_mean_squared_error: 0.6031 - val_loss: 0.9674 - val_output_loss: 0.4441 - val_output_stddev_loss: 0.0361 - val_output_samp_loss: 0.4872 - val_output_root_mean_squared_error: 0.5584 - val_output_stddev_root_mean_squared_error: 0.0470 - val_output_samp_root_mean_squared_error: 0.6120
# Epoch 40/100
# 10/10 - 2s - loss: 0.7206 - output_loss: 0.2229 - output_stddev_loss: 0.0535 - output_samp_loss: 0.4442 - output_root_mean_squared_error: 0.2844 - output_stddev_root_mean_squared_error: 0.0741 - output_samp_root_mean_squared_error: 0.5577 - val_loss: 0.9269 - val_output_loss: 0.4465 - val_output_stddev_loss: 0.0248 - val_output_samp_loss: 0.4555 - val_output_root_mean_squared_error: 0.5584 - val_output_stddev_root_mean_squared_error: 0.0315 - val_output_samp_root_mean_squared_error: 0.5695
# Epoch 41/100
# 10/10 - 2s - loss: 0.7577 - output_loss: 0.2655 - output_stddev_loss: 0.0573 - output_samp_loss: 0.4349 - output_root_mean_squared_error: 0.3361 - output_stddev_root_mean_squared_error: 0.0772 - output_samp_root_mean_squared_error: 0.5464 - val_loss: 1.1642 - val_output_loss: 0.5894 - val_output_stddev_loss: 0.0279 - val_output_samp_loss: 0.5469 - val_output_root_mean_squared_error: 0.7203 - val_output_stddev_root_mean_squared_error: 0.0370 - val_output_samp_root_mean_squared_error: 0.6758
# Epoch 42/100
# 10/10 - 3s - loss: 0.7895 - output_loss: 0.2658 - output_stddev_loss: 0.0514 - output_samp_loss: 0.4723 - output_root_mean_squared_error: 0.3323 - output_stddev_root_mean_squared_error: 0.0746 - output_samp_root_mean_squared_error: 0.5938 - val_loss: 1.1231 - val_output_loss: 0.5544 - val_output_stddev_loss: 0.0554 - val_output_samp_loss: 0.5133 - val_output_root_mean_squared_error: 0.6852 - val_output_stddev_root_mean_squared_error: 0.0618 - val_output_samp_root_mean_squared_error: 0.6398
# Epoch 43/100
# 10/10 - 2s - loss: 0.7758 - output_loss: 0.2702 - output_stddev_loss: 0.0592 - output_samp_loss: 0.4464 - output_root_mean_squared_error: 0.3421 - output_stddev_root_mean_squared_error: 0.0772 - output_samp_root_mean_squared_error: 0.5730 - val_loss: 0.9314 - val_output_loss: 0.4445 - val_output_stddev_loss: 0.0357 - val_output_samp_loss: 0.4513 - val_output_root_mean_squared_error: 0.5555 - val_output_stddev_root_mean_squared_error: 0.0442 - val_output_samp_root_mean_squared_error: 0.5603
# Epoch 44/100
# 10/10 - 2s - loss: 0.7222 - output_loss: 0.2175 - output_stddev_loss: 0.0515 - output_samp_loss: 0.4531 - output_root_mean_squared_error: 0.2815 - output_stddev_root_mean_squared_error: 0.0778 - output_samp_root_mean_squared_error: 0.5671 - val_loss: 0.9244 - val_output_loss: 0.4319 - val_output_stddev_loss: 0.0307 - val_output_samp_loss: 0.4618 - val_output_root_mean_squared_error: 0.5432 - val_output_stddev_root_mean_squared_error: 0.0398 - val_output_samp_root_mean_squared_error: 0.5772
# Epoch 45/100
# 10/10 - 2s - loss: 0.7252 - output_loss: 0.2076 - output_stddev_loss: 0.0579 - output_samp_loss: 0.4597 - output_root_mean_squared_error: 0.2662 - output_stddev_root_mean_squared_error: 0.0767 - output_samp_root_mean_squared_error: 0.5699 - val_loss: 0.9097 - val_output_loss: 0.4366 - val_output_stddev_loss: 0.0281 - val_output_samp_loss: 0.4450 - val_output_root_mean_squared_error: 0.5449 - val_output_stddev_root_mean_squared_error: 0.0372 - val_output_samp_root_mean_squared_error: 0.5554
# Epoch 46/100
# 10/10 - 2s - loss: 0.7245 - output_loss: 0.1997 - output_stddev_loss: 0.0819 - output_samp_loss: 0.4430 - output_root_mean_squared_error: 0.2570 - output_stddev_root_mean_squared_error: 0.1007 - output_samp_root_mean_squared_error: 0.5614 - val_loss: 1.1483 - val_output_loss: 0.5360 - val_output_stddev_loss: 0.1478 - val_output_samp_loss: 0.4645 - val_output_root_mean_squared_error: 0.6624 - val_output_stddev_root_mean_squared_error: 0.1550 - val_output_samp_root_mean_squared_error: 0.5833
# Epoch 47/100
# 10/10 - 2s - loss: 0.7665 - output_loss: 0.2535 - output_stddev_loss: 0.0777 - output_samp_loss: 0.4353 - output_root_mean_squared_error: 0.3142 - output_stddev_root_mean_squared_error: 0.1004 - output_samp_root_mean_squared_error: 0.5558 - val_loss: 0.9070 - val_output_loss: 0.4339 - val_output_stddev_loss: 0.0328 - val_output_samp_loss: 0.4403 - val_output_root_mean_squared_error: 0.5416 - val_output_stddev_root_mean_squared_error: 0.0433 - val_output_samp_root_mean_squared_error: 0.5500
# Epoch 48/100
# 10/10 - 2s - loss: 0.7302 - output_loss: 0.2100 - output_stddev_loss: 0.0611 - output_samp_loss: 0.4591 - output_root_mean_squared_error: 0.2689 - output_stddev_root_mean_squared_error: 0.0803 - output_samp_root_mean_squared_error: 0.5756 - val_loss: 0.8987 - val_output_loss: 0.4393 - val_output_stddev_loss: 0.0322 - val_output_samp_loss: 0.4272 - val_output_root_mean_squared_error: 0.5530 - val_output_stddev_root_mean_squared_error: 0.0415 - val_output_samp_root_mean_squared_error: 0.5390
# Epoch 49/100
# 10/10 - 2s - loss: 0.6836 - output_loss: 0.1877 - output_stddev_loss: 0.0597 - output_samp_loss: 0.4362 - output_root_mean_squared_error: 0.2402 - output_stddev_root_mean_squared_error: 0.0812 - output_samp_root_mean_squared_error: 0.5437 - val_loss: 0.9269 - val_output_loss: 0.4229 - val_output_stddev_loss: 0.0503 - val_output_samp_loss: 0.4537 - val_output_root_mean_squared_error: 0.5283 - val_output_stddev_root_mean_squared_error: 0.0580 - val_output_samp_root_mean_squared_error: 0.5675
# Epoch 50/100
# 10/10 - 2s - loss: 0.7083 - output_loss: 0.1942 - output_stddev_loss: 0.0690 - output_samp_loss: 0.4450 - output_root_mean_squared_error: 0.2487 - output_stddev_root_mean_squared_error: 0.0882 - output_samp_root_mean_squared_error: 0.5611 - val_loss: 0.8789 - val_output_loss: 0.4243 - val_output_stddev_loss: 0.0299 - val_output_samp_loss: 0.4247 - val_output_root_mean_squared_error: 0.5317 - val_output_stddev_root_mean_squared_error: 0.0394 - val_output_samp_root_mean_squared_error: 0.5328
# Epoch 51/100
# 10/10 - 2s - loss: 0.6598 - output_loss: 0.1741 - output_stddev_loss: 0.0530 - output_samp_loss: 0.4328 - output_root_mean_squared_error: 0.2211 - output_stddev_root_mean_squared_error: 0.0721 - output_samp_root_mean_squared_error: 0.5561 - val_loss: 0.9557 - val_output_loss: 0.4798 - val_output_stddev_loss: 0.0476 - val_output_samp_loss: 0.4284 - val_output_root_mean_squared_error: 0.5997 - val_output_stddev_root_mean_squared_error: 0.0543 - val_output_samp_root_mean_squared_error: 0.5358
# Epoch 52/100
# 10/10 - 2s - loss: 0.6826 - output_loss: 0.1821 - output_stddev_loss: 0.0585 - output_samp_loss: 0.4421 - output_root_mean_squared_error: 0.2312 - output_stddev_root_mean_squared_error: 0.0755 - output_samp_root_mean_squared_error: 0.5615 - val_loss: 0.8986 - val_output_loss: 0.4464 - val_output_stddev_loss: 0.0299 - val_output_samp_loss: 0.4224 - val_output_root_mean_squared_error: 0.5624 - val_output_stddev_root_mean_squared_error: 0.0400 - val_output_samp_root_mean_squared_error: 0.5302
# Epoch 53/100
# 10/10 - 2s - loss: 0.6924 - output_loss: 0.1822 - output_stddev_loss: 0.0603 - output_samp_loss: 0.4499 - output_root_mean_squared_error: 0.2280 - output_stddev_root_mean_squared_error: 0.0791 - output_samp_root_mean_squared_error: 0.5619 - val_loss: 0.9775 - val_output_loss: 0.4855 - val_output_stddev_loss: 0.0578 - val_output_samp_loss: 0.4342 - val_output_root_mean_squared_error: 0.6067 - val_output_stddev_root_mean_squared_error: 0.0645 - val_output_samp_root_mean_squared_error: 0.5444
# Epoch 54/100
# 10/10 - 2s - loss: 0.6812 - output_loss: 0.1880 - output_stddev_loss: 0.0503 - output_samp_loss: 0.4429 - output_root_mean_squared_error: 0.2423 - output_stddev_root_mean_squared_error: 0.0676 - output_samp_root_mean_squared_error: 0.5582 - val_loss: 0.9254 - val_output_loss: 0.4305 - val_output_stddev_loss: 0.0245 - val_output_samp_loss: 0.4704 - val_output_root_mean_squared_error: 0.5411 - val_output_stddev_root_mean_squared_error: 0.0312 - val_output_samp_root_mean_squared_error: 0.5913
# Epoch 55/100
# 10/10 - 2s - loss: 0.6558 - output_loss: 0.1687 - output_stddev_loss: 0.0445 - output_samp_loss: 0.4426 - output_root_mean_squared_error: 0.2142 - output_stddev_root_mean_squared_error: 0.0589 - output_samp_root_mean_squared_error: 0.5609 - val_loss: 0.9320 - val_output_loss: 0.4225 - val_output_stddev_loss: 0.0547 - val_output_samp_loss: 0.4547 - val_output_root_mean_squared_error: 0.5301 - val_output_stddev_root_mean_squared_error: 0.0600 - val_output_samp_root_mean_squared_error: 0.5699
# Epoch 56/100
# 10/10 - 2s - loss: 0.6526 - output_loss: 0.1685 - output_stddev_loss: 0.0511 - output_samp_loss: 0.4330 - output_root_mean_squared_error: 0.2118 - output_stddev_root_mean_squared_error: 0.0678 - output_samp_root_mean_squared_error: 0.5416 - val_loss: 0.9464 - val_output_loss: 0.4480 - val_output_stddev_loss: 0.0223 - val_output_samp_loss: 0.4762 - val_output_root_mean_squared_error: 0.5628 - val_output_stddev_root_mean_squared_error: 0.0289 - val_output_samp_root_mean_squared_error: 0.5976
# Epoch 57/100
# 10/10 - 2s - loss: 0.6437 - output_loss: 0.1765 - output_stddev_loss: 0.0464 - output_samp_loss: 0.4207 - output_root_mean_squared_error: 0.2283 - output_stddev_root_mean_squared_error: 0.0609 - output_samp_root_mean_squared_error: 0.5424 - val_loss: 0.8767 - val_output_loss: 0.4260 - val_output_stddev_loss: 0.0281 - val_output_samp_loss: 0.4226 - val_output_root_mean_squared_error: 0.5364 - val_output_stddev_root_mean_squared_error: 0.0369 - val_output_samp_root_mean_squared_error: 0.5321
# Epoch 58/100
# 10/10 - 2s - loss: 0.6770 - output_loss: 0.1883 - output_stddev_loss: 0.0487 - output_samp_loss: 0.4399 - output_root_mean_squared_error: 0.2434 - output_stddev_root_mean_squared_error: 0.0662 - output_samp_root_mean_squared_error: 0.5553 - val_loss: 0.8643 - val_output_loss: 0.4217 - val_output_stddev_loss: 0.0244 - val_output_samp_loss: 0.4181 - val_output_root_mean_squared_error: 0.5330 - val_output_stddev_root_mean_squared_error: 0.0314 - val_output_samp_root_mean_squared_error: 0.5274
# Epoch 59/100
# 10/10 - 2s - loss: 0.6733 - output_loss: 0.2006 - output_stddev_loss: 0.0421 - output_samp_loss: 0.4305 - output_root_mean_squared_error: 0.2538 - output_stddev_root_mean_squared_error: 0.0537 - output_samp_root_mean_squared_error: 0.5522 - val_loss: 0.8833 - val_output_loss: 0.4259 - val_output_stddev_loss: 0.0220 - val_output_samp_loss: 0.4355 - val_output_root_mean_squared_error: 0.5333 - val_output_stddev_root_mean_squared_error: 0.0286 - val_output_samp_root_mean_squared_error: 0.5442
# Epoch 60/100
# 10/10 - 2s - loss: 0.6721 - output_loss: 0.1766 - output_stddev_loss: 0.0499 - output_samp_loss: 0.4455 - output_root_mean_squared_error: 0.2274 - output_stddev_root_mean_squared_error: 0.0648 - output_samp_root_mean_squared_error: 0.5563 - val_loss: 1.0335 - val_output_loss: 0.5143 - val_output_stddev_loss: 0.0340 - val_output_samp_loss: 0.4852 - val_output_root_mean_squared_error: 0.6382 - val_output_stddev_root_mean_squared_error: 0.0447 - val_output_samp_root_mean_squared_error: 0.6060
# Epoch 61/100
# 10/10 - 2s - loss: 0.6990 - output_loss: 0.1820 - output_stddev_loss: 0.0742 - output_samp_loss: 0.4427 - output_root_mean_squared_error: 0.2303 - output_stddev_root_mean_squared_error: 0.0902 - output_samp_root_mean_squared_error: 0.5648 - val_loss: 0.9493 - val_output_loss: 0.4471 - val_output_stddev_loss: 0.0778 - val_output_samp_loss: 0.4243 - val_output_root_mean_squared_error: 0.5643 - val_output_stddev_root_mean_squared_error: 0.0830 - val_output_samp_root_mean_squared_error: 0.5395
# Epoch 62/100
# 10/10 - 2s - loss: 0.6471 - output_loss: 0.1592 - output_stddev_loss: 0.0654 - output_samp_loss: 0.4225 - output_root_mean_squared_error: 0.2056 - output_stddev_root_mean_squared_error: 0.0799 - output_samp_root_mean_squared_error: 0.5336 - val_loss: 0.8928 - val_output_loss: 0.4366 - val_output_stddev_loss: 0.0376 - val_output_samp_loss: 0.4186 - val_output_root_mean_squared_error: 0.5475 - val_output_stddev_root_mean_squared_error: 0.0438 - val_output_samp_root_mean_squared_error: 0.5291
# Epoch 63/100
# 10/10 - 3s - loss: 0.6865 - output_loss: 0.1832 - output_stddev_loss: 0.0538 - output_samp_loss: 0.4495 - output_root_mean_squared_error: 0.2354 - output_stddev_root_mean_squared_error: 0.0733 - output_samp_root_mean_squared_error: 0.5645 - val_loss: 0.9409 - val_output_loss: 0.4516 - val_output_stddev_loss: 0.0462 - val_output_samp_loss: 0.4431 - val_output_root_mean_squared_error: 0.5641 - val_output_stddev_root_mean_squared_error: 0.0577 - val_output_samp_root_mean_squared_error: 0.5541
# Epoch 64/100
# 10/10 - 2s - loss: 0.6819 - output_loss: 0.1691 - output_stddev_loss: 0.0648 - output_samp_loss: 0.4479 - output_root_mean_squared_error: 0.2166 - output_stddev_root_mean_squared_error: 0.0809 - output_samp_root_mean_squared_error: 0.5569 - val_loss: 0.9463 - val_output_loss: 0.4506 - val_output_stddev_loss: 0.0286 - val_output_samp_loss: 0.4671 - val_output_root_mean_squared_error: 0.5654 - val_output_stddev_root_mean_squared_error: 0.0377 - val_output_samp_root_mean_squared_error: 0.5837
# Epoch 65/100
# 10/10 - 2s - loss: 0.6325 - output_loss: 0.1598 - output_stddev_loss: 0.0507 - output_samp_loss: 0.4220 - output_root_mean_squared_error: 0.2086 - output_stddev_root_mean_squared_error: 0.0671 - output_samp_root_mean_squared_error: 0.5296 - val_loss: 0.9208 - val_output_loss: 0.4539 - val_output_stddev_loss: 0.0257 - val_output_samp_loss: 0.4411 - val_output_root_mean_squared_error: 0.5679 - val_output_stddev_root_mean_squared_error: 0.0318 - val_output_samp_root_mean_squared_error: 0.5512
# Epoch 66/100
# 10/10 - 2s - loss: 0.6930 - output_loss: 0.2105 - output_stddev_loss: 0.0495 - output_samp_loss: 0.4330 - output_root_mean_squared_error: 0.2608 - output_stddev_root_mean_squared_error: 0.0639 - output_samp_root_mean_squared_error: 0.5429 - val_loss: 0.9316 - val_output_loss: 0.4449 - val_output_stddev_loss: 0.0528 - val_output_samp_loss: 0.4339 - val_output_root_mean_squared_error: 0.5598 - val_output_stddev_root_mean_squared_error: 0.0598 - val_output_samp_root_mean_squared_error: 0.5435
# Epoch 67/100
# 10/10 - 2s - loss: 0.6340 - output_loss: 0.1615 - output_stddev_loss: 0.0484 - output_samp_loss: 0.4241 - output_root_mean_squared_error: 0.2043 - output_stddev_root_mean_squared_error: 0.0621 - output_samp_root_mean_squared_error: 0.5319 - val_loss: 0.8921 - val_output_loss: 0.4387 - val_output_stddev_loss: 0.0335 - val_output_samp_loss: 0.4199 - val_output_root_mean_squared_error: 0.5502 - val_output_stddev_root_mean_squared_error: 0.0411 - val_output_samp_root_mean_squared_error: 0.5310
# Epoch 68/100
# 10/10 - 2s - loss: 0.6662 - output_loss: 0.1736 - output_stddev_loss: 0.0487 - output_samp_loss: 0.4438 - output_root_mean_squared_error: 0.2216 - output_stddev_root_mean_squared_error: 0.0619 - output_samp_root_mean_squared_error: 0.5568 - val_loss: 0.9516 - val_output_loss: 0.4417 - val_output_stddev_loss: 0.0716 - val_output_samp_loss: 0.4383 - val_output_root_mean_squared_error: 0.5520 - val_output_stddev_root_mean_squared_error: 0.0779 - val_output_samp_root_mean_squared_error: 0.5490
# Epoch 69/100
# 10/10 - 2s - loss: 0.6763 - output_loss: 0.1864 - output_stddev_loss: 0.0513 - output_samp_loss: 0.4385 - output_root_mean_squared_error: 0.2343 - output_stddev_root_mean_squared_error: 0.0649 - output_samp_root_mean_squared_error: 0.5577 - val_loss: 0.8831 - val_output_loss: 0.4307 - val_output_stddev_loss: 0.0226 - val_output_samp_loss: 0.4297 - val_output_root_mean_squared_error: 0.5411 - val_output_stddev_root_mean_squared_error: 0.0289 - val_output_samp_root_mean_squared_error: 0.5413
# Epoch 70/100
# 10/10 - 2s - loss: 0.6708 - output_loss: 0.1854 - output_stddev_loss: 0.0436 - output_samp_loss: 0.4418 - output_root_mean_squared_error: 0.2311 - output_stddev_root_mean_squared_error: 0.0582 - output_samp_root_mean_squared_error: 0.5555 - val_loss: 0.9581 - val_output_loss: 0.4709 - val_output_stddev_loss: 0.0630 - val_output_samp_loss: 0.4242 - val_output_root_mean_squared_error: 0.5900 - val_output_stddev_root_mean_squared_error: 0.0696 - val_output_samp_root_mean_squared_error: 0.5303
# Epoch 71/100
# 10/10 - 2s - loss: 0.6577 - output_loss: 0.1608 - output_stddev_loss: 0.0537 - output_samp_loss: 0.4432 - output_root_mean_squared_error: 0.2069 - output_stddev_root_mean_squared_error: 0.0664 - output_samp_root_mean_squared_error: 0.5621 - val_loss: 0.9929 - val_output_loss: 0.5024 - val_output_stddev_loss: 0.0331 - val_output_samp_loss: 0.4574 - val_output_root_mean_squared_error: 0.6270 - val_output_stddev_root_mean_squared_error: 0.0390 - val_output_samp_root_mean_squared_error: 0.5734
# Epoch 72/100
# 10/10 - 2s - loss: 0.6457 - output_loss: 0.1683 - output_stddev_loss: 0.0437 - output_samp_loss: 0.4337 - output_root_mean_squared_error: 0.2135 - output_stddev_root_mean_squared_error: 0.0584 - output_samp_root_mean_squared_error: 0.5367 - val_loss: 0.9309 - val_output_loss: 0.4710 - val_output_stddev_loss: 0.0294 - val_output_samp_loss: 0.4305 - val_output_root_mean_squared_error: 0.5843 - val_output_stddev_root_mean_squared_error: 0.0372 - val_output_samp_root_mean_squared_error: 0.5386
# Epoch 73/100
# 10/10 - 2s - loss: 0.6786 - output_loss: 0.1873 - output_stddev_loss: 0.0437 - output_samp_loss: 0.4476 - output_root_mean_squared_error: 0.2415 - output_stddev_root_mean_squared_error: 0.0590 - output_samp_root_mean_squared_error: 0.5733 - val_loss: 0.9626 - val_output_loss: 0.4833 - val_output_stddev_loss: 0.0391 - val_output_samp_loss: 0.4402 - val_output_root_mean_squared_error: 0.6019 - val_output_stddev_root_mean_squared_error: 0.0459 - val_output_samp_root_mean_squared_error: 0.5531
# Epoch 74/100
# 10/10 - 2s - loss: 0.6808 - output_loss: 0.2053 - output_stddev_loss: 0.0508 - output_samp_loss: 0.4247 - output_root_mean_squared_error: 0.2568 - output_stddev_root_mean_squared_error: 0.0654 - output_samp_root_mean_squared_error: 0.5408 - val_loss: 0.9866 - val_output_loss: 0.5001 - val_output_stddev_loss: 0.0296 - val_output_samp_loss: 0.4569 - val_output_root_mean_squared_error: 0.6228 - val_output_stddev_root_mean_squared_error: 0.0361 - val_output_samp_root_mean_squared_error: 0.5739
# Epoch 75/100
# 10/10 - 2s - loss: 0.6609 - output_loss: 0.1928 - output_stddev_loss: 0.0451 - output_samp_loss: 0.4230 - output_root_mean_squared_error: 0.2511 - output_stddev_root_mean_squared_error: 0.0616 - output_samp_root_mean_squared_error: 0.5409 - val_loss: 1.1023 - val_output_loss: 0.5487 - val_output_stddev_loss: 0.0566 - val_output_samp_loss: 0.4970 - val_output_root_mean_squared_error: 0.6740 - val_output_stddev_root_mean_squared_error: 0.0662 - val_output_samp_root_mean_squared_error: 0.6176
# Epoch 76/100
# 10/10 - 2s - loss: 0.6717 - output_loss: 0.1834 - output_stddev_loss: 0.0619 - output_samp_loss: 0.4264 - output_root_mean_squared_error: 0.2322 - output_stddev_root_mean_squared_error: 0.0791 - output_samp_root_mean_squared_error: 0.5319 - val_loss: 1.1399 - val_output_loss: 0.4758 - val_output_stddev_loss: 0.0605 - val_output_samp_loss: 0.6036 - val_output_root_mean_squared_error: 0.5970 - val_output_stddev_root_mean_squared_error: 0.0684 - val_output_samp_root_mean_squared_error: 0.7334
# Epoch 77/100
# 10/10 - 2s - loss: 0.7211 - output_loss: 0.1999 - output_stddev_loss: 0.0585 - output_samp_loss: 0.4627 - output_root_mean_squared_error: 0.2561 - output_stddev_root_mean_squared_error: 0.0747 - output_samp_root_mean_squared_error: 0.5907 - val_loss: 0.9924 - val_output_loss: 0.4729 - val_output_stddev_loss: 0.0355 - val_output_samp_loss: 0.4840 - val_output_root_mean_squared_error: 0.5938 - val_output_stddev_root_mean_squared_error: 0.0447 - val_output_samp_root_mean_squared_error: 0.6081
# Epoch 78/100
# 10/10 - 2s - loss: 0.6819 - output_loss: 0.1903 - output_stddev_loss: 0.0481 - output_samp_loss: 0.4435 - output_root_mean_squared_error: 0.2356 - output_stddev_root_mean_squared_error: 0.0638 - output_samp_root_mean_squared_error: 0.5537 - val_loss: 0.9135 - val_output_loss: 0.4531 - val_output_stddev_loss: 0.0236 - val_output_samp_loss: 0.4368 - val_output_root_mean_squared_error: 0.5711 - val_output_stddev_root_mean_squared_error: 0.0309 - val_output_samp_root_mean_squared_error: 0.5524
# Epoch 79/100
# 10/10 - 2s - loss: 0.6757 - output_loss: 0.2019 - output_stddev_loss: 0.0433 - output_samp_loss: 0.4304 - output_root_mean_squared_error: 0.2547 - output_stddev_root_mean_squared_error: 0.0579 - output_samp_root_mean_squared_error: 0.5502 - val_loss: 1.0495 - val_output_loss: 0.5393 - val_output_stddev_loss: 0.0285 - val_output_samp_loss: 0.4817 - val_output_root_mean_squared_error: 0.6662 - val_output_stddev_root_mean_squared_error: 0.0375 - val_output_samp_root_mean_squared_error: 0.6051
# Restoring model weights from the end of the best epoch.
# Epoch 00079: early stopping
# #### FOLD 1 OOF RMSE = 0.5283
# #### FOLD 1 OOF RMSE = 0.5274

# %% [markdown]
# ## Model loss and metrics graph

# %%
for fold, history in enumerate(history_list):
    print(f'\nFOLD: {fold+1}')
    plot_metrics(history)
# Out:
# FOLD: 1

# %% [markdown]
# # Model evaluation
#
# We are evaluating the model on the `OOF` predictions, it stands for `Out Of Fold`, since we are training using `K-Fold` our model will see all the data, and the correct way to evaluate each fold is by looking at the predictions that are not from that fold.
#
# ## OOF metrics

# %%
y_true = np.concatenate(oof_labels)
y_preds = np.concatenate(oof_pred)

for fold, history in enumerate(history_list):
    print(f"FOLD {fold+1} RMSE: {np.min(history['val_output_root_mean_squared_error']):.4f}")
    
print(f'OOF RMSE: {mean_squared_error(y_true, y_preds, squared=False):.4f}')
# Out:
# FOLD 1 RMSE: 0.5283
# OOF RMSE: 0.5283

# %% [markdown]
# ### **Error analysis**, label x prediction distribution
#
# Here we can compare the distribution from the labels and the predicted values, in a perfect scenario they should align.

# %%
preds_df = pd.DataFrame({'Label': y_true, 'Prediction': y_preds[:,0]})

fig, ax = plt.subplots(1, 1, figsize=(20, 6))
sns.distplot(preds_df['Label'], ax=ax, label='Label')
sns.distplot(preds_df['Prediction'], ax=ax, label='Prediction')
ax.legend()
plt.show()

# %%
sns.jointplot(data=preds_df, x='Label', y='Prediction', kind='reg', height=10)
plt.show()
