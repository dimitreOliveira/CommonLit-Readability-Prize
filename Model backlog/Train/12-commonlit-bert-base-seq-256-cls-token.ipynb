# %% [markdown]
# ## Dependencies

# %%
import warnings, math, json
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
from tensorflow.keras import optimizers, losses, metrics, Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from transformers import TFAutoModelForSequenceClassification, TFAutoModel, AutoTokenizer
from commonlit_scripts import *


seed = 0
seed_everything(seed)
sns.set(style='whitegrid')
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 150)

# %% [markdown]
# ### Hardware configuration

# %%
strategy, tpu = get_strategy()
AUTO = tf.data.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
print(f'REPLICAS: {REPLICAS}')
# Out:
# Running on TPU grpc://10.0.0.2:8470
# REPLICAS: 8

# %% [markdown]
# # Load data

# %%
train_filepath = '/kaggle/input/commonlitreadabilityprize/train.csv'
train = pd.read_csv(train_filepath)
print(f'Train samples: {len(train)}')
# removing unused columns
train.drop(['url_legal', 'license'], axis=1, inplace=True)
display(train.head())
# Out:
# Train samples: 2834
#           id  \
# 0  c12129c31
# 1  85aa80a4c
# 2  b69ac6792
# 3  dd1000b26
# 4  37c1b32fb
#
#                                                                                                                                                  excerpt  \
# 0  When the young people returned to the ballroom, it presented a decidedly changed appearance. Instead of an interior scene, it was a winter landsca...
# 1  All through dinner time, Mrs. Fayre was somewhat silent, her eyes resting on Dolly with a wistful, uncertain expression. She wanted to give the ch...
# 2  As Roger had predicted, the snow departed as quickly as it came, and two days after their sleigh ride there was scarcely a vestige of white on the...
# 3  And outside before the palace a great garden was walled round, filled full of stately fruit-trees, gray olives and sweet figs, and pomegranates, p...
# 4  Once upon a time there were Three Bears who lived together in a house of their own in a wood. One of them was a Little, Small, Wee Bear; and one w...
#
#      target  standard_error
# 0 -0.340259        0.464009
# 1 -0.315372        0.480805
# 2 -0.580118        0.476676
# 3 -1.054013        0.450007
# 4  0.247197        0.510845

# %% [markdown]
# # Model parameters

# %%
config = {
  "BATCH_SIZE": 8 * REPLICAS,
  "LEARNING_RATE": 1e-5 * REPLICAS,
  "EPOCHS": 100,
  "ES_PATIENCE": 30,
  "N_FOLDS": 5,
  "N_USED_FOLDS": 1,
  "SEQ_LEN": 256,
  "BASE_MODEL": '/kaggle/input/huggingface-bert/bert-base-uncased',
  "SEED": seed,
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# ## Auxiliary functions

# %%
# Datasets utility functions
def custom_standardization(text, is_lower=True):
    if is_lower:
        text = text.lower() # if encoder is uncased
    text = text.strip()
    return text

def sample_target(features, target):
    mean, stddev = target
    sampled_target = tf.random.normal([], mean=tf.cast(mean, dtype=tf.float32), 
                                      stddev=tf.cast(stddev, dtype=tf.float32), dtype=tf.float32)
    return (features, sampled_target)

def get_dataset(pandas_df, tokenizer, labeled=True, ordered=False, repeated=False, 
                is_sampled=False, batch_size=32, seq_len=128, is_lower=True):
    """
        Return a Tensorflow dataset ready for training or inference.
    """
    text = [custom_standardization(text, is_lower) for text in pandas_df['excerpt']]
    
    # Tokenize inputs
    tokenized_inputs = tokenizer(text, max_length=seq_len, truncation=True, 
                                 padding='max_length', return_tensors='tf')
    
    if labeled:
        dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': tokenized_inputs['input_ids'], 
                                                       'token_type_ids': tokenized_inputs['token_type_ids'], 
                                                       'attention_mask': tokenized_inputs['attention_mask']}, 
                                                      (pandas_df['target'], pandas_df['standard_error'])))
        if is_sampled:
            dataset = dataset.map(sample_target, num_parallel_calls=tf.data.AUTOTUNE)
    else:
        dataset = tf.data.Dataset.from_tensor_slices({'input_ids': tokenized_inputs['input_ids'], 
                                                      'token_type_ids': tokenized_inputs['token_type_ids'], 
                                                      'attention_mask': tokenized_inputs['attention_mask']})
        
    if repeated:
        dataset = dataset.repeat()
    if not ordered:
        dataset = dataset.shuffle(2048)
    dataset = dataset.batch(batch_size)
    dataset = dataset.cache()
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# %% [markdown]
# # Model

# %%
def model_fn(encoder, seq_len=256):
    input_ids = L.Input(shape=(seq_len,), dtype=tf.int32, name='input_ids')
    input_token_type_ids = L.Input(shape=(seq_len,), dtype=tf.int32, name='token_type_ids')
    input_attention_mask = L.Input(shape=(seq_len,), dtype=tf.int32, name='attention_mask')
    
    outputs = encoder({'input_ids': input_ids,  
                       'token_type_ids': input_token_type_ids, 
                       'attention_mask': input_attention_mask})
    last_hidden_state = outputs['last_hidden_state']
    
    cls_token = last_hidden_state[:, 0, :]
    output = L.Dense(1, name='output')(cls_token)
    
    model = Model(inputs=[input_ids, input_token_type_ids, input_attention_mask], outputs=output)

    optimizer = optimizers.Adam(lr=config['LEARNING_RATE'])
    model.compile(optimizer=optimizer, 
                  loss=losses.MeanSquaredError(), 
                  metrics=[metrics.RootMeanSquaredError()])
    return model


with strategy.scope():
    encoder = TFAutoModel.from_pretrained(config['BASE_MODEL'])
    model = model_fn(encoder, config['SEQ_LEN'])
    
model.summary()
# Out:
# Some layers from the model checkpoint at /kaggle/input/huggingface-bert/bert-base-uncased were not used when initializing TFBertModel: ['nsp___cls', 'mlm___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at /kaggle/input/huggingface-bert/bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# attention_mask (InputLayer)     [(None, 256)]        0
# __________________________________________________________________________________________________
# input_ids (InputLayer)          [(None, 256)]        0
# __________________________________________________________________________________________________
# token_type_ids (InputLayer)     [(None, 256)]        0
# __________________________________________________________________________________________________
# tf_bert_model (TFBertModel)     TFBaseModelOutputWit 109482240   attention_mask[0][0]
#                                                                  input_ids[0][0]
#                                                                  token_type_ids[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici (None, 768)          0           tf_bert_model[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            769         tf.__operators__.getitem[0][0]
# ==================================================================================================
# Total params: 109,483,009
# Trainable params: 109,483,009
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
tokenizer = AutoTokenizer.from_pretrained(config['BASE_MODEL'])
skf = KFold(n_splits=config['N_FOLDS'], shuffle=True, random_state=seed)
oof_pred = []; oof_labels = []; history_list = []

for fold,(idxT, idxV) in enumerate(skf.split(train)):
    if fold >= config['N_USED_FOLDS']:
        break
    if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    print(f'\nFOLD: {fold+1}')
    print(f'TRAIN: {len(idxT)} VALID: {len(idxV)}')

    # Model
    K.clear_session()
    with strategy.scope():
        encoder = TFAutoModel.from_pretrained(config['BASE_MODEL'])
        model = model_fn(encoder, config['SEQ_LEN'])
        
    model_path = f'model_{fold}.h5'
    es = EarlyStopping(monitor='val_root_mean_squared_error', mode='min', 
                       patience=config['ES_PATIENCE'], restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_root_mean_squared_error', mode='min', 
                                 save_best_only=True, save_weights_only=True)

    # Train
    history = model.fit(x=get_dataset(train.loc[idxT], tokenizer, repeated=True, is_sampled=True, 
                                      batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN']), 
                        validation_data=get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                                                    batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN']), 
                        steps_per_epoch=10, 
                        callbacks=[es, checkpoint], 
                        epochs=config['EPOCHS'],  
                        verbose=2).history
      
    history_list.append(history)
    # Save last model weights
    model.load_weights(model_path)
    
    # Results
    print(f"#### FOLD {fold+1} OOF RMSE = {np.min(history['val_root_mean_squared_error']):.4f}")

    # OOF predictions
    valid_ds = get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                           batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN'])
    oof_labels.append([target[0].numpy() for sample, target in iter(valid_ds.unbatch())])
    x_oof = valid_ds.map(lambda sample, target: sample)
    oof_pred.append(model.predict(x_oof))
# Out:
# FOLD: 1
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-bert/bert-base-uncased were not used when initializing TFBertModel: ['nsp___cls', 'mlm___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at /kaggle/input/huggingface-bert/bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Epoch 1/100
# 10/10 - 86s - loss: 2.0018 - root_mean_squared_error: 1.4149 - val_loss: 1.0216 - val_root_mean_squared_error: 1.0107
# Epoch 2/100
# 10/10 - 2s - loss: 1.1615 - root_mean_squared_error: 1.0777 - val_loss: 0.6731 - val_root_mean_squared_error: 0.8204
# Epoch 3/100
# 10/10 - 2s - loss: 0.8357 - root_mean_squared_error: 0.9142 - val_loss: 0.4721 - val_root_mean_squared_error: 0.6871
# Epoch 4/100
# 10/10 - 2s - loss: 0.7256 - root_mean_squared_error: 0.8518 - val_loss: 0.4870 - val_root_mean_squared_error: 0.6979
# Epoch 5/100
# 10/10 - 2s - loss: 0.6648 - root_mean_squared_error: 0.8153 - val_loss: 0.5403 - val_root_mean_squared_error: 0.7350
# Epoch 6/100
# 10/10 - 2s - loss: 0.5777 - root_mean_squared_error: 0.7601 - val_loss: 0.3486 - val_root_mean_squared_error: 0.5905
# Epoch 7/100
# 10/10 - 2s - loss: 0.5816 - root_mean_squared_error: 0.7626 - val_loss: 0.6495 - val_root_mean_squared_error: 0.8059
# Epoch 8/100
# 10/10 - 2s - loss: 0.5000 - root_mean_squared_error: 0.7071 - val_loss: 0.3263 - val_root_mean_squared_error: 0.5712
# Epoch 9/100
# 10/10 - 2s - loss: 0.5148 - root_mean_squared_error: 0.7175 - val_loss: 0.3705 - val_root_mean_squared_error: 0.6087
# Epoch 10/100
# 10/10 - 2s - loss: 0.4979 - root_mean_squared_error: 0.7056 - val_loss: 0.3663 - val_root_mean_squared_error: 0.6052
# Epoch 11/100
# 10/10 - 2s - loss: 0.4989 - root_mean_squared_error: 0.7063 - val_loss: 0.5186 - val_root_mean_squared_error: 0.7201
# Epoch 12/100
# 10/10 - 2s - loss: 0.4204 - root_mean_squared_error: 0.6484 - val_loss: 0.3297 - val_root_mean_squared_error: 0.5742
# Epoch 13/100
# 10/10 - 2s - loss: 0.4436 - root_mean_squared_error: 0.6660 - val_loss: 0.4097 - val_root_mean_squared_error: 0.6401
# Epoch 14/100
# 10/10 - 2s - loss: 0.4558 - root_mean_squared_error: 0.6751 - val_loss: 0.3391 - val_root_mean_squared_error: 0.5823
# Epoch 15/100
# 10/10 - 2s - loss: 0.3760 - root_mean_squared_error: 0.6132 - val_loss: 0.4890 - val_root_mean_squared_error: 0.6993
# Epoch 16/100
# 10/10 - 2s - loss: 0.3464 - root_mean_squared_error: 0.5885 - val_loss: 0.4219 - val_root_mean_squared_error: 0.6496
# Epoch 17/100
# 10/10 - 2s - loss: 0.3363 - root_mean_squared_error: 0.5799 - val_loss: 0.3461 - val_root_mean_squared_error: 0.5883
# Epoch 18/100
# 10/10 - 2s - loss: 0.3427 - root_mean_squared_error: 0.5854 - val_loss: 0.4238 - val_root_mean_squared_error: 0.6510
# Epoch 19/100
# 10/10 - 2s - loss: 0.3815 - root_mean_squared_error: 0.6176 - val_loss: 0.4776 - val_root_mean_squared_error: 0.6911
# Epoch 20/100
# 10/10 - 2s - loss: 0.3191 - root_mean_squared_error: 0.5649 - val_loss: 0.5178 - val_root_mean_squared_error: 0.7196
# Epoch 21/100
# 10/10 - 2s - loss: 0.3749 - root_mean_squared_error: 0.6123 - val_loss: 0.3128 - val_root_mean_squared_error: 0.5593
# Epoch 22/100
# 10/10 - 3s - loss: 0.3952 - root_mean_squared_error: 0.6287 - val_loss: 0.5646 - val_root_mean_squared_error: 0.7514
# Epoch 23/100
# 10/10 - 2s - loss: 0.3980 - root_mean_squared_error: 0.6309 - val_loss: 0.3148 - val_root_mean_squared_error: 0.5611
# Epoch 24/100
# 10/10 - 2s - loss: 0.3671 - root_mean_squared_error: 0.6059 - val_loss: 0.4188 - val_root_mean_squared_error: 0.6472
# Epoch 25/100
# 10/10 - 2s - loss: 0.3470 - root_mean_squared_error: 0.5891 - val_loss: 0.3912 - val_root_mean_squared_error: 0.6254
# Epoch 26/100
# 10/10 - 2s - loss: 0.3372 - root_mean_squared_error: 0.5807 - val_loss: 0.5785 - val_root_mean_squared_error: 0.7606
# Epoch 27/100
# 10/10 - 2s - loss: 0.3252 - root_mean_squared_error: 0.5703 - val_loss: 0.2996 - val_root_mean_squared_error: 0.5473
# Epoch 28/100
# 10/10 - 2s - loss: 0.3316 - root_mean_squared_error: 0.5759 - val_loss: 0.4632 - val_root_mean_squared_error: 0.6806
# Epoch 29/100
# 10/10 - 2s - loss: 0.2827 - root_mean_squared_error: 0.5317 - val_loss: 0.3669 - val_root_mean_squared_error: 0.6057
# Epoch 30/100
# 10/10 - 2s - loss: 0.3046 - root_mean_squared_error: 0.5519 - val_loss: 0.3458 - val_root_mean_squared_error: 0.5881
# Epoch 31/100
# 10/10 - 2s - loss: 0.3099 - root_mean_squared_error: 0.5567 - val_loss: 0.3413 - val_root_mean_squared_error: 0.5842
# Epoch 32/100
# 10/10 - 2s - loss: 0.2964 - root_mean_squared_error: 0.5444 - val_loss: 0.4027 - val_root_mean_squared_error: 0.6346
# Epoch 33/100
# 10/10 - 2s - loss: 0.3396 - root_mean_squared_error: 0.5827 - val_loss: 0.4290 - val_root_mean_squared_error: 0.6550
# Epoch 34/100
# 10/10 - 2s - loss: 0.3668 - root_mean_squared_error: 0.6057 - val_loss: 0.6059 - val_root_mean_squared_error: 0.7784
# Epoch 35/100
# 10/10 - 2s - loss: 0.3663 - root_mean_squared_error: 0.6052 - val_loss: 0.5322 - val_root_mean_squared_error: 0.7295
# Epoch 36/100
# 10/10 - 2s - loss: 0.2986 - root_mean_squared_error: 0.5464 - val_loss: 0.4515 - val_root_mean_squared_error: 0.6719
# Epoch 37/100
# 10/10 - 2s - loss: 0.3329 - root_mean_squared_error: 0.5770 - val_loss: 0.3811 - val_root_mean_squared_error: 0.6173
# Epoch 38/100
# 10/10 - 2s - loss: 0.3196 - root_mean_squared_error: 0.5654 - val_loss: 0.5093 - val_root_mean_squared_error: 0.7136
# Epoch 39/100
# 10/10 - 2s - loss: 0.3808 - root_mean_squared_error: 0.6171 - val_loss: 0.4019 - val_root_mean_squared_error: 0.6339
# Epoch 40/100
# 10/10 - 2s - loss: 0.2953 - root_mean_squared_error: 0.5434 - val_loss: 0.3270 - val_root_mean_squared_error: 0.5719
# Epoch 41/100
# 10/10 - 2s - loss: 0.2776 - root_mean_squared_error: 0.5269 - val_loss: 0.3323 - val_root_mean_squared_error: 0.5764
# Epoch 42/100
# 10/10 - 3s - loss: 0.2862 - root_mean_squared_error: 0.5349 - val_loss: 0.3786 - val_root_mean_squared_error: 0.6153
# Epoch 43/100
# 10/10 - 2s - loss: 0.2707 - root_mean_squared_error: 0.5203 - val_loss: 0.3998 - val_root_mean_squared_error: 0.6323
# Epoch 44/100
# 10/10 - 2s - loss: 0.2835 - root_mean_squared_error: 0.5325 - val_loss: 0.5479 - val_root_mean_squared_error: 0.7402
# Epoch 45/100
# 10/10 - 2s - loss: 0.3358 - root_mean_squared_error: 0.5795 - val_loss: 0.3377 - val_root_mean_squared_error: 0.5811
# Epoch 46/100
# 10/10 - 2s - loss: 0.3304 - root_mean_squared_error: 0.5748 - val_loss: 0.3366 - val_root_mean_squared_error: 0.5802
# Epoch 47/100
# 10/10 - 2s - loss: 0.3426 - root_mean_squared_error: 0.5853 - val_loss: 0.5476 - val_root_mean_squared_error: 0.7400
# Epoch 48/100
# 10/10 - 2s - loss: 0.3340 - root_mean_squared_error: 0.5779 - val_loss: 0.2916 - val_root_mean_squared_error: 0.5400
# Epoch 49/100
# 10/10 - 2s - loss: 0.3726 - root_mean_squared_error: 0.6104 - val_loss: 0.3463 - val_root_mean_squared_error: 0.5885
# Epoch 50/100
# 10/10 - 2s - loss: 0.3212 - root_mean_squared_error: 0.5667 - val_loss: 0.5314 - val_root_mean_squared_error: 0.7290
# Epoch 51/100
# 10/10 - 2s - loss: 0.3444 - root_mean_squared_error: 0.5869 - val_loss: 0.3979 - val_root_mean_squared_error: 0.6308
# Epoch 52/100
# 10/10 - 2s - loss: 0.2966 - root_mean_squared_error: 0.5446 - val_loss: 0.4706 - val_root_mean_squared_error: 0.6860
# Epoch 53/100
# 10/10 - 2s - loss: 0.3245 - root_mean_squared_error: 0.5696 - val_loss: 0.4194 - val_root_mean_squared_error: 0.6476
# Epoch 54/100
# 10/10 - 2s - loss: 0.3203 - root_mean_squared_error: 0.5659 - val_loss: 0.3825 - val_root_mean_squared_error: 0.6184
# Epoch 55/100
# 10/10 - 2s - loss: 0.3093 - root_mean_squared_error: 0.5561 - val_loss: 0.3952 - val_root_mean_squared_error: 0.6287
# Epoch 56/100
# 10/10 - 2s - loss: 0.3068 - root_mean_squared_error: 0.5539 - val_loss: 0.5004 - val_root_mean_squared_error: 0.7074
# Epoch 57/100
# 10/10 - 2s - loss: 0.3133 - root_mean_squared_error: 0.5597 - val_loss: 0.3285 - val_root_mean_squared_error: 0.5731
# Epoch 58/100
# 10/10 - 2s - loss: 0.3197 - root_mean_squared_error: 0.5654 - val_loss: 0.3289 - val_root_mean_squared_error: 0.5735
# Epoch 59/100
# 10/10 - 2s - loss: 0.3290 - root_mean_squared_error: 0.5736 - val_loss: 0.3186 - val_root_mean_squared_error: 0.5645
# Epoch 60/100
# 10/10 - 2s - loss: 0.3451 - root_mean_squared_error: 0.5874 - val_loss: 0.5006 - val_root_mean_squared_error: 0.7075
# Epoch 61/100
# 10/10 - 2s - loss: 0.3288 - root_mean_squared_error: 0.5735 - val_loss: 0.3724 - val_root_mean_squared_error: 0.6102
# Epoch 62/100
# 10/10 - 2s - loss: 0.2968 - root_mean_squared_error: 0.5448 - val_loss: 0.3703 - val_root_mean_squared_error: 0.6085
# Epoch 63/100
# 10/10 - 3s - loss: 0.3052 - root_mean_squared_error: 0.5524 - val_loss: 0.4386 - val_root_mean_squared_error: 0.6622
# Epoch 64/100
# 10/10 - 2s - loss: 0.3018 - root_mean_squared_error: 0.5493 - val_loss: 0.4792 - val_root_mean_squared_error: 0.6922
# Epoch 65/100
# 10/10 - 2s - loss: 0.2969 - root_mean_squared_error: 0.5449 - val_loss: 0.3197 - val_root_mean_squared_error: 0.5654
# Epoch 66/100
# 10/10 - 2s - loss: 0.2992 - root_mean_squared_error: 0.5470 - val_loss: 0.3913 - val_root_mean_squared_error: 0.6255
# Epoch 67/100
# 10/10 - 2s - loss: 0.2935 - root_mean_squared_error: 0.5417 - val_loss: 0.3027 - val_root_mean_squared_error: 0.5502
# Epoch 68/100
# 10/10 - 2s - loss: 0.3060 - root_mean_squared_error: 0.5532 - val_loss: 0.3781 - val_root_mean_squared_error: 0.6149
# Epoch 69/100
# 10/10 - 2s - loss: 0.3039 - root_mean_squared_error: 0.5513 - val_loss: 0.4184 - val_root_mean_squared_error: 0.6468
# Epoch 70/100
# 10/10 - 2s - loss: 0.2643 - root_mean_squared_error: 0.5141 - val_loss: 0.3277 - val_root_mean_squared_error: 0.5725
# Epoch 71/100
# 10/10 - 2s - loss: 0.3149 - root_mean_squared_error: 0.5611 - val_loss: 0.3127 - val_root_mean_squared_error: 0.5592
# Epoch 72/100
# 10/10 - 2s - loss: 0.2741 - root_mean_squared_error: 0.5235 - val_loss: 0.3786 - val_root_mean_squared_error: 0.6153
# Epoch 73/100
# 10/10 - 2s - loss: 0.3024 - root_mean_squared_error: 0.5499 - val_loss: 0.4350 - val_root_mean_squared_error: 0.6596
# Epoch 74/100
# 10/10 - 2s - loss: 0.2870 - root_mean_squared_error: 0.5357 - val_loss: 0.3309 - val_root_mean_squared_error: 0.5753
# Epoch 75/100
# 10/10 - 2s - loss: 0.2873 - root_mean_squared_error: 0.5360 - val_loss: 0.3442 - val_root_mean_squared_error: 0.5867
# Epoch 76/100
# 10/10 - 2s - loss: 0.2942 - root_mean_squared_error: 0.5424 - val_loss: 0.3798 - val_root_mean_squared_error: 0.6163
# Epoch 77/100
# 10/10 - 2s - loss: 0.3144 - root_mean_squared_error: 0.5607 - val_loss: 0.3518 - val_root_mean_squared_error: 0.5932
# Epoch 78/100
# 10/10 - 2s - loss: 0.2491 - root_mean_squared_error: 0.4991 - val_loss: 0.3430 - val_root_mean_squared_error: 0.5856
# Restoring model weights from the end of the best epoch.
# Epoch 00078: early stopping
# #### FOLD 1 OOF RMSE = 0.5400

# %% [markdown]
# ## Model loss and metrics graph

# %%
for fold, history in enumerate(history_list):
    print(f'\nFOLD: {fold+1}')
    plot_metrics(history)
# Out:
# FOLD: 1

# %% [markdown]
# # Model evaluation
#
# We are evaluating the model on the `OOF` predictions, it stands for `Out Of Fold`, since we are training using `K-Fold` our model will see all the data, and the correct way to evaluate each fold is by looking at the predictions that are not from that fold.
#
# ## OOF metrics

# %%
y_true = np.concatenate(oof_labels)
y_preds = np.concatenate(oof_pred)


for fold, history in enumerate(history_list):
    print(f"FOLD {fold+1} RMSE: {np.min(history['val_root_mean_squared_error']):.4f}")
    
print(f'OOF RMSE: {mean_squared_error(y_true, y_preds, squared=False):.4f}')
# Out:
# FOLD 1 RMSE: 0.5400
# OOF RMSE: 0.5400

# %% [markdown]
# ### **Error analysis**, label x prediction distribution
#
# Here we can compare the distribution from the labels and the predicted values, in a perfect scenario they should align.

# %%
preds_df = pd.DataFrame({'Label': y_true, 'Prediction': y_preds[:,0]})

fig, ax = plt.subplots(1, 1, figsize=(20, 6))
sns.distplot(preds_df['Label'], ax=ax, label='Label')
sns.distplot(preds_df['Prediction'], ax=ax, label='Prediction')
ax.legend()
plt.show()

# %%
sns.jointplot(data=preds_df, x='Label', y='Prediction', kind='reg', height=10)
plt.show()
