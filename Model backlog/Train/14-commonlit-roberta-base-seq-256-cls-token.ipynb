# %% [markdown]
# ## Dependencies

# %%
import warnings, math, json
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
from tensorflow.keras import optimizers, losses, metrics, Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from transformers import TFAutoModelForSequenceClassification, TFAutoModel, AutoTokenizer
from commonlit_scripts import *


seed = 0
seed_everything(seed)
sns.set(style='whitegrid')
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 150)

# %% [markdown]
# ### Hardware configuration

# %%
strategy, tpu = get_strategy()
AUTO = tf.data.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
print(f'REPLICAS: {REPLICAS}')
# Out:
# Running on TPU grpc://10.0.0.2:8470
# REPLICAS: 8

# %% [markdown]
# # Load data

# %%
train_filepath = '/kaggle/input/commonlitreadabilityprize/train.csv'
train = pd.read_csv(train_filepath)
print(f'Train samples: {len(train)}')
# removing unused columns
train.drop(['url_legal', 'license'], axis=1, inplace=True)
display(train.head())
# Out:
# Train samples: 2834
#           id  \
# 0  c12129c31
# 1  85aa80a4c
# 2  b69ac6792
# 3  dd1000b26
# 4  37c1b32fb
#
#                                                                                                                                                  excerpt  \
# 0  When the young people returned to the ballroom, it presented a decidedly changed appearance. Instead of an interior scene, it was a winter landsca...
# 1  All through dinner time, Mrs. Fayre was somewhat silent, her eyes resting on Dolly with a wistful, uncertain expression. She wanted to give the ch...
# 2  As Roger had predicted, the snow departed as quickly as it came, and two days after their sleigh ride there was scarcely a vestige of white on the...
# 3  And outside before the palace a great garden was walled round, filled full of stately fruit-trees, gray olives and sweet figs, and pomegranates, p...
# 4  Once upon a time there were Three Bears who lived together in a house of their own in a wood. One of them was a Little, Small, Wee Bear; and one w...
#
#      target  standard_error
# 0 -0.340259        0.464009
# 1 -0.315372        0.480805
# 2 -0.580118        0.476676
# 3 -1.054013        0.450007
# 4  0.247197        0.510845

# %% [markdown]
# # Model parameters

# %%
config = {
  "BATCH_SIZE": 8 * REPLICAS,
  "LEARNING_RATE": 1e-5 * REPLICAS,
  "EPOCHS": 100,
  "ES_PATIENCE": 30,
  "N_FOLDS": 5,
  "N_USED_FOLDS": 1,
  "SEQ_LEN": 256,
  "BASE_MODEL": '/kaggle/input/huggingface-roberta/roberta-base/',
  "SEED": seed,
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# ## Auxiliary functions

# %%
# Datasets utility functions
def custom_standardization(text, is_lower=True):
    if is_lower:
        text = text.lower() # if encoder is uncased
    text = text.strip()
    return text

def sample_target(features, target):
    mean, stddev = target
    sampled_target = tf.random.normal([], mean=tf.cast(mean, dtype=tf.float32), 
                                      stddev=tf.cast(stddev, dtype=tf.float32), dtype=tf.float32)
    return (features, sampled_target)
    
def get_dataset(pandas_df, tokenizer, labeled=True, ordered=False, repeated=False, 
                is_sampled=False, batch_size=32, seq_len=128, is_lower=True):
    """
        Return a Tensorflow dataset ready for training or inference.
    """
    text = [custom_standardization(text, is_lower) for text in pandas_df['excerpt']]
    
    # Tokenize inputs
    tokenized_inputs = tokenizer(text, max_length=seq_len, truncation=True, 
                                 padding='max_length', return_tensors='tf')
    
    if labeled:
        dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': tokenized_inputs['input_ids'], 
                                                       'attention_mask': tokenized_inputs['attention_mask']}, 
                                                      (pandas_df['target'], pandas_df['standard_error'])))
        if is_sampled:
            dataset = dataset.map(sample_target, num_parallel_calls=tf.data.AUTOTUNE)
    else:
        dataset = tf.data.Dataset.from_tensor_slices({'input_ids': tokenized_inputs['input_ids'], 
                                                      'attention_mask': tokenized_inputs['attention_mask']})
        
    if repeated:
        dataset = dataset.repeat()
    if not ordered:
        dataset = dataset.shuffle(2048)
    dataset = dataset.batch(batch_size)
    dataset = dataset.cache()
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# %% [markdown]
# # Model

# %%
def model_fn(encoder, seq_len=256):
    input_ids = L.Input(shape=(seq_len,), dtype=tf.int32, name='input_ids')
    input_attention_mask = L.Input(shape=(seq_len,), dtype=tf.int32, name='attention_mask')
    
    outputs = encoder({'input_ids': input_ids,  
                       'attention_mask': input_attention_mask})
    last_hidden_state = outputs['last_hidden_state']
    
    cls_token = last_hidden_state[:, 0, :]
#     x = L.GlobalAveragePooling1D()(last_hidden_state)
    output = L.Dense(1, name='output')(cls_token)
    
    model = Model(inputs=[input_ids, input_attention_mask], outputs=output)

    optimizer = optimizers.Adam(lr=config['LEARNING_RATE'])
    model.compile(optimizer=optimizer, 
                  loss=losses.MeanSquaredError(), 
                  metrics=[metrics.RootMeanSquaredError()])
    return model


with strategy.scope():
    encoder = TFAutoModel.from_pretrained(config['BASE_MODEL'])
    model = model_fn(encoder, config['SEQ_LEN'])
    
model.summary()
# Out:
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# attention_mask (InputLayer)     [(None, 256)]        0
# __________________________________________________________________________________________________
# input_ids (InputLayer)          [(None, 256)]        0
# __________________________________________________________________________________________________
# tf_roberta_model (TFRobertaMode TFBaseModelOutputWit 124645632   attention_mask[0][0]
#                                                                  input_ids[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici (None, 768)          0           tf_roberta_model[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            769         tf.__operators__.getitem[0][0]
# ==================================================================================================
# Total params: 124,646,401
# Trainable params: 124,646,401
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
tokenizer = AutoTokenizer.from_pretrained(config['BASE_MODEL'])
skf = KFold(n_splits=config['N_FOLDS'], shuffle=True, random_state=seed)
oof_pred = []; oof_labels = []; history_list = []

for fold,(idxT, idxV) in enumerate(skf.split(train)):
    if fold >= config['N_USED_FOLDS']:
        break
    if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    print(f'\nFOLD: {fold+1}')
    print(f'TRAIN: {len(idxT)} VALID: {len(idxV)}')

    # Model
    K.clear_session()
    with strategy.scope():
        encoder = TFAutoModel.from_pretrained(config['BASE_MODEL'])
        model = model_fn(encoder, config['SEQ_LEN'])
        
    model_path = f'model_{fold}.h5'
    es = EarlyStopping(monitor='val_root_mean_squared_error', mode='min', 
                       patience=config['ES_PATIENCE'], restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_root_mean_squared_error', mode='min', 
                                 save_best_only=True, save_weights_only=True)

    # Train
    history = model.fit(x=get_dataset(train.loc[idxT], tokenizer, repeated=True, is_sampled=True, 
                                      batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN']), 
                        validation_data=get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                                                    batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN']), 
                        steps_per_epoch=10, 
                        callbacks=[es, checkpoint], 
                        epochs=config['EPOCHS'],  
                        verbose=2).history
      
    history_list.append(history)
    # Save last model weights
    model.load_weights(model_path)
    
    # Results
    print(f"#### FOLD {fold+1} OOF RMSE = {np.min(history['val_root_mean_squared_error']):.4f}")

    # OOF predictions
    valid_ds = get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                           batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN'])
    oof_labels.append([target[0].numpy() for sample, target in iter(valid_ds.unbatch())])
    x_oof = valid_ds.map(lambda sample, target: sample)
    oof_pred.append(model.predict(x_oof))
# Out:
# FOLD: 1
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/100
# 10/10 - 85s - loss: 1.4640 - root_mean_squared_error: 1.2100 - val_loss: 0.7248 - val_root_mean_squared_error: 0.8514
# Epoch 2/100
# 10/10 - 2s - loss: 1.3107 - root_mean_squared_error: 1.1449 - val_loss: 0.8102 - val_root_mean_squared_error: 0.9001
# Epoch 3/100
# 10/10 - 2s - loss: 1.0011 - root_mean_squared_error: 1.0005 - val_loss: 0.4270 - val_root_mean_squared_error: 0.6535
# Epoch 4/100
# 10/10 - 2s - loss: 0.7531 - root_mean_squared_error: 0.8678 - val_loss: 0.4792 - val_root_mean_squared_error: 0.6922
# Epoch 5/100
# 10/10 - 2s - loss: 0.6939 - root_mean_squared_error: 0.8330 - val_loss: 0.4690 - val_root_mean_squared_error: 0.6848
# Epoch 6/100
# 10/10 - 2s - loss: 0.5743 - root_mean_squared_error: 0.7578 - val_loss: 0.3966 - val_root_mean_squared_error: 0.6298
# Epoch 7/100
# 10/10 - 2s - loss: 0.6282 - root_mean_squared_error: 0.7926 - val_loss: 0.5508 - val_root_mean_squared_error: 0.7422
# Epoch 8/100
# 10/10 - 2s - loss: 0.5705 - root_mean_squared_error: 0.7553 - val_loss: 0.4057 - val_root_mean_squared_error: 0.6369
# Epoch 9/100
# 10/10 - 2s - loss: 0.5441 - root_mean_squared_error: 0.7376 - val_loss: 0.4826 - val_root_mean_squared_error: 0.6947
# Epoch 10/100
# 10/10 - 2s - loss: 0.5446 - root_mean_squared_error: 0.7379 - val_loss: 0.2893 - val_root_mean_squared_error: 0.5378
# Epoch 11/100
# 10/10 - 2s - loss: 0.4751 - root_mean_squared_error: 0.6892 - val_loss: 0.4799 - val_root_mean_squared_error: 0.6928
# Epoch 12/100
# 10/10 - 2s - loss: 0.4418 - root_mean_squared_error: 0.6647 - val_loss: 0.3781 - val_root_mean_squared_error: 0.6149
# Epoch 13/100
# 10/10 - 2s - loss: 0.4768 - root_mean_squared_error: 0.6905 - val_loss: 0.6349 - val_root_mean_squared_error: 0.7968
# Epoch 14/100
# 10/10 - 2s - loss: 0.5343 - root_mean_squared_error: 0.7310 - val_loss: 0.3518 - val_root_mean_squared_error: 0.5931
# Epoch 15/100
# 10/10 - 2s - loss: 0.4505 - root_mean_squared_error: 0.6712 - val_loss: 0.4159 - val_root_mean_squared_error: 0.6449
# Epoch 16/100
# 10/10 - 2s - loss: 0.4961 - root_mean_squared_error: 0.7043 - val_loss: 0.4286 - val_root_mean_squared_error: 0.6547
# Epoch 17/100
# 10/10 - 2s - loss: 0.3754 - root_mean_squared_error: 0.6127 - val_loss: 0.4560 - val_root_mean_squared_error: 0.6753
# Epoch 18/100
# 10/10 - 2s - loss: 0.4317 - root_mean_squared_error: 0.6571 - val_loss: 0.3131 - val_root_mean_squared_error: 0.5595
# Epoch 19/100
# 10/10 - 2s - loss: 0.4318 - root_mean_squared_error: 0.6571 - val_loss: 0.6499 - val_root_mean_squared_error: 0.8061
# Epoch 20/100
# 10/10 - 2s - loss: 0.4383 - root_mean_squared_error: 0.6620 - val_loss: 0.5106 - val_root_mean_squared_error: 0.7146
# Epoch 21/100
# 10/10 - 2s - loss: 0.4574 - root_mean_squared_error: 0.6763 - val_loss: 0.2727 - val_root_mean_squared_error: 0.5223
# Epoch 22/100
# 10/10 - 2s - loss: 0.5301 - root_mean_squared_error: 0.7281 - val_loss: 0.4754 - val_root_mean_squared_error: 0.6895
# Epoch 23/100
# 10/10 - 2s - loss: 0.4090 - root_mean_squared_error: 0.6395 - val_loss: 0.2983 - val_root_mean_squared_error: 0.5461
# Epoch 24/100
# 10/10 - 2s - loss: 0.3849 - root_mean_squared_error: 0.6204 - val_loss: 0.4576 - val_root_mean_squared_error: 0.6765
# Epoch 25/100
# 10/10 - 2s - loss: 0.3929 - root_mean_squared_error: 0.6268 - val_loss: 0.2741 - val_root_mean_squared_error: 0.5236
# Epoch 26/100
# 10/10 - 2s - loss: 0.3842 - root_mean_squared_error: 0.6198 - val_loss: 0.6204 - val_root_mean_squared_error: 0.7877
# Epoch 27/100
# 10/10 - 2s - loss: 0.4713 - root_mean_squared_error: 0.6865 - val_loss: 0.2931 - val_root_mean_squared_error: 0.5414
# Epoch 28/100
# 10/10 - 2s - loss: 0.5126 - root_mean_squared_error: 0.7159 - val_loss: 0.3565 - val_root_mean_squared_error: 0.5971
# Epoch 29/100
# 10/10 - 2s - loss: 0.5824 - root_mean_squared_error: 0.7632 - val_loss: 0.3756 - val_root_mean_squared_error: 0.6129
# Epoch 30/100
# 10/10 - 3s - loss: 0.4752 - root_mean_squared_error: 0.6893 - val_loss: 0.3907 - val_root_mean_squared_error: 0.6250
# Epoch 31/100
# 10/10 - 2s - loss: 0.4279 - root_mean_squared_error: 0.6541 - val_loss: 0.3187 - val_root_mean_squared_error: 0.5645
# Epoch 32/100
# 10/10 - 2s - loss: 0.3918 - root_mean_squared_error: 0.6259 - val_loss: 0.3875 - val_root_mean_squared_error: 0.6225
# Epoch 33/100
# 10/10 - 2s - loss: 0.3918 - root_mean_squared_error: 0.6259 - val_loss: 0.2833 - val_root_mean_squared_error: 0.5323
# Epoch 34/100
# 10/10 - 2s - loss: 0.4032 - root_mean_squared_error: 0.6349 - val_loss: 0.4373 - val_root_mean_squared_error: 0.6613
# Epoch 35/100
# 10/10 - 2s - loss: 0.3678 - root_mean_squared_error: 0.6065 - val_loss: 0.3696 - val_root_mean_squared_error: 0.6080
# Epoch 36/100
# 10/10 - 2s - loss: 0.3767 - root_mean_squared_error: 0.6138 - val_loss: 0.2977 - val_root_mean_squared_error: 0.5456
# Epoch 37/100
# 10/10 - 2s - loss: 0.3969 - root_mean_squared_error: 0.6300 - val_loss: 0.4588 - val_root_mean_squared_error: 0.6774
# Epoch 38/100
# 10/10 - 2s - loss: 0.3843 - root_mean_squared_error: 0.6199 - val_loss: 0.3078 - val_root_mean_squared_error: 0.5548
# Epoch 39/100
# 10/10 - 2s - loss: 0.4377 - root_mean_squared_error: 0.6616 - val_loss: 0.5384 - val_root_mean_squared_error: 0.7337
# Epoch 40/100
# 10/10 - 2s - loss: 0.3328 - root_mean_squared_error: 0.5769 - val_loss: 0.3064 - val_root_mean_squared_error: 0.5535
# Epoch 41/100
# 10/10 - 2s - loss: 0.3212 - root_mean_squared_error: 0.5667 - val_loss: 0.4603 - val_root_mean_squared_error: 0.6784
# Epoch 42/100
# 10/10 - 2s - loss: 0.3506 - root_mean_squared_error: 0.5921 - val_loss: 0.3553 - val_root_mean_squared_error: 0.5961
# Epoch 43/100
# 10/10 - 2s - loss: 0.3438 - root_mean_squared_error: 0.5864 - val_loss: 0.3714 - val_root_mean_squared_error: 0.6094
# Epoch 44/100
# 10/10 - 2s - loss: 0.3348 - root_mean_squared_error: 0.5786 - val_loss: 0.3232 - val_root_mean_squared_error: 0.5685
# Epoch 45/100
# 10/10 - 2s - loss: 0.3836 - root_mean_squared_error: 0.6194 - val_loss: 0.4098 - val_root_mean_squared_error: 0.6401
# Epoch 46/100
# 10/10 - 2s - loss: 0.3402 - root_mean_squared_error: 0.5833 - val_loss: 0.2883 - val_root_mean_squared_error: 0.5369
# Epoch 47/100
# 10/10 - 2s - loss: 0.3812 - root_mean_squared_error: 0.6174 - val_loss: 0.4487 - val_root_mean_squared_error: 0.6699
# Epoch 48/100
# 10/10 - 2s - loss: 0.4003 - root_mean_squared_error: 0.6327 - val_loss: 0.3960 - val_root_mean_squared_error: 0.6293
# Epoch 49/100
# 10/10 - 2s - loss: 0.3705 - root_mean_squared_error: 0.6087 - val_loss: 0.3575 - val_root_mean_squared_error: 0.5979
# Epoch 50/100
# 10/10 - 2s - loss: 0.3090 - root_mean_squared_error: 0.5559 - val_loss: 0.3674 - val_root_mean_squared_error: 0.6061
# Epoch 51/100
# 10/10 - 2s - loss: 0.3400 - root_mean_squared_error: 0.5831 - val_loss: 0.2928 - val_root_mean_squared_error: 0.5411
# Restoring model weights from the end of the best epoch.
# Epoch 00051: early stopping
# #### FOLD 1 OOF RMSE = 0.5223

# %% [markdown]
# ## Model loss and metrics graph

# %%
for fold, history in enumerate(history_list):
    print(f'\nFOLD: {fold+1}')
    plot_metrics(history)
# Out:
# FOLD: 1

# %% [markdown]
# # Model evaluation
#
# We are evaluating the model on the `OOF` predictions, it stands for `Out Of Fold`, since we are training using `K-Fold` our model will see all the data, and the correct way to evaluate each fold is by looking at the predictions that are not from that fold.
#
# ## OOF metrics

# %%
y_true = np.concatenate(oof_labels)
y_preds = np.concatenate(oof_pred)

for fold, history in enumerate(history_list):
    print(f"FOLD {fold+1} RMSE: {np.min(history['val_root_mean_squared_error']):.4f}")
    
print(f'OOF RMSE: {mean_squared_error(y_true, y_preds, squared=False):.4f}')
# Out:
# FOLD 1 RMSE: 0.5223
# OOF RMSE: 0.5223

# %% [markdown]
# ### **Error analysis**, label x prediction distribution
#
# Here we can compare the distribution from the labels and the predicted values, in a perfect scenario they should align.

# %%
preds_df = pd.DataFrame({'Label': y_true, 'Prediction': y_preds[:,0]})

fig, ax = plt.subplots(1, 1, figsize=(20, 6))
sns.distplot(preds_df['Label'], ax=ax, label='Label')
sns.distplot(preds_df['Prediction'], ax=ax, label='Prediction')
ax.legend()
plt.show()

# %%
sns.jointplot(data=preds_df, x='Label', y='Prediction', kind='reg', height=10)
plt.show()
