# %% [markdown]
# ## Dependencies

# %%
import random, os, warnings, math
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import tensorflow as tf
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
from tensorflow.keras import optimizers, losses, metrics, Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from transformers import TFAutoModelForSequenceClassification, TFAutoModel, AutoTokenizer


def seed_everything(seed=0):
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'

seed = 0
seed_everything(seed)
sns.set(style='whitegrid')
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 150)

# %% [markdown]
# ### Hardware configuration

# %%
# TPU or GPU detection
# Detect hardware, return appropriate distribution strategy
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print(f'Running on TPU {tpu.master()}')
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy()

AUTO = tf.data.experimental.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
print(f'REPLICAS: {REPLICAS}')
# Out:
# Running on TPU grpc://10.0.0.2:8470
# REPLICAS: 8

# %% [markdown]
# # Load data

# %%
train_filepath = '/kaggle/input/commonlitreadabilityprize/train.csv'
train = pd.read_csv(train_filepath)
print(f'Train samples: {len(train)}')
display(train.head())
# removing unused columns
train.drop(['url_legal', 'license'], axis=1, inplace=True)
# Out:
# Train samples: 2834
#           id url_legal license  \
# 0  c12129c31       NaN     NaN
# 1  85aa80a4c       NaN     NaN
# 2  b69ac6792       NaN     NaN
# 3  dd1000b26       NaN     NaN
# 4  37c1b32fb       NaN     NaN
#
#                                                                                                                                                  excerpt  \
# 0  When the young people returned to the ballroom, it presented a decidedly changed appearance. Instead of an interior scene, it was a winter landsca...
# 1  All through dinner time, Mrs. Fayre was somewhat silent, her eyes resting on Dolly with a wistful, uncertain expression. She wanted to give the ch...
# 2  As Roger had predicted, the snow departed as quickly as it came, and two days after their sleigh ride there was scarcely a vestige of white on the...
# 3  And outside before the palace a great garden was walled round, filled full of stately fruit-trees, gray olives and sweet figs, and pomegranates, p...
# 4  Once upon a time there were Three Bears who lived together in a house of their own in a wood. One of them was a Little, Small, Wee Bear; and one w...
#
#      target  standard_error
# 0 -0.340259        0.464009
# 1 -0.315372        0.480805
# 2 -0.580118        0.476676
# 3 -1.054013        0.450007
# 4  0.247197        0.510845

# %% [markdown]
# # Model parameters

# %%
BATCH_SIZE = 8 * REPLICAS
LEARNING_RATE = 1e-5 * REPLICAS
EPOCHS = 35
ES_PATIENCE = 10
PATIENCE = 2
N_FOLDS = 5
SEQ_LEN = 300
BASE_MODEL = '/kaggle/input/huggingface-roberta/roberta-large/'

# %% [markdown]
# ## Auxiliary functions

# %%
# Datasets utility functions
def custom_standardization(text):
    text = text.lower() # if encoder is uncased
    text = text.strip()
    return text


def sample_target(features, target):
    mean, stddev = target
    sampled_target = tf.random.normal([], mean=tf.cast(mean, dtype=tf.float32), 
                                      stddev=tf.cast(stddev, dtype=tf.float32), dtype=tf.float32)
    
    return (features, sampled_target)
    

def get_dataset(pandas_df, tokenizer, labeled=True, ordered=False, repeated=False, 
                is_sampled=False, batch_size=32, seq_len=128):
    """
        Return a Tensorflow dataset ready for training or inference.
    """
    text = [custom_standardization(text) for text in pandas_df['excerpt']]
    
    # Tokenize inputs
    tokenized_inputs = tokenizer(text, max_length=seq_len, truncation=True, 
                                 padding='max_length', return_tensors='tf')
    
    if labeled:
        dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': tokenized_inputs['input_ids'], 
                                                      'attention_mask': tokenized_inputs['attention_mask']}, 
                                                      (pandas_df['target'], pandas_df['standard_error'])))
        if is_sampled:
            dataset = dataset.map(sample_target, num_parallel_calls=tf.data.AUTOTUNE)
    else:
        dataset = tf.data.Dataset.from_tensor_slices({'input_ids': tokenized_inputs['input_ids'], 
                                                      'attention_mask': tokenized_inputs['attention_mask']})
        
    if repeated:
        dataset = dataset.repeat()
    if not ordered:
        dataset = dataset.shuffle(1024)
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    
    return dataset


def plot_metrics(history):
    metric_list = list(history.keys())
    size = len(metric_list)//2
    fig, axes = plt.subplots(size, 1, sharex='col', figsize=(20, size * 5))
    axes = axes.flatten()
    
    for index in range(len(metric_list)//2):
        metric_name = metric_list[index]
        val_metric_name = metric_list[index+size]
        axes[index].plot(history[metric_name], label='Train %s' % metric_name)
        axes[index].plot(history[val_metric_name], label='Validation %s' % metric_name)
        axes[index].legend(loc='best', fontsize=16)
        axes[index].set_title(metric_name)

    plt.xlabel('Epochs', fontsize=16)
    sns.despine()
    plt.show()

# %% [markdown]
# # Model

# %%
def model_fn(encoder, seq_len=256):
    input_ids = L.Input(shape=(seq_len,), dtype=tf.int32, name='input_ids')
    input_attention_mask = L.Input(shape=(seq_len,), dtype=tf.int32, name='attention_mask')
    
    outputs = encoder({'input_ids': input_ids, 
                       'attention_mask': input_attention_mask})
    last_hidden_state = outputs['last_hidden_state']
    
    x = L.GlobalAveragePooling1D()(last_hidden_state)
#     x = L.Dropout(.5)(x)
    output = L.Dense(1, name='output')(x)
    
    model = Model(inputs=[input_ids, input_attention_mask], outputs=output)

    optimizer = optimizers.Adam(lr=LEARNING_RATE)
    model.compile(optimizer=optimizer, 
                  loss=losses.MeanSquaredError(), 
                  metrics=[metrics.RootMeanSquaredError()])
    
    return model


with strategy.scope():
#     encoder = TFAutoModelForSequenceClassification.from_pretrained(BASE_MODEL, num_labels=1)
    encoder = TFAutoModel.from_pretrained(BASE_MODEL)
    model = model_fn(encoder, SEQ_LEN)
    
model.summary()
# Out:
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-large/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-large/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# attention_mask (InputLayer)     [(None, 300)]        0
# __________________________________________________________________________________________________
# input_ids (InputLayer)          [(None, 300)]        0
# __________________________________________________________________________________________________
# tf_roberta_model (TFRobertaMode TFBaseModelOutputWit 355359744   attention_mask[0][0]
#                                                                  input_ids[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 1024)         0           tf_roberta_model[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            1025        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 355,360,769
# Trainable params: 355,360,769
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL)
skf = KFold(n_splits=N_FOLDS, shuffle=True, random_state=seed)
oof_pred = []; oof_labels = []; history_list = []

for fold,(idxT, idxV) in enumerate(skf.split(train)):
    if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    print(f'\nFOLD: {fold+1}')
    print(f'TRAIN: {len(idxT)} VALID: {len(idxV)}')

    # Model
    K.clear_session()
    with strategy.scope():
#         encoder = TFAutoModelForSequenceClassification.from_pretrained(BASE_MODEL, num_labels=1)
        encoder = TFAutoModel.from_pretrained(BASE_MODEL)
        model = model_fn(encoder, SEQ_LEN)
        
    model_path = f'model_{fold}.h5'
    es = EarlyStopping(monitor='val_root_mean_squared_error', mode='min', 
                       patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_root_mean_squared_error', mode='min', 
                                 save_best_only=True, save_weights_only=True)

    # Train
    history = model.fit(x=get_dataset(train.loc[idxT], tokenizer, repeated=True, is_sampled=True, 
                                      batch_size=BATCH_SIZE, seq_len=SEQ_LEN), 
                        validation_data=get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                                                    batch_size=BATCH_SIZE, seq_len=SEQ_LEN), 
                        steps_per_epoch=50, 
                        callbacks=[es, checkpoint], 
                        epochs=EPOCHS,  
                        verbose=2).history
      
    history_list.append(history)
    # Save last model weights
    model.load_weights(model_path)
    
    # Results
    print(f"#### FOLD {fold+1} OOF RMSE = {np.min(history['val_root_mean_squared_error']):.4f}")

    # OOF predictions
    valid_ds = get_dataset(train.loc[idxV], tokenizer, ordered=True, batch_size=BATCH_SIZE, seq_len=SEQ_LEN)
    oof_labels.append([target[0].numpy() for sample, target in iter(valid_ds.unbatch())])
    x_oof = valid_ds.map(lambda sample, target: sample)
    oof_pred.append(model.predict(x_oof))
# Out:
# FOLD: 1
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-large/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-large/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/35
# 50/50 - 187s - loss: 1.5505 - root_mean_squared_error: 1.2452 - val_loss: 0.9676 - val_root_mean_squared_error: 0.9837
# Epoch 2/35
# 50/50 - 16s - loss: 0.8076 - root_mean_squared_error: 0.8987 - val_loss: 0.7683 - val_root_mean_squared_error: 0.8765
# Epoch 3/35
# 50/50 - 16s - loss: 0.5814 - root_mean_squared_error: 0.7625 - val_loss: 0.5545 - val_root_mean_squared_error: 0.7446
# Epoch 4/35
# 50/50 - 16s - loss: 0.5301 - root_mean_squared_error: 0.7281 - val_loss: 0.4932 - val_root_mean_squared_error: 0.7023
# Epoch 5/35
# 50/50 - 17s - loss: 0.4336 - root_mean_squared_error: 0.6585 - val_loss: 0.5118 - val_root_mean_squared_error: 0.7154
# Epoch 6/35
# 50/50 - 16s - loss: 0.5883 - root_mean_squared_error: 0.7670 - val_loss: 0.4804 - val_root_mean_squared_error: 0.6931
# Epoch 7/35
# 50/50 - 16s - loss: 0.4565 - root_mean_squared_error: 0.6757 - val_loss: 0.5176 - val_root_mean_squared_error: 0.7194
# Epoch 8/35
# 50/50 - 16s - loss: 0.7374 - root_mean_squared_error: 0.8587 - val_loss: 1.1699 - val_root_mean_squared_error: 1.0816
# Epoch 9/35
# 50/50 - 16s - loss: 1.3564 - root_mean_squared_error: 1.1647 - val_loss: 1.0892 - val_root_mean_squared_error: 1.0436
# Epoch 10/35
# 50/50 - 16s - loss: 1.2926 - root_mean_squared_error: 1.1369 - val_loss: 1.0905 - val_root_mean_squared_error: 1.0443
# Epoch 11/35
# 50/50 - 16s - loss: 1.3475 - root_mean_squared_error: 1.1608 - val_loss: 1.0718 - val_root_mean_squared_error: 1.0353
# Epoch 12/35
# 50/50 - 16s - loss: 1.3188 - root_mean_squared_error: 1.1484 - val_loss: 1.0887 - val_root_mean_squared_error: 1.0434
# Epoch 13/35
# 50/50 - 16s - loss: 1.3226 - root_mean_squared_error: 1.1500 - val_loss: 1.0976 - val_root_mean_squared_error: 1.0477
# Epoch 14/35
# 50/50 - 16s - loss: 1.3282 - root_mean_squared_error: 1.1525 - val_loss: 1.1798 - val_root_mean_squared_error: 1.0862
# Epoch 15/35
# 50/50 - 16s - loss: 1.3211 - root_mean_squared_error: 1.1494 - val_loss: 1.0915 - val_root_mean_squared_error: 1.0447
# Epoch 16/35
# 50/50 - 16s - loss: 1.3564 - root_mean_squared_error: 1.1646 - val_loss: 1.1130 - val_root_mean_squared_error: 1.0550
# Restoring model weights from the end of the best epoch.
# Epoch 00016: early stopping
# #### FOLD 1 OOF RMSE = 0.6931
#
# FOLD: 2
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-large/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-large/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/35
# 50/50 - 193s - loss: 1.8365 - root_mean_squared_error: 1.3552 - val_loss: 0.7433 - val_root_mean_squared_error: 0.8621
# Epoch 2/35
# 50/50 - 16s - loss: 0.6313 - root_mean_squared_error: 0.7946 - val_loss: 0.7843 - val_root_mean_squared_error: 0.8856
# Epoch 3/35
# 50/50 - 16s - loss: 0.5235 - root_mean_squared_error: 0.7235 - val_loss: 1.0294 - val_root_mean_squared_error: 1.0146
# Epoch 4/35
# 50/50 - 16s - loss: 0.4585 - root_mean_squared_error: 0.6772 - val_loss: 0.4948 - val_root_mean_squared_error: 0.7034
# Epoch 5/35
# 50/50 - 17s - loss: 0.5339 - root_mean_squared_error: 0.7307 - val_loss: 0.6777 - val_root_mean_squared_error: 0.8232
# Epoch 6/35
# 50/50 - 16s - loss: 0.9283 - root_mean_squared_error: 0.9635 - val_loss: 0.9579 - val_root_mean_squared_error: 0.9787
# Epoch 7/35
# 50/50 - 16s - loss: 0.4566 - root_mean_squared_error: 0.6757 - val_loss: 1.1570 - val_root_mean_squared_error: 1.0756
# Epoch 8/35
# 50/50 - 16s - loss: 0.4575 - root_mean_squared_error: 0.6764 - val_loss: 1.0650 - val_root_mean_squared_error: 1.0320
# Epoch 9/35
# 50/50 - 16s - loss: 0.4209 - root_mean_squared_error: 0.6487 - val_loss: 1.1137 - val_root_mean_squared_error: 1.0553
# Epoch 10/35
# 50/50 - 16s - loss: 0.3873 - root_mean_squared_error: 0.6223 - val_loss: 0.8526 - val_root_mean_squared_error: 0.9234
# Epoch 11/35
# 50/50 - 16s - loss: 0.3798 - root_mean_squared_error: 0.6163 - val_loss: 0.7706 - val_root_mean_squared_error: 0.8778
# Epoch 12/35
# 50/50 - 16s - loss: 0.3729 - root_mean_squared_error: 0.6107 - val_loss: 0.9801 - val_root_mean_squared_error: 0.9900
# Epoch 13/35
# 50/50 - 16s - loss: 0.3762 - root_mean_squared_error: 0.6134 - val_loss: 0.6642 - val_root_mean_squared_error: 0.8150
# Epoch 14/35
# 50/50 - 16s - loss: 0.3289 - root_mean_squared_error: 0.5735 - val_loss: 0.8589 - val_root_mean_squared_error: 0.9268
# Restoring model weights from the end of the best epoch.
# Epoch 00014: early stopping
# #### FOLD 2 OOF RMSE = 0.7034
#
# FOLD: 3
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-large/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-large/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/35
# 50/50 - 194s - loss: 1.5546 - root_mean_squared_error: 1.2468 - val_loss: 0.8253 - val_root_mean_squared_error: 0.9084
# Epoch 2/35
# 50/50 - 16s - loss: 0.8127 - root_mean_squared_error: 0.9015 - val_loss: 0.6523 - val_root_mean_squared_error: 0.8077
# Epoch 3/35
# 50/50 - 16s - loss: 0.5981 - root_mean_squared_error: 0.7734 - val_loss: 0.3852 - val_root_mean_squared_error: 0.6206
# Epoch 4/35
# 50/50 - 16s - loss: 0.6723 - root_mean_squared_error: 0.8199 - val_loss: 0.5738 - val_root_mean_squared_error: 0.7575
# Epoch 5/35
# 50/50 - 16s - loss: 0.4979 - root_mean_squared_error: 0.7056 - val_loss: 0.4598 - val_root_mean_squared_error: 0.6781
# Epoch 6/35
# 50/50 - 17s - loss: 0.4762 - root_mean_squared_error: 0.6901 - val_loss: 0.4580 - val_root_mean_squared_error: 0.6767
# Epoch 7/35
# 50/50 - 16s - loss: 0.5701 - root_mean_squared_error: 0.7550 - val_loss: 0.4413 - val_root_mean_squared_error: 0.6643
# Epoch 8/35
# 50/50 - 16s - loss: 0.4338 - root_mean_squared_error: 0.6586 - val_loss: 0.3583 - val_root_mean_squared_error: 0.5986
# Epoch 9/35
# 50/50 - 16s - loss: 0.3456 - root_mean_squared_error: 0.5879 - val_loss: 0.4326 - val_root_mean_squared_error: 0.6577
# Epoch 10/35
# 50/50 - 16s - loss: 0.3679 - root_mean_squared_error: 0.6066 - val_loss: 0.3543 - val_root_mean_squared_error: 0.5952
# Epoch 11/35
# 50/50 - 16s - loss: 0.4254 - root_mean_squared_error: 0.6522 - val_loss: 0.6087 - val_root_mean_squared_error: 0.7802
# Epoch 12/35
# 50/50 - 16s - loss: 1.2931 - root_mean_squared_error: 1.1372 - val_loss: 1.0418 - val_root_mean_squared_error: 1.0207
# Epoch 13/35
# 50/50 - 16s - loss: 1.3592 - root_mean_squared_error: 1.1658 - val_loss: 1.0338 - val_root_mean_squared_error: 1.0168
# Epoch 14/35
# 50/50 - 16s - loss: 1.3546 - root_mean_squared_error: 1.1639 - val_loss: 1.0540 - val_root_mean_squared_error: 1.0266
# Epoch 15/35
# 50/50 - 16s - loss: 1.3125 - root_mean_squared_error: 1.1457 - val_loss: 1.0525 - val_root_mean_squared_error: 1.0259
# Epoch 16/35
# 50/50 - 16s - loss: 1.3981 - root_mean_squared_error: 1.1824 - val_loss: 1.0797 - val_root_mean_squared_error: 1.0391
# Epoch 17/35
# 50/50 - 16s - loss: 1.2886 - root_mean_squared_error: 1.1352 - val_loss: 1.0622 - val_root_mean_squared_error: 1.0306
# Epoch 18/35
# 50/50 - 16s - loss: 1.3530 - root_mean_squared_error: 1.1632 - val_loss: 1.0333 - val_root_mean_squared_error: 1.0165
# Epoch 19/35
# 50/50 - 16s - loss: 1.3700 - root_mean_squared_error: 1.1705 - val_loss: 1.1274 - val_root_mean_squared_error: 1.0618
# Epoch 20/35
# 50/50 - 16s - loss: 1.3049 - root_mean_squared_error: 1.1423 - val_loss: 1.1201 - val_root_mean_squared_error: 1.0583
# Restoring model weights from the end of the best epoch.
# Epoch 00020: early stopping
# #### FOLD 3 OOF RMSE = 0.5952
#
# FOLD: 4
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-large/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-large/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/35
# 50/50 - 197s - loss: 1.1270 - root_mean_squared_error: 1.0616 - val_loss: 0.4907 - val_root_mean_squared_error: 0.7005
# Epoch 2/35
# 50/50 - 16s - loss: 0.7156 - root_mean_squared_error: 0.8459 - val_loss: 0.7122 - val_root_mean_squared_error: 0.8439
# Epoch 3/35
# 50/50 - 17s - loss: 0.8549 - root_mean_squared_error: 0.9246 - val_loss: 0.5926 - val_root_mean_squared_error: 0.7698
# Epoch 4/35
# 50/50 - 16s - loss: 0.5683 - root_mean_squared_error: 0.7538 - val_loss: 0.7511 - val_root_mean_squared_error: 0.8667
# Epoch 5/35
# 50/50 - 16s - loss: 0.4679 - root_mean_squared_error: 0.6840 - val_loss: 0.4822 - val_root_mean_squared_error: 0.6944
# Epoch 6/35
# 50/50 - 16s - loss: 0.4204 - root_mean_squared_error: 0.6484 - val_loss: 0.3556 - val_root_mean_squared_error: 0.5963
# Epoch 7/35
# 50/50 - 16s - loss: 0.3529 - root_mean_squared_error: 0.5941 - val_loss: 0.4406 - val_root_mean_squared_error: 0.6638
# Epoch 8/35
# 50/50 - 16s - loss: 0.3332 - root_mean_squared_error: 0.5773 - val_loss: 0.4978 - val_root_mean_squared_error: 0.7056
# Epoch 9/35
# 50/50 - 16s - loss: 0.3246 - root_mean_squared_error: 0.5698 - val_loss: 0.4596 - val_root_mean_squared_error: 0.6779
# Epoch 10/35
# 50/50 - 16s - loss: 0.3555 - root_mean_squared_error: 0.5963 - val_loss: 0.5198 - val_root_mean_squared_error: 0.7209
# Epoch 11/35
# 50/50 - 16s - loss: 0.3116 - root_mean_squared_error: 0.5582 - val_loss: 0.5960 - val_root_mean_squared_error: 0.7720
# Epoch 12/35
# 50/50 - 16s - loss: 0.3314 - root_mean_squared_error: 0.5756 - val_loss: 0.5043 - val_root_mean_squared_error: 0.7101
# Epoch 13/35
# 50/50 - 16s - loss: 0.3348 - root_mean_squared_error: 0.5786 - val_loss: 0.4155 - val_root_mean_squared_error: 0.6446
# Epoch 14/35
# 50/50 - 16s - loss: 0.3204 - root_mean_squared_error: 0.5660 - val_loss: 0.4084 - val_root_mean_squared_error: 0.6391
# Epoch 15/35
# 50/50 - 16s - loss: 0.3015 - root_mean_squared_error: 0.5491 - val_loss: 0.3572 - val_root_mean_squared_error: 0.5977
# Epoch 16/35
# 50/50 - 16s - loss: 0.3394 - root_mean_squared_error: 0.5826 - val_loss: 0.4160 - val_root_mean_squared_error: 0.6450
# Restoring model weights from the end of the best epoch.
# Epoch 00016: early stopping
# #### FOLD 4 OOF RMSE = 0.5963
#
# FOLD: 5
# TRAIN: 2268 VALID: 566
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-large/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-large/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/35
# 50/50 - 194s - loss: 1.5660 - root_mean_squared_error: 1.2514 - val_loss: 0.4185 - val_root_mean_squared_error: 0.6469
# Epoch 2/35
# 50/50 - 16s - loss: 0.8440 - root_mean_squared_error: 0.9187 - val_loss: 0.6553 - val_root_mean_squared_error: 0.8095
# Epoch 3/35
# 50/50 - 16s - loss: 1.4813 - root_mean_squared_error: 1.2171 - val_loss: 1.0678 - val_root_mean_squared_error: 1.0333
# Epoch 4/35
# 50/50 - 16s - loss: 1.3430 - root_mean_squared_error: 1.1589 - val_loss: 1.0613 - val_root_mean_squared_error: 1.0302
# Epoch 5/35
# 50/50 - 16s - loss: 1.3425 - root_mean_squared_error: 1.1587 - val_loss: 1.0624 - val_root_mean_squared_error: 1.0307
# Epoch 6/35
# 50/50 - 16s - loss: 1.3666 - root_mean_squared_error: 1.1690 - val_loss: 1.1117 - val_root_mean_squared_error: 1.0544
# Epoch 7/35
# 50/50 - 16s - loss: 1.2970 - root_mean_squared_error: 1.1388 - val_loss: 1.0824 - val_root_mean_squared_error: 1.0404
# Epoch 8/35
# 50/50 - 16s - loss: 1.3175 - root_mean_squared_error: 1.1478 - val_loss: 1.2149 - val_root_mean_squared_error: 1.1022
# Epoch 9/35
# 50/50 - 16s - loss: 1.2926 - root_mean_squared_error: 1.1369 - val_loss: 1.0633 - val_root_mean_squared_error: 1.0312
# Epoch 10/35
# 50/50 - 16s - loss: 1.3732 - root_mean_squared_error: 1.1718 - val_loss: 1.1058 - val_root_mean_squared_error: 1.0516
# Epoch 11/35
# 50/50 - 16s - loss: 1.3675 - root_mean_squared_error: 1.1694 - val_loss: 1.0561 - val_root_mean_squared_error: 1.0277
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping
# #### FOLD 5 OOF RMSE = 0.6469

# %% [markdown]
# ## Model loss and metrics graph

# %%
for fold, history in enumerate(history_list):
    print(f'\nFOLD: {fold+1}')
    plot_metrics(history)
# Out:
# FOLD: 1
# FOLD: 2
# FOLD: 3
# FOLD: 4
# FOLD: 5

# %% [markdown]
# # Model evaluation
#
# We are evaluating the model on the `OOF` predictions, it stands for `Out Of Fold`, since we are training using `K-Fold` our model will see all the data, and the correct way to evaluate each fold is by looking at the predictions that are not from that fold.
#
# ## OOF metrics

# %%
y_true = np.concatenate(oof_labels)
y_preds = np.concatenate(oof_pred)


for fold, history in enumerate(history_list):
    print(f"FOLD {fold+1} RMSE: {np.min(history['val_root_mean_squared_error']):.4f}")
    
print(f'OOF RMSE: {mean_squared_error(y_true, y_preds, squared=False):.4f}')
# Out:
# FOLD 1 RMSE: 0.6931
# FOLD 2 RMSE: 0.7034
# FOLD 3 RMSE: 0.5952
# FOLD 4 RMSE: 0.5963
# FOLD 5 RMSE: 0.6469
# OOF RMSE: 0.6486

# %% [markdown]
# ### **Error analysis**, label x prediction distribution
#
# Here we can compare the distribution from the labels and the predicted values, in a perfect scenario they should align.

# %%
preds_df = pd.DataFrame({'Label': y_true, 'Prediction': y_preds[:,0]})

fig, ax = plt.subplots(1, 1, figsize=(20, 6))
sns.distplot(preds_df['Label'], ax=ax, label='Label')
sns.distplot(preds_df['Prediction'], ax=ax, label='Prediction')
ax.legend()
plt.show()

# %%
sns.jointplot(data=preds_df, x='Label', y='Prediction', kind='reg', height=10)
plt.show()
