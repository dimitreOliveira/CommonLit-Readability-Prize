# %% [markdown]
# ## Dependencies

# %%
import warnings, math, json
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import tensorflow_addons as tfa
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
from tensorflow.keras import optimizers, losses, metrics, Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from transformers import TFAutoModelForSequenceClassification, TFAutoModel, AutoTokenizer
from commonlit_scripts import *


seed = 0
seed_everything(seed)
sns.set(style='whitegrid')
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 150)

# %% [markdown]
# ### Hardware configuration

# %%
strategy, tpu = get_strategy()
AUTO = tf.data.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
print(f'REPLICAS: {REPLICAS}')
# Out:
# Running on TPU grpc://10.0.0.2:8470
# REPLICAS: 8

# %% [markdown]
# # Load data

# %%
train_filepath = '/kaggle/input/commonlitreadabilityprize/train.csv'
train = pd.read_csv(train_filepath)
print(f'Train samples: {len(train)}')
# removing unused columns
train.drop(['url_legal', 'license'], axis=1, inplace=True)
display(train.head())
# Out:
# Train samples: 2834
#           id  \
# 0  c12129c31
# 1  85aa80a4c
# 2  b69ac6792
# 3  dd1000b26
# 4  37c1b32fb
#
#                                                                                                                                                  excerpt  \
# 0  When the young people returned to the ballroom, it presented a decidedly changed appearance. Instead of an interior scene, it was a winter landsca...
# 1  All through dinner time, Mrs. Fayre was somewhat silent, her eyes resting on Dolly with a wistful, uncertain expression. She wanted to give the ch...
# 2  As Roger had predicted, the snow departed as quickly as it came, and two days after their sleigh ride there was scarcely a vestige of white on the...
# 3  And outside before the palace a great garden was walled round, filled full of stately fruit-trees, gray olives and sweet figs, and pomegranates, p...
# 4  Once upon a time there were Three Bears who lived together in a house of their own in a wood. One of them was a Little, Small, Wee Bear; and one w...
#
#      target  standard_error
# 0 -0.340259        0.464009
# 1 -0.315372        0.480805
# 2 -0.580118        0.476676
# 3 -1.054013        0.450007
# 4  0.247197        0.510845

# %% [markdown]
# # Model parameters

# %%
config = {
  "BATCH_SIZE": 8 * REPLICAS,
  "LEARNING_RATE": 1e-5 * REPLICAS,
  "EPOCHS": 100,
  "ES_PATIENCE": 30,
  "N_FOLDS": 5,
  "N_USED_FOLDS": 1,
  "SEQ_LEN": 256,
  "BASE_MODEL": '/kaggle/input/huggingface-roberta/roberta-base/',
  "SEED": seed,
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# ## Auxiliary functions

# %%
# Datasets utility functions
def custom_standardization(text, is_lower=True):
    if is_lower:
        text = text.lower() # if encoder is uncased
    text = text.strip()
    return text

def sample_target(features, target):
    mean, stddev = target
    sampled_target = tf.random.normal([], mean=tf.cast(mean, dtype=tf.float32), 
                                      stddev=tf.cast(stddev, dtype=tf.float32), dtype=tf.float32)
    return (features, sampled_target)
    
def get_dataset(pandas_df, tokenizer, labeled=True, ordered=False, repeated=False, 
                is_sampled=False, batch_size=32, seq_len=128, is_lower=True):
    """
        Return a Tensorflow dataset ready for training or inference.
    """
    text = [custom_standardization(text, is_lower) for text in pandas_df['excerpt']]
    
    # Tokenize inputs
    tokenized_inputs = tokenizer(text, max_length=seq_len, truncation=True, 
                                 padding='max_length', return_tensors='tf')
    
    if labeled:
        dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': tokenized_inputs['input_ids'], 
                                                       'attention_mask': tokenized_inputs['attention_mask']}, 
                                                      (pandas_df['target'], pandas_df['standard_error'])))
        if is_sampled:
            dataset = dataset.map(sample_target, num_parallel_calls=tf.data.AUTOTUNE)
    else:
        dataset = tf.data.Dataset.from_tensor_slices({'input_ids': tokenized_inputs['input_ids'], 
                                                      'attention_mask': tokenized_inputs['attention_mask']})
        
    if repeated:
        dataset = dataset.repeat()
    if not ordered:
        dataset = dataset.shuffle(2048)
    dataset = dataset.batch(batch_size)
    dataset = dataset.cache()
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# %% [markdown]
# # Model

# %%
def model_fn(encoder, seq_len=256):
    input_ids = L.Input(shape=(seq_len,), dtype=tf.int32, name='input_ids')
    input_attention_mask = L.Input(shape=(seq_len,), dtype=tf.int32, name='attention_mask')
    
    outputs = encoder({'input_ids': input_ids,  
                       'attention_mask': input_attention_mask})
    last_hidden_state = outputs['last_hidden_state']
    
    cls_token = last_hidden_state[:, 0, :]
#     x = L.GlobalAveragePooling1D()(last_hidden_state)
    output = L.Dense(1, name='output')(cls_token)
    
    model = Model(inputs=[input_ids, input_attention_mask], outputs=output)

#     optimizer = optimizers.Adam(lr=config['LEARNING_RATE'])
    optimizer = tfa.optimizers.RectifiedAdam(lr=config['LEARNING_RATE'],
                                             total_steps=(config['EPOCHS'] * 10),
                                             warmup_proportion=0.1,
                                             min_lr=1e-7)
    model.compile(optimizer=optimizer, 
                  loss=losses.MeanSquaredError(), 
                  metrics=[metrics.RootMeanSquaredError()])
    return model


with strategy.scope():
    encoder = TFAutoModel.from_pretrained(config['BASE_MODEL'])
    model = model_fn(encoder, config['SEQ_LEN'])
    
model.summary()
# Out:
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# attention_mask (InputLayer)     [(None, 256)]        0
# __________________________________________________________________________________________________
# input_ids (InputLayer)          [(None, 256)]        0
# __________________________________________________________________________________________________
# tf_roberta_model (TFRobertaMode TFBaseModelOutputWit 124645632   attention_mask[0][0]
#                                                                  input_ids[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici (None, 768)          0           tf_roberta_model[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            769         tf.__operators__.getitem[0][0]
# ==================================================================================================
# Total params: 124,646,401
# Trainable params: 124,646,401
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
tokenizer = AutoTokenizer.from_pretrained(config['BASE_MODEL'])
skf = KFold(n_splits=config['N_FOLDS'], shuffle=True, random_state=seed)
oof_pred = []; oof_labels = []; history_list = []

for fold,(idxT, idxV) in enumerate(skf.split(train)):
    if fold >= config['N_USED_FOLDS']:
        break
    if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    print(f'\nFOLD: {fold+1}')
    print(f'TRAIN: {len(idxT)} VALID: {len(idxV)}')

    # Model
    K.clear_session()
    with strategy.scope():
        encoder = TFAutoModel.from_pretrained(config['BASE_MODEL'])
        model = model_fn(encoder, config['SEQ_LEN'])
        
    model_path = f'model_{fold}.h5'
    es = EarlyStopping(monitor='val_root_mean_squared_error', mode='min', 
                       patience=config['ES_PATIENCE'], restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_root_mean_squared_error', mode='min', 
                                 save_best_only=True, save_weights_only=True)

    # Train
    history = model.fit(x=get_dataset(train.loc[idxT], tokenizer, repeated=True, is_sampled=True, 
                                      batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN']), 
                        validation_data=get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                                                    batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN']), 
                        steps_per_epoch=10, 
                        callbacks=[es, checkpoint], 
                        epochs=config['EPOCHS'],  
                        verbose=2).history
      
    history_list.append(history)
    # Save last model weights
    model.load_weights(model_path)
    
    # Results
    print(f"#### FOLD {fold+1} OOF RMSE = {np.min(history['val_root_mean_squared_error']):.4f}")

    # OOF predictions
    valid_ds = get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                           batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN'])
    oof_labels.append([target[0].numpy() for sample, target in iter(valid_ds.unbatch())])
    x_oof = valid_ds.map(lambda sample, target: sample)
    oof_pred.append(model.predict(x_oof))
# Out:
# FOLD: 1
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/100
# 10/10 - 108s - loss: 5.9621 - root_mean_squared_error: 2.4417 - val_loss: 4.6978 - val_root_mean_squared_error: 2.1674
# Epoch 2/100
# 10/10 - 2s - loss: 5.6935 - root_mean_squared_error: 2.3861 - val_loss: 4.4733 - val_root_mean_squared_error: 2.1150
# Epoch 3/100
# 10/10 - 2s - loss: 4.8805 - root_mean_squared_error: 2.2092 - val_loss: 3.7927 - val_root_mean_squared_error: 1.9475
# Epoch 4/100
# 10/10 - 2s - loss: 3.7950 - root_mean_squared_error: 1.9481 - val_loss: 2.3302 - val_root_mean_squared_error: 1.5265
# Epoch 5/100
# 10/10 - 2s - loss: 1.8302 - root_mean_squared_error: 1.3528 - val_loss: 1.2069 - val_root_mean_squared_error: 1.0986
# Epoch 6/100
# 10/10 - 2s - loss: 1.6230 - root_mean_squared_error: 1.2740 - val_loss: 1.0201 - val_root_mean_squared_error: 1.0100
# Epoch 7/100
# 10/10 - 2s - loss: 1.3776 - root_mean_squared_error: 1.1737 - val_loss: 0.9685 - val_root_mean_squared_error: 0.9841
# Epoch 8/100
# 10/10 - 2s - loss: 1.1743 - root_mean_squared_error: 1.0836 - val_loss: 0.8012 - val_root_mean_squared_error: 0.8951
# Epoch 9/100
# 10/10 - 2s - loss: 0.8866 - root_mean_squared_error: 0.9416 - val_loss: 0.6115 - val_root_mean_squared_error: 0.7820
# Epoch 10/100
# 10/10 - 2s - loss: 0.7088 - root_mean_squared_error: 0.8419 - val_loss: 0.4050 - val_root_mean_squared_error: 0.6364
# Epoch 11/100
# 10/10 - 2s - loss: 0.7165 - root_mean_squared_error: 0.8465 - val_loss: 0.5194 - val_root_mean_squared_error: 0.7207
# Epoch 12/100
# 10/10 - 2s - loss: 0.5711 - root_mean_squared_error: 0.7557 - val_loss: 0.4227 - val_root_mean_squared_error: 0.6502
# Epoch 13/100
# 10/10 - 2s - loss: 0.5921 - root_mean_squared_error: 0.7695 - val_loss: 0.4757 - val_root_mean_squared_error: 0.6897
# Epoch 14/100
# 10/10 - 2s - loss: 0.5490 - root_mean_squared_error: 0.7409 - val_loss: 0.6084 - val_root_mean_squared_error: 0.7800
# Epoch 15/100
# 10/10 - 2s - loss: 0.6110 - root_mean_squared_error: 0.7817 - val_loss: 0.4769 - val_root_mean_squared_error: 0.6906
# Epoch 16/100
# 10/10 - 2s - loss: 0.5424 - root_mean_squared_error: 0.7365 - val_loss: 0.5245 - val_root_mean_squared_error: 0.7242
# Epoch 17/100
# 10/10 - 2s - loss: 0.5466 - root_mean_squared_error: 0.7393 - val_loss: 0.3216 - val_root_mean_squared_error: 0.5671
# Epoch 18/100
# 10/10 - 2s - loss: 0.5505 - root_mean_squared_error: 0.7419 - val_loss: 0.3764 - val_root_mean_squared_error: 0.6135
# Epoch 19/100
# 10/10 - 2s - loss: 0.5109 - root_mean_squared_error: 0.7148 - val_loss: 0.6338 - val_root_mean_squared_error: 0.7961
# Epoch 20/100
# 10/10 - 2s - loss: 0.5023 - root_mean_squared_error: 0.7087 - val_loss: 0.3511 - val_root_mean_squared_error: 0.5926
# Epoch 21/100
# 10/10 - 2s - loss: 0.4649 - root_mean_squared_error: 0.6818 - val_loss: 0.4443 - val_root_mean_squared_error: 0.6665
# Epoch 22/100
# 10/10 - 2s - loss: 0.5404 - root_mean_squared_error: 0.7351 - val_loss: 0.7520 - val_root_mean_squared_error: 0.8672
# Epoch 23/100
# 10/10 - 2s - loss: 0.5331 - root_mean_squared_error: 0.7301 - val_loss: 0.2905 - val_root_mean_squared_error: 0.5390
# Epoch 24/100
# 10/10 - 2s - loss: 0.4636 - root_mean_squared_error: 0.6808 - val_loss: 0.5787 - val_root_mean_squared_error: 0.7607
# Epoch 25/100
# 10/10 - 2s - loss: 0.5010 - root_mean_squared_error: 0.7078 - val_loss: 0.3475 - val_root_mean_squared_error: 0.5895
# Epoch 26/100
# 10/10 - 2s - loss: 0.4590 - root_mean_squared_error: 0.6775 - val_loss: 0.4025 - val_root_mean_squared_error: 0.6344
# Epoch 27/100
# 10/10 - 3s - loss: 0.4269 - root_mean_squared_error: 0.6534 - val_loss: 0.5412 - val_root_mean_squared_error: 0.7357
# Epoch 28/100
# 10/10 - 2s - loss: 0.4001 - root_mean_squared_error: 0.6326 - val_loss: 0.4565 - val_root_mean_squared_error: 0.6757
# Epoch 29/100
# 10/10 - 2s - loss: 0.4429 - root_mean_squared_error: 0.6655 - val_loss: 0.3439 - val_root_mean_squared_error: 0.5864
# Epoch 30/100
# 10/10 - 2s - loss: 0.4393 - root_mean_squared_error: 0.6628 - val_loss: 0.3918 - val_root_mean_squared_error: 0.6260
# Epoch 31/100
# 10/10 - 3s - loss: 0.4120 - root_mean_squared_error: 0.6419 - val_loss: 0.4078 - val_root_mean_squared_error: 0.6386
# Epoch 32/100
# 10/10 - 2s - loss: 0.3717 - root_mean_squared_error: 0.6097 - val_loss: 0.3633 - val_root_mean_squared_error: 0.6027
# Epoch 33/100
# 10/10 - 2s - loss: 0.3868 - root_mean_squared_error: 0.6219 - val_loss: 0.4526 - val_root_mean_squared_error: 0.6727
# Epoch 34/100
# 10/10 - 2s - loss: 0.4372 - root_mean_squared_error: 0.6612 - val_loss: 0.2922 - val_root_mean_squared_error: 0.5406
# Epoch 35/100
# 10/10 - 2s - loss: 0.5550 - root_mean_squared_error: 0.7450 - val_loss: 0.8199 - val_root_mean_squared_error: 0.9055
# Epoch 36/100
# 10/10 - 2s - loss: 0.4907 - root_mean_squared_error: 0.7005 - val_loss: 0.2835 - val_root_mean_squared_error: 0.5324
# Epoch 37/100
# 10/10 - 2s - loss: 0.4895 - root_mean_squared_error: 0.6996 - val_loss: 0.5040 - val_root_mean_squared_error: 0.7099
# Epoch 38/100
# 10/10 - 2s - loss: 0.4451 - root_mean_squared_error: 0.6671 - val_loss: 0.3822 - val_root_mean_squared_error: 0.6182
# Epoch 39/100
# 10/10 - 2s - loss: 0.4150 - root_mean_squared_error: 0.6442 - val_loss: 0.6615 - val_root_mean_squared_error: 0.8133
# Epoch 40/100
# 10/10 - 2s - loss: 0.4677 - root_mean_squared_error: 0.6839 - val_loss: 0.3310 - val_root_mean_squared_error: 0.5753
# Epoch 41/100
# 10/10 - 2s - loss: 0.4323 - root_mean_squared_error: 0.6575 - val_loss: 0.5328 - val_root_mean_squared_error: 0.7299
# Epoch 42/100
# 10/10 - 2s - loss: 0.4316 - root_mean_squared_error: 0.6569 - val_loss: 0.4872 - val_root_mean_squared_error: 0.6980
# Epoch 43/100
# 10/10 - 2s - loss: 0.4827 - root_mean_squared_error: 0.6948 - val_loss: 0.2952 - val_root_mean_squared_error: 0.5433
# Epoch 44/100
# 10/10 - 2s - loss: 0.3990 - root_mean_squared_error: 0.6317 - val_loss: 0.3472 - val_root_mean_squared_error: 0.5893
# Epoch 45/100
# 10/10 - 2s - loss: 0.3755 - root_mean_squared_error: 0.6128 - val_loss: 0.5639 - val_root_mean_squared_error: 0.7510
# Epoch 46/100
# 10/10 - 2s - loss: 0.4248 - root_mean_squared_error: 0.6517 - val_loss: 0.2803 - val_root_mean_squared_error: 0.5294
# Epoch 47/100
# 10/10 - 2s - loss: 0.4837 - root_mean_squared_error: 0.6955 - val_loss: 0.5568 - val_root_mean_squared_error: 0.7462
# Epoch 48/100
# 10/10 - 2s - loss: 0.4473 - root_mean_squared_error: 0.6688 - val_loss: 0.5924 - val_root_mean_squared_error: 0.7697
# Epoch 49/100
# 10/10 - 2s - loss: 0.3695 - root_mean_squared_error: 0.6078 - val_loss: 0.5271 - val_root_mean_squared_error: 0.7260
# Epoch 50/100
# 10/10 - 2s - loss: 0.3695 - root_mean_squared_error: 0.6079 - val_loss: 0.5626 - val_root_mean_squared_error: 0.7500
# Epoch 51/100
# 10/10 - 2s - loss: 0.3726 - root_mean_squared_error: 0.6104 - val_loss: 0.5367 - val_root_mean_squared_error: 0.7326
# Epoch 52/100
# 10/10 - 2s - loss: 0.3643 - root_mean_squared_error: 0.6036 - val_loss: 0.4221 - val_root_mean_squared_error: 0.6497
# Epoch 53/100
# 10/10 - 2s - loss: 0.3701 - root_mean_squared_error: 0.6083 - val_loss: 0.4284 - val_root_mean_squared_error: 0.6545
# Epoch 54/100
# 10/10 - 2s - loss: 0.4090 - root_mean_squared_error: 0.6395 - val_loss: 0.3170 - val_root_mean_squared_error: 0.5630
# Epoch 55/100
# 10/10 - 2s - loss: 0.3871 - root_mean_squared_error: 0.6222 - val_loss: 0.2869 - val_root_mean_squared_error: 0.5357
# Epoch 56/100
# 10/10 - 2s - loss: 0.4386 - root_mean_squared_error: 0.6623 - val_loss: 0.7310 - val_root_mean_squared_error: 0.8550
# Epoch 57/100
# 10/10 - 3s - loss: 0.3584 - root_mean_squared_error: 0.5987 - val_loss: 0.5659 - val_root_mean_squared_error: 0.7523
# Epoch 58/100
# 10/10 - 2s - loss: 0.4035 - root_mean_squared_error: 0.6352 - val_loss: 0.6474 - val_root_mean_squared_error: 0.8046
# Epoch 59/100
# 10/10 - 2s - loss: 0.3572 - root_mean_squared_error: 0.5977 - val_loss: 0.5200 - val_root_mean_squared_error: 0.7211
# Epoch 60/100
# 10/10 - 2s - loss: 0.3387 - root_mean_squared_error: 0.5820 - val_loss: 0.5039 - val_root_mean_squared_error: 0.7099
# Epoch 61/100
# 10/10 - 2s - loss: 0.3571 - root_mean_squared_error: 0.5976 - val_loss: 0.5028 - val_root_mean_squared_error: 0.7091
# Epoch 62/100
# 10/10 - 2s - loss: 0.3417 - root_mean_squared_error: 0.5845 - val_loss: 0.3149 - val_root_mean_squared_error: 0.5611
# Epoch 63/100
# 10/10 - 2s - loss: 0.3436 - root_mean_squared_error: 0.5862 - val_loss: 0.3509 - val_root_mean_squared_error: 0.5923
# Epoch 64/100
# 10/10 - 2s - loss: 0.3326 - root_mean_squared_error: 0.5767 - val_loss: 0.3761 - val_root_mean_squared_error: 0.6133
# Epoch 65/100
# 10/10 - 2s - loss: 0.3176 - root_mean_squared_error: 0.5636 - val_loss: 0.3614 - val_root_mean_squared_error: 0.6012
# Epoch 66/100
# 10/10 - 2s - loss: 0.3009 - root_mean_squared_error: 0.5485 - val_loss: 0.4677 - val_root_mean_squared_error: 0.6839
# Epoch 67/100
# 10/10 - 2s - loss: 0.3371 - root_mean_squared_error: 0.5806 - val_loss: 0.6482 - val_root_mean_squared_error: 0.8051
# Epoch 68/100
# 10/10 - 2s - loss: 0.3287 - root_mean_squared_error: 0.5734 - val_loss: 0.5149 - val_root_mean_squared_error: 0.7176
# Epoch 69/100
# 10/10 - 2s - loss: 0.3378 - root_mean_squared_error: 0.5812 - val_loss: 0.3852 - val_root_mean_squared_error: 0.6207
# Epoch 70/100
# 10/10 - 2s - loss: 0.3709 - root_mean_squared_error: 0.6090 - val_loss: 0.4619 - val_root_mean_squared_error: 0.6796
# Epoch 71/100
# 10/10 - 2s - loss: 0.3100 - root_mean_squared_error: 0.5568 - val_loss: 0.4995 - val_root_mean_squared_error: 0.7068
# Epoch 72/100
# 10/10 - 2s - loss: 0.3057 - root_mean_squared_error: 0.5529 - val_loss: 0.5246 - val_root_mean_squared_error: 0.7243
# Epoch 73/100
# 10/10 - 2s - loss: 0.3711 - root_mean_squared_error: 0.6092 - val_loss: 0.5645 - val_root_mean_squared_error: 0.7513
# Epoch 74/100
# 10/10 - 2s - loss: 0.3151 - root_mean_squared_error: 0.5613 - val_loss: 0.5755 - val_root_mean_squared_error: 0.7586
# Epoch 75/100
# 10/10 - 2s - loss: 0.3613 - root_mean_squared_error: 0.6011 - val_loss: 0.4433 - val_root_mean_squared_error: 0.6658
# Epoch 76/100
# 10/10 - 2s - loss: 0.3246 - root_mean_squared_error: 0.5697 - val_loss: 0.4620 - val_root_mean_squared_error: 0.6797
# Restoring model weights from the end of the best epoch.
# Epoch 00076: early stopping
# #### FOLD 1 OOF RMSE = 0.5294

# %% [markdown]
# ## Model loss and metrics graph

# %%
for fold, history in enumerate(history_list):
    print(f'\nFOLD: {fold+1}')
    plot_metrics(history)
# Out:
# FOLD: 1

# %% [markdown]
# # Model evaluation
#
# We are evaluating the model on the `OOF` predictions, it stands for `Out Of Fold`, since we are training using `K-Fold` our model will see all the data, and the correct way to evaluate each fold is by looking at the predictions that are not from that fold.
#
# ## OOF metrics

# %%
y_true = np.concatenate(oof_labels)
y_preds = np.concatenate(oof_pred)

for fold, history in enumerate(history_list):
    print(f"FOLD {fold+1} RMSE: {np.min(history['val_root_mean_squared_error']):.4f}")
    
print(f'OOF RMSE: {mean_squared_error(y_true, y_preds, squared=False):.4f}')
# Out:
# FOLD 1 RMSE: 0.5294
# OOF RMSE: 0.5294

# %% [markdown]
# ### **Error analysis**, label x prediction distribution
#
# Here we can compare the distribution from the labels and the predicted values, in a perfect scenario they should align.

# %%
preds_df = pd.DataFrame({'Label': y_true, 'Prediction': y_preds[:,0]})

fig, ax = plt.subplots(1, 1, figsize=(20, 6))
sns.distplot(preds_df['Label'], ax=ax, label='Label')
sns.distplot(preds_df['Prediction'], ax=ax, label='Prediction')
ax.legend()
plt.show()

# %%
sns.jointplot(data=preds_df, x='Label', y='Prediction', kind='reg', height=10)
plt.show()
