# %% [markdown]
# ## Dependencies

# %%
import warnings, math, json
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
from tensorflow.keras import optimizers, losses, metrics, Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from transformers import TFAutoModelForSequenceClassification, TFAutoModel, AutoTokenizer
from commonlit_scripts import *


seed = 0
seed_everything(seed)
sns.set(style='whitegrid')
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 150)

# %% [markdown]
# ### Hardware configuration

# %%
strategy, tpu = get_strategy()
AUTO = tf.data.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
print(f'REPLICAS: {REPLICAS}')
# Out:
# Running on TPU grpc://10.0.0.2:8470
# REPLICAS: 8

# %% [markdown]
# # Load data

# %%
train_filepath = '/kaggle/input/commonlitreadabilityprize/train.csv'
train = pd.read_csv(train_filepath)
print(f'Train samples: {len(train)}')
# removing unused columns
train.drop(['url_legal', 'license'], axis=1, inplace=True)
display(train.head())
# Out:
# Train samples: 2834
#           id  \
# 0  c12129c31
# 1  85aa80a4c
# 2  b69ac6792
# 3  dd1000b26
# 4  37c1b32fb
#
#                                                                                                                                                  excerpt  \
# 0  When the young people returned to the ballroom, it presented a decidedly changed appearance. Instead of an interior scene, it was a winter landsca...
# 1  All through dinner time, Mrs. Fayre was somewhat silent, her eyes resting on Dolly with a wistful, uncertain expression. She wanted to give the ch...
# 2  As Roger had predicted, the snow departed as quickly as it came, and two days after their sleigh ride there was scarcely a vestige of white on the...
# 3  And outside before the palace a great garden was walled round, filled full of stately fruit-trees, gray olives and sweet figs, and pomegranates, p...
# 4  Once upon a time there were Three Bears who lived together in a house of their own in a wood. One of them was a Little, Small, Wee Bear; and one w...
#
#      target  standard_error
# 0 -0.340259        0.464009
# 1 -0.315372        0.480805
# 2 -0.580118        0.476676
# 3 -1.054013        0.450007
# 4  0.247197        0.510845

# %% [markdown]
# # Model parameters

# %%
config = {
  "BATCH_SIZE": 8 * REPLICAS,
  "LEARNING_RATE": 1e-5 * REPLICAS,
  "EPOCHS": 100,
  "ES_PATIENCE": 30,
  "N_FOLDS": 5,
  "N_USED_FOLDS": 1,
  "SEQ_LEN": 256,
  "BASE_MODEL": '/kaggle/input/huggingface-roberta/roberta-base/',
  "SEED": seed,
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# ## Auxiliary functions

# %%
# Datasets utility functions
def custom_standardization(text, is_lower=True):
    if is_lower:
        text = text.lower() # if encoder is uncased
    text = text.strip()
    return text

def sample_target(features, target):
    mean, stddev = target
    sampled_target = tf.random.normal([], mean=tf.cast(mean, dtype=tf.float32), 
                                      stddev=tf.cast(stddev, dtype=tf.float32), dtype=tf.float32)
    return (features, sampled_target)
    
def get_dataset(pandas_df, tokenizer, labeled=True, ordered=False, repeated=False, 
                is_sampled=False, batch_size=32, seq_len=128, is_lower=True):
    """
        Return a Tensorflow dataset ready for training or inference.
    """
    text = [custom_standardization(text, is_lower) for text in pandas_df['excerpt']]
    
    # Tokenize inputs
    tokenized_inputs = tokenizer(text, max_length=seq_len, truncation=True, 
                                 padding='max_length', return_tensors='tf')
    
    if labeled:
        dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': tokenized_inputs['input_ids'], 
                                                       'attention_mask': tokenized_inputs['attention_mask']}, 
                                                      (pandas_df['target'], pandas_df['standard_error'])))
        if is_sampled:
            dataset = dataset.map(sample_target, num_parallel_calls=tf.data.AUTOTUNE)
    else:
        dataset = tf.data.Dataset.from_tensor_slices({'input_ids': tokenized_inputs['input_ids'], 
                                                      'attention_mask': tokenized_inputs['attention_mask']})
        
    if repeated:
        dataset = dataset.repeat()
    if not ordered:
        dataset = dataset.shuffle(2048)
    dataset = dataset.batch(batch_size)
    dataset = dataset.cache()
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# %% [markdown]
# # Model

# %%
def model_fn(encoder, seq_len=256):
    input_ids = L.Input(shape=(seq_len,), dtype=tf.int32, name='input_ids')
    input_attention_mask = L.Input(shape=(seq_len,), dtype=tf.int32, name='attention_mask')
    
    outputs = encoder({'input_ids': input_ids,  
                       'attention_mask': input_attention_mask})
    last_hidden_state = outputs['last_hidden_state']
    
    x = L.GlobalAveragePooling1D()(last_hidden_state)
    output = L.Dense(1, name='output')(x)
    
    model = Model(inputs=[input_ids, input_attention_mask], outputs=output)

    optimizer = optimizers.Adam(lr=config['LEARNING_RATE'])
    model.compile(optimizer=optimizer, 
                  loss=losses.MeanSquaredError(), 
                  metrics=[metrics.RootMeanSquaredError()])
    return model


with strategy.scope():
    encoder = TFAutoModel.from_pretrained(config['BASE_MODEL'])
    model = model_fn(encoder, config['SEQ_LEN'])
    
model.summary()
# Out:
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# attention_mask (InputLayer)     [(None, 256)]        0
# __________________________________________________________________________________________________
# input_ids (InputLayer)          [(None, 256)]        0
# __________________________________________________________________________________________________
# tf_roberta_model (TFRobertaMode TFBaseModelOutputWit 124645632   attention_mask[0][0]
#                                                                  input_ids[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 768)          0           tf_roberta_model[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            769         global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 124,646,401
# Trainable params: 124,646,401
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
tokenizer = AutoTokenizer.from_pretrained(config['BASE_MODEL'])
skf = KFold(n_splits=config['N_FOLDS'], shuffle=True, random_state=seed)
oof_pred = []; oof_labels = []; history_list = []

for fold,(idxT, idxV) in enumerate(skf.split(train)):
    if fold >= config['N_USED_FOLDS']:
        break
    if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    print(f'\nFOLD: {fold+1}')
    print(f'TRAIN: {len(idxT)} VALID: {len(idxV)}')

    # Model
    K.clear_session()
    with strategy.scope():
        encoder = TFAutoModel.from_pretrained(config['BASE_MODEL'])
        model = model_fn(encoder, config['SEQ_LEN'])
        
    model_path = f'model_{fold}.h5'
    es = EarlyStopping(monitor='val_root_mean_squared_error', mode='min', 
                       patience=config['ES_PATIENCE'], restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_root_mean_squared_error', mode='min', 
                                 save_best_only=True, save_weights_only=True)

    # Train
    history = model.fit(x=get_dataset(train.loc[idxT], tokenizer, repeated=True, is_sampled=True, 
                                      batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN']), 
                        validation_data=get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                                                    batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN']), 
                        steps_per_epoch=10, 
                        callbacks=[es, checkpoint], 
                        epochs=config['EPOCHS'],  
                        verbose=2).history
      
    history_list.append(history)
    # Save last model weights
    model.load_weights(model_path)
    
    # Results
    print(f"#### FOLD {fold+1} OOF RMSE = {np.min(history['val_root_mean_squared_error']):.4f}")

    # OOF predictions
    valid_ds = get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                           batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN'])
    oof_labels.append([target[0].numpy() for sample, target in iter(valid_ds.unbatch())])
    x_oof = valid_ds.map(lambda sample, target: sample)
    oof_pred.append(model.predict(x_oof))
# Out:
# FOLD: 1
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/100
# 10/10 - 95s - loss: 1.5879 - root_mean_squared_error: 1.2601 - val_loss: 0.8408 - val_root_mean_squared_error: 0.9170
# Epoch 2/100
# 10/10 - 3s - loss: 0.9813 - root_mean_squared_error: 0.9906 - val_loss: 0.7325 - val_root_mean_squared_error: 0.8559
# Epoch 3/100
# 10/10 - 2s - loss: 0.8395 - root_mean_squared_error: 0.9162 - val_loss: 0.4440 - val_root_mean_squared_error: 0.6663
# Epoch 4/100
# 10/10 - 2s - loss: 0.6509 - root_mean_squared_error: 0.8068 - val_loss: 0.3786 - val_root_mean_squared_error: 0.6153
# Epoch 5/100
# 10/10 - 2s - loss: 0.5851 - root_mean_squared_error: 0.7649 - val_loss: 0.4475 - val_root_mean_squared_error: 0.6689
# Epoch 6/100
# 10/10 - 2s - loss: 0.5243 - root_mean_squared_error: 0.7241 - val_loss: 0.6235 - val_root_mean_squared_error: 0.7896
# Epoch 7/100
# 10/10 - 2s - loss: 0.6053 - root_mean_squared_error: 0.7780 - val_loss: 0.7516 - val_root_mean_squared_error: 0.8670
# Epoch 8/100
# 10/10 - 2s - loss: 0.5228 - root_mean_squared_error: 0.7230 - val_loss: 0.3401 - val_root_mean_squared_error: 0.5832
# Epoch 9/100
# 10/10 - 2s - loss: 0.5260 - root_mean_squared_error: 0.7253 - val_loss: 0.3006 - val_root_mean_squared_error: 0.5482
# Epoch 10/100
# 10/10 - 2s - loss: 0.5257 - root_mean_squared_error: 0.7251 - val_loss: 0.5311 - val_root_mean_squared_error: 0.7288
# Epoch 11/100
# 10/10 - 2s - loss: 0.4831 - root_mean_squared_error: 0.6950 - val_loss: 0.3308 - val_root_mean_squared_error: 0.5752
# Epoch 12/100
# 10/10 - 2s - loss: 0.4745 - root_mean_squared_error: 0.6888 - val_loss: 0.5243 - val_root_mean_squared_error: 0.7241
# Epoch 13/100
# 10/10 - 2s - loss: 0.4794 - root_mean_squared_error: 0.6924 - val_loss: 0.3149 - val_root_mean_squared_error: 0.5612
# Epoch 14/100
# 10/10 - 2s - loss: 0.5062 - root_mean_squared_error: 0.7115 - val_loss: 0.3992 - val_root_mean_squared_error: 0.6318
# Epoch 15/100
# 10/10 - 2s - loss: 0.4340 - root_mean_squared_error: 0.6588 - val_loss: 0.3241 - val_root_mean_squared_error: 0.5693
# Epoch 16/100
# 10/10 - 2s - loss: 0.4612 - root_mean_squared_error: 0.6791 - val_loss: 0.7011 - val_root_mean_squared_error: 0.8373
# Epoch 17/100
# 10/10 - 2s - loss: 0.4595 - root_mean_squared_error: 0.6779 - val_loss: 0.3471 - val_root_mean_squared_error: 0.5892
# Epoch 18/100
# 10/10 - 2s - loss: 0.4178 - root_mean_squared_error: 0.6463 - val_loss: 0.3648 - val_root_mean_squared_error: 0.6040
# Epoch 19/100
# 10/10 - 2s - loss: 0.3990 - root_mean_squared_error: 0.6317 - val_loss: 0.5136 - val_root_mean_squared_error: 0.7167
# Epoch 20/100
# 10/10 - 2s - loss: 0.4101 - root_mean_squared_error: 0.6404 - val_loss: 0.4517 - val_root_mean_squared_error: 0.6721
# Epoch 21/100
# 10/10 - 2s - loss: 0.3844 - root_mean_squared_error: 0.6200 - val_loss: 0.3174 - val_root_mean_squared_error: 0.5634
# Epoch 22/100
# 10/10 - 2s - loss: 0.4568 - root_mean_squared_error: 0.6759 - val_loss: 0.3678 - val_root_mean_squared_error: 0.6064
# Epoch 23/100
# 10/10 - 3s - loss: 0.4760 - root_mean_squared_error: 0.6899 - val_loss: 0.5012 - val_root_mean_squared_error: 0.7080
# Epoch 24/100
# 10/10 - 2s - loss: 0.4168 - root_mean_squared_error: 0.6456 - val_loss: 0.3804 - val_root_mean_squared_error: 0.6168
# Epoch 25/100
# 10/10 - 2s - loss: 0.4162 - root_mean_squared_error: 0.6452 - val_loss: 0.5865 - val_root_mean_squared_error: 0.7658
# Epoch 26/100
# 10/10 - 2s - loss: 0.3707 - root_mean_squared_error: 0.6088 - val_loss: 0.4886 - val_root_mean_squared_error: 0.6990
# Epoch 27/100
# 10/10 - 2s - loss: 0.3713 - root_mean_squared_error: 0.6093 - val_loss: 0.4041 - val_root_mean_squared_error: 0.6357
# Epoch 28/100
# 10/10 - 2s - loss: 0.3556 - root_mean_squared_error: 0.5963 - val_loss: 0.4891 - val_root_mean_squared_error: 0.6993
# Epoch 29/100
# 10/10 - 2s - loss: 0.3895 - root_mean_squared_error: 0.6241 - val_loss: 0.3764 - val_root_mean_squared_error: 0.6135
# Epoch 30/100
# 10/10 - 2s - loss: 0.3426 - root_mean_squared_error: 0.5853 - val_loss: 0.7007 - val_root_mean_squared_error: 0.8371
# Epoch 31/100
# 10/10 - 2s - loss: 0.3701 - root_mean_squared_error: 0.6084 - val_loss: 0.3396 - val_root_mean_squared_error: 0.5828
# Epoch 32/100
# 10/10 - 2s - loss: 0.3406 - root_mean_squared_error: 0.5836 - val_loss: 0.3933 - val_root_mean_squared_error: 0.6271
# Epoch 33/100
# 10/10 - 2s - loss: 0.3287 - root_mean_squared_error: 0.5733 - val_loss: 0.4206 - val_root_mean_squared_error: 0.6485
# Epoch 34/100
# 10/10 - 2s - loss: 0.3316 - root_mean_squared_error: 0.5759 - val_loss: 0.8419 - val_root_mean_squared_error: 0.9175
# Epoch 35/100
# 10/10 - 2s - loss: 0.3702 - root_mean_squared_error: 0.6084 - val_loss: 0.3604 - val_root_mean_squared_error: 0.6003
# Epoch 36/100
# 10/10 - 2s - loss: 0.3284 - root_mean_squared_error: 0.5730 - val_loss: 0.5781 - val_root_mean_squared_error: 0.7603
# Epoch 37/100
# 10/10 - 2s - loss: 0.3745 - root_mean_squared_error: 0.6120 - val_loss: 0.6550 - val_root_mean_squared_error: 0.8093
# Epoch 38/100
# 10/10 - 2s - loss: 0.3800 - root_mean_squared_error: 0.6164 - val_loss: 0.5592 - val_root_mean_squared_error: 0.7478
# Epoch 39/100
# 10/10 - 2s - loss: 0.3985 - root_mean_squared_error: 0.6313 - val_loss: 0.2992 - val_root_mean_squared_error: 0.5470
# Epoch 40/100
# 10/10 - 2s - loss: 0.3651 - root_mean_squared_error: 0.6042 - val_loss: 0.5009 - val_root_mean_squared_error: 0.7077
# Epoch 41/100
# 10/10 - 2s - loss: 0.3245 - root_mean_squared_error: 0.5696 - val_loss: 0.5153 - val_root_mean_squared_error: 0.7178
# Epoch 42/100
# 10/10 - 2s - loss: 0.3658 - root_mean_squared_error: 0.6048 - val_loss: 0.3034 - val_root_mean_squared_error: 0.5508
# Epoch 43/100
# 10/10 - 2s - loss: 0.3524 - root_mean_squared_error: 0.5936 - val_loss: 0.4682 - val_root_mean_squared_error: 0.6842
# Epoch 44/100
# 10/10 - 2s - loss: 0.3210 - root_mean_squared_error: 0.5665 - val_loss: 0.4348 - val_root_mean_squared_error: 0.6594
# Epoch 45/100
# 10/10 - 2s - loss: 0.3235 - root_mean_squared_error: 0.5688 - val_loss: 0.4017 - val_root_mean_squared_error: 0.6338
# Epoch 46/100
# 10/10 - 3s - loss: 0.3722 - root_mean_squared_error: 0.6101 - val_loss: 0.3056 - val_root_mean_squared_error: 0.5528
# Epoch 47/100
# 10/10 - 2s - loss: 0.3724 - root_mean_squared_error: 0.6103 - val_loss: 0.3608 - val_root_mean_squared_error: 0.6007
# Epoch 48/100
# 10/10 - 2s - loss: 0.3564 - root_mean_squared_error: 0.5970 - val_loss: 0.5929 - val_root_mean_squared_error: 0.7700
# Epoch 49/100
# 10/10 - 2s - loss: 0.3169 - root_mean_squared_error: 0.5629 - val_loss: 0.5591 - val_root_mean_squared_error: 0.7477
# Epoch 50/100
# 10/10 - 2s - loss: 0.3314 - root_mean_squared_error: 0.5757 - val_loss: 0.4525 - val_root_mean_squared_error: 0.6727
# Epoch 51/100
# 10/10 - 2s - loss: 0.3506 - root_mean_squared_error: 0.5921 - val_loss: 0.5722 - val_root_mean_squared_error: 0.7564
# Epoch 52/100
# 10/10 - 2s - loss: 0.3390 - root_mean_squared_error: 0.5823 - val_loss: 0.4960 - val_root_mean_squared_error: 0.7043
# Epoch 53/100
# 10/10 - 2s - loss: 0.2985 - root_mean_squared_error: 0.5463 - val_loss: 0.3849 - val_root_mean_squared_error: 0.6204
# Epoch 54/100
# 10/10 - 2s - loss: 0.2949 - root_mean_squared_error: 0.5430 - val_loss: 0.6231 - val_root_mean_squared_error: 0.7894
# Epoch 55/100
# 10/10 - 2s - loss: 0.3506 - root_mean_squared_error: 0.5921 - val_loss: 0.3935 - val_root_mean_squared_error: 0.6273
# Epoch 56/100
# 10/10 - 2s - loss: 0.3662 - root_mean_squared_error: 0.6052 - val_loss: 0.3094 - val_root_mean_squared_error: 0.5562
# Epoch 57/100
# 10/10 - 2s - loss: 0.3225 - root_mean_squared_error: 0.5679 - val_loss: 0.6654 - val_root_mean_squared_error: 0.8157
# Epoch 58/100
# 10/10 - 2s - loss: 0.3296 - root_mean_squared_error: 0.5741 - val_loss: 0.4036 - val_root_mean_squared_error: 0.6353
# Epoch 59/100
# 10/10 - 2s - loss: 0.3417 - root_mean_squared_error: 0.5845 - val_loss: 0.7456 - val_root_mean_squared_error: 0.8635
# Epoch 60/100
# 10/10 - 2s - loss: 0.3586 - root_mean_squared_error: 0.5989 - val_loss: 0.3304 - val_root_mean_squared_error: 0.5748
# Epoch 61/100
# 10/10 - 2s - loss: 0.3425 - root_mean_squared_error: 0.5852 - val_loss: 0.4894 - val_root_mean_squared_error: 0.6996
# Epoch 62/100
# 10/10 - 2s - loss: 0.3196 - root_mean_squared_error: 0.5654 - val_loss: 0.5048 - val_root_mean_squared_error: 0.7105
# Epoch 63/100
# 10/10 - 2s - loss: 0.3028 - root_mean_squared_error: 0.5502 - val_loss: 0.3022 - val_root_mean_squared_error: 0.5497
# Epoch 64/100
# 10/10 - 2s - loss: 0.3294 - root_mean_squared_error: 0.5739 - val_loss: 0.4605 - val_root_mean_squared_error: 0.6786
# Epoch 65/100
# 10/10 - 2s - loss: 0.3108 - root_mean_squared_error: 0.5575 - val_loss: 0.5060 - val_root_mean_squared_error: 0.7113
# Epoch 66/100
# 10/10 - 2s - loss: 0.3202 - root_mean_squared_error: 0.5659 - val_loss: 0.4267 - val_root_mean_squared_error: 0.6533
# Epoch 67/100
# 10/10 - 2s - loss: 0.2980 - root_mean_squared_error: 0.5459 - val_loss: 0.3877 - val_root_mean_squared_error: 0.6226
# Epoch 68/100
# 10/10 - 3s - loss: 0.3264 - root_mean_squared_error: 0.5713 - val_loss: 0.4825 - val_root_mean_squared_error: 0.6946
# Epoch 69/100
# 10/10 - 2s - loss: 0.2985 - root_mean_squared_error: 0.5463 - val_loss: 0.5280 - val_root_mean_squared_error: 0.7267
# Restoring model weights from the end of the best epoch.
# Epoch 00069: early stopping
# #### FOLD 1 OOF RMSE = 0.5470

# %% [markdown]
# ## Model loss and metrics graph

# %%
for fold, history in enumerate(history_list):
    print(f'\nFOLD: {fold+1}')
    plot_metrics(history)
# Out:
# FOLD: 1

# %% [markdown]
# # Model evaluation
#
# We are evaluating the model on the `OOF` predictions, it stands for `Out Of Fold`, since we are training using `K-Fold` our model will see all the data, and the correct way to evaluate each fold is by looking at the predictions that are not from that fold.
#
# ## OOF metrics

# %%
y_true = np.concatenate(oof_labels)
y_preds = np.concatenate(oof_pred)

for fold, history in enumerate(history_list):
    print(f"FOLD {fold+1} RMSE: {np.min(history['val_root_mean_squared_error']):.4f}")
    
print(f'OOF RMSE: {mean_squared_error(y_true, y_preds, squared=False):.4f}')
# Out:
# FOLD 1 RMSE: 0.5470
# OOF RMSE: 0.5470

# %% [markdown]
# ### **Error analysis**, label x prediction distribution
#
# Here we can compare the distribution from the labels and the predicted values, in a perfect scenario they should align.

# %%
preds_df = pd.DataFrame({'Label': y_true, 'Prediction': y_preds[:,0]})

fig, ax = plt.subplots(1, 1, figsize=(20, 6))
sns.distplot(preds_df['Label'], ax=ax, label='Label')
sns.distplot(preds_df['Prediction'], ax=ax, label='Prediction')
ax.legend()
plt.show()

# %%
sns.jointplot(data=preds_df, x='Label', y='Prediction', kind='reg', height=10)
plt.show()
