# %% [markdown]
# ## Dependencies

# %%
import warnings, math, json
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import tensorflow_addons as tfa
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
from tensorflow.keras import optimizers, losses, metrics, Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from transformers import TFAutoModelForSequenceClassification, TFAutoModel, AutoTokenizer
from commonlit_scripts import *


seed = 0
seed_everything(seed)
sns.set(style='whitegrid')
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 150)

# %% [markdown]
# ### Hardware configuration

# %%
strategy, tpu = get_strategy()
AUTO = tf.data.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
print(f'REPLICAS: {REPLICAS}')
# Out:
# Running on TPU grpc://10.0.0.2:8470
# REPLICAS: 8

# %% [markdown]
# # Load data

# %%
train_filepath = '/kaggle/input/commonlitreadabilityprize/train.csv'
train = pd.read_csv(train_filepath)
print(f'Train samples: {len(train)}')
# removing unused columns
train.drop(['url_legal', 'license'], axis=1, inplace=True)
display(train.head())
# Out:
# Train samples: 2834
#           id  \
# 0  c12129c31
# 1  85aa80a4c
# 2  b69ac6792
# 3  dd1000b26
# 4  37c1b32fb
#
#                                                                                                                                                  excerpt  \
# 0  When the young people returned to the ballroom, it presented a decidedly changed appearance. Instead of an interior scene, it was a winter landsca...
# 1  All through dinner time, Mrs. Fayre was somewhat silent, her eyes resting on Dolly with a wistful, uncertain expression. She wanted to give the ch...
# 2  As Roger had predicted, the snow departed as quickly as it came, and two days after their sleigh ride there was scarcely a vestige of white on the...
# 3  And outside before the palace a great garden was walled round, filled full of stately fruit-trees, gray olives and sweet figs, and pomegranates, p...
# 4  Once upon a time there were Three Bears who lived together in a house of their own in a wood. One of them was a Little, Small, Wee Bear; and one w...
#
#      target  standard_error
# 0 -0.340259        0.464009
# 1 -0.315372        0.480805
# 2 -0.580118        0.476676
# 3 -1.054013        0.450007
# 4  0.247197        0.510845

# %% [markdown]
# # Model parameters

# %%
config = {
  "BATCH_SIZE": 8 * REPLICAS,
  "LEARNING_RATE": 1e-5 * REPLICAS,
  "EPOCHS": 100,
  "ES_PATIENCE": 30,
  "N_FOLDS": 5,
  "N_USED_FOLDS": 1,
  "SEQ_LEN": 256,
  "BASE_MODEL": '/kaggle/input/huggingface-roberta/roberta-base/',
  "SEED": seed,
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# ## Auxiliary functions

# %%
# Datasets utility functions
def custom_standardization(text, is_lower=True):
    if is_lower:
        text = text.lower() # if encoder is uncased
    text = text.strip()
    return text

def sample_target(features, target):
    mean, _, stddev = target
    sampled_target = tf.random.normal([], mean=tf.cast(mean, dtype=tf.float32), 
                                      stddev=tf.cast(stddev, dtype=tf.float32), dtype=tf.float32)
    return (features, (mean, sampled_target))
    
def get_dataset(pandas_df, tokenizer, labeled=True, ordered=False, repeated=False, 
                is_sampled=False, batch_size=32, seq_len=128, is_lower=True):
    """
        Return a Tensorflow dataset ready for training or inference.
    """
    text = [custom_standardization(text, is_lower) for text in pandas_df['excerpt']]
    
    # Tokenize inputs
    tokenized_inputs = tokenizer(text, max_length=seq_len, truncation=True, 
                                 padding='max_length', return_tensors='tf')
    
    if labeled:
        dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': tokenized_inputs['input_ids'], 
                                                       'attention_mask': tokenized_inputs['attention_mask']}, 
                                                      (pandas_df['target'], pandas_df['target'], pandas_df['standard_error'])))
        if is_sampled:
            dataset = dataset.map(sample_target, num_parallel_calls=tf.data.AUTOTUNE)
    else:
        dataset = tf.data.Dataset.from_tensor_slices({'input_ids': tokenized_inputs['input_ids'], 
                                                      'attention_mask': tokenized_inputs['attention_mask']})
        
    if repeated:
        dataset = dataset.repeat()
    if not ordered:
        dataset = dataset.shuffle(2048)
    dataset = dataset.batch(batch_size)
    dataset = dataset.cache()
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# %% [markdown]
# # Model

# %%
def model_fn(encoder, seq_len=256):
    input_ids = L.Input(shape=(seq_len,), dtype=tf.int32, name='input_ids')
    input_attention_mask = L.Input(shape=(seq_len,), dtype=tf.int32, name='attention_mask')
    
    outputs = encoder({'input_ids': input_ids,  
                       'attention_mask': input_attention_mask})
    last_hidden_state = outputs['last_hidden_state']
    
    cls_token = last_hidden_state[:, 0, :]
    output = L.Dense(1, name='output')(cls_token)
    output_sample = L.Dense(1, name='output_sample')(cls_token)
    
    model = Model(inputs=[input_ids, input_attention_mask], 
                  outputs=[output, output_sample])

    optimizer = optimizers.Adam(lr=config['LEARNING_RATE'])
    model.compile(optimizer=optimizer, 
                  loss=losses.MeanSquaredError(), 
                  metrics=[metrics.RootMeanSquaredError()])
    return model


with strategy.scope():
    encoder = TFAutoModel.from_pretrained(config['BASE_MODEL'])
    # Freeze embeddings
    encoder.layers[0].embeddings.trainable = False
    model = model_fn(encoder, config['SEQ_LEN'])
    
model.summary()
# Out:
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# attention_mask (InputLayer)     [(None, 256)]        0
# __________________________________________________________________________________________________
# input_ids (InputLayer)          [(None, 256)]        0
# __________________________________________________________________________________________________
# tf_roberta_model (TFRobertaMode TFBaseModelOutputWit 124645632   attention_mask[0][0]
#                                                                  input_ids[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici (None, 768)          0           tf_roberta_model[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            769         tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# output_sample (Dense)           (None, 1)            769         tf.__operators__.getitem[0][0]
# ==================================================================================================
# Total params: 124,647,170
# Trainable params: 85,646,594
# Non-trainable params: 39,000,576
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
tokenizer = AutoTokenizer.from_pretrained(config['BASE_MODEL'])
skf = KFold(n_splits=config['N_FOLDS'], shuffle=True, random_state=seed)
oof_pred = []; oof_labels = []; history_list = []; oof_pred2 = []


for fold,(idxT, idxV) in enumerate(skf.split(train)):
    if fold >= config['N_USED_FOLDS']:
        break
    if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    print(f'\nFOLD: {fold+1}')
    print(f'TRAIN: {len(idxT)} VALID: {len(idxV)}')
    
    # Model
    K.clear_session()
    with strategy.scope():
        encoder = TFAutoModel.from_pretrained(config['BASE_MODEL'])
        # Freeze embeddings
        encoder.layers[0].embeddings.trainable = False
        model = model_fn(encoder, seq_len=config['SEQ_LEN'])

    model_path = f'model_{fold}.h5'
    es = EarlyStopping(monitor='val_output_root_mean_squared_error', mode='min', 
                       patience=config['ES_PATIENCE'], restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_output_root_mean_squared_error', mode='min', 
                                 save_best_only=True, save_weights_only=True)

    # Train
    history = model.fit(x=get_dataset(train.loc[idxT], tokenizer, repeated=True, is_sampled=True, 
                                      batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN']), 
                        validation_data=get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                                                    batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN']), 
                        steps_per_epoch=10, 
                        callbacks=[es, checkpoint], 
                        epochs=config['EPOCHS'],  
                        verbose=2).history

    history_list.append(history)
    # Save last model weights
    model.load_weights(model_path)

    # Results
    print(f"#### FOLD {fold+1} OOF RMSE = {np.min(history['val_output_root_mean_squared_error']):.4f}")
    print(f"#### FOLD {fold+1} OOF RMSE = {np.min(history['val_output_sample_root_mean_squared_error']):.4f}")

    # OOF predictions
    valid_ds = get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                           batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN'])
    oof_labels.append([target[0].numpy() for sample, target in iter(valid_ds.unbatch())])
    x_oof = valid_ds.map(lambda sample, target: sample)
    preds = model.predict(x_oof)
    oof_pred.append(preds[0])
    oof_pred2.append(preds[1])
# Out:
# FOLD: 1
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/100
# 10/10 - 87s - loss: 2.6703 - output_loss: 1.1081 - output_sample_loss: 1.5622 - output_root_mean_squared_error: 1.0527 - output_sample_root_mean_squared_error: 1.2499 - val_loss: 1.8285 - val_output_loss: 0.8839 - val_output_sample_loss: 0.9446 - val_output_root_mean_squared_error: 0.9402 - val_output_sample_root_mean_squared_error: 0.9719
# Epoch 2/100
# 10/10 - 2s - loss: 1.6116 - output_loss: 0.6974 - output_sample_loss: 0.9141 - output_root_mean_squared_error: 0.8351 - output_sample_root_mean_squared_error: 0.9561 - val_loss: 1.3029 - val_output_loss: 0.5258 - val_output_sample_loss: 0.7771 - val_output_root_mean_squared_error: 0.7251 - val_output_sample_root_mean_squared_error: 0.8815
# Epoch 3/100
# 10/10 - 2s - loss: 1.4618 - output_loss: 0.6215 - output_sample_loss: 0.8403 - output_root_mean_squared_error: 0.7883 - output_sample_root_mean_squared_error: 0.9167 - val_loss: 1.2674 - val_output_loss: 0.5864 - val_output_sample_loss: 0.6810 - val_output_root_mean_squared_error: 0.7658 - val_output_sample_root_mean_squared_error: 0.8252
# Epoch 4/100
# 10/10 - 2s - loss: 1.3812 - output_loss: 0.5551 - output_sample_loss: 0.8261 - output_root_mean_squared_error: 0.7450 - output_sample_root_mean_squared_error: 0.9089 - val_loss: 0.8970 - val_output_loss: 0.4437 - val_output_sample_loss: 0.4533 - val_output_root_mean_squared_error: 0.6661 - val_output_sample_root_mean_squared_error: 0.6733
# Epoch 5/100
# 10/10 - 2s - loss: 1.1714 - output_loss: 0.4795 - output_sample_loss: 0.6919 - output_root_mean_squared_error: 0.6924 - output_sample_root_mean_squared_error: 0.8318 - val_loss: 0.8401 - val_output_loss: 0.3819 - val_output_sample_loss: 0.4582 - val_output_root_mean_squared_error: 0.6180 - val_output_sample_root_mean_squared_error: 0.6769
# Epoch 6/100
# 10/10 - 2s - loss: 1.0272 - output_loss: 0.4096 - output_sample_loss: 0.6175 - output_root_mean_squared_error: 0.6400 - output_sample_root_mean_squared_error: 0.7858 - val_loss: 0.9808 - val_output_loss: 0.4695 - val_output_sample_loss: 0.5112 - val_output_root_mean_squared_error: 0.6852 - val_output_sample_root_mean_squared_error: 0.7150
# Epoch 7/100
# 10/10 - 2s - loss: 0.8341 - output_loss: 0.3012 - output_sample_loss: 0.5329 - output_root_mean_squared_error: 0.5488 - output_sample_root_mean_squared_error: 0.7300 - val_loss: 0.6737 - val_output_loss: 0.3472 - val_output_sample_loss: 0.3266 - val_output_root_mean_squared_error: 0.5892 - val_output_sample_root_mean_squared_error: 0.5715
# Epoch 8/100
# 10/10 - 2s - loss: 0.9171 - output_loss: 0.3156 - output_sample_loss: 0.6014 - output_root_mean_squared_error: 0.5618 - output_sample_root_mean_squared_error: 0.7755 - val_loss: 1.7238 - val_output_loss: 0.9549 - val_output_sample_loss: 0.7689 - val_output_root_mean_squared_error: 0.9772 - val_output_sample_root_mean_squared_error: 0.8769
# Epoch 9/100
# 10/10 - 2s - loss: 0.8439 - output_loss: 0.3085 - output_sample_loss: 0.5355 - output_root_mean_squared_error: 0.5554 - output_sample_root_mean_squared_error: 0.7317 - val_loss: 0.9590 - val_output_loss: 0.4680 - val_output_sample_loss: 0.4911 - val_output_root_mean_squared_error: 0.6841 - val_output_sample_root_mean_squared_error: 0.7008
# Epoch 10/100
# 10/10 - 2s - loss: 0.7966 - output_loss: 0.2695 - output_sample_loss: 0.5272 - output_root_mean_squared_error: 0.5191 - output_sample_root_mean_squared_error: 0.7261 - val_loss: 1.0536 - val_output_loss: 0.5236 - val_output_sample_loss: 0.5300 - val_output_root_mean_squared_error: 0.7236 - val_output_sample_root_mean_squared_error: 0.7280
# Epoch 11/100
# 10/10 - 2s - loss: 0.8522 - output_loss: 0.2844 - output_sample_loss: 0.5678 - output_root_mean_squared_error: 0.5333 - output_sample_root_mean_squared_error: 0.7535 - val_loss: 0.8112 - val_output_loss: 0.4111 - val_output_sample_loss: 0.4001 - val_output_root_mean_squared_error: 0.6412 - val_output_sample_root_mean_squared_error: 0.6325
# Epoch 12/100
# 10/10 - 2s - loss: 0.8572 - output_loss: 0.2808 - output_sample_loss: 0.5764 - output_root_mean_squared_error: 0.5299 - output_sample_root_mean_squared_error: 0.7592 - val_loss: 0.8314 - val_output_loss: 0.4561 - val_output_sample_loss: 0.3753 - val_output_root_mean_squared_error: 0.6754 - val_output_sample_root_mean_squared_error: 0.6126
# Epoch 13/100
# 10/10 - 2s - loss: 0.7210 - output_loss: 0.2298 - output_sample_loss: 0.4912 - output_root_mean_squared_error: 0.4794 - output_sample_root_mean_squared_error: 0.7008 - val_loss: 1.1920 - val_output_loss: 0.5368 - val_output_sample_loss: 0.6551 - val_output_root_mean_squared_error: 0.7327 - val_output_sample_root_mean_squared_error: 0.8094
# Epoch 14/100
# 10/10 - 2s - loss: 0.7943 - output_loss: 0.2781 - output_sample_loss: 0.5161 - output_root_mean_squared_error: 0.5274 - output_sample_root_mean_squared_error: 0.7184 - val_loss: 0.8084 - val_output_loss: 0.4506 - val_output_sample_loss: 0.3578 - val_output_root_mean_squared_error: 0.6713 - val_output_sample_root_mean_squared_error: 0.5982
# Epoch 15/100
# 10/10 - 2s - loss: 0.6885 - output_loss: 0.2309 - output_sample_loss: 0.4577 - output_root_mean_squared_error: 0.4805 - output_sample_root_mean_squared_error: 0.6765 - val_loss: 0.6497 - val_output_loss: 0.3277 - val_output_sample_loss: 0.3220 - val_output_root_mean_squared_error: 0.5724 - val_output_sample_root_mean_squared_error: 0.5675
# Epoch 16/100
# 10/10 - 2s - loss: 0.6490 - output_loss: 0.1877 - output_sample_loss: 0.4613 - output_root_mean_squared_error: 0.4333 - output_sample_root_mean_squared_error: 0.6792 - val_loss: 0.9930 - val_output_loss: 0.5072 - val_output_sample_loss: 0.4858 - val_output_root_mean_squared_error: 0.7122 - val_output_sample_root_mean_squared_error: 0.6970
# Epoch 17/100
# 10/10 - 2s - loss: 0.5833 - output_loss: 0.1672 - output_sample_loss: 0.4161 - output_root_mean_squared_error: 0.4089 - output_sample_root_mean_squared_error: 0.6451 - val_loss: 0.8200 - val_output_loss: 0.4217 - val_output_sample_loss: 0.3983 - val_output_root_mean_squared_error: 0.6494 - val_output_sample_root_mean_squared_error: 0.6311
# Epoch 18/100
# 10/10 - 2s - loss: 0.6031 - output_loss: 0.1785 - output_sample_loss: 0.4246 - output_root_mean_squared_error: 0.4225 - output_sample_root_mean_squared_error: 0.6516 - val_loss: 0.6651 - val_output_loss: 0.3508 - val_output_sample_loss: 0.3143 - val_output_root_mean_squared_error: 0.5923 - val_output_sample_root_mean_squared_error: 0.5607
# Epoch 19/100
# 10/10 - 2s - loss: 0.6623 - output_loss: 0.2248 - output_sample_loss: 0.4375 - output_root_mean_squared_error: 0.4742 - output_sample_root_mean_squared_error: 0.6614 - val_loss: 0.5511 - val_output_loss: 0.2743 - val_output_sample_loss: 0.2767 - val_output_root_mean_squared_error: 0.5238 - val_output_sample_root_mean_squared_error: 0.5260
# Epoch 20/100
# 10/10 - 2s - loss: 0.6243 - output_loss: 0.2213 - output_sample_loss: 0.4029 - output_root_mean_squared_error: 0.4704 - output_sample_root_mean_squared_error: 0.6348 - val_loss: 0.6453 - val_output_loss: 0.3565 - val_output_sample_loss: 0.2888 - val_output_root_mean_squared_error: 0.5971 - val_output_sample_root_mean_squared_error: 0.5374
# Epoch 21/100
# 10/10 - 2s - loss: 0.6123 - output_loss: 0.1574 - output_sample_loss: 0.4550 - output_root_mean_squared_error: 0.3967 - output_sample_root_mean_squared_error: 0.6745 - val_loss: 1.0731 - val_output_loss: 0.5870 - val_output_sample_loss: 0.4862 - val_output_root_mean_squared_error: 0.7661 - val_output_sample_root_mean_squared_error: 0.6973
# Epoch 22/100
# 10/10 - 2s - loss: 0.5701 - output_loss: 0.1526 - output_sample_loss: 0.4175 - output_root_mean_squared_error: 0.3906 - output_sample_root_mean_squared_error: 0.6461 - val_loss: 0.6026 - val_output_loss: 0.2983 - val_output_sample_loss: 0.3043 - val_output_root_mean_squared_error: 0.5462 - val_output_sample_root_mean_squared_error: 0.5516
# Epoch 23/100
# 10/10 - 2s - loss: 0.4819 - output_loss: 0.1321 - output_sample_loss: 0.3498 - output_root_mean_squared_error: 0.3634 - output_sample_root_mean_squared_error: 0.5914 - val_loss: 0.8148 - val_output_loss: 0.4299 - val_output_sample_loss: 0.3850 - val_output_root_mean_squared_error: 0.6556 - val_output_sample_root_mean_squared_error: 0.6205
# Epoch 24/100
# 10/10 - 2s - loss: 0.4586 - output_loss: 0.1283 - output_sample_loss: 0.3303 - output_root_mean_squared_error: 0.3581 - output_sample_root_mean_squared_error: 0.5747 - val_loss: 0.6688 - val_output_loss: 0.3406 - val_output_sample_loss: 0.3281 - val_output_root_mean_squared_error: 0.5836 - val_output_sample_root_mean_squared_error: 0.5728
# Epoch 25/100
# 10/10 - 2s - loss: 0.4711 - output_loss: 0.1137 - output_sample_loss: 0.3574 - output_root_mean_squared_error: 0.3372 - output_sample_root_mean_squared_error: 0.5978 - val_loss: 0.7737 - val_output_loss: 0.3567 - val_output_sample_loss: 0.4170 - val_output_root_mean_squared_error: 0.5973 - val_output_sample_root_mean_squared_error: 0.6458
# Epoch 26/100
# 10/10 - 3s - loss: 0.5104 - output_loss: 0.1394 - output_sample_loss: 0.3710 - output_root_mean_squared_error: 0.3734 - output_sample_root_mean_squared_error: 0.6091 - val_loss: 1.3818 - val_output_loss: 0.7063 - val_output_sample_loss: 0.6754 - val_output_root_mean_squared_error: 0.8404 - val_output_sample_root_mean_squared_error: 0.8218
# Epoch 27/100
# 10/10 - 2s - loss: 0.4530 - output_loss: 0.1170 - output_sample_loss: 0.3360 - output_root_mean_squared_error: 0.3421 - output_sample_root_mean_squared_error: 0.5796 - val_loss: 0.8722 - val_output_loss: 0.4574 - val_output_sample_loss: 0.4149 - val_output_root_mean_squared_error: 0.6763 - val_output_sample_root_mean_squared_error: 0.6441
# Epoch 28/100
# 10/10 - 2s - loss: 0.5205 - output_loss: 0.1367 - output_sample_loss: 0.3838 - output_root_mean_squared_error: 0.3698 - output_sample_root_mean_squared_error: 0.6195 - val_loss: 1.4429 - val_output_loss: 0.6587 - val_output_sample_loss: 0.7842 - val_output_root_mean_squared_error: 0.8116 - val_output_sample_root_mean_squared_error: 0.8855
# Epoch 29/100
# 10/10 - 2s - loss: 0.5289 - output_loss: 0.1300 - output_sample_loss: 0.3989 - output_root_mean_squared_error: 0.3606 - output_sample_root_mean_squared_error: 0.6316 - val_loss: 1.0418 - val_output_loss: 0.6549 - val_output_sample_loss: 0.3869 - val_output_root_mean_squared_error: 0.8092 - val_output_sample_root_mean_squared_error: 0.6220
# Epoch 30/100
# 10/10 - 2s - loss: 0.4645 - output_loss: 0.1169 - output_sample_loss: 0.3476 - output_root_mean_squared_error: 0.3420 - output_sample_root_mean_squared_error: 0.5896 - val_loss: 0.7183 - val_output_loss: 0.3269 - val_output_sample_loss: 0.3913 - val_output_root_mean_squared_error: 0.5718 - val_output_sample_root_mean_squared_error: 0.6256
# Epoch 31/100
# 10/10 - 2s - loss: 0.4093 - output_loss: 0.0775 - output_sample_loss: 0.3318 - output_root_mean_squared_error: 0.2783 - output_sample_root_mean_squared_error: 0.5760 - val_loss: 0.9699 - val_output_loss: 0.4364 - val_output_sample_loss: 0.5336 - val_output_root_mean_squared_error: 0.6606 - val_output_sample_root_mean_squared_error: 0.7305
# Epoch 32/100
# 10/10 - 2s - loss: 0.3721 - output_loss: 0.0903 - output_sample_loss: 0.2819 - output_root_mean_squared_error: 0.3004 - output_sample_root_mean_squared_error: 0.5309 - val_loss: 1.0498 - val_output_loss: 0.6164 - val_output_sample_loss: 0.4334 - val_output_root_mean_squared_error: 0.7851 - val_output_sample_root_mean_squared_error: 0.6583
# Epoch 33/100
# 10/10 - 2s - loss: 0.4579 - output_loss: 0.1032 - output_sample_loss: 0.3546 - output_root_mean_squared_error: 0.3213 - output_sample_root_mean_squared_error: 0.5955 - val_loss: 1.1510 - val_output_loss: 0.6651 - val_output_sample_loss: 0.4859 - val_output_root_mean_squared_error: 0.8155 - val_output_sample_root_mean_squared_error: 0.6971
# Epoch 34/100
# 10/10 - 2s - loss: 0.4491 - output_loss: 0.1271 - output_sample_loss: 0.3220 - output_root_mean_squared_error: 0.3565 - output_sample_root_mean_squared_error: 0.5674 - val_loss: 0.8230 - val_output_loss: 0.3686 - val_output_sample_loss: 0.4544 - val_output_root_mean_squared_error: 0.6071 - val_output_sample_root_mean_squared_error: 0.6741
# Epoch 35/100
# 10/10 - 2s - loss: 0.5295 - output_loss: 0.1357 - output_sample_loss: 0.3938 - output_root_mean_squared_error: 0.3684 - output_sample_root_mean_squared_error: 0.6275 - val_loss: 1.0232 - val_output_loss: 0.5510 - val_output_sample_loss: 0.4722 - val_output_root_mean_squared_error: 0.7423 - val_output_sample_root_mean_squared_error: 0.6872
# Epoch 36/100
# 10/10 - 2s - loss: 0.5455 - output_loss: 0.1324 - output_sample_loss: 0.4131 - output_root_mean_squared_error: 0.3638 - output_sample_root_mean_squared_error: 0.6427 - val_loss: 0.6650 - val_output_loss: 0.3441 - val_output_sample_loss: 0.3209 - val_output_root_mean_squared_error: 0.5866 - val_output_sample_root_mean_squared_error: 0.5665
# Epoch 37/100
# 10/10 - 2s - loss: 0.4024 - output_loss: 0.1029 - output_sample_loss: 0.2995 - output_root_mean_squared_error: 0.3208 - output_sample_root_mean_squared_error: 0.5473 - val_loss: 0.8676 - val_output_loss: 0.4414 - val_output_sample_loss: 0.4262 - val_output_root_mean_squared_error: 0.6644 - val_output_sample_root_mean_squared_error: 0.6528
# Epoch 38/100
# 10/10 - 2s - loss: 0.3797 - output_loss: 0.0905 - output_sample_loss: 0.2891 - output_root_mean_squared_error: 0.3009 - output_sample_root_mean_squared_error: 0.5377 - val_loss: 0.9702 - val_output_loss: 0.5524 - val_output_sample_loss: 0.4179 - val_output_root_mean_squared_error: 0.7432 - val_output_sample_root_mean_squared_error: 0.6464
# Epoch 39/100
# 10/10 - 2s - loss: 0.3886 - output_loss: 0.0796 - output_sample_loss: 0.3090 - output_root_mean_squared_error: 0.2821 - output_sample_root_mean_squared_error: 0.5559 - val_loss: 0.6900 - val_output_loss: 0.3467 - val_output_sample_loss: 0.3433 - val_output_root_mean_squared_error: 0.5888 - val_output_sample_root_mean_squared_error: 0.5859
# Epoch 40/100
# 10/10 - 2s - loss: 0.3854 - output_loss: 0.0964 - output_sample_loss: 0.2890 - output_root_mean_squared_error: 0.3105 - output_sample_root_mean_squared_error: 0.5376 - val_loss: 0.6592 - val_output_loss: 0.3439 - val_output_sample_loss: 0.3153 - val_output_root_mean_squared_error: 0.5865 - val_output_sample_root_mean_squared_error: 0.5615
# Epoch 41/100
# 10/10 - 2s - loss: 0.4269 - output_loss: 0.0986 - output_sample_loss: 0.3283 - output_root_mean_squared_error: 0.3140 - output_sample_root_mean_squared_error: 0.5730 - val_loss: 0.6387 - val_output_loss: 0.3114 - val_output_sample_loss: 0.3273 - val_output_root_mean_squared_error: 0.5580 - val_output_sample_root_mean_squared_error: 0.5721
# Epoch 42/100
# 10/10 - 2s - loss: 0.3990 - output_loss: 0.0801 - output_sample_loss: 0.3189 - output_root_mean_squared_error: 0.2830 - output_sample_root_mean_squared_error: 0.5647 - val_loss: 0.9155 - val_output_loss: 0.4581 - val_output_sample_loss: 0.4574 - val_output_root_mean_squared_error: 0.6769 - val_output_sample_root_mean_squared_error: 0.6763
# Epoch 43/100
# 10/10 - 2s - loss: 0.3636 - output_loss: 0.0716 - output_sample_loss: 0.2919 - output_root_mean_squared_error: 0.2676 - output_sample_root_mean_squared_error: 0.5403 - val_loss: 0.9336 - val_output_loss: 0.4594 - val_output_sample_loss: 0.4741 - val_output_root_mean_squared_error: 0.6778 - val_output_sample_root_mean_squared_error: 0.6886
# Epoch 44/100
# 10/10 - 2s - loss: 0.3382 - output_loss: 0.0606 - output_sample_loss: 0.2777 - output_root_mean_squared_error: 0.2461 - output_sample_root_mean_squared_error: 0.5269 - val_loss: 0.9010 - val_output_loss: 0.4509 - val_output_sample_loss: 0.4501 - val_output_root_mean_squared_error: 0.6715 - val_output_sample_root_mean_squared_error: 0.6709
# Epoch 45/100
# 10/10 - 2s - loss: 0.3805 - output_loss: 0.0759 - output_sample_loss: 0.3046 - output_root_mean_squared_error: 0.2755 - output_sample_root_mean_squared_error: 0.5519 - val_loss: 1.0810 - val_output_loss: 0.6806 - val_output_sample_loss: 0.4004 - val_output_root_mean_squared_error: 0.8250 - val_output_sample_root_mean_squared_error: 0.6328
# Epoch 46/100
# 10/10 - 2s - loss: 0.3924 - output_loss: 0.0856 - output_sample_loss: 0.3067 - output_root_mean_squared_error: 0.2926 - output_sample_root_mean_squared_error: 0.5538 - val_loss: 0.8537 - val_output_loss: 0.3956 - val_output_sample_loss: 0.4582 - val_output_root_mean_squared_error: 0.6289 - val_output_sample_root_mean_squared_error: 0.6769
# Epoch 47/100
# 10/10 - 3s - loss: 0.3630 - output_loss: 0.0767 - output_sample_loss: 0.2863 - output_root_mean_squared_error: 0.2769 - output_sample_root_mean_squared_error: 0.5350 - val_loss: 0.8350 - val_output_loss: 0.3750 - val_output_sample_loss: 0.4600 - val_output_root_mean_squared_error: 0.6123 - val_output_sample_root_mean_squared_error: 0.6783
# Epoch 48/100
# 10/10 - 2s - loss: 0.3441 - output_loss: 0.0657 - output_sample_loss: 0.2784 - output_root_mean_squared_error: 0.2563 - output_sample_root_mean_squared_error: 0.5276 - val_loss: 0.7397 - val_output_loss: 0.3826 - val_output_sample_loss: 0.3571 - val_output_root_mean_squared_error: 0.6185 - val_output_sample_root_mean_squared_error: 0.5976
# Epoch 49/100
# 10/10 - 2s - loss: 0.3888 - output_loss: 0.0641 - output_sample_loss: 0.3247 - output_root_mean_squared_error: 0.2532 - output_sample_root_mean_squared_error: 0.5698 - val_loss: 0.7599 - val_output_loss: 0.3691 - val_output_sample_loss: 0.3908 - val_output_root_mean_squared_error: 0.6076 - val_output_sample_root_mean_squared_error: 0.6252
# Restoring model weights from the end of the best epoch.
# Epoch 00049: early stopping
# #### FOLD 1 OOF RMSE = 0.5238
# #### FOLD 1 OOF RMSE = 0.5260

# %% [markdown]
# ## Model loss and metrics graph

# %%
for fold, history in enumerate(history_list):
    print(f'\nFOLD: {fold+1}')
    plot_metrics(history)
# Out:
# FOLD: 1

# %% [markdown]
# # Model evaluation
#
# We are evaluating the model on the `OOF` predictions, it stands for `Out Of Fold`, since we are training using `K-Fold` our model will see all the data, and the correct way to evaluate each fold is by looking at the predictions that are not from that fold.
#
# ## OOF metrics

# %%
y_true = np.concatenate(oof_labels)
y_preds = np.concatenate(oof_pred)
y_preds2 = np.concatenate(oof_pred2)

for fold, history in enumerate(history_list):
    print(f"FOLD {fold+1} RMSE: {np.min(history['val_output_root_mean_squared_error']):.4f}")
    print(f"FOLD {fold+1} RMSE: {np.min(history['val_output_sample_root_mean_squared_error']):.4f}")
    
print(f'OOF RMSE: {mean_squared_error(y_true, y_preds, squared=False):.4f}')
print(f'OOF RMSE: {mean_squared_error(y_true, y_preds2, squared=False):.4f}')
# Out:
# FOLD 1 RMSE: 0.5238
# FOLD 1 RMSE: 0.5260
# OOF RMSE: 0.5238
# OOF RMSE: 0.5260

# %% [markdown]
# ### **Error analysis**, label x prediction distribution
#
# Here we can compare the distribution from the labels and the predicted values, in a perfect scenario they should align.

# %%
preds_df = pd.DataFrame({'Label': y_true, 'Prediction': y_preds[:,0], 'Prediction2': y_preds2[:,0]})

fig, ax = plt.subplots(1, 1, figsize=(20, 6))
sns.distplot(preds_df['Label'], ax=ax, label='Label')
sns.distplot(preds_df['Prediction'], ax=ax, label='Prediction')
ax.legend()
plt.show()

fig, ax = plt.subplots(1, 1, figsize=(20, 6))
sns.distplot(preds_df['Label'], ax=ax, label='Label')
sns.distplot(preds_df['Prediction'], ax=ax, label='Prediction')
ax.legend()
plt.show()

# %%
sns.jointplot(data=preds_df, x='Label', y='Prediction', kind='reg', height=10)
plt.show()
sns.jointplot(data=preds_df, x='Label', y='Prediction2', kind='reg', height=10)
plt.show()
