# %% [markdown]
# ## Dependencies

# %%
import random, os, warnings, math
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import tensorflow as tf
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
from tensorflow.keras import optimizers, losses, metrics, Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from transformers import TFAutoModelForSequenceClassification, TFAutoModel, AutoTokenizer


def seed_everything(seed=0):
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'

seed = 0
seed_everything(seed)
sns.set(style='whitegrid')
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 150)

# %% [markdown]
# ### Hardware configuration

# %%
# TPU or GPU detection
# Detect hardware, return appropriate distribution strategy
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print(f'Running on TPU {tpu.master()}')
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy()

AUTO = tf.data.experimental.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
print(f'REPLICAS: {REPLICAS}')
# Out:
# Running on TPU grpc://10.0.0.2:8470
# REPLICAS: 8

# %% [markdown]
# # Load data

# %%
train_filepath = '/kaggle/input/commonlitreadabilityprize/train.csv'
train = pd.read_csv(train_filepath)
print(f'Train samples: {len(train)}')
display(train.head())
# removing unused columns
train.drop(['url_legal', 'license'], axis=1, inplace=True)
# Out:
# Train samples: 2834
#           id url_legal license  \
# 0  c12129c31       NaN     NaN
# 1  85aa80a4c       NaN     NaN
# 2  b69ac6792       NaN     NaN
# 3  dd1000b26       NaN     NaN
# 4  37c1b32fb       NaN     NaN
#
#                                                                                                                                                  excerpt  \
# 0  When the young people returned to the ballroom, it presented a decidedly changed appearance. Instead of an interior scene, it was a winter landsca...
# 1  All through dinner time, Mrs. Fayre was somewhat silent, her eyes resting on Dolly with a wistful, uncertain expression. She wanted to give the ch...
# 2  As Roger had predicted, the snow departed as quickly as it came, and two days after their sleigh ride there was scarcely a vestige of white on the...
# 3  And outside before the palace a great garden was walled round, filled full of stately fruit-trees, gray olives and sweet figs, and pomegranates, p...
# 4  Once upon a time there were Three Bears who lived together in a house of their own in a wood. One of them was a Little, Small, Wee Bear; and one w...
#
#      target  standard_error
# 0 -0.340259        0.464009
# 1 -0.315372        0.480805
# 2 -0.580118        0.476676
# 3 -1.054013        0.450007
# 4  0.247197        0.510845

# %% [markdown]
# # Model parameters

# %%
BATCH_SIZE = 8 * REPLICAS
LEARNING_RATE = 1e-5 * REPLICAS
EPOCHS = 35
ES_PATIENCE = 10
PATIENCE = 2
N_FOLDS = 5
SEQ_LEN = 256 #300
BASE_MODEL = '/kaggle/input/huggingface-roberta/roberta-base/'

# %% [markdown]
# ## Auxiliary functions

# %%
# Datasets utility functions
def custom_standardization(text):
    text = text.lower() # if encoder is uncased
    text = text.strip()
    return text


def sample_target(features, target):
    mean, stddev = target
    sampled_target = tf.random.normal([], mean=tf.cast(mean, dtype=tf.float32), 
                                      stddev=tf.cast(stddev, dtype=tf.float32), dtype=tf.float32)
    
    return (features, sampled_target)
    

def get_dataset(pandas_df, tokenizer, labeled=True, ordered=False, repeated=False, 
                is_sampled=False, batch_size=32, seq_len=128):
    """
        Return a Tensorflow dataset ready for training or inference.
    """
    text = [custom_standardization(text) for text in pandas_df['excerpt']]
    
    # Tokenize inputs
    tokenized_inputs = tokenizer(text, max_length=seq_len, truncation=True, 
                                 padding='max_length', return_tensors='tf')
    
    if labeled:
        dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': tokenized_inputs['input_ids'], 
                                                      'attention_mask': tokenized_inputs['attention_mask']}, 
                                                      (pandas_df['target'], pandas_df['standard_error'])))
        if is_sampled:
            dataset = dataset.map(sample_target, num_parallel_calls=tf.data.AUTOTUNE)
    else:
        dataset = tf.data.Dataset.from_tensor_slices({'input_ids': tokenized_inputs['input_ids'], 
                                                      'attention_mask': tokenized_inputs['attention_mask']})
        
    if repeated:
        dataset = dataset.repeat()
    if not ordered:
        dataset = dataset.shuffle(1024)
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    
    return dataset


def plot_metrics(history):
    metric_list = list(history.keys())
    size = len(metric_list)//2
    fig, axes = plt.subplots(size, 1, sharex='col', figsize=(20, size * 5))
    axes = axes.flatten()
    
    for index in range(len(metric_list)//2):
        metric_name = metric_list[index]
        val_metric_name = metric_list[index+size]
        axes[index].plot(history[metric_name], label='Train %s' % metric_name)
        axes[index].plot(history[val_metric_name], label='Validation %s' % metric_name)
        axes[index].legend(loc='best', fontsize=16)
        axes[index].set_title(metric_name)

    plt.xlabel('Epochs', fontsize=16)
    sns.despine()
    plt.show()

# %% [markdown]
# # Model

# %%
def model_fn(encoder, seq_len=256):
    input_ids = L.Input(shape=(seq_len,), dtype=tf.int32, name='input_ids')
    input_attention_mask = L.Input(shape=(seq_len,), dtype=tf.int32, name='attention_mask')
    
    outputs = encoder({'input_ids': input_ids, 
                       'attention_mask': input_attention_mask})
    last_hidden_state = outputs['last_hidden_state']
    
    x = L.GlobalAveragePooling1D()(last_hidden_state)
#     x = L.Dropout(.5)(x)
    output = L.Dense(1, name='output')(x)
    
    model = Model(inputs=[input_ids, input_attention_mask], outputs=output)

    optimizer = optimizers.Adam(lr=LEARNING_RATE)
    model.compile(optimizer=optimizer, 
                  loss=losses.MeanSquaredError(), 
                  metrics=[metrics.RootMeanSquaredError()])
    
    return model


with strategy.scope():
#     encoder = TFAutoModelForSequenceClassification.from_pretrained(BASE_MODEL, num_labels=1)
    encoder = TFAutoModel.from_pretrained(BASE_MODEL)
    model = model_fn(encoder, SEQ_LEN)
    
model.summary()
# Out:
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# attention_mask (InputLayer)     [(None, 256)]        0
# __________________________________________________________________________________________________
# input_ids (InputLayer)          [(None, 256)]        0
# __________________________________________________________________________________________________
# tf_roberta_model (TFRobertaMode TFBaseModelOutputWit 124645632   attention_mask[0][0]
#                                                                  input_ids[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 768)          0           tf_roberta_model[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            769         global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 124,646,401
# Trainable params: 124,646,401
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL)
skf = KFold(n_splits=N_FOLDS, shuffle=True, random_state=seed)
oof_pred = []; oof_labels = []; history_list = []

for fold,(idxT, idxV) in enumerate(skf.split(train)):
    if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    print(f'\nFOLD: {fold+1}')
    print(f'TRAIN: {len(idxT)} VALID: {len(idxV)}')

    # Model
    K.clear_session()
    with strategy.scope():
#         encoder = TFAutoModelForSequenceClassification.from_pretrained(BASE_MODEL, num_labels=1)
        encoder = TFAutoModel.from_pretrained(BASE_MODEL)
        model = model_fn(encoder, SEQ_LEN)
        
    model_path = f'model_{fold}.h5'
    es = EarlyStopping(monitor='val_root_mean_squared_error', mode='min', 
                       patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_root_mean_squared_error', mode='min', 
                                 save_best_only=True, save_weights_only=True)

    # Train
    history = model.fit(x=get_dataset(train.loc[idxT], tokenizer, repeated=True, is_sampled=True, 
                                      batch_size=BATCH_SIZE, seq_len=SEQ_LEN), 
                        validation_data=get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                                                    batch_size=BATCH_SIZE, seq_len=SEQ_LEN), 
                        steps_per_epoch=50, 
                        callbacks=[es, checkpoint], 
                        epochs=EPOCHS,  
                        verbose=2).history
      
    history_list.append(history)
    # Save last model weights
    model.load_weights(model_path)
    
    # Results
    print(f"#### FOLD {fold+1} OOF RMSE = {np.min(history['val_root_mean_squared_error']):.4f}")

    # OOF predictions
    valid_ds = get_dataset(train.loc[idxV], tokenizer, ordered=True, batch_size=BATCH_SIZE, seq_len=SEQ_LEN)
    oof_labels.append([target[0].numpy() for sample, target in iter(valid_ds.unbatch())])
    x_oof = valid_ds.map(lambda sample, target: sample)
    oof_pred.append(model.predict(x_oof))
# Out:
# FOLD: 1
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/35
# 50/50 - 91s - loss: 0.9386 - root_mean_squared_error: 0.9688 - val_loss: 0.3711 - val_root_mean_squared_error: 0.6092
# Epoch 2/35
# 50/50 - 5s - loss: 0.5552 - root_mean_squared_error: 0.7451 - val_loss: 0.4811 - val_root_mean_squared_error: 0.6936
# Epoch 3/35
# 50/50 - 5s - loss: 0.4725 - root_mean_squared_error: 0.6874 - val_loss: 0.2982 - val_root_mean_squared_error: 0.5461
# Epoch 4/35
# 50/50 - 5s - loss: 0.4120 - root_mean_squared_error: 0.6419 - val_loss: 0.3657 - val_root_mean_squared_error: 0.6047
# Epoch 5/35
# 50/50 - 5s - loss: 0.3826 - root_mean_squared_error: 0.6186 - val_loss: 0.3809 - val_root_mean_squared_error: 0.6172
# Epoch 6/35
# 50/50 - 5s - loss: 0.3156 - root_mean_squared_error: 0.5618 - val_loss: 0.4490 - val_root_mean_squared_error: 0.6700
# Epoch 7/35
# 50/50 - 5s - loss: 0.3462 - root_mean_squared_error: 0.5884 - val_loss: 0.4606 - val_root_mean_squared_error: 0.6787
# Epoch 8/35
# 50/50 - 5s - loss: 0.3549 - root_mean_squared_error: 0.5957 - val_loss: 0.5802 - val_root_mean_squared_error: 0.7617
# Epoch 9/35
# 50/50 - 5s - loss: 0.3394 - root_mean_squared_error: 0.5826 - val_loss: 0.4826 - val_root_mean_squared_error: 0.6947
# Epoch 10/35
# 50/50 - 5s - loss: 0.3342 - root_mean_squared_error: 0.5781 - val_loss: 0.5153 - val_root_mean_squared_error: 0.7178
# Epoch 11/35
# 50/50 - 5s - loss: 0.3515 - root_mean_squared_error: 0.5929 - val_loss: 0.3263 - val_root_mean_squared_error: 0.5712
# Epoch 12/35
# 50/50 - 5s - loss: 0.4039 - root_mean_squared_error: 0.6355 - val_loss: 0.3247 - val_root_mean_squared_error: 0.5698
# Epoch 13/35
# 50/50 - 5s - loss: 0.3393 - root_mean_squared_error: 0.5825 - val_loss: 0.5710 - val_root_mean_squared_error: 0.7556
# Restoring model weights from the end of the best epoch.
# Epoch 00013: early stopping
# #### FOLD 1 OOF RMSE = 0.5461
#
# FOLD: 2
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/35
# 50/50 - 91s - loss: 0.9914 - root_mean_squared_error: 0.9957 - val_loss: 0.3762 - val_root_mean_squared_error: 0.6134
# Epoch 2/35
# 50/50 - 5s - loss: 0.5597 - root_mean_squared_error: 0.7481 - val_loss: 0.4233 - val_root_mean_squared_error: 0.6506
# Epoch 3/35
# 50/50 - 5s - loss: 0.4130 - root_mean_squared_error: 0.6427 - val_loss: 0.4422 - val_root_mean_squared_error: 0.6650
# Epoch 4/35
# 50/50 - 5s - loss: 0.3676 - root_mean_squared_error: 0.6063 - val_loss: 0.5415 - val_root_mean_squared_error: 0.7359
# Epoch 5/35
# 50/50 - 5s - loss: 0.3723 - root_mean_squared_error: 0.6101 - val_loss: 0.4530 - val_root_mean_squared_error: 0.6731
# Epoch 6/35
# 50/50 - 5s - loss: 0.3646 - root_mean_squared_error: 0.6039 - val_loss: 0.3146 - val_root_mean_squared_error: 0.5609
# Epoch 7/35
# 50/50 - 5s - loss: 0.3536 - root_mean_squared_error: 0.5946 - val_loss: 0.5206 - val_root_mean_squared_error: 0.7215
# Epoch 8/35
# 50/50 - 5s - loss: 0.3226 - root_mean_squared_error: 0.5680 - val_loss: 0.3706 - val_root_mean_squared_error: 0.6087
# Epoch 9/35
# 50/50 - 5s - loss: 0.3018 - root_mean_squared_error: 0.5494 - val_loss: 0.4271 - val_root_mean_squared_error: 0.6535
# Epoch 10/35
# 50/50 - 5s - loss: 0.2928 - root_mean_squared_error: 0.5411 - val_loss: 0.3385 - val_root_mean_squared_error: 0.5818
# Epoch 11/35
# 50/50 - 5s - loss: 0.3268 - root_mean_squared_error: 0.5716 - val_loss: 0.5942 - val_root_mean_squared_error: 0.7709
# Epoch 12/35
# 50/50 - 5s - loss: 0.2823 - root_mean_squared_error: 0.5313 - val_loss: 0.3624 - val_root_mean_squared_error: 0.6020
# Epoch 13/35
# 50/50 - 5s - loss: 0.2888 - root_mean_squared_error: 0.5374 - val_loss: 0.4096 - val_root_mean_squared_error: 0.6400
# Epoch 14/35
# 50/50 - 5s - loss: 0.3239 - root_mean_squared_error: 0.5691 - val_loss: 0.6442 - val_root_mean_squared_error: 0.8026
# Epoch 15/35
# 50/50 - 5s - loss: 0.3058 - root_mean_squared_error: 0.5530 - val_loss: 0.3025 - val_root_mean_squared_error: 0.5500
# Epoch 16/35
# 50/50 - 5s - loss: 0.3088 - root_mean_squared_error: 0.5557 - val_loss: 0.3087 - val_root_mean_squared_error: 0.5557
# Epoch 17/35
# 50/50 - 5s - loss: 0.3118 - root_mean_squared_error: 0.5584 - val_loss: 0.5402 - val_root_mean_squared_error: 0.7350
# Epoch 18/35
# 50/50 - 5s - loss: 0.2917 - root_mean_squared_error: 0.5401 - val_loss: 0.3996 - val_root_mean_squared_error: 0.6321
# Epoch 19/35
# 50/50 - 5s - loss: 0.3054 - root_mean_squared_error: 0.5526 - val_loss: 0.6499 - val_root_mean_squared_error: 0.8061
# Epoch 20/35
# 50/50 - 5s - loss: 0.3194 - root_mean_squared_error: 0.5651 - val_loss: 0.8241 - val_root_mean_squared_error: 0.9078
# Epoch 21/35
# 50/50 - 5s - loss: 0.3922 - root_mean_squared_error: 0.6263 - val_loss: 0.2980 - val_root_mean_squared_error: 0.5459
# Epoch 22/35
# 50/50 - 5s - loss: 0.3036 - root_mean_squared_error: 0.5510 - val_loss: 0.4613 - val_root_mean_squared_error: 0.6792
# Epoch 23/35
# 50/50 - 5s - loss: 0.3003 - root_mean_squared_error: 0.5480 - val_loss: 0.7931 - val_root_mean_squared_error: 0.8905
# Epoch 24/35
# 50/50 - 6s - loss: 0.3123 - root_mean_squared_error: 0.5588 - val_loss: 0.4098 - val_root_mean_squared_error: 0.6402
# Epoch 25/35
# 50/50 - 5s - loss: 0.3606 - root_mean_squared_error: 0.6005 - val_loss: 0.6817 - val_root_mean_squared_error: 0.8256
# Epoch 26/35
# 50/50 - 5s - loss: 0.3283 - root_mean_squared_error: 0.5729 - val_loss: 0.4690 - val_root_mean_squared_error: 0.6848
# Epoch 27/35
# 50/50 - 5s - loss: 0.2753 - root_mean_squared_error: 0.5247 - val_loss: 0.4338 - val_root_mean_squared_error: 0.6586
# Epoch 28/35
# 50/50 - 5s - loss: 0.3031 - root_mean_squared_error: 0.5505 - val_loss: 0.4512 - val_root_mean_squared_error: 0.6717
# Epoch 29/35
# 50/50 - 5s - loss: 0.2966 - root_mean_squared_error: 0.5446 - val_loss: 0.4861 - val_root_mean_squared_error: 0.6972
# Epoch 30/35
# 50/50 - 5s - loss: 0.2797 - root_mean_squared_error: 0.5288 - val_loss: 0.4890 - val_root_mean_squared_error: 0.6993
# Epoch 31/35
# 50/50 - 5s - loss: 0.2988 - root_mean_squared_error: 0.5466 - val_loss: 0.4631 - val_root_mean_squared_error: 0.6805
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# #### FOLD 2 OOF RMSE = 0.5459
#
# FOLD: 3
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/35
# 50/50 - 93s - loss: 0.9891 - root_mean_squared_error: 0.9945 - val_loss: 0.4406 - val_root_mean_squared_error: 0.6638
# Epoch 2/35
# 50/50 - 5s - loss: 0.6106 - root_mean_squared_error: 0.7814 - val_loss: 0.3647 - val_root_mean_squared_error: 0.6039
# Epoch 3/35
# 50/50 - 5s - loss: 0.5192 - root_mean_squared_error: 0.7206 - val_loss: 0.5819 - val_root_mean_squared_error: 0.7628
# Epoch 4/35
# 50/50 - 5s - loss: 0.5003 - root_mean_squared_error: 0.7073 - val_loss: 0.4271 - val_root_mean_squared_error: 0.6535
# Epoch 5/35
# 50/50 - 5s - loss: 0.4657 - root_mean_squared_error: 0.6824 - val_loss: 0.3557 - val_root_mean_squared_error: 0.5964
# Epoch 6/35
# 50/50 - 5s - loss: 0.3849 - root_mean_squared_error: 0.6204 - val_loss: 0.3412 - val_root_mean_squared_error: 0.5842
# Epoch 7/35
# 50/50 - 5s - loss: 0.3672 - root_mean_squared_error: 0.6060 - val_loss: 0.2971 - val_root_mean_squared_error: 0.5450
# Epoch 8/35
# 50/50 - 5s - loss: 0.3456 - root_mean_squared_error: 0.5879 - val_loss: 0.3268 - val_root_mean_squared_error: 0.5717
# Epoch 9/35
# 50/50 - 5s - loss: 0.3253 - root_mean_squared_error: 0.5704 - val_loss: 0.3682 - val_root_mean_squared_error: 0.6068
# Epoch 10/35
# 50/50 - 5s - loss: 0.3049 - root_mean_squared_error: 0.5522 - val_loss: 0.3328 - val_root_mean_squared_error: 0.5769
# Epoch 11/35
# 50/50 - 5s - loss: 0.3363 - root_mean_squared_error: 0.5799 - val_loss: 0.2907 - val_root_mean_squared_error: 0.5392
# Epoch 12/35
# 50/50 - 5s - loss: 0.3137 - root_mean_squared_error: 0.5601 - val_loss: 0.3861 - val_root_mean_squared_error: 0.6214
# Epoch 13/35
# 50/50 - 6s - loss: 0.3122 - root_mean_squared_error: 0.5588 - val_loss: 0.3854 - val_root_mean_squared_error: 0.6208
# Epoch 14/35
# 50/50 - 5s - loss: 0.2980 - root_mean_squared_error: 0.5459 - val_loss: 0.3608 - val_root_mean_squared_error: 0.6006
# Epoch 15/35
# 50/50 - 5s - loss: 0.3175 - root_mean_squared_error: 0.5635 - val_loss: 0.2988 - val_root_mean_squared_error: 0.5466
# Epoch 16/35
# 50/50 - 5s - loss: 0.3015 - root_mean_squared_error: 0.5491 - val_loss: 0.3420 - val_root_mean_squared_error: 0.5848
# Epoch 17/35
# 50/50 - 5s - loss: 0.2976 - root_mean_squared_error: 0.5456 - val_loss: 0.2930 - val_root_mean_squared_error: 0.5413
# Epoch 18/35
# 50/50 - 5s - loss: 0.3055 - root_mean_squared_error: 0.5527 - val_loss: 0.2827 - val_root_mean_squared_error: 0.5317
# Epoch 19/35
# 50/50 - 5s - loss: 0.2934 - root_mean_squared_error: 0.5417 - val_loss: 0.3301 - val_root_mean_squared_error: 0.5745
# Epoch 20/35
# 50/50 - 5s - loss: 0.2992 - root_mean_squared_error: 0.5470 - val_loss: 0.2944 - val_root_mean_squared_error: 0.5426
# Epoch 21/35
# 50/50 - 5s - loss: 0.2925 - root_mean_squared_error: 0.5408 - val_loss: 0.4599 - val_root_mean_squared_error: 0.6782
# Epoch 22/35
# 50/50 - 5s - loss: 0.2994 - root_mean_squared_error: 0.5471 - val_loss: 0.3375 - val_root_mean_squared_error: 0.5810
# Epoch 23/35
# 50/50 - 5s - loss: 0.2936 - root_mean_squared_error: 0.5418 - val_loss: 0.3749 - val_root_mean_squared_error: 0.6123
# Epoch 24/35
# 50/50 - 5s - loss: 0.3091 - root_mean_squared_error: 0.5560 - val_loss: 0.4680 - val_root_mean_squared_error: 0.6841
# Epoch 25/35
# 50/50 - 5s - loss: 0.3108 - root_mean_squared_error: 0.5575 - val_loss: 0.3674 - val_root_mean_squared_error: 0.6062
# Epoch 26/35
# 50/50 - 5s - loss: 0.2891 - root_mean_squared_error: 0.5377 - val_loss: 0.4306 - val_root_mean_squared_error: 0.6562
# Epoch 27/35
# 50/50 - 5s - loss: 0.3084 - root_mean_squared_error: 0.5554 - val_loss: 0.2853 - val_root_mean_squared_error: 0.5341
# Epoch 28/35
# 50/50 - 5s - loss: 0.2986 - root_mean_squared_error: 0.5465 - val_loss: 0.3532 - val_root_mean_squared_error: 0.5943
# Restoring model weights from the end of the best epoch.
# Epoch 00028: early stopping
# #### FOLD 3 OOF RMSE = 0.5317
#
# FOLD: 4
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/35
# 50/50 - 92s - loss: 0.9169 - root_mean_squared_error: 0.9575 - val_loss: 0.3819 - val_root_mean_squared_error: 0.6180
# Epoch 2/35
# 50/50 - 5s - loss: 0.5634 - root_mean_squared_error: 0.7506 - val_loss: 0.4245 - val_root_mean_squared_error: 0.6515
# Epoch 3/35
# 50/50 - 5s - loss: 0.4507 - root_mean_squared_error: 0.6713 - val_loss: 0.3919 - val_root_mean_squared_error: 0.6260
# Epoch 4/35
# 50/50 - 5s - loss: 0.3776 - root_mean_squared_error: 0.6145 - val_loss: 0.3584 - val_root_mean_squared_error: 0.5987
# Epoch 5/35
# 50/50 - 5s - loss: 0.3882 - root_mean_squared_error: 0.6231 - val_loss: 0.3871 - val_root_mean_squared_error: 0.6222
# Epoch 6/35
# 50/50 - 5s - loss: 0.3355 - root_mean_squared_error: 0.5792 - val_loss: 0.3382 - val_root_mean_squared_error: 0.5816
# Epoch 7/35
# 50/50 - 5s - loss: 0.3557 - root_mean_squared_error: 0.5964 - val_loss: 0.4355 - val_root_mean_squared_error: 0.6599
# Epoch 8/35
# 50/50 - 5s - loss: 0.3244 - root_mean_squared_error: 0.5695 - val_loss: 0.2930 - val_root_mean_squared_error: 0.5413
# Epoch 9/35
# 50/50 - 5s - loss: 0.3447 - root_mean_squared_error: 0.5871 - val_loss: 0.3353 - val_root_mean_squared_error: 0.5791
# Epoch 10/35
# 50/50 - 5s - loss: 0.3118 - root_mean_squared_error: 0.5584 - val_loss: 0.4112 - val_root_mean_squared_error: 0.6413
# Epoch 11/35
# 50/50 - 5s - loss: 0.3195 - root_mean_squared_error: 0.5652 - val_loss: 0.2856 - val_root_mean_squared_error: 0.5344
# Epoch 12/35
# 50/50 - 5s - loss: 0.3066 - root_mean_squared_error: 0.5537 - val_loss: 0.4595 - val_root_mean_squared_error: 0.6779
# Epoch 13/35
# 50/50 - 5s - loss: 0.3004 - root_mean_squared_error: 0.5481 - val_loss: 0.3947 - val_root_mean_squared_error: 0.6283
# Epoch 14/35
# 50/50 - 5s - loss: 0.3041 - root_mean_squared_error: 0.5515 - val_loss: 0.4225 - val_root_mean_squared_error: 0.6500
# Epoch 15/35
# 50/50 - 6s - loss: 0.2984 - root_mean_squared_error: 0.5463 - val_loss: 0.4575 - val_root_mean_squared_error: 0.6764
# Epoch 16/35
# 50/50 - 5s - loss: 0.3056 - root_mean_squared_error: 0.5528 - val_loss: 0.3959 - val_root_mean_squared_error: 0.6292
# Epoch 17/35
# 50/50 - 5s - loss: 0.3024 - root_mean_squared_error: 0.5499 - val_loss: 0.4396 - val_root_mean_squared_error: 0.6630
# Epoch 18/35
# 50/50 - 5s - loss: 0.3024 - root_mean_squared_error: 0.5499 - val_loss: 0.4264 - val_root_mean_squared_error: 0.6530
# Epoch 19/35
# 50/50 - 5s - loss: 0.3078 - root_mean_squared_error: 0.5548 - val_loss: 0.3846 - val_root_mean_squared_error: 0.6201
# Epoch 20/35
# 50/50 - 5s - loss: 0.3013 - root_mean_squared_error: 0.5489 - val_loss: 0.3804 - val_root_mean_squared_error: 0.6167
# Epoch 21/35
# 50/50 - 5s - loss: 0.3059 - root_mean_squared_error: 0.5531 - val_loss: 0.3783 - val_root_mean_squared_error: 0.6151
# Restoring model weights from the end of the best epoch.
# Epoch 00021: early stopping
# #### FOLD 4 OOF RMSE = 0.5344
#
# FOLD: 5
# TRAIN: 2268 VALID: 566
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/35
# 50/50 - 94s - loss: 1.0632 - root_mean_squared_error: 1.0311 - val_loss: 0.3854 - val_root_mean_squared_error: 0.6208
# Epoch 2/35
# 50/50 - 5s - loss: 0.5662 - root_mean_squared_error: 0.7525 - val_loss: 0.4006 - val_root_mean_squared_error: 0.6329
# Epoch 3/35
# 50/50 - 5s - loss: 0.4645 - root_mean_squared_error: 0.6815 - val_loss: 0.2843 - val_root_mean_squared_error: 0.5332
# Epoch 4/35
# 50/50 - 5s - loss: 0.4129 - root_mean_squared_error: 0.6426 - val_loss: 0.6716 - val_root_mean_squared_error: 0.8195
# Epoch 5/35
# 50/50 - 5s - loss: 0.4227 - root_mean_squared_error: 0.6501 - val_loss: 0.4021 - val_root_mean_squared_error: 0.6341
# Epoch 6/35
# 50/50 - 5s - loss: 0.3641 - root_mean_squared_error: 0.6034 - val_loss: 0.3710 - val_root_mean_squared_error: 0.6091
# Epoch 7/35
# 50/50 - 5s - loss: 0.3668 - root_mean_squared_error: 0.6056 - val_loss: 0.6504 - val_root_mean_squared_error: 0.8065
# Epoch 8/35
# 50/50 - 5s - loss: 0.3607 - root_mean_squared_error: 0.6006 - val_loss: 0.6987 - val_root_mean_squared_error: 0.8359
# Epoch 9/35
# 50/50 - 5s - loss: 0.3269 - root_mean_squared_error: 0.5717 - val_loss: 0.5750 - val_root_mean_squared_error: 0.7583
# Epoch 10/35
# 50/50 - 5s - loss: 0.3468 - root_mean_squared_error: 0.5889 - val_loss: 0.7395 - val_root_mean_squared_error: 0.8600
# Epoch 11/35
# 50/50 - 5s - loss: 0.3719 - root_mean_squared_error: 0.6098 - val_loss: 0.3465 - val_root_mean_squared_error: 0.5887
# Epoch 12/35
# 50/50 - 5s - loss: 0.3258 - root_mean_squared_error: 0.5708 - val_loss: 0.3176 - val_root_mean_squared_error: 0.5636
# Epoch 13/35
# 50/50 - 5s - loss: 0.3278 - root_mean_squared_error: 0.5725 - val_loss: 0.4026 - val_root_mean_squared_error: 0.6345
# Restoring model weights from the end of the best epoch.
# Epoch 00013: early stopping
# #### FOLD 5 OOF RMSE = 0.5332

# %% [markdown]
# ## Model loss and metrics graph

# %%
for fold, history in enumerate(history_list):
    print(f'\nFOLD: {fold+1}')
    plot_metrics(history)
# Out:
# FOLD: 1
# FOLD: 2
# FOLD: 3
# FOLD: 4
# FOLD: 5

# %% [markdown]
# # Model evaluation
#
# We are evaluating the model on the `OOF` predictions, it stands for `Out Of Fold`, since we are training using `K-Fold` our model will see all the data, and the correct way to evaluate each fold is by looking at the predictions that are not from that fold.
#
# ## OOF metrics

# %%
y_true = np.concatenate(oof_labels)
y_preds = np.concatenate(oof_pred)


for fold, history in enumerate(history_list):
    print(f"FOLD {fold+1} RMSE: {np.min(history['val_root_mean_squared_error']):.4f}")
    
print(f'OOF RMSE: {mean_squared_error(y_true, y_preds, squared=False):.4f}')
# Out:
# FOLD 1 RMSE: 0.5461
# FOLD 2 RMSE: 0.5459
# FOLD 3 RMSE: 0.5317
# FOLD 4 RMSE: 0.5344
# FOLD 5 RMSE: 0.5332
# OOF RMSE: 0.5383

# %% [markdown]
# ### **Error analysis**, label x prediction distribution
#
# Here we can compare the distribution from the labels and the predicted values, in a perfect scenario they should align.

# %%
preds_df = pd.DataFrame({'Label': y_true, 'Prediction': y_preds[:,0]})

fig, ax = plt.subplots(1, 1, figsize=(20, 6))
sns.distplot(preds_df['Label'], ax=ax, label='Label')
sns.distplot(preds_df['Prediction'], ax=ax, label='Prediction')
ax.legend()
plt.show()

# %%
sns.jointplot(data=preds_df, x='Label', y='Prediction', kind='reg', height=10)
plt.show()
