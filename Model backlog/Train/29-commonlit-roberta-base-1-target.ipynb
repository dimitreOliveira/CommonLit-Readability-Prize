# %% [markdown]
# ## Dependencies

# %%
import warnings, math, json
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import tensorflow_addons as tfa
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
from tensorflow.keras import optimizers, losses, metrics, Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from transformers import TFAutoModelForSequenceClassification, TFAutoModel, AutoTokenizer
from commonlit_scripts import *


seed = 0
seed_everything(seed)
sns.set(style='whitegrid')
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 150)

# %% [markdown]
# ### Hardware configuration

# %%
strategy, tpu = get_strategy()
AUTO = tf.data.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
print(f'REPLICAS: {REPLICAS}')
# Out:
# Running on TPU grpc://10.0.0.2:8470
# REPLICAS: 8

# %% [markdown]
# # Load data

# %%
train_filepath = '/kaggle/input/commonlitreadabilityprize/train.csv'
train = pd.read_csv(train_filepath)
print(f'Train samples: {len(train)}')
# removing unused columns
train.drop(['url_legal', 'license'], axis=1, inplace=True)
display(train.head())
# Out:
# Train samples: 2834
#           id  \
# 0  c12129c31
# 1  85aa80a4c
# 2  b69ac6792
# 3  dd1000b26
# 4  37c1b32fb
#
#                                                                                                                                                  excerpt  \
# 0  When the young people returned to the ballroom, it presented a decidedly changed appearance. Instead of an interior scene, it was a winter landsca...
# 1  All through dinner time, Mrs. Fayre was somewhat silent, her eyes resting on Dolly with a wistful, uncertain expression. She wanted to give the ch...
# 2  As Roger had predicted, the snow departed as quickly as it came, and two days after their sleigh ride there was scarcely a vestige of white on the...
# 3  And outside before the palace a great garden was walled round, filled full of stately fruit-trees, gray olives and sweet figs, and pomegranates, p...
# 4  Once upon a time there were Three Bears who lived together in a house of their own in a wood. One of them was a Little, Small, Wee Bear; and one w...
#
#      target  standard_error
# 0 -0.340259        0.464009
# 1 -0.315372        0.480805
# 2 -0.580118        0.476676
# 3 -1.054013        0.450007
# 4  0.247197        0.510845

# %% [markdown]
# # Model parameters

# %%
config = {
  "BATCH_SIZE": 8 * REPLICAS,
  "LEARNING_RATE": 1e-5 * REPLICAS,
  "EPOCHS": 100,
  "ES_PATIENCE": 30,
  "N_FOLDS": 5,
  "N_USED_FOLDS": 1,
  "SEQ_LEN": 256,
  "BASE_MODEL": '/kaggle/input/huggingface-roberta/roberta-base/',
  "SEED": seed,
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# ## Auxiliary functions

# %%
# Datasets utility functions
def custom_standardization(text, is_lower=True):
    if is_lower:
        text = text.lower() # if encoder is uncased
    text = text.strip()
    return text

def sample_target(features, target):
    mean, stddev = target
    sampled_target = tf.random.normal([], mean=tf.cast(mean, dtype=tf.float32), 
                                      stddev=tf.cast(stddev, dtype=tf.float32), dtype=tf.float32)
    return (features, sampled_target)
    
def get_dataset(pandas_df, tokenizer, labeled=True, ordered=False, repeated=False, 
                is_sampled=False, batch_size=32, seq_len=128, is_lower=True):
    """
        Return a Tensorflow dataset ready for training or inference.
    """
    text = [custom_standardization(text, is_lower) for text in pandas_df['excerpt']]
    
    # Tokenize inputs
    tokenized_inputs = tokenizer(text, max_length=seq_len, truncation=True, 
                                 padding='max_length', return_tensors='tf')
    
    if labeled:
        dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': tokenized_inputs['input_ids'], 
                                                       'attention_mask': tokenized_inputs['attention_mask']}, 
                                                      (pandas_df['target'], pandas_df['standard_error'])))
        if is_sampled:
            dataset = dataset.map(sample_target, num_parallel_calls=tf.data.AUTOTUNE)
    else:
        dataset = tf.data.Dataset.from_tensor_slices({'input_ids': tokenized_inputs['input_ids'], 
                                                      'attention_mask': tokenized_inputs['attention_mask']})
        
    if repeated:
        dataset = dataset.repeat()
    if not ordered:
        dataset = dataset.shuffle(2048)
    dataset = dataset.batch(batch_size)
    dataset = dataset.cache()
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# %% [markdown]
# # Model

# %%
def model_fn(encoder, seq_len=256):
    input_ids = L.Input(shape=(seq_len,), dtype=tf.int32, name='input_ids')
    input_attention_mask = L.Input(shape=(seq_len,), dtype=tf.int32, name='attention_mask')
    
    outputs = encoder({'input_ids': input_ids,  
                       'attention_mask': input_attention_mask})
    last_hidden_state = outputs['last_hidden_state']
    
    cls_token = last_hidden_state[:, 0, :]
    output = L.Dense(1, name='output')(cls_token)
    
    model = Model(inputs=[input_ids, input_attention_mask], 
                  outputs=[output])

    optimizer = optimizers.Adam(lr=config['LEARNING_RATE'])
    model.compile(optimizer=optimizer, 
                  loss=losses.MeanSquaredError(), 
                  metrics=[metrics.RootMeanSquaredError()])
    return model


with strategy.scope():
    encoder = TFAutoModel.from_pretrained(config['BASE_MODEL'])
    # Freeze embeddings
    encoder.layers[0].embeddings.trainable = False
    model = model_fn(encoder, config['SEQ_LEN'])
    
model.summary()
# Out:
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# attention_mask (InputLayer)     [(None, 256)]        0
# __________________________________________________________________________________________________
# input_ids (InputLayer)          [(None, 256)]        0
# __________________________________________________________________________________________________
# tf_roberta_model (TFRobertaMode TFBaseModelOutputWit 124645632   attention_mask[0][0]
#                                                                  input_ids[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici (None, 768)          0           tf_roberta_model[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            769         tf.__operators__.getitem[0][0]
# ==================================================================================================
# Total params: 124,646,401
# Trainable params: 85,645,825
# Non-trainable params: 39,000,576
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
tokenizer = AutoTokenizer.from_pretrained(config['BASE_MODEL'])
skf = KFold(n_splits=config['N_FOLDS'], shuffle=True, random_state=seed)
oof_pred = []; oof_labels = []; history_list = []


for fold,(idxT, idxV) in enumerate(skf.split(train)):
    if fold >= config['N_USED_FOLDS']:
        break
    if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    print(f'\nFOLD: {fold+1}')
    print(f'TRAIN: {len(idxT)} VALID: {len(idxV)}')
    
    # Model
    K.clear_session()
    with strategy.scope():
        encoder = TFAutoModel.from_pretrained(config['BASE_MODEL'])
        # Freeze embeddings
        encoder.layers[0].embeddings.trainable = False
        model = model_fn(encoder, seq_len=config['SEQ_LEN'])

    model_path = f'model_{fold}.h5'
    es = EarlyStopping(monitor='val_root_mean_squared_error', mode='min', 
                       patience=config['ES_PATIENCE'], restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_root_mean_squared_error', mode='min', 
                                 save_best_only=True, save_weights_only=True)

    # Train
    history = model.fit(x=get_dataset(train.loc[idxT], tokenizer, repeated=True, is_sampled=True, 
                                      batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN']), 
                        validation_data=get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                                                    batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN']), 
                        steps_per_epoch=10, 
                        callbacks=[es, checkpoint], 
                        epochs=config['EPOCHS'],  
                        verbose=2).history

    history_list.append(history)
    # Save last model weights
    model.load_weights(model_path)

    # Results
    print(f"#### FOLD {fold+1} OOF RMSE = {np.min(history['val_root_mean_squared_error']):.4f}")

    # OOF predictions
    valid_ds = get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                           batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN'])
    oof_labels.append([target[0].numpy() for sample, target in iter(valid_ds.unbatch())])
    x_oof = valid_ds.map(lambda sample, target: sample)
    oof_pred.append(model.predict(x_oof))
# Out:
# FOLD: 1
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/100
# 10/10 - 83s - loss: 1.6954 - root_mean_squared_error: 1.3021 - val_loss: 1.0079 - val_root_mean_squared_error: 1.0039
# Epoch 2/100
# 10/10 - 2s - loss: 1.2814 - root_mean_squared_error: 1.1320 - val_loss: 0.6607 - val_root_mean_squared_error: 0.8128
# Epoch 3/100
# 10/10 - 2s - loss: 1.1839 - root_mean_squared_error: 1.0881 - val_loss: 0.6396 - val_root_mean_squared_error: 0.7997
# Epoch 4/100
# 10/10 - 2s - loss: 0.9040 - root_mean_squared_error: 0.9508 - val_loss: 0.6161 - val_root_mean_squared_error: 0.7849
# Epoch 5/100
# 10/10 - 2s - loss: 0.7789 - root_mean_squared_error: 0.8825 - val_loss: 0.7216 - val_root_mean_squared_error: 0.8494
# Epoch 6/100
# 10/10 - 2s - loss: 0.6647 - root_mean_squared_error: 0.8153 - val_loss: 0.7058 - val_root_mean_squared_error: 0.8401
# Epoch 7/100
# 10/10 - 2s - loss: 0.6359 - root_mean_squared_error: 0.7975 - val_loss: 0.4972 - val_root_mean_squared_error: 0.7051
# Epoch 8/100
# 10/10 - 2s - loss: 0.5605 - root_mean_squared_error: 0.7486 - val_loss: 0.4816 - val_root_mean_squared_error: 0.6940
# Epoch 9/100
# 10/10 - 2s - loss: 0.6335 - root_mean_squared_error: 0.7959 - val_loss: 0.4977 - val_root_mean_squared_error: 0.7054
# Epoch 10/100
# 10/10 - 2s - loss: 0.7072 - root_mean_squared_error: 0.8410 - val_loss: 0.3804 - val_root_mean_squared_error: 0.6168
# Epoch 11/100
# 10/10 - 2s - loss: 0.5854 - root_mean_squared_error: 0.7651 - val_loss: 0.7473 - val_root_mean_squared_error: 0.8645
# Epoch 12/100
# 10/10 - 2s - loss: 0.4880 - root_mean_squared_error: 0.6986 - val_loss: 0.3609 - val_root_mean_squared_error: 0.6008
# Epoch 13/100
# 10/10 - 2s - loss: 0.5686 - root_mean_squared_error: 0.7541 - val_loss: 0.4738 - val_root_mean_squared_error: 0.6883
# Epoch 14/100
# 10/10 - 2s - loss: 0.5269 - root_mean_squared_error: 0.7259 - val_loss: 0.3505 - val_root_mean_squared_error: 0.5920
# Epoch 15/100
# 10/10 - 2s - loss: 0.4976 - root_mean_squared_error: 0.7054 - val_loss: 0.3939 - val_root_mean_squared_error: 0.6277
# Epoch 16/100
# 10/10 - 2s - loss: 0.4430 - root_mean_squared_error: 0.6656 - val_loss: 0.5910 - val_root_mean_squared_error: 0.7687
# Epoch 17/100
# 10/10 - 2s - loss: 0.4474 - root_mean_squared_error: 0.6689 - val_loss: 0.3418 - val_root_mean_squared_error: 0.5846
# Epoch 18/100
# 10/10 - 2s - loss: 0.5215 - root_mean_squared_error: 0.7222 - val_loss: 0.3151 - val_root_mean_squared_error: 0.5614
# Epoch 19/100
# 10/10 - 2s - loss: 0.4594 - root_mean_squared_error: 0.6778 - val_loss: 0.3583 - val_root_mean_squared_error: 0.5986
# Epoch 20/100
# 10/10 - 2s - loss: 0.5615 - root_mean_squared_error: 0.7493 - val_loss: 0.6898 - val_root_mean_squared_error: 0.8305
# Epoch 21/100
# 10/10 - 2s - loss: 0.4237 - root_mean_squared_error: 0.6509 - val_loss: 0.3565 - val_root_mean_squared_error: 0.5971
# Epoch 22/100
# 10/10 - 2s - loss: 0.4591 - root_mean_squared_error: 0.6776 - val_loss: 0.4358 - val_root_mean_squared_error: 0.6601
# Epoch 23/100
# 10/10 - 2s - loss: 0.4097 - root_mean_squared_error: 0.6400 - val_loss: 0.4136 - val_root_mean_squared_error: 0.6431
# Epoch 24/100
# 10/10 - 2s - loss: 0.3998 - root_mean_squared_error: 0.6323 - val_loss: 0.3207 - val_root_mean_squared_error: 0.5663
# Epoch 25/100
# 10/10 - 3s - loss: 0.4850 - root_mean_squared_error: 0.6964 - val_loss: 0.3201 - val_root_mean_squared_error: 0.5658
# Epoch 26/100
# 10/10 - 2s - loss: 0.4745 - root_mean_squared_error: 0.6888 - val_loss: 0.5811 - val_root_mean_squared_error: 0.7623
# Epoch 27/100
# 10/10 - 2s - loss: 0.4956 - root_mean_squared_error: 0.7040 - val_loss: 0.5955 - val_root_mean_squared_error: 0.7717
# Epoch 28/100
# 10/10 - 2s - loss: 0.4204 - root_mean_squared_error: 0.6484 - val_loss: 0.3118 - val_root_mean_squared_error: 0.5584
# Epoch 29/100
# 10/10 - 2s - loss: 0.4159 - root_mean_squared_error: 0.6449 - val_loss: 0.8140 - val_root_mean_squared_error: 0.9022
# Epoch 30/100
# 10/10 - 2s - loss: 0.4312 - root_mean_squared_error: 0.6566 - val_loss: 0.3491 - val_root_mean_squared_error: 0.5909
# Epoch 31/100
# 10/10 - 2s - loss: 0.4001 - root_mean_squared_error: 0.6325 - val_loss: 0.3496 - val_root_mean_squared_error: 0.5913
# Epoch 32/100
# 10/10 - 2s - loss: 0.3747 - root_mean_squared_error: 0.6122 - val_loss: 0.5596 - val_root_mean_squared_error: 0.7481
# Epoch 33/100
# 10/10 - 2s - loss: 0.4413 - root_mean_squared_error: 0.6643 - val_loss: 0.3159 - val_root_mean_squared_error: 0.5620
# Epoch 34/100
# 10/10 - 2s - loss: 0.4693 - root_mean_squared_error: 0.6851 - val_loss: 0.7483 - val_root_mean_squared_error: 0.8650
# Epoch 35/100
# 10/10 - 2s - loss: 0.3954 - root_mean_squared_error: 0.6288 - val_loss: 0.3905 - val_root_mean_squared_error: 0.6249
# Epoch 36/100
# 10/10 - 2s - loss: 0.3430 - root_mean_squared_error: 0.5856 - val_loss: 0.6112 - val_root_mean_squared_error: 0.7818
# Epoch 37/100
# 10/10 - 2s - loss: 0.4509 - root_mean_squared_error: 0.6715 - val_loss: 0.3423 - val_root_mean_squared_error: 0.5850
# Epoch 38/100
# 10/10 - 2s - loss: 0.3961 - root_mean_squared_error: 0.6293 - val_loss: 0.5541 - val_root_mean_squared_error: 0.7444
# Epoch 39/100
# 10/10 - 2s - loss: 0.4173 - root_mean_squared_error: 0.6460 - val_loss: 0.2996 - val_root_mean_squared_error: 0.5473
# Epoch 40/100
# 10/10 - 2s - loss: 0.3378 - root_mean_squared_error: 0.5812 - val_loss: 0.3665 - val_root_mean_squared_error: 0.6054
# Epoch 41/100
# 10/10 - 2s - loss: 0.3873 - root_mean_squared_error: 0.6223 - val_loss: 0.5492 - val_root_mean_squared_error: 0.7411
# Epoch 42/100
# 10/10 - 2s - loss: 0.3312 - root_mean_squared_error: 0.5755 - val_loss: 0.4751 - val_root_mean_squared_error: 0.6893
# Epoch 43/100
# 10/10 - 2s - loss: 0.3668 - root_mean_squared_error: 0.6057 - val_loss: 0.4445 - val_root_mean_squared_error: 0.6667
# Epoch 44/100
# 10/10 - 2s - loss: 0.3605 - root_mean_squared_error: 0.6004 - val_loss: 0.8039 - val_root_mean_squared_error: 0.8966
# Epoch 45/100
# 10/10 - 2s - loss: 0.4187 - root_mean_squared_error: 0.6470 - val_loss: 0.3129 - val_root_mean_squared_error: 0.5593
# Epoch 46/100
# 10/10 - 2s - loss: 0.3814 - root_mean_squared_error: 0.6176 - val_loss: 0.5363 - val_root_mean_squared_error: 0.7323
# Epoch 47/100
# 10/10 - 2s - loss: 0.3194 - root_mean_squared_error: 0.5651 - val_loss: 0.4762 - val_root_mean_squared_error: 0.6901
# Epoch 48/100
# 10/10 - 2s - loss: 0.3044 - root_mean_squared_error: 0.5518 - val_loss: 0.3331 - val_root_mean_squared_error: 0.5772
# Epoch 49/100
# 10/10 - 2s - loss: 0.3507 - root_mean_squared_error: 0.5922 - val_loss: 0.6581 - val_root_mean_squared_error: 0.8112
# Epoch 50/100
# 10/10 - 2s - loss: 0.3098 - root_mean_squared_error: 0.5566 - val_loss: 0.3914 - val_root_mean_squared_error: 0.6256
# Epoch 51/100
# 10/10 - 2s - loss: 0.3362 - root_mean_squared_error: 0.5799 - val_loss: 0.6147 - val_root_mean_squared_error: 0.7840
# Epoch 52/100
# 10/10 - 3s - loss: 0.3289 - root_mean_squared_error: 0.5735 - val_loss: 0.4975 - val_root_mean_squared_error: 0.7054
# Epoch 53/100
# 10/10 - 2s - loss: 0.3252 - root_mean_squared_error: 0.5702 - val_loss: 0.3910 - val_root_mean_squared_error: 0.6253
# Epoch 54/100
# 10/10 - 2s - loss: 0.3656 - root_mean_squared_error: 0.6046 - val_loss: 0.6330 - val_root_mean_squared_error: 0.7956
# Epoch 55/100
# 10/10 - 2s - loss: 0.3693 - root_mean_squared_error: 0.6077 - val_loss: 0.4491 - val_root_mean_squared_error: 0.6702
# Epoch 56/100
# 10/10 - 2s - loss: 0.3353 - root_mean_squared_error: 0.5790 - val_loss: 0.5699 - val_root_mean_squared_error: 0.7549
# Epoch 57/100
# 10/10 - 2s - loss: 0.2789 - root_mean_squared_error: 0.5281 - val_loss: 0.5092 - val_root_mean_squared_error: 0.7136
# Epoch 58/100
# 10/10 - 2s - loss: 0.3093 - root_mean_squared_error: 0.5562 - val_loss: 0.4683 - val_root_mean_squared_error: 0.6843
# Epoch 59/100
# 10/10 - 2s - loss: 0.3231 - root_mean_squared_error: 0.5685 - val_loss: 0.4746 - val_root_mean_squared_error: 0.6889
# Epoch 60/100
# 10/10 - 2s - loss: 0.3518 - root_mean_squared_error: 0.5931 - val_loss: 0.3845 - val_root_mean_squared_error: 0.6201
# Epoch 61/100
# 10/10 - 2s - loss: 0.3415 - root_mean_squared_error: 0.5843 - val_loss: 0.4794 - val_root_mean_squared_error: 0.6924
# Epoch 62/100
# 10/10 - 2s - loss: 0.2982 - root_mean_squared_error: 0.5461 - val_loss: 0.3682 - val_root_mean_squared_error: 0.6068
# Epoch 63/100
# 10/10 - 2s - loss: 0.2875 - root_mean_squared_error: 0.5362 - val_loss: 0.3920 - val_root_mean_squared_error: 0.6261
# Epoch 64/100
# 10/10 - 2s - loss: 0.3320 - root_mean_squared_error: 0.5762 - val_loss: 0.3646 - val_root_mean_squared_error: 0.6038
# Epoch 65/100
# 10/10 - 2s - loss: 0.2572 - root_mean_squared_error: 0.5072 - val_loss: 0.3946 - val_root_mean_squared_error: 0.6282
# Epoch 66/100
# 10/10 - 2s - loss: 0.2715 - root_mean_squared_error: 0.5211 - val_loss: 0.4197 - val_root_mean_squared_error: 0.6479
# Epoch 67/100
# 10/10 - 2s - loss: 0.2846 - root_mean_squared_error: 0.5335 - val_loss: 0.3666 - val_root_mean_squared_error: 0.6054
# Epoch 68/100
# 10/10 - 2s - loss: 0.2653 - root_mean_squared_error: 0.5151 - val_loss: 0.7200 - val_root_mean_squared_error: 0.8485
# Epoch 69/100
# 10/10 - 2s - loss: 0.2838 - root_mean_squared_error: 0.5327 - val_loss: 0.4176 - val_root_mean_squared_error: 0.6462
# Restoring model weights from the end of the best epoch.
# Epoch 00069: early stopping
# #### FOLD 1 OOF RMSE = 0.5473

# %% [markdown]
# ## Model loss and metrics graph

# %%
for fold, history in enumerate(history_list):
    print(f'\nFOLD: {fold+1}')
    plot_metrics(history)
# Out:
# FOLD: 1

# %% [markdown]
# # Model evaluation
#
# We are evaluating the model on the `OOF` predictions, it stands for `Out Of Fold`, since we are training using `K-Fold` our model will see all the data, and the correct way to evaluate each fold is by looking at the predictions that are not from that fold.
#
# ## OOF metrics

# %%
y_true = np.concatenate(oof_labels)
y_preds = np.concatenate(oof_pred)

for fold, history in enumerate(history_list):
    print(f"FOLD {fold+1} RMSE: {np.min(history['val_root_mean_squared_error']):.4f}")
    
print(f'OOF RMSE: {mean_squared_error(y_true, y_preds, squared=False):.4f}')
# Out:
# FOLD 1 RMSE: 0.5473
# OOF RMSE: 0.5473

# %% [markdown]
# ### **Error analysis**, label x prediction distribution
#
# Here we can compare the distribution from the labels and the predicted values, in a perfect scenario they should align.

# %%
preds_df = pd.DataFrame({'Label': y_true, 'Prediction': y_preds[:,0]})

fig, ax = plt.subplots(1, 1, figsize=(20, 6))
sns.distplot(preds_df['Label'], ax=ax, label='Label')
sns.distplot(preds_df['Prediction'], ax=ax, label='Prediction')
ax.legend()
plt.show()

# %%
sns.jointplot(data=preds_df, x='Label', y='Prediction', kind='reg', height=10)
plt.show()
