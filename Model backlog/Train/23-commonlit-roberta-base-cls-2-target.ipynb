# %% [markdown]
# ## Dependencies

# %%
import warnings, math, json
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import tensorflow_addons as tfa
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
from tensorflow.keras import optimizers, losses, metrics, Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from transformers import TFAutoModelForSequenceClassification, TFAutoModel, AutoTokenizer
from commonlit_scripts import *


seed = 0
seed_everything(seed)
sns.set(style='whitegrid')
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 150)

# %% [markdown]
# ### Hardware configuration

# %%
strategy, tpu = get_strategy()
AUTO = tf.data.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
print(f'REPLICAS: {REPLICAS}')
# Out:
# Running on TPU grpc://10.0.0.2:8470
# REPLICAS: 8

# %% [markdown]
# # Load data

# %%
train_filepath = '/kaggle/input/commonlitreadabilityprize/train.csv'
train = pd.read_csv(train_filepath)
print(f'Train samples: {len(train)}')
# removing unused columns
train.drop(['url_legal', 'license'], axis=1, inplace=True)
display(train.head())
# Out:
# Train samples: 2834
#           id  \
# 0  c12129c31
# 1  85aa80a4c
# 2  b69ac6792
# 3  dd1000b26
# 4  37c1b32fb
#
#                                                                                                                                                  excerpt  \
# 0  When the young people returned to the ballroom, it presented a decidedly changed appearance. Instead of an interior scene, it was a winter landsca...
# 1  All through dinner time, Mrs. Fayre was somewhat silent, her eyes resting on Dolly with a wistful, uncertain expression. She wanted to give the ch...
# 2  As Roger had predicted, the snow departed as quickly as it came, and two days after their sleigh ride there was scarcely a vestige of white on the...
# 3  And outside before the palace a great garden was walled round, filled full of stately fruit-trees, gray olives and sweet figs, and pomegranates, p...
# 4  Once upon a time there were Three Bears who lived together in a house of their own in a wood. One of them was a Little, Small, Wee Bear; and one w...
#
#      target  standard_error
# 0 -0.340259        0.464009
# 1 -0.315372        0.480805
# 2 -0.580118        0.476676
# 3 -1.054013        0.450007
# 4  0.247197        0.510845

# %% [markdown]
# # Model parameters

# %%
config = {
  "BATCH_SIZE": 8 * REPLICAS,
  "LEARNING_RATE": 1e-5 * REPLICAS,
  "EPOCHS": 100,
  "ES_PATIENCE": 30,
  "N_FOLDS": 5,
  "N_USED_FOLDS": 1,
  "SEQ_LEN": 256,
  "BASE_MODEL": '/kaggle/input/huggingface-roberta/roberta-base/',
  "SEED": seed,
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# ## Auxiliary functions

# %%
# Datasets utility functions
def custom_standardization(text, is_lower=True):
    if is_lower:
        text = text.lower() # if encoder is uncased
    text = text.strip()
    return text

def sample_target(features, target):
    mean, _, stddev = target
    sampled_target = tf.random.normal([], mean=tf.cast(mean, dtype=tf.float32), 
                                      stddev=tf.cast(stddev, dtype=tf.float32), dtype=tf.float32)
    return (features, (mean, sampled_target))
    
def get_dataset(pandas_df, tokenizer, labeled=True, ordered=False, repeated=False, 
                is_sampled=False, batch_size=32, seq_len=128, is_lower=True):
    """
        Return a Tensorflow dataset ready for training or inference.
    """
    text = [custom_standardization(text, is_lower) for text in pandas_df['excerpt']]
    
    # Tokenize inputs
    tokenized_inputs = tokenizer(text, max_length=seq_len, truncation=True, 
                                 padding='max_length', return_tensors='tf')
    
    if labeled:
        dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': tokenized_inputs['input_ids'], 
                                                       'attention_mask': tokenized_inputs['attention_mask']}, 
                                                      (pandas_df['target'], pandas_df['target'], pandas_df['standard_error'])))
        if is_sampled:
            dataset = dataset.map(sample_target, num_parallel_calls=tf.data.AUTOTUNE)
    else:
        dataset = tf.data.Dataset.from_tensor_slices({'input_ids': tokenized_inputs['input_ids'], 
                                                      'attention_mask': tokenized_inputs['attention_mask']})
        
    if repeated:
        dataset = dataset.repeat()
    if not ordered:
        dataset = dataset.shuffle(2048)
    dataset = dataset.batch(batch_size)
    dataset = dataset.cache()
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# %% [markdown]
# # Model

# %%
def model_fn(encoder, seq_len=256):
    input_ids = L.Input(shape=(seq_len,), dtype=tf.int32, name='input_ids')
    input_attention_mask = L.Input(shape=(seq_len,), dtype=tf.int32, name='attention_mask')
    
    outputs = encoder({'input_ids': input_ids,  
                       'attention_mask': input_attention_mask})
    last_hidden_state = outputs['last_hidden_state']
    
    cls_token = last_hidden_state[:, 0, :]
#     x = L.GlobalAveragePooling1D()(last_hidden_state)
    output = L.Dense(1, name='output')(cls_token)
    output_samp = L.Dense(1, name='output_samp')(cls_token)
    
    model = Model(inputs=[input_ids, input_attention_mask], 
                  outputs=[output, output_samp])

    optimizer = optimizers.Adam(lr=config['LEARNING_RATE'])
    model.compile(optimizer=optimizer, 
                  loss=losses.MeanSquaredError(), 
                  metrics=[metrics.RootMeanSquaredError()])
    return model


with strategy.scope():
    encoder = TFAutoModel.from_pretrained(config['BASE_MODEL'])
    model = model_fn(encoder, config['SEQ_LEN'])
    
model.summary()
# Out:
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# attention_mask (InputLayer)     [(None, 256)]        0
# __________________________________________________________________________________________________
# input_ids (InputLayer)          [(None, 256)]        0
# __________________________________________________________________________________________________
# tf_roberta_model (TFRobertaMode TFBaseModelOutputWit 124645632   attention_mask[0][0]
#                                                                  input_ids[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici (None, 768)          0           tf_roberta_model[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            769         tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# output_samp (Dense)             (None, 1)            769         tf.__operators__.getitem[0][0]
# ==================================================================================================
# Total params: 124,647,170
# Trainable params: 124,647,170
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
tokenizer = AutoTokenizer.from_pretrained(config['BASE_MODEL'])
skf = KFold(n_splits=config['N_FOLDS'], shuffle=True, random_state=seed)
oof_pred = []; oof_labels = []; history_list = []


for fold,(idxT, idxV) in enumerate(skf.split(train)):
    if fold >= config['N_USED_FOLDS']:
        break
    if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    print(f'\nFOLD: {fold+1}')
    print(f'TRAIN: {len(idxT)} VALID: {len(idxV)}')
    
    # Model
    K.clear_session()
    with strategy.scope():
        encoder = TFAutoModel.from_pretrained(config['BASE_MODEL'])
        model = model_fn(encoder, seq_len=config['SEQ_LEN'])

    model_path = f'model_{fold}.h5'
    es = EarlyStopping(monitor='val_output_root_mean_squared_error', mode='min', 
                       patience=config['ES_PATIENCE'], restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_output_root_mean_squared_error', mode='min', 
                                 save_best_only=True, save_weights_only=True)

    # Train
    history = model.fit(x=get_dataset(train.loc[idxT], tokenizer, repeated=True, is_sampled=True, 
                                      batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN']), 
                        validation_data=get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                                                    batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN']), 
                        steps_per_epoch=10, 
                        callbacks=[es, checkpoint], 
                        epochs=config['EPOCHS'],  
                        verbose=2).history

    history_list.append(history)
    # Save last model weights
    model.load_weights(model_path)

    # Results
    print(f"#### FOLD {fold+1} OOF RMSE = {np.min(history['val_output_root_mean_squared_error']):.4f}")
    print(f"#### FOLD {fold+1} OOF RMSE = {np.min(history['val_output_samp_root_mean_squared_error']):.4f}")

    # OOF predictions
    valid_ds = get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                           batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN'])
    oof_labels.append([target[0].numpy() for sample, target in iter(valid_ds.unbatch())])
    x_oof = valid_ds.map(lambda sample, target: sample)
    oof_pred.append(model.predict(x_oof)[0])
# Out:
# FOLD: 1
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/100
# 10/10 - 85s - loss: 2.7321 - output_loss: 1.1680 - output_samp_loss: 1.5641 - output_root_mean_squared_error: 1.0807 - output_samp_root_mean_squared_error: 1.2507 - val_loss: 1.8678 - val_output_loss: 1.0053 - val_output_samp_loss: 0.8625 - val_output_root_mean_squared_error: 1.0026 - val_output_samp_root_mean_squared_error: 0.9287
# Epoch 2/100
# 10/10 - 2s - loss: 1.8463 - output_loss: 0.7667 - output_samp_loss: 1.0796 - output_root_mean_squared_error: 0.8756 - output_samp_root_mean_squared_error: 1.0390 - val_loss: 0.8212 - val_output_loss: 0.4151 - val_output_samp_loss: 0.4062 - val_output_root_mean_squared_error: 0.6443 - val_output_samp_root_mean_squared_error: 0.6373
# Epoch 3/100
# 10/10 - 2s - loss: 1.1856 - output_loss: 0.4406 - output_samp_loss: 0.7451 - output_root_mean_squared_error: 0.6637 - output_samp_root_mean_squared_error: 0.8632 - val_loss: 0.7904 - val_output_loss: 0.4038 - val_output_samp_loss: 0.3866 - val_output_root_mean_squared_error: 0.6354 - val_output_samp_root_mean_squared_error: 0.6218
# Epoch 4/100
# 10/10 - 2s - loss: 1.1703 - output_loss: 0.4516 - output_samp_loss: 0.7187 - output_root_mean_squared_error: 0.6720 - output_samp_root_mean_squared_error: 0.8477 - val_loss: 1.0041 - val_output_loss: 0.4233 - val_output_samp_loss: 0.5808 - val_output_root_mean_squared_error: 0.6506 - val_output_samp_root_mean_squared_error: 0.7621
# Epoch 5/100
# 10/10 - 2s - loss: 1.0530 - output_loss: 0.4051 - output_samp_loss: 0.6478 - output_root_mean_squared_error: 0.6365 - output_samp_root_mean_squared_error: 0.8049 - val_loss: 0.8474 - val_output_loss: 0.4916 - val_output_samp_loss: 0.3559 - val_output_root_mean_squared_error: 0.7011 - val_output_samp_root_mean_squared_error: 0.5966
# Epoch 6/100
# 10/10 - 2s - loss: 0.9430 - output_loss: 0.3345 - output_samp_loss: 0.6086 - output_root_mean_squared_error: 0.5783 - output_samp_root_mean_squared_error: 0.7801 - val_loss: 0.8181 - val_output_loss: 0.3965 - val_output_samp_loss: 0.4216 - val_output_root_mean_squared_error: 0.6297 - val_output_samp_root_mean_squared_error: 0.6493
# Epoch 7/100
# 10/10 - 2s - loss: 0.8139 - output_loss: 0.2654 - output_samp_loss: 0.5484 - output_root_mean_squared_error: 0.5152 - output_samp_root_mean_squared_error: 0.7405 - val_loss: 0.8858 - val_output_loss: 0.4963 - val_output_samp_loss: 0.3895 - val_output_root_mean_squared_error: 0.7045 - val_output_samp_root_mean_squared_error: 0.6241
# Epoch 8/100
# 10/10 - 2s - loss: 0.9512 - output_loss: 0.3783 - output_samp_loss: 0.5729 - output_root_mean_squared_error: 0.6151 - output_samp_root_mean_squared_error: 0.7569 - val_loss: 0.8388 - val_output_loss: 0.4155 - val_output_samp_loss: 0.4233 - val_output_root_mean_squared_error: 0.6446 - val_output_samp_root_mean_squared_error: 0.6506
# Epoch 9/100
# 10/10 - 2s - loss: 0.8687 - output_loss: 0.3041 - output_samp_loss: 0.5645 - output_root_mean_squared_error: 0.5515 - output_samp_root_mean_squared_error: 0.7513 - val_loss: 0.7011 - val_output_loss: 0.3775 - val_output_samp_loss: 0.3236 - val_output_root_mean_squared_error: 0.6144 - val_output_samp_root_mean_squared_error: 0.5689
# Epoch 10/100
# 10/10 - 2s - loss: 0.6827 - output_loss: 0.2346 - output_samp_loss: 0.4480 - output_root_mean_squared_error: 0.4844 - output_samp_root_mean_squared_error: 0.6693 - val_loss: 0.9918 - val_output_loss: 0.5034 - val_output_samp_loss: 0.4884 - val_output_root_mean_squared_error: 0.7095 - val_output_samp_root_mean_squared_error: 0.6989
# Epoch 11/100
# 10/10 - 2s - loss: 0.6890 - output_loss: 0.2493 - output_samp_loss: 0.4397 - output_root_mean_squared_error: 0.4993 - output_samp_root_mean_squared_error: 0.6631 - val_loss: 0.7085 - val_output_loss: 0.3654 - val_output_samp_loss: 0.3431 - val_output_root_mean_squared_error: 0.6045 - val_output_samp_root_mean_squared_error: 0.5857
# Epoch 12/100
# 10/10 - 2s - loss: 0.6931 - output_loss: 0.2358 - output_samp_loss: 0.4573 - output_root_mean_squared_error: 0.4855 - output_samp_root_mean_squared_error: 0.6763 - val_loss: 0.6416 - val_output_loss: 0.3161 - val_output_samp_loss: 0.3255 - val_output_root_mean_squared_error: 0.5622 - val_output_samp_root_mean_squared_error: 0.5705
# Epoch 13/100
# 10/10 - 2s - loss: 0.5948 - output_loss: 0.1758 - output_samp_loss: 0.4191 - output_root_mean_squared_error: 0.4192 - output_samp_root_mean_squared_error: 0.6474 - val_loss: 0.7853 - val_output_loss: 0.4784 - val_output_samp_loss: 0.3069 - val_output_root_mean_squared_error: 0.6916 - val_output_samp_root_mean_squared_error: 0.5540
# Epoch 14/100
# 10/10 - 2s - loss: 0.6158 - output_loss: 0.1955 - output_samp_loss: 0.4203 - output_root_mean_squared_error: 0.4421 - output_samp_root_mean_squared_error: 0.6483 - val_loss: 1.1447 - val_output_loss: 0.5892 - val_output_samp_loss: 0.5555 - val_output_root_mean_squared_error: 0.7676 - val_output_samp_root_mean_squared_error: 0.7453
# Epoch 15/100
# 10/10 - 2s - loss: 0.6510 - output_loss: 0.2048 - output_samp_loss: 0.4463 - output_root_mean_squared_error: 0.4525 - output_samp_root_mean_squared_error: 0.6680 - val_loss: 0.6138 - val_output_loss: 0.2984 - val_output_samp_loss: 0.3154 - val_output_root_mean_squared_error: 0.5463 - val_output_samp_root_mean_squared_error: 0.5616
# Epoch 16/100
# 10/10 - 2s - loss: 0.5953 - output_loss: 0.2073 - output_samp_loss: 0.3880 - output_root_mean_squared_error: 0.4553 - output_samp_root_mean_squared_error: 0.6229 - val_loss: 0.7801 - val_output_loss: 0.4000 - val_output_samp_loss: 0.3801 - val_output_root_mean_squared_error: 0.6325 - val_output_samp_root_mean_squared_error: 0.6165
# Epoch 17/100
# 10/10 - 2s - loss: 0.6421 - output_loss: 0.1971 - output_samp_loss: 0.4450 - output_root_mean_squared_error: 0.4440 - output_samp_root_mean_squared_error: 0.6671 - val_loss: 0.7190 - val_output_loss: 0.3300 - val_output_samp_loss: 0.3890 - val_output_root_mean_squared_error: 0.5745 - val_output_samp_root_mean_squared_error: 0.6237
# Epoch 18/100
# 10/10 - 2s - loss: 0.5670 - output_loss: 0.1430 - output_samp_loss: 0.4240 - output_root_mean_squared_error: 0.3782 - output_samp_root_mean_squared_error: 0.6511 - val_loss: 0.6901 - val_output_loss: 0.3488 - val_output_samp_loss: 0.3414 - val_output_root_mean_squared_error: 0.5906 - val_output_samp_root_mean_squared_error: 0.5843
# Epoch 19/100
# 10/10 - 2s - loss: 0.5226 - output_loss: 0.1449 - output_samp_loss: 0.3778 - output_root_mean_squared_error: 0.3806 - output_samp_root_mean_squared_error: 0.6146 - val_loss: 0.6613 - val_output_loss: 0.3053 - val_output_samp_loss: 0.3560 - val_output_root_mean_squared_error: 0.5526 - val_output_samp_root_mean_squared_error: 0.5966
# Epoch 20/100
# 10/10 - 2s - loss: 0.5156 - output_loss: 0.1436 - output_samp_loss: 0.3720 - output_root_mean_squared_error: 0.3790 - output_samp_root_mean_squared_error: 0.6099 - val_loss: 0.6186 - val_output_loss: 0.3495 - val_output_samp_loss: 0.2691 - val_output_root_mean_squared_error: 0.5912 - val_output_samp_root_mean_squared_error: 0.5187
# Epoch 21/100
# 10/10 - 2s - loss: 0.4345 - output_loss: 0.1026 - output_samp_loss: 0.3319 - output_root_mean_squared_error: 0.3203 - output_samp_root_mean_squared_error: 0.5761 - val_loss: 0.7166 - val_output_loss: 0.3357 - val_output_samp_loss: 0.3808 - val_output_root_mean_squared_error: 0.5794 - val_output_samp_root_mean_squared_error: 0.6171
# Epoch 22/100
# 10/10 - 3s - loss: 0.4980 - output_loss: 0.1221 - output_samp_loss: 0.3759 - output_root_mean_squared_error: 0.3495 - output_samp_root_mean_squared_error: 0.6131 - val_loss: 0.5859 - val_output_loss: 0.3173 - val_output_samp_loss: 0.2686 - val_output_root_mean_squared_error: 0.5633 - val_output_samp_root_mean_squared_error: 0.5183
# Epoch 23/100
# 10/10 - 2s - loss: 0.5591 - output_loss: 0.1343 - output_samp_loss: 0.4248 - output_root_mean_squared_error: 0.3664 - output_samp_root_mean_squared_error: 0.6518 - val_loss: 0.6609 - val_output_loss: 0.2979 - val_output_samp_loss: 0.3630 - val_output_root_mean_squared_error: 0.5458 - val_output_samp_root_mean_squared_error: 0.6025
# Epoch 24/100
# 10/10 - 2s - loss: 0.4705 - output_loss: 0.1130 - output_samp_loss: 0.3575 - output_root_mean_squared_error: 0.3361 - output_samp_root_mean_squared_error: 0.5979 - val_loss: 0.6431 - val_output_loss: 0.3511 - val_output_samp_loss: 0.2920 - val_output_root_mean_squared_error: 0.5926 - val_output_samp_root_mean_squared_error: 0.5403
# Epoch 25/100
# 10/10 - 2s - loss: 0.4598 - output_loss: 0.0951 - output_samp_loss: 0.3647 - output_root_mean_squared_error: 0.3084 - output_samp_root_mean_squared_error: 0.6039 - val_loss: 0.7138 - val_output_loss: 0.3420 - val_output_samp_loss: 0.3718 - val_output_root_mean_squared_error: 0.5848 - val_output_samp_root_mean_squared_error: 0.6098
# Epoch 26/100
# 10/10 - 2s - loss: 0.3587 - output_loss: 0.0791 - output_samp_loss: 0.2796 - output_root_mean_squared_error: 0.2813 - output_samp_root_mean_squared_error: 0.5288 - val_loss: 0.7740 - val_output_loss: 0.3895 - val_output_samp_loss: 0.3845 - val_output_root_mean_squared_error: 0.6241 - val_output_samp_root_mean_squared_error: 0.6201
# Epoch 27/100
# 10/10 - 2s - loss: 0.4736 - output_loss: 0.0953 - output_samp_loss: 0.3782 - output_root_mean_squared_error: 0.3088 - output_samp_root_mean_squared_error: 0.6150 - val_loss: 0.6301 - val_output_loss: 0.3159 - val_output_samp_loss: 0.3142 - val_output_root_mean_squared_error: 0.5620 - val_output_samp_root_mean_squared_error: 0.5605
# Epoch 28/100
# 10/10 - 2s - loss: 0.4554 - output_loss: 0.1080 - output_samp_loss: 0.3474 - output_root_mean_squared_error: 0.3287 - output_samp_root_mean_squared_error: 0.5894 - val_loss: 0.6343 - val_output_loss: 0.3003 - val_output_samp_loss: 0.3340 - val_output_root_mean_squared_error: 0.5480 - val_output_samp_root_mean_squared_error: 0.5779
# Epoch 29/100
# 10/10 - 2s - loss: 0.5126 - output_loss: 0.1146 - output_samp_loss: 0.3979 - output_root_mean_squared_error: 0.3386 - output_samp_root_mean_squared_error: 0.6308 - val_loss: 0.7302 - val_output_loss: 0.3464 - val_output_samp_loss: 0.3838 - val_output_root_mean_squared_error: 0.5886 - val_output_samp_root_mean_squared_error: 0.6195
# Epoch 30/100
# 10/10 - 2s - loss: 0.4268 - output_loss: 0.1004 - output_samp_loss: 0.3264 - output_root_mean_squared_error: 0.3168 - output_samp_root_mean_squared_error: 0.5714 - val_loss: 0.8719 - val_output_loss: 0.4123 - val_output_samp_loss: 0.4596 - val_output_root_mean_squared_error: 0.6421 - val_output_samp_root_mean_squared_error: 0.6779
# Epoch 31/100
# 10/10 - 2s - loss: 0.3930 - output_loss: 0.0773 - output_samp_loss: 0.3157 - output_root_mean_squared_error: 0.2780 - output_samp_root_mean_squared_error: 0.5619 - val_loss: 1.0244 - val_output_loss: 0.5663 - val_output_samp_loss: 0.4580 - val_output_root_mean_squared_error: 0.7526 - val_output_samp_root_mean_squared_error: 0.6768
# Epoch 32/100
# 10/10 - 2s - loss: 0.3909 - output_loss: 0.0850 - output_samp_loss: 0.3058 - output_root_mean_squared_error: 0.2916 - output_samp_root_mean_squared_error: 0.5530 - val_loss: 0.9872 - val_output_loss: 0.4276 - val_output_samp_loss: 0.5595 - val_output_root_mean_squared_error: 0.6539 - val_output_samp_root_mean_squared_error: 0.7480
# Epoch 33/100
# 10/10 - 2s - loss: 0.4585 - output_loss: 0.1054 - output_samp_loss: 0.3531 - output_root_mean_squared_error: 0.3246 - output_samp_root_mean_squared_error: 0.5942 - val_loss: 1.0965 - val_output_loss: 0.5899 - val_output_samp_loss: 0.5065 - val_output_root_mean_squared_error: 0.7681 - val_output_samp_root_mean_squared_error: 0.7117
# Epoch 34/100
# 10/10 - 2s - loss: 0.4425 - output_loss: 0.1165 - output_samp_loss: 0.3259 - output_root_mean_squared_error: 0.3414 - output_samp_root_mean_squared_error: 0.5709 - val_loss: 1.1396 - val_output_loss: 0.5533 - val_output_samp_loss: 0.5864 - val_output_root_mean_squared_error: 0.7438 - val_output_samp_root_mean_squared_error: 0.7657
# Epoch 35/100
# 10/10 - 2s - loss: 0.5120 - output_loss: 0.1107 - output_samp_loss: 0.4012 - output_root_mean_squared_error: 0.3328 - output_samp_root_mean_squared_error: 0.6334 - val_loss: 1.2563 - val_output_loss: 0.5975 - val_output_samp_loss: 0.6588 - val_output_root_mean_squared_error: 0.7730 - val_output_samp_root_mean_squared_error: 0.8117
# Epoch 36/100
# 10/10 - 2s - loss: 0.5521 - output_loss: 0.1533 - output_samp_loss: 0.3988 - output_root_mean_squared_error: 0.3915 - output_samp_root_mean_squared_error: 0.6315 - val_loss: 1.1845 - val_output_loss: 0.4702 - val_output_samp_loss: 0.7143 - val_output_root_mean_squared_error: 0.6857 - val_output_samp_root_mean_squared_error: 0.8452
# Epoch 37/100
# 10/10 - 2s - loss: 0.4217 - output_loss: 0.0809 - output_samp_loss: 0.3408 - output_root_mean_squared_error: 0.2844 - output_samp_root_mean_squared_error: 0.5837 - val_loss: 0.7420 - val_output_loss: 0.3840 - val_output_samp_loss: 0.3580 - val_output_root_mean_squared_error: 0.6197 - val_output_samp_root_mean_squared_error: 0.5983
# Epoch 38/100
# 10/10 - 2s - loss: 0.4279 - output_loss: 0.0846 - output_samp_loss: 0.3433 - output_root_mean_squared_error: 0.2909 - output_samp_root_mean_squared_error: 0.5859 - val_loss: 0.8650 - val_output_loss: 0.5094 - val_output_samp_loss: 0.3557 - val_output_root_mean_squared_error: 0.7137 - val_output_samp_root_mean_squared_error: 0.5964
# Epoch 39/100
# 10/10 - 2s - loss: 0.4434 - output_loss: 0.0964 - output_samp_loss: 0.3470 - output_root_mean_squared_error: 0.3104 - output_samp_root_mean_squared_error: 0.5891 - val_loss: 0.9463 - val_output_loss: 0.4023 - val_output_samp_loss: 0.5440 - val_output_root_mean_squared_error: 0.6343 - val_output_samp_root_mean_squared_error: 0.7375
# Epoch 40/100
# 10/10 - 2s - loss: 0.5191 - output_loss: 0.1335 - output_samp_loss: 0.3856 - output_root_mean_squared_error: 0.3654 - output_samp_root_mean_squared_error: 0.6209 - val_loss: 0.7353 - val_output_loss: 0.3406 - val_output_samp_loss: 0.3947 - val_output_root_mean_squared_error: 0.5836 - val_output_samp_root_mean_squared_error: 0.6283
# Epoch 41/100
# 10/10 - 2s - loss: 0.6095 - output_loss: 0.1590 - output_samp_loss: 0.4505 - output_root_mean_squared_error: 0.3988 - output_samp_root_mean_squared_error: 0.6712 - val_loss: 0.6548 - val_output_loss: 0.3166 - val_output_samp_loss: 0.3382 - val_output_root_mean_squared_error: 0.5626 - val_output_samp_root_mean_squared_error: 0.5816
# Epoch 42/100
# 10/10 - 2s - loss: 0.4224 - output_loss: 0.0920 - output_samp_loss: 0.3304 - output_root_mean_squared_error: 0.3033 - output_samp_root_mean_squared_error: 0.5748 - val_loss: 0.7053 - val_output_loss: 0.3548 - val_output_samp_loss: 0.3504 - val_output_root_mean_squared_error: 0.5957 - val_output_samp_root_mean_squared_error: 0.5920
# Epoch 43/100
# 10/10 - 2s - loss: 0.4294 - output_loss: 0.0876 - output_samp_loss: 0.3418 - output_root_mean_squared_error: 0.2960 - output_samp_root_mean_squared_error: 0.5847 - val_loss: 0.7325 - val_output_loss: 0.3870 - val_output_samp_loss: 0.3454 - val_output_root_mean_squared_error: 0.6221 - val_output_samp_root_mean_squared_error: 0.5877
# Epoch 44/100
# 10/10 - 2s - loss: 0.3838 - output_loss: 0.0681 - output_samp_loss: 0.3157 - output_root_mean_squared_error: 0.2609 - output_samp_root_mean_squared_error: 0.5619 - val_loss: 0.6719 - val_output_loss: 0.3376 - val_output_samp_loss: 0.3343 - val_output_root_mean_squared_error: 0.5810 - val_output_samp_root_mean_squared_error: 0.5782
# Epoch 45/100
# 10/10 - 2s - loss: 0.4281 - output_loss: 0.0815 - output_samp_loss: 0.3467 - output_root_mean_squared_error: 0.2854 - output_samp_root_mean_squared_error: 0.5888 - val_loss: 1.6160 - val_output_loss: 0.8250 - val_output_samp_loss: 0.7911 - val_output_root_mean_squared_error: 0.9083 - val_output_samp_root_mean_squared_error: 0.8894
# Epoch 46/100
# 10/10 - 2s - loss: 0.4730 - output_loss: 0.1115 - output_samp_loss: 0.3615 - output_root_mean_squared_error: 0.3339 - output_samp_root_mean_squared_error: 0.6013 - val_loss: 1.0795 - val_output_loss: 0.5574 - val_output_samp_loss: 0.5221 - val_output_root_mean_squared_error: 0.7466 - val_output_samp_root_mean_squared_error: 0.7226
# Epoch 47/100
# 10/10 - 2s - loss: 0.4122 - output_loss: 0.0747 - output_samp_loss: 0.3375 - output_root_mean_squared_error: 0.2733 - output_samp_root_mean_squared_error: 0.5809 - val_loss: 0.7975 - val_output_loss: 0.4123 - val_output_samp_loss: 0.3852 - val_output_root_mean_squared_error: 0.6421 - val_output_samp_root_mean_squared_error: 0.6206
# Epoch 48/100
# 10/10 - 2s - loss: 0.3807 - output_loss: 0.0621 - output_samp_loss: 0.3186 - output_root_mean_squared_error: 0.2492 - output_samp_root_mean_squared_error: 0.5644 - val_loss: 1.0593 - val_output_loss: 0.6036 - val_output_samp_loss: 0.4556 - val_output_root_mean_squared_error: 0.7769 - val_output_samp_root_mean_squared_error: 0.6750
# Epoch 49/100
# 10/10 - 2s - loss: 0.4077 - output_loss: 0.0934 - output_samp_loss: 0.3143 - output_root_mean_squared_error: 0.3056 - output_samp_root_mean_squared_error: 0.5606 - val_loss: 0.8410 - val_output_loss: 0.3864 - val_output_samp_loss: 0.4546 - val_output_root_mean_squared_error: 0.6216 - val_output_samp_root_mean_squared_error: 0.6742
# Epoch 50/100
# 10/10 - 2s - loss: 0.3650 - output_loss: 0.0569 - output_samp_loss: 0.3081 - output_root_mean_squared_error: 0.2386 - output_samp_root_mean_squared_error: 0.5551 - val_loss: 0.7955 - val_output_loss: 0.4276 - val_output_samp_loss: 0.3679 - val_output_root_mean_squared_error: 0.6539 - val_output_samp_root_mean_squared_error: 0.6065
# Epoch 51/100
# 10/10 - 2s - loss: 0.4047 - output_loss: 0.0687 - output_samp_loss: 0.3359 - output_root_mean_squared_error: 0.2622 - output_samp_root_mean_squared_error: 0.5796 - val_loss: 0.6500 - val_output_loss: 0.3356 - val_output_samp_loss: 0.3145 - val_output_root_mean_squared_error: 0.5793 - val_output_samp_root_mean_squared_error: 0.5608
# Epoch 52/100
# 10/10 - 2s - loss: 0.3807 - output_loss: 0.0730 - output_samp_loss: 0.3077 - output_root_mean_squared_error: 0.2702 - output_samp_root_mean_squared_error: 0.5547 - val_loss: 0.6410 - val_output_loss: 0.3333 - val_output_samp_loss: 0.3077 - val_output_root_mean_squared_error: 0.5773 - val_output_samp_root_mean_squared_error: 0.5547
# Epoch 53/100
# 10/10 - 2s - loss: 0.3678 - output_loss: 0.0611 - output_samp_loss: 0.3066 - output_root_mean_squared_error: 0.2473 - output_samp_root_mean_squared_error: 0.5538 - val_loss: 0.6364 - val_output_loss: 0.3035 - val_output_samp_loss: 0.3329 - val_output_root_mean_squared_error: 0.5509 - val_output_samp_root_mean_squared_error: 0.5770
# Restoring model weights from the end of the best epoch.
# Epoch 00053: early stopping
# #### FOLD 1 OOF RMSE = 0.5458
# #### FOLD 1 OOF RMSE = 0.5183

# %% [markdown]
# ## Model loss and metrics graph

# %%
for fold, history in enumerate(history_list):
    print(f'\nFOLD: {fold+1}')
    plot_metrics(history)
# Out:
# FOLD: 1

# %% [markdown]
# # Model evaluation
#
# We are evaluating the model on the `OOF` predictions, it stands for `Out Of Fold`, since we are training using `K-Fold` our model will see all the data, and the correct way to evaluate each fold is by looking at the predictions that are not from that fold.
#
# ## OOF metrics

# %%
y_true = np.concatenate(oof_labels)
y_preds = np.concatenate(oof_pred)

for fold, history in enumerate(history_list):
    print(f"FOLD {fold+1} RMSE: {np.min(history['val_output_root_mean_squared_error']):.4f}")
    
print(f'OOF RMSE: {mean_squared_error(y_true, y_preds, squared=False):.4f}')
# Out:
# FOLD 1 RMSE: 0.5458
# OOF RMSE: 0.5458

# %% [markdown]
# ### **Error analysis**, label x prediction distribution
#
# Here we can compare the distribution from the labels and the predicted values, in a perfect scenario they should align.

# %%
preds_df = pd.DataFrame({'Label': y_true, 'Prediction': y_preds[:,0]})

fig, ax = plt.subplots(1, 1, figsize=(20, 6))
sns.distplot(preds_df['Label'], ax=ax, label='Label')
sns.distplot(preds_df['Prediction'], ax=ax, label='Prediction')
ax.legend()
plt.show()

# %%
sns.jointplot(data=preds_df, x='Label', y='Prediction', kind='reg', height=10)
plt.show()
