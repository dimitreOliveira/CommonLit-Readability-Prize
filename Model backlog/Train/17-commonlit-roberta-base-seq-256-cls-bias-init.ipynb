# %% [markdown]
# ## Dependencies

# %%
import warnings, math, json
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import tensorflow_addons as tfa
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
from tensorflow.keras import optimizers, losses, metrics, Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from transformers import TFAutoModelForSequenceClassification, TFAutoModel, AutoTokenizer
from commonlit_scripts import *


seed = 0
seed_everything(seed)
sns.set(style='whitegrid')
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 150)

# %% [markdown]
# ### Hardware configuration

# %%
strategy, tpu = get_strategy()
AUTO = tf.data.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
print(f'REPLICAS: {REPLICAS}')
# Out:
# Running on TPU grpc://10.0.0.2:8470
# REPLICAS: 8

# %% [markdown]
# # Load data

# %%
train_filepath = '/kaggle/input/commonlitreadabilityprize/train.csv'
train = pd.read_csv(train_filepath)
print(f'Train samples: {len(train)}')
# removing unused columns
train.drop(['url_legal', 'license'], axis=1, inplace=True)
display(train.head())
# Out:
# Train samples: 2834
#           id  \
# 0  c12129c31
# 1  85aa80a4c
# 2  b69ac6792
# 3  dd1000b26
# 4  37c1b32fb
#
#                                                                                                                                                  excerpt  \
# 0  When the young people returned to the ballroom, it presented a decidedly changed appearance. Instead of an interior scene, it was a winter landsca...
# 1  All through dinner time, Mrs. Fayre was somewhat silent, her eyes resting on Dolly with a wistful, uncertain expression. She wanted to give the ch...
# 2  As Roger had predicted, the snow departed as quickly as it came, and two days after their sleigh ride there was scarcely a vestige of white on the...
# 3  And outside before the palace a great garden was walled round, filled full of stately fruit-trees, gray olives and sweet figs, and pomegranates, p...
# 4  Once upon a time there were Three Bears who lived together in a house of their own in a wood. One of them was a Little, Small, Wee Bear; and one w...
#
#      target  standard_error
# 0 -0.340259        0.464009
# 1 -0.315372        0.480805
# 2 -0.580118        0.476676
# 3 -1.054013        0.450007
# 4  0.247197        0.510845

# %% [markdown]
# # Model parameters

# %%
config = {
  "BATCH_SIZE": 8 * REPLICAS,
  "LEARNING_RATE": 1e-5 * REPLICAS,
  "EPOCHS": 100,
  "ES_PATIENCE": 30,
  "N_FOLDS": 5,
  "N_USED_FOLDS": 1,
  "SEQ_LEN": 256,
  "BASE_MODEL": '/kaggle/input/huggingface-roberta/roberta-base/',
  "SEED": seed,
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# ## Auxiliary functions

# %%
# Datasets utility functions
def custom_standardization(text, is_lower=True):
    if is_lower:
        text = text.lower() # if encoder is uncased
    text = text.strip()
    return text

def sample_target(features, target):
    mean, stddev = target
    sampled_target = tf.random.normal([], mean=tf.cast(mean, dtype=tf.float32), 
                                      stddev=tf.cast(stddev, dtype=tf.float32), dtype=tf.float32)
    return (features, sampled_target)
    
def get_dataset(pandas_df, tokenizer, labeled=True, ordered=False, repeated=False, 
                is_sampled=False, batch_size=32, seq_len=128, is_lower=True):
    """
        Return a Tensorflow dataset ready for training or inference.
    """
    text = [custom_standardization(text, is_lower) for text in pandas_df['excerpt']]
    
    # Tokenize inputs
    tokenized_inputs = tokenizer(text, max_length=seq_len, truncation=True, 
                                 padding='max_length', return_tensors='tf')
    
    if labeled:
        dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': tokenized_inputs['input_ids'], 
                                                       'attention_mask': tokenized_inputs['attention_mask']}, 
                                                      (pandas_df['target'], pandas_df['standard_error'])))
        if is_sampled:
            dataset = dataset.map(sample_target, num_parallel_calls=tf.data.AUTOTUNE)
    else:
        dataset = tf.data.Dataset.from_tensor_slices({'input_ids': tokenized_inputs['input_ids'], 
                                                      'attention_mask': tokenized_inputs['attention_mask']})
        
    if repeated:
        dataset = dataset.repeat()
    if not ordered:
        dataset = dataset.shuffle(2048)
    dataset = dataset.batch(batch_size)
    dataset = dataset.cache()
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# %% [markdown]
# # Model

# %%
def model_fn(encoder, seq_len=256, mean=0., stddev=1.):
    input_ids = L.Input(shape=(seq_len,), dtype=tf.int32, name='input_ids')
    input_attention_mask = L.Input(shape=(seq_len,), dtype=tf.int32, name='attention_mask')
    
    outputs = encoder({'input_ids': input_ids,  
                       'attention_mask': input_attention_mask})
    last_hidden_state = outputs['last_hidden_state']
    
    cls_token = last_hidden_state[:, 0, :]
#     x = L.GlobalAveragePooling1D()(last_hidden_state)
#     output = L.Dense(1, name='output')(cls_token)
    output = L.Dense(1, bias_initializer=tf.keras.initializers.RandomNormal(mean=mean, stddev=stddev), 
                     name='output')(cls_token)
    
    model = Model(inputs=[input_ids, input_attention_mask], outputs=output)

    optimizer = optimizers.Adam(lr=config['LEARNING_RATE'])
    model.compile(optimizer=optimizer, 
                  loss=losses.MeanSquaredError(), 
                  metrics=[metrics.RootMeanSquaredError()])
    return model


with strategy.scope():
    encoder = TFAutoModel.from_pretrained(config['BASE_MODEL'])
    model = model_fn(encoder, config['SEQ_LEN'])
    
model.summary()
# Out:
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# attention_mask (InputLayer)     [(None, 256)]        0
# __________________________________________________________________________________________________
# input_ids (InputLayer)          [(None, 256)]        0
# __________________________________________________________________________________________________
# tf_roberta_model (TFRobertaMode TFBaseModelOutputWit 124645632   attention_mask[0][0]
#                                                                  input_ids[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici (None, 768)          0           tf_roberta_model[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            769         tf.__operators__.getitem[0][0]
# ==================================================================================================
# Total params: 124,646,401
# Trainable params: 124,646,401
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
tokenizer = AutoTokenizer.from_pretrained(config['BASE_MODEL'])
skf = KFold(n_splits=config['N_FOLDS'], shuffle=True, random_state=seed)
oof_pred = []; oof_labels = []; history_list = []


for fold,(idxT, idxV) in enumerate(skf.split(train)):
    if fold >= config['N_USED_FOLDS']:
        break
    if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    print(f'\nFOLD: {fold+1}')
    print(f'TRAIN: {len(idxT)} VALID: {len(idxV)}')
    
    mean = train.loc[idxT]['target'].mean()
    stddev = train.loc[idxT]['standard_error'].mean()

    # Model
    K.clear_session()
    with strategy.scope():
        encoder = TFAutoModel.from_pretrained(config['BASE_MODEL'])
        model = model_fn(encoder, seq_len=config['SEQ_LEN'], mean=mean, stddev=stddev)

    model_path = f'model_{fold}.h5'
    es = EarlyStopping(monitor='val_root_mean_squared_error', mode='min', 
                       patience=config['ES_PATIENCE'], restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_root_mean_squared_error', mode='min', 
                                 save_best_only=True, save_weights_only=True)

    # Train
    history = model.fit(x=get_dataset(train.loc[idxT], tokenizer, repeated=True, is_sampled=True, 
                                      batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN']), 
                        validation_data=get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                                                    batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN']), 
                        steps_per_epoch=10, 
                        callbacks=[es, checkpoint], 
                        epochs=config['EPOCHS'],  
                        verbose=2).history

    history_list.append(history)
    # Save last model weights
    model.load_weights(model_path)

    # Results
    print(f"#### FOLD {fold+1} OOF RMSE = {np.min(history['val_root_mean_squared_error']):.4f}")

    # OOF predictions
    valid_ds = get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                           batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN'])
    oof_labels.append([target[0].numpy() for sample, target in iter(valid_ds.unbatch())])
    x_oof = valid_ds.map(lambda sample, target: sample)
    oof_pred.append(model.predict(x_oof))
# Out:
# FOLD: 1
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/100
# 10/10 - 85s - loss: 1.5933 - root_mean_squared_error: 1.2623 - val_loss: 0.9737 - val_root_mean_squared_error: 0.9867
# Epoch 2/100
# 10/10 - 2s - loss: 1.1836 - root_mean_squared_error: 1.0879 - val_loss: 0.5667 - val_root_mean_squared_error: 0.7528
# Epoch 3/100
# 10/10 - 2s - loss: 0.9237 - root_mean_squared_error: 0.9611 - val_loss: 0.4789 - val_root_mean_squared_error: 0.6921
# Epoch 4/100
# 10/10 - 2s - loss: 0.8470 - root_mean_squared_error: 0.9203 - val_loss: 0.4656 - val_root_mean_squared_error: 0.6823
# Epoch 5/100
# 10/10 - 2s - loss: 0.6040 - root_mean_squared_error: 0.7772 - val_loss: 0.3583 - val_root_mean_squared_error: 0.5985
# Epoch 6/100
# 10/10 - 2s - loss: 0.7315 - root_mean_squared_error: 0.8553 - val_loss: 0.3861 - val_root_mean_squared_error: 0.6214
# Epoch 7/100
# 10/10 - 2s - loss: 0.5900 - root_mean_squared_error: 0.7681 - val_loss: 0.3887 - val_root_mean_squared_error: 0.6235
# Epoch 8/100
# 10/10 - 2s - loss: 0.4915 - root_mean_squared_error: 0.7010 - val_loss: 0.4108 - val_root_mean_squared_error: 0.6410
# Epoch 9/100
# 10/10 - 2s - loss: 0.5446 - root_mean_squared_error: 0.7380 - val_loss: 0.6315 - val_root_mean_squared_error: 0.7947
# Epoch 10/100
# 10/10 - 2s - loss: 0.6302 - root_mean_squared_error: 0.7938 - val_loss: 0.8481 - val_root_mean_squared_error: 0.9209
# Epoch 11/100
# 10/10 - 2s - loss: 0.5135 - root_mean_squared_error: 0.7166 - val_loss: 0.3326 - val_root_mean_squared_error: 0.5768
# Epoch 12/100
# 10/10 - 2s - loss: 0.4823 - root_mean_squared_error: 0.6945 - val_loss: 0.4822 - val_root_mean_squared_error: 0.6944
# Epoch 13/100
# 10/10 - 2s - loss: 0.5032 - root_mean_squared_error: 0.7094 - val_loss: 0.3454 - val_root_mean_squared_error: 0.5877
# Epoch 14/100
# 10/10 - 2s - loss: 0.4898 - root_mean_squared_error: 0.6999 - val_loss: 0.4355 - val_root_mean_squared_error: 0.6600
# Epoch 15/100
# 10/10 - 2s - loss: 0.4954 - root_mean_squared_error: 0.7039 - val_loss: 0.3354 - val_root_mean_squared_error: 0.5792
# Epoch 16/100
# 10/10 - 2s - loss: 0.4661 - root_mean_squared_error: 0.6827 - val_loss: 0.4307 - val_root_mean_squared_error: 0.6563
# Epoch 17/100
# 10/10 - 2s - loss: 0.4740 - root_mean_squared_error: 0.6885 - val_loss: 0.6111 - val_root_mean_squared_error: 0.7817
# Epoch 18/100
# 10/10 - 2s - loss: 0.4599 - root_mean_squared_error: 0.6782 - val_loss: 0.2974 - val_root_mean_squared_error: 0.5453
# Epoch 19/100
# 10/10 - 2s - loss: 0.4076 - root_mean_squared_error: 0.6384 - val_loss: 0.3444 - val_root_mean_squared_error: 0.5869
# Epoch 20/100
# 10/10 - 2s - loss: 0.4879 - root_mean_squared_error: 0.6985 - val_loss: 0.5617 - val_root_mean_squared_error: 0.7495
# Epoch 21/100
# 10/10 - 2s - loss: 0.5456 - root_mean_squared_error: 0.7387 - val_loss: 0.4787 - val_root_mean_squared_error: 0.6918
# Epoch 22/100
# 10/10 - 2s - loss: 0.5082 - root_mean_squared_error: 0.7129 - val_loss: 0.4719 - val_root_mean_squared_error: 0.6870
# Epoch 23/100
# 10/10 - 2s - loss: 0.4275 - root_mean_squared_error: 0.6538 - val_loss: 0.3203 - val_root_mean_squared_error: 0.5660
# Epoch 24/100
# 10/10 - 2s - loss: 0.3801 - root_mean_squared_error: 0.6165 - val_loss: 0.3924 - val_root_mean_squared_error: 0.6264
# Epoch 25/100
# 10/10 - 2s - loss: 0.3851 - root_mean_squared_error: 0.6206 - val_loss: 0.3585 - val_root_mean_squared_error: 0.5987
# Epoch 26/100
# 10/10 - 2s - loss: 0.3554 - root_mean_squared_error: 0.5962 - val_loss: 0.3803 - val_root_mean_squared_error: 0.6167
# Epoch 27/100
# 10/10 - 2s - loss: 0.3444 - root_mean_squared_error: 0.5868 - val_loss: 0.3980 - val_root_mean_squared_error: 0.6309
# Epoch 28/100
# 10/10 - 3s - loss: 0.3548 - root_mean_squared_error: 0.5956 - val_loss: 0.5507 - val_root_mean_squared_error: 0.7421
# Epoch 29/100
# 10/10 - 2s - loss: 0.3869 - root_mean_squared_error: 0.6220 - val_loss: 0.3594 - val_root_mean_squared_error: 0.5995
# Epoch 30/100
# 10/10 - 2s - loss: 0.3499 - root_mean_squared_error: 0.5915 - val_loss: 0.3652 - val_root_mean_squared_error: 0.6043
# Epoch 31/100
# 10/10 - 2s - loss: 0.3333 - root_mean_squared_error: 0.5773 - val_loss: 0.6361 - val_root_mean_squared_error: 0.7975
# Epoch 32/100
# 10/10 - 2s - loss: 0.3733 - root_mean_squared_error: 0.6110 - val_loss: 0.3443 - val_root_mean_squared_error: 0.5868
# Epoch 33/100
# 10/10 - 2s - loss: 0.3193 - root_mean_squared_error: 0.5651 - val_loss: 0.3871 - val_root_mean_squared_error: 0.6222
# Epoch 34/100
# 10/10 - 2s - loss: 0.3136 - root_mean_squared_error: 0.5600 - val_loss: 0.5308 - val_root_mean_squared_error: 0.7286
# Epoch 35/100
# 10/10 - 2s - loss: 0.4489 - root_mean_squared_error: 0.6700 - val_loss: 0.2943 - val_root_mean_squared_error: 0.5425
# Epoch 36/100
# 10/10 - 2s - loss: 0.3620 - root_mean_squared_error: 0.6016 - val_loss: 0.5137 - val_root_mean_squared_error: 0.7167
# Epoch 37/100
# 10/10 - 2s - loss: 0.4601 - root_mean_squared_error: 0.6783 - val_loss: 0.5085 - val_root_mean_squared_error: 0.7131
# Epoch 38/100
# 10/10 - 2s - loss: 0.3863 - root_mean_squared_error: 0.6215 - val_loss: 0.3996 - val_root_mean_squared_error: 0.6321
# Epoch 39/100
# 10/10 - 2s - loss: 0.3870 - root_mean_squared_error: 0.6221 - val_loss: 0.3431 - val_root_mean_squared_error: 0.5857
# Epoch 40/100
# 10/10 - 2s - loss: 0.4036 - root_mean_squared_error: 0.6353 - val_loss: 0.3093 - val_root_mean_squared_error: 0.5561
# Epoch 41/100
# 10/10 - 2s - loss: 0.3629 - root_mean_squared_error: 0.6024 - val_loss: 0.2962 - val_root_mean_squared_error: 0.5443
# Epoch 42/100
# 10/10 - 2s - loss: 0.3448 - root_mean_squared_error: 0.5872 - val_loss: 0.3405 - val_root_mean_squared_error: 0.5835
# Epoch 43/100
# 10/10 - 2s - loss: 0.2842 - root_mean_squared_error: 0.5331 - val_loss: 0.3998 - val_root_mean_squared_error: 0.6323
# Epoch 44/100
# 10/10 - 2s - loss: 0.2909 - root_mean_squared_error: 0.5393 - val_loss: 0.3102 - val_root_mean_squared_error: 0.5570
# Epoch 45/100
# 10/10 - 2s - loss: 0.3410 - root_mean_squared_error: 0.5839 - val_loss: 0.4369 - val_root_mean_squared_error: 0.6610
# Epoch 46/100
# 10/10 - 2s - loss: 0.3481 - root_mean_squared_error: 0.5900 - val_loss: 0.3288 - val_root_mean_squared_error: 0.5734
# Epoch 47/100
# 10/10 - 2s - loss: 0.3189 - root_mean_squared_error: 0.5647 - val_loss: 0.3621 - val_root_mean_squared_error: 0.6017
# Epoch 48/100
# 10/10 - 2s - loss: 0.3471 - root_mean_squared_error: 0.5892 - val_loss: 0.5333 - val_root_mean_squared_error: 0.7303
# Epoch 49/100
# 10/10 - 3s - loss: 0.3730 - root_mean_squared_error: 0.6107 - val_loss: 0.4261 - val_root_mean_squared_error: 0.6528
# Epoch 50/100
# 10/10 - 2s - loss: 0.3812 - root_mean_squared_error: 0.6174 - val_loss: 0.4267 - val_root_mean_squared_error: 0.6532
# Epoch 51/100
# 10/10 - 2s - loss: 0.3421 - root_mean_squared_error: 0.5849 - val_loss: 0.3409 - val_root_mean_squared_error: 0.5839
# Epoch 52/100
# 10/10 - 2s - loss: 0.3333 - root_mean_squared_error: 0.5773 - val_loss: 0.4059 - val_root_mean_squared_error: 0.6371
# Epoch 53/100
# 10/10 - 2s - loss: 0.3175 - root_mean_squared_error: 0.5635 - val_loss: 0.6432 - val_root_mean_squared_error: 0.8020
# Epoch 54/100
# 10/10 - 2s - loss: 0.3590 - root_mean_squared_error: 0.5992 - val_loss: 0.3675 - val_root_mean_squared_error: 0.6062
# Epoch 55/100
# 10/10 - 2s - loss: 0.3204 - root_mean_squared_error: 0.5661 - val_loss: 0.4887 - val_root_mean_squared_error: 0.6991
# Epoch 56/100
# 10/10 - 2s - loss: 0.2962 - root_mean_squared_error: 0.5443 - val_loss: 0.3229 - val_root_mean_squared_error: 0.5682
# Epoch 57/100
# 10/10 - 2s - loss: 0.2991 - root_mean_squared_error: 0.5469 - val_loss: 0.3368 - val_root_mean_squared_error: 0.5803
# Epoch 58/100
# 10/10 - 2s - loss: 0.3370 - root_mean_squared_error: 0.5805 - val_loss: 0.4152 - val_root_mean_squared_error: 0.6444
# Epoch 59/100
# 10/10 - 2s - loss: 0.3535 - root_mean_squared_error: 0.5946 - val_loss: 0.3726 - val_root_mean_squared_error: 0.6104
# Epoch 60/100
# 10/10 - 2s - loss: 0.3020 - root_mean_squared_error: 0.5495 - val_loss: 0.4471 - val_root_mean_squared_error: 0.6686
# Epoch 61/100
# 10/10 - 2s - loss: 0.3594 - root_mean_squared_error: 0.5995 - val_loss: 0.3109 - val_root_mean_squared_error: 0.5576
# Epoch 62/100
# 10/10 - 2s - loss: 0.4271 - root_mean_squared_error: 0.6535 - val_loss: 0.3123 - val_root_mean_squared_error: 0.5589
# Epoch 63/100
# 10/10 - 2s - loss: 0.3835 - root_mean_squared_error: 0.6193 - val_loss: 0.3946 - val_root_mean_squared_error: 0.6282
# Epoch 64/100
# 10/10 - 2s - loss: 0.3304 - root_mean_squared_error: 0.5748 - val_loss: 0.3375 - val_root_mean_squared_error: 0.5810
# Epoch 65/100
# 10/10 - 2s - loss: 0.3846 - root_mean_squared_error: 0.6201 - val_loss: 0.6561 - val_root_mean_squared_error: 0.8100
# Restoring model weights from the end of the best epoch.
# Epoch 00065: early stopping
# #### FOLD 1 OOF RMSE = 0.5425

# %% [markdown]
# ## Model loss and metrics graph

# %%
for fold, history in enumerate(history_list):
    print(f'\nFOLD: {fold+1}')
    plot_metrics(history)
# Out:
# FOLD: 1

# %% [markdown]
# # Model evaluation
#
# We are evaluating the model on the `OOF` predictions, it stands for `Out Of Fold`, since we are training using `K-Fold` our model will see all the data, and the correct way to evaluate each fold is by looking at the predictions that are not from that fold.
#
# ## OOF metrics

# %%
y_true = np.concatenate(oof_labels)
y_preds = np.concatenate(oof_pred)

for fold, history in enumerate(history_list):
    print(f"FOLD {fold+1} RMSE: {np.min(history['val_root_mean_squared_error']):.4f}")
    
print(f'OOF RMSE: {mean_squared_error(y_true, y_preds, squared=False):.4f}')
# Out:
# FOLD 1 RMSE: 0.5425
# OOF RMSE: 0.5425

# %% [markdown]
# ### **Error analysis**, label x prediction distribution
#
# Here we can compare the distribution from the labels and the predicted values, in a perfect scenario they should align.

# %%
preds_df = pd.DataFrame({'Label': y_true, 'Prediction': y_preds[:,0]})

fig, ax = plt.subplots(1, 1, figsize=(20, 6))
sns.distplot(preds_df['Label'], ax=ax, label='Label')
sns.distplot(preds_df['Prediction'], ax=ax, label='Prediction')
ax.legend()
plt.show()

# %%
sns.jointplot(data=preds_df, x='Label', y='Prediction', kind='reg', height=10)
plt.show()
