# %% [markdown]
# ## Dependencies

# %%
import warnings, math, json
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import tensorflow_addons as tfa
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
from tensorflow.keras import optimizers, losses, metrics, Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from transformers import TFAutoModelForSequenceClassification, TFAutoModel, AutoTokenizer
from commonlit_scripts import *


seed = 0
seed_everything(seed)
sns.set(style='whitegrid')
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 150)

# %% [markdown]
# ### Hardware configuration

# %%
strategy, tpu = get_strategy()
AUTO = tf.data.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
print(f'REPLICAS: {REPLICAS}')
# Out:
# Running on TPU grpc://10.0.0.2:8470
# REPLICAS: 8

# %% [markdown]
# # Load data

# %%
train_filepath = '/kaggle/input/commonlitreadabilityprize/train.csv'
train = pd.read_csv(train_filepath)
print(f'Train samples: {len(train)}')
# removing unused columns
train.drop(['url_legal', 'license'], axis=1, inplace=True)
display(train.head())
# Out:
# Train samples: 2834
#           id  \
# 0  c12129c31
# 1  85aa80a4c
# 2  b69ac6792
# 3  dd1000b26
# 4  37c1b32fb
#
#                                                                                                                                                  excerpt  \
# 0  When the young people returned to the ballroom, it presented a decidedly changed appearance. Instead of an interior scene, it was a winter landsca...
# 1  All through dinner time, Mrs. Fayre was somewhat silent, her eyes resting on Dolly with a wistful, uncertain expression. She wanted to give the ch...
# 2  As Roger had predicted, the snow departed as quickly as it came, and two days after their sleigh ride there was scarcely a vestige of white on the...
# 3  And outside before the palace a great garden was walled round, filled full of stately fruit-trees, gray olives and sweet figs, and pomegranates, p...
# 4  Once upon a time there were Three Bears who lived together in a house of their own in a wood. One of them was a Little, Small, Wee Bear; and one w...
#
#      target  standard_error
# 0 -0.340259        0.464009
# 1 -0.315372        0.480805
# 2 -0.580118        0.476676
# 3 -1.054013        0.450007
# 4  0.247197        0.510845

# %% [markdown]
# # Model parameters

# %%
config = {
  "BATCH_SIZE": 8 * REPLICAS,
  "LEARNING_RATE": 1e-5 * REPLICAS,
  "EPOCHS": 100,
  "ES_PATIENCE": 30,
  "N_FOLDS": 5,
  "N_USED_FOLDS": 1,
  "SEQ_LEN": 256,
  "BASE_MODEL": '/kaggle/input/huggingface-roberta/roberta-base/',
  "SEED": seed,
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# ## Auxiliary functions

# %%
# Datasets utility functions
def custom_standardization(text, is_lower=True):
    if is_lower:
        text = text.lower() # if encoder is uncased
    text = text.strip()
    return text

def sample_target(features, target):
    mean, stddev, _ = target
    sampled_target = tf.random.normal([], mean=tf.cast(mean, dtype=tf.float32), 
                                      stddev=tf.cast(stddev, dtype=tf.float32), dtype=tf.float32)
    return (features, (mean, stddev, sampled_target))
    
def get_dataset(pandas_df, tokenizer, labeled=True, ordered=False, repeated=False, 
                is_sampled=False, batch_size=32, seq_len=128, is_lower=True):
    """
        Return a Tensorflow dataset ready for training or inference.
    """
    text = [custom_standardization(text, is_lower) for text in pandas_df['excerpt']]
    
    # Tokenize inputs
    tokenized_inputs = tokenizer(text, max_length=seq_len, truncation=True, 
                                 padding='max_length', return_tensors='tf')
    
    if labeled:
        dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': tokenized_inputs['input_ids'], 
                                                       'attention_mask': tokenized_inputs['attention_mask']}, 
                                                      (pandas_df['target'], pandas_df['standard_error'], pandas_df['target'])))
        if is_sampled:
            dataset = dataset.map(sample_target, num_parallel_calls=tf.data.AUTOTUNE)
    else:
        dataset = tf.data.Dataset.from_tensor_slices({'input_ids': tokenized_inputs['input_ids'], 
                                                      'attention_mask': tokenized_inputs['attention_mask']})
        
    if repeated:
        dataset = dataset.repeat()
    if not ordered:
        dataset = dataset.shuffle(2048)
    dataset = dataset.batch(batch_size)
    dataset = dataset.cache()
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# %% [markdown]
# # Model

# %%
def model_fn(encoder, seq_len=256):
    input_ids = L.Input(shape=(seq_len,), dtype=tf.int32, name='input_ids')
    input_attention_mask = L.Input(shape=(seq_len,), dtype=tf.int32, name='attention_mask')
    
    outputs = encoder({'input_ids': input_ids,  
                       'attention_mask': input_attention_mask})
    last_hidden_state = outputs['last_hidden_state']
    
    cls_token = last_hidden_state[:, 0, :]
#     x = L.GlobalAveragePooling1D()(last_hidden_state)
    output = L.Dense(1, name='output')(cls_token)
    output_stddev = L.Dense(1, name='output_stddev')(cls_token)
    output_samp = L.Dense(1, name='output_samp')(cls_token)
    
    model = Model(inputs=[input_ids, input_attention_mask], 
                  outputs=[output, output_stddev, output_samp])

    optimizer = optimizers.Adam(lr=config['LEARNING_RATE'])
    model.compile(optimizer=optimizer, 
                  loss=losses.MeanSquaredError(), 
                  metrics=[metrics.RootMeanSquaredError()])
    return model


with strategy.scope():
    encoder = TFAutoModel.from_pretrained(config['BASE_MODEL'])
    model = model_fn(encoder, config['SEQ_LEN'])
    
model.summary()
# Out:
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# attention_mask (InputLayer)     [(None, 256)]        0
# __________________________________________________________________________________________________
# input_ids (InputLayer)          [(None, 256)]        0
# __________________________________________________________________________________________________
# tf_roberta_model (TFRobertaMode TFBaseModelOutputWit 124645632   attention_mask[0][0]
#                                                                  input_ids[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici (None, 768)          0           tf_roberta_model[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            769         tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# output_stddev (Dense)           (None, 1)            769         tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# output_samp (Dense)             (None, 1)            769         tf.__operators__.getitem[0][0]
# ==================================================================================================
# Total params: 124,647,939
# Trainable params: 124,647,939
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
tokenizer = AutoTokenizer.from_pretrained(config['BASE_MODEL'])
skf = KFold(n_splits=config['N_FOLDS'], shuffle=True, random_state=seed)
oof_pred = []; oof_labels = []; history_list = []


for fold,(idxT, idxV) in enumerate(skf.split(train)):
    if fold >= config['N_USED_FOLDS']:
        break
    if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    print(f'\nFOLD: {fold+1}')
    print(f'TRAIN: {len(idxT)} VALID: {len(idxV)}')
    
    # Model
    K.clear_session()
    with strategy.scope():
        encoder = TFAutoModel.from_pretrained(config['BASE_MODEL'])
        model = model_fn(encoder, seq_len=config['SEQ_LEN'])

    model_path = f'model_{fold}.h5'
    es = EarlyStopping(monitor='val_output_root_mean_squared_error', mode='min', 
                       patience=config['ES_PATIENCE'], restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_output_root_mean_squared_error', mode='min', 
                                 save_best_only=True, save_weights_only=True)

    # Train
    history = model.fit(x=get_dataset(train.loc[idxT], tokenizer, repeated=True, is_sampled=True, 
                                      batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN']), 
                        validation_data=get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                                                    batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN']), 
                        steps_per_epoch=10, 
                        callbacks=[es, checkpoint], 
                        epochs=config['EPOCHS'],  
                        verbose=2).history

    history_list.append(history)
    # Save last model weights
    model.load_weights(model_path)

    # Results
    print(f"#### FOLD {fold+1} OOF RMSE = {np.min(history['val_output_root_mean_squared_error']):.4f}")
    print(f"#### FOLD {fold+1} OOF RMSE = {np.min(history['val_output_samp_root_mean_squared_error']):.4f}")

    # OOF predictions
    valid_ds = get_dataset(train.loc[idxV], tokenizer, ordered=True, 
                           batch_size=config['BATCH_SIZE'], seq_len=config['SEQ_LEN'])
    oof_labels.append([target[0].numpy() for sample, target in iter(valid_ds.unbatch())])
    x_oof = valid_ds.map(lambda sample, target: sample)
    oof_pred.append(model.predict(x_oof)[0])
# Out:
# FOLD: 1
# TRAIN: 2267 VALID: 567
# Some layers from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/ were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at /kaggle/input/huggingface-roberta/roberta-base/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/100
# 10/10 - 90s - loss: 2.8804 - output_loss: 1.2635 - output_stddev_loss: 0.2112 - output_samp_loss: 1.4058 - output_root_mean_squared_error: 1.1241 - output_stddev_root_mean_squared_error: 0.4595 - output_samp_root_mean_squared_error: 1.1857 - val_loss: 1.7786 - val_output_loss: 0.8479 - val_output_stddev_loss: 0.1183 - val_output_samp_loss: 0.8124 - val_output_root_mean_squared_error: 0.9208 - val_output_stddev_root_mean_squared_error: 0.3440 - val_output_samp_root_mean_squared_error: 0.9013
# Epoch 2/100
# 10/10 - 2s - loss: 1.8503 - output_loss: 0.7317 - output_stddev_loss: 0.1034 - output_samp_loss: 1.0152 - output_root_mean_squared_error: 0.8554 - output_stddev_root_mean_squared_error: 0.3216 - output_samp_root_mean_squared_error: 1.0076 - val_loss: 1.0156 - val_output_loss: 0.5077 - val_output_stddev_loss: 0.0183 - val_output_samp_loss: 0.4896 - val_output_root_mean_squared_error: 0.7125 - val_output_stddev_root_mean_squared_error: 0.1352 - val_output_samp_root_mean_squared_error: 0.6997
# Epoch 3/100
# 10/10 - 2s - loss: 1.2009 - output_loss: 0.4693 - output_stddev_loss: 0.0229 - output_samp_loss: 0.7087 - output_root_mean_squared_error: 0.6850 - output_stddev_root_mean_squared_error: 0.1513 - output_samp_root_mean_squared_error: 0.8419 - val_loss: 0.7688 - val_output_loss: 0.4101 - val_output_stddev_loss: 0.0098 - val_output_samp_loss: 0.3488 - val_output_root_mean_squared_error: 0.6404 - val_output_stddev_root_mean_squared_error: 0.0990 - val_output_samp_root_mean_squared_error: 0.5906
# Epoch 4/100
# 10/10 - 3s - loss: 1.0832 - output_loss: 0.3928 - output_stddev_loss: 0.0382 - output_samp_loss: 0.6523 - output_root_mean_squared_error: 0.6267 - output_stddev_root_mean_squared_error: 0.1954 - output_samp_root_mean_squared_error: 0.8076 - val_loss: 0.6869 - val_output_loss: 0.3429 - val_output_stddev_loss: 0.0079 - val_output_samp_loss: 0.3361 - val_output_root_mean_squared_error: 0.5855 - val_output_stddev_root_mean_squared_error: 0.0889 - val_output_samp_root_mean_squared_error: 0.5797
# Epoch 5/100
# 10/10 - 2s - loss: 0.9599 - output_loss: 0.3485 - output_stddev_loss: 0.0261 - output_samp_loss: 0.5853 - output_root_mean_squared_error: 0.5904 - output_stddev_root_mean_squared_error: 0.1617 - output_samp_root_mean_squared_error: 0.7650 - val_loss: 0.7404 - val_output_loss: 0.3426 - val_output_stddev_loss: 0.0097 - val_output_samp_loss: 0.3882 - val_output_root_mean_squared_error: 0.5853 - val_output_stddev_root_mean_squared_error: 0.0984 - val_output_samp_root_mean_squared_error: 0.6230
# Epoch 6/100
# 10/10 - 2s - loss: 0.8454 - output_loss: 0.3004 - output_stddev_loss: 0.0310 - output_samp_loss: 0.5140 - output_root_mean_squared_error: 0.5481 - output_stddev_root_mean_squared_error: 0.1759 - output_samp_root_mean_squared_error: 0.7170 - val_loss: 0.6762 - val_output_loss: 0.3665 - val_output_stddev_loss: 0.0035 - val_output_samp_loss: 0.3061 - val_output_root_mean_squared_error: 0.6054 - val_output_stddev_root_mean_squared_error: 0.0594 - val_output_samp_root_mean_squared_error: 0.5533
# Epoch 7/100
# 10/10 - 2s - loss: 0.9202 - output_loss: 0.3187 - output_stddev_loss: 0.0253 - output_samp_loss: 0.5762 - output_root_mean_squared_error: 0.5645 - output_stddev_root_mean_squared_error: 0.1591 - output_samp_root_mean_squared_error: 0.7591 - val_loss: 0.6581 - val_output_loss: 0.3241 - val_output_stddev_loss: 0.0041 - val_output_samp_loss: 0.3299 - val_output_root_mean_squared_error: 0.5693 - val_output_stddev_root_mean_squared_error: 0.0641 - val_output_samp_root_mean_squared_error: 0.5744
# Epoch 8/100
# 10/10 - 2s - loss: 0.7702 - output_loss: 0.2635 - output_stddev_loss: 0.0201 - output_samp_loss: 0.4865 - output_root_mean_squared_error: 0.5134 - output_stddev_root_mean_squared_error: 0.1419 - output_samp_root_mean_squared_error: 0.6975 - val_loss: 0.6539 - val_output_loss: 0.3095 - val_output_stddev_loss: 0.0024 - val_output_samp_loss: 0.3421 - val_output_root_mean_squared_error: 0.5563 - val_output_stddev_root_mean_squared_error: 0.0485 - val_output_samp_root_mean_squared_error: 0.5849
# Epoch 9/100
# 10/10 - 2s - loss: 0.7926 - output_loss: 0.2628 - output_stddev_loss: 0.0239 - output_samp_loss: 0.5059 - output_root_mean_squared_error: 0.5126 - output_stddev_root_mean_squared_error: 0.1546 - output_samp_root_mean_squared_error: 0.7113 - val_loss: 0.6639 - val_output_loss: 0.3561 - val_output_stddev_loss: 0.0077 - val_output_samp_loss: 0.3000 - val_output_root_mean_squared_error: 0.5968 - val_output_stddev_root_mean_squared_error: 0.0879 - val_output_samp_root_mean_squared_error: 0.5478
# Epoch 10/100
# 10/10 - 2s - loss: 0.8341 - output_loss: 0.2758 - output_stddev_loss: 0.0331 - output_samp_loss: 0.5252 - output_root_mean_squared_error: 0.5252 - output_stddev_root_mean_squared_error: 0.1818 - output_samp_root_mean_squared_error: 0.7247 - val_loss: 1.5612 - val_output_loss: 0.7150 - val_output_stddev_loss: 0.0064 - val_output_samp_loss: 0.8398 - val_output_root_mean_squared_error: 0.8456 - val_output_stddev_root_mean_squared_error: 0.0799 - val_output_samp_root_mean_squared_error: 0.9164
# Epoch 11/100
# 10/10 - 2s - loss: 0.7210 - output_loss: 0.2718 - output_stddev_loss: 0.0196 - output_samp_loss: 0.4296 - output_root_mean_squared_error: 0.5213 - output_stddev_root_mean_squared_error: 0.1401 - output_samp_root_mean_squared_error: 0.6554 - val_loss: 0.6402 - val_output_loss: 0.3277 - val_output_stddev_loss: 0.0030 - val_output_samp_loss: 0.3095 - val_output_root_mean_squared_error: 0.5724 - val_output_stddev_root_mean_squared_error: 0.0547 - val_output_samp_root_mean_squared_error: 0.5563
# Epoch 12/100
# 10/10 - 2s - loss: 0.7417 - output_loss: 0.2481 - output_stddev_loss: 0.0158 - output_samp_loss: 0.4779 - output_root_mean_squared_error: 0.4981 - output_stddev_root_mean_squared_error: 0.1256 - output_samp_root_mean_squared_error: 0.6913 - val_loss: 0.8671 - val_output_loss: 0.5462 - val_output_stddev_loss: 0.0035 - val_output_samp_loss: 0.3174 - val_output_root_mean_squared_error: 0.7390 - val_output_stddev_root_mean_squared_error: 0.0594 - val_output_samp_root_mean_squared_error: 0.5634
# Epoch 13/100
# 10/10 - 2s - loss: 0.6773 - output_loss: 0.2220 - output_stddev_loss: 0.0196 - output_samp_loss: 0.4358 - output_root_mean_squared_error: 0.4712 - output_stddev_root_mean_squared_error: 0.1399 - output_samp_root_mean_squared_error: 0.6601 - val_loss: 0.9012 - val_output_loss: 0.4781 - val_output_stddev_loss: 0.0064 - val_output_samp_loss: 0.4168 - val_output_root_mean_squared_error: 0.6915 - val_output_stddev_root_mean_squared_error: 0.0797 - val_output_samp_root_mean_squared_error: 0.6456
# Epoch 14/100
# 10/10 - 2s - loss: 0.7388 - output_loss: 0.2346 - output_stddev_loss: 0.0194 - output_samp_loss: 0.4847 - output_root_mean_squared_error: 0.4844 - output_stddev_root_mean_squared_error: 0.1395 - output_samp_root_mean_squared_error: 0.6962 - val_loss: 0.7081 - val_output_loss: 0.3701 - val_output_stddev_loss: 0.0075 - val_output_samp_loss: 0.3306 - val_output_root_mean_squared_error: 0.6083 - val_output_stddev_root_mean_squared_error: 0.0866 - val_output_samp_root_mean_squared_error: 0.5749
# Epoch 15/100
# 10/10 - 2s - loss: 0.5824 - output_loss: 0.1557 - output_stddev_loss: 0.0167 - output_samp_loss: 0.4100 - output_root_mean_squared_error: 0.3945 - output_stddev_root_mean_squared_error: 0.1294 - output_samp_root_mean_squared_error: 0.6403 - val_loss: 0.8904 - val_output_loss: 0.4479 - val_output_stddev_loss: 0.0038 - val_output_samp_loss: 0.4387 - val_output_root_mean_squared_error: 0.6693 - val_output_stddev_root_mean_squared_error: 0.0615 - val_output_samp_root_mean_squared_error: 0.6624
# Epoch 16/100
# 10/10 - 2s - loss: 0.5653 - output_loss: 0.1700 - output_stddev_loss: 0.0169 - output_samp_loss: 0.3784 - output_root_mean_squared_error: 0.4123 - output_stddev_root_mean_squared_error: 0.1300 - output_samp_root_mean_squared_error: 0.6152 - val_loss: 0.8334 - val_output_loss: 0.3606 - val_output_stddev_loss: 0.0047 - val_output_samp_loss: 0.4681 - val_output_root_mean_squared_error: 0.6005 - val_output_stddev_root_mean_squared_error: 0.0685 - val_output_samp_root_mean_squared_error: 0.6842
# Epoch 17/100
# 10/10 - 2s - loss: 0.5310 - output_loss: 0.1448 - output_stddev_loss: 0.0177 - output_samp_loss: 0.3684 - output_root_mean_squared_error: 0.3806 - output_stddev_root_mean_squared_error: 0.1331 - output_samp_root_mean_squared_error: 0.6070 - val_loss: 0.9367 - val_output_loss: 0.3959 - val_output_stddev_loss: 0.0048 - val_output_samp_loss: 0.5360 - val_output_root_mean_squared_error: 0.6292 - val_output_stddev_root_mean_squared_error: 0.0695 - val_output_samp_root_mean_squared_error: 0.7321
# Epoch 18/100
# 10/10 - 2s - loss: 0.4788 - output_loss: 0.1388 - output_stddev_loss: 0.0137 - output_samp_loss: 0.3263 - output_root_mean_squared_error: 0.3725 - output_stddev_root_mean_squared_error: 0.1172 - output_samp_root_mean_squared_error: 0.5712 - val_loss: 1.0135 - val_output_loss: 0.6132 - val_output_stddev_loss: 0.0029 - val_output_samp_loss: 0.3974 - val_output_root_mean_squared_error: 0.7831 - val_output_stddev_root_mean_squared_error: 0.0535 - val_output_samp_root_mean_squared_error: 0.6304
# Epoch 19/100
# 10/10 - 2s - loss: 0.5321 - output_loss: 0.1309 - output_stddev_loss: 0.0144 - output_samp_loss: 0.3869 - output_root_mean_squared_error: 0.3618 - output_stddev_root_mean_squared_error: 0.1198 - output_samp_root_mean_squared_error: 0.6220 - val_loss: 0.5856 - val_output_loss: 0.2936 - val_output_stddev_loss: 0.0032 - val_output_samp_loss: 0.2888 - val_output_root_mean_squared_error: 0.5418 - val_output_stddev_root_mean_squared_error: 0.0565 - val_output_samp_root_mean_squared_error: 0.5374
# Epoch 20/100
# 10/10 - 2s - loss: 0.5410 - output_loss: 0.1671 - output_stddev_loss: 0.0124 - output_samp_loss: 0.3615 - output_root_mean_squared_error: 0.4087 - output_stddev_root_mean_squared_error: 0.1113 - output_samp_root_mean_squared_error: 0.6013 - val_loss: 0.6474 - val_output_loss: 0.3335 - val_output_stddev_loss: 0.0022 - val_output_samp_loss: 0.3117 - val_output_root_mean_squared_error: 0.5775 - val_output_stddev_root_mean_squared_error: 0.0471 - val_output_samp_root_mean_squared_error: 0.5583
# Epoch 21/100
# 10/10 - 2s - loss: 0.4913 - output_loss: 0.1290 - output_stddev_loss: 0.0124 - output_samp_loss: 0.3498 - output_root_mean_squared_error: 0.3592 - output_stddev_root_mean_squared_error: 0.1115 - output_samp_root_mean_squared_error: 0.5915 - val_loss: 0.6854 - val_output_loss: 0.3289 - val_output_stddev_loss: 0.0036 - val_output_samp_loss: 0.3529 - val_output_root_mean_squared_error: 0.5735 - val_output_stddev_root_mean_squared_error: 0.0599 - val_output_samp_root_mean_squared_error: 0.5941
# Epoch 22/100
# 10/10 - 2s - loss: 0.4927 - output_loss: 0.1090 - output_stddev_loss: 0.0136 - output_samp_loss: 0.3701 - output_root_mean_squared_error: 0.3302 - output_stddev_root_mean_squared_error: 0.1165 - output_samp_root_mean_squared_error: 0.6084 - val_loss: 0.5638 - val_output_loss: 0.2789 - val_output_stddev_loss: 0.0022 - val_output_samp_loss: 0.2827 - val_output_root_mean_squared_error: 0.5281 - val_output_stddev_root_mean_squared_error: 0.0472 - val_output_samp_root_mean_squared_error: 0.5317
# Epoch 23/100
# 10/10 - 2s - loss: 0.4862 - output_loss: 0.1197 - output_stddev_loss: 0.0150 - output_samp_loss: 0.3516 - output_root_mean_squared_error: 0.3459 - output_stddev_root_mean_squared_error: 0.1224 - output_samp_root_mean_squared_error: 0.5929 - val_loss: 0.6597 - val_output_loss: 0.3195 - val_output_stddev_loss: 0.0023 - val_output_samp_loss: 0.3379 - val_output_root_mean_squared_error: 0.5652 - val_output_stddev_root_mean_squared_error: 0.0480 - val_output_samp_root_mean_squared_error: 0.5813
# Epoch 24/100
# 10/10 - 2s - loss: 0.4304 - output_loss: 0.1069 - output_stddev_loss: 0.0132 - output_samp_loss: 0.3103 - output_root_mean_squared_error: 0.3270 - output_stddev_root_mean_squared_error: 0.1148 - output_samp_root_mean_squared_error: 0.5571 - val_loss: 0.6946 - val_output_loss: 0.3803 - val_output_stddev_loss: 0.0038 - val_output_samp_loss: 0.3104 - val_output_root_mean_squared_error: 0.6167 - val_output_stddev_root_mean_squared_error: 0.0618 - val_output_samp_root_mean_squared_error: 0.5572
# Epoch 25/100
# 10/10 - 2s - loss: 0.4747 - output_loss: 0.1008 - output_stddev_loss: 0.0132 - output_samp_loss: 0.3607 - output_root_mean_squared_error: 0.3175 - output_stddev_root_mean_squared_error: 0.1148 - output_samp_root_mean_squared_error: 0.6006 - val_loss: 0.7949 - val_output_loss: 0.3394 - val_output_stddev_loss: 0.0035 - val_output_samp_loss: 0.4521 - val_output_root_mean_squared_error: 0.5825 - val_output_stddev_root_mean_squared_error: 0.0588 - val_output_samp_root_mean_squared_error: 0.6724
# Epoch 26/100
# 10/10 - 3s - loss: 0.4168 - output_loss: 0.0938 - output_stddev_loss: 0.0118 - output_samp_loss: 0.3112 - output_root_mean_squared_error: 0.3062 - output_stddev_root_mean_squared_error: 0.1088 - output_samp_root_mean_squared_error: 0.5578 - val_loss: 0.9255 - val_output_loss: 0.5109 - val_output_stddev_loss: 0.0084 - val_output_samp_loss: 0.4062 - val_output_root_mean_squared_error: 0.7148 - val_output_stddev_root_mean_squared_error: 0.0915 - val_output_samp_root_mean_squared_error: 0.6374
# Epoch 27/100
# 10/10 - 2s - loss: 0.4505 - output_loss: 0.1065 - output_stddev_loss: 0.0130 - output_samp_loss: 0.3310 - output_root_mean_squared_error: 0.3263 - output_stddev_root_mean_squared_error: 0.1141 - output_samp_root_mean_squared_error: 0.5753 - val_loss: 1.1106 - val_output_loss: 0.4019 - val_output_stddev_loss: 0.0050 - val_output_samp_loss: 0.7037 - val_output_root_mean_squared_error: 0.6339 - val_output_stddev_root_mean_squared_error: 0.0706 - val_output_samp_root_mean_squared_error: 0.8389
# Epoch 28/100
# 10/10 - 2s - loss: 0.4872 - output_loss: 0.1001 - output_stddev_loss: 0.0152 - output_samp_loss: 0.3719 - output_root_mean_squared_error: 0.3164 - output_stddev_root_mean_squared_error: 0.1233 - output_samp_root_mean_squared_error: 0.6099 - val_loss: 0.8988 - val_output_loss: 0.5114 - val_output_stddev_loss: 0.0032 - val_output_samp_loss: 0.3842 - val_output_root_mean_squared_error: 0.7151 - val_output_stddev_root_mean_squared_error: 0.0566 - val_output_samp_root_mean_squared_error: 0.6199
# Epoch 29/100
# 10/10 - 2s - loss: 0.4791 - output_loss: 0.1174 - output_stddev_loss: 0.0118 - output_samp_loss: 0.3499 - output_root_mean_squared_error: 0.3426 - output_stddev_root_mean_squared_error: 0.1088 - output_samp_root_mean_squared_error: 0.5915 - val_loss: 0.5956 - val_output_loss: 0.3083 - val_output_stddev_loss: 0.0023 - val_output_samp_loss: 0.2850 - val_output_root_mean_squared_error: 0.5552 - val_output_stddev_root_mean_squared_error: 0.0478 - val_output_samp_root_mean_squared_error: 0.5339
# Epoch 30/100
# 10/10 - 2s - loss: 0.5325 - output_loss: 0.1179 - output_stddev_loss: 0.0116 - output_samp_loss: 0.4029 - output_root_mean_squared_error: 0.3434 - output_stddev_root_mean_squared_error: 0.1079 - output_samp_root_mean_squared_error: 0.6348 - val_loss: 0.5881 - val_output_loss: 0.2868 - val_output_stddev_loss: 0.0022 - val_output_samp_loss: 0.2990 - val_output_root_mean_squared_error: 0.5356 - val_output_stddev_root_mean_squared_error: 0.0471 - val_output_samp_root_mean_squared_error: 0.5468
# Epoch 31/100
# 10/10 - 2s - loss: 0.5859 - output_loss: 0.1398 - output_stddev_loss: 0.0098 - output_samp_loss: 0.4363 - output_root_mean_squared_error: 0.3739 - output_stddev_root_mean_squared_error: 0.0991 - output_samp_root_mean_squared_error: 0.6605 - val_loss: 0.9935 - val_output_loss: 0.5405 - val_output_stddev_loss: 0.0021 - val_output_samp_loss: 0.4508 - val_output_root_mean_squared_error: 0.7352 - val_output_stddev_root_mean_squared_error: 0.0461 - val_output_samp_root_mean_squared_error: 0.6715
# Epoch 32/100
# 10/10 - 2s - loss: 0.4779 - output_loss: 0.1060 - output_stddev_loss: 0.0092 - output_samp_loss: 0.3627 - output_root_mean_squared_error: 0.3256 - output_stddev_root_mean_squared_error: 0.0960 - output_samp_root_mean_squared_error: 0.6022 - val_loss: 0.8787 - val_output_loss: 0.4958 - val_output_stddev_loss: 0.0019 - val_output_samp_loss: 0.3810 - val_output_root_mean_squared_error: 0.7041 - val_output_stddev_root_mean_squared_error: 0.0433 - val_output_samp_root_mean_squared_error: 0.6173
# Epoch 33/100
# 10/10 - 2s - loss: 0.4531 - output_loss: 0.0874 - output_stddev_loss: 0.0105 - output_samp_loss: 0.3552 - output_root_mean_squared_error: 0.2956 - output_stddev_root_mean_squared_error: 0.1024 - output_samp_root_mean_squared_error: 0.5960 - val_loss: 0.7599 - val_output_loss: 0.3335 - val_output_stddev_loss: 0.0021 - val_output_samp_loss: 0.4243 - val_output_root_mean_squared_error: 0.5775 - val_output_stddev_root_mean_squared_error: 0.0459 - val_output_samp_root_mean_squared_error: 0.6514
# Epoch 34/100
# 10/10 - 2s - loss: 0.3827 - output_loss: 0.0729 - output_stddev_loss: 0.0105 - output_samp_loss: 0.2993 - output_root_mean_squared_error: 0.2700 - output_stddev_root_mean_squared_error: 0.1025 - output_samp_root_mean_squared_error: 0.5471 - val_loss: 0.9192 - val_output_loss: 0.4587 - val_output_stddev_loss: 0.0024 - val_output_samp_loss: 0.4580 - val_output_root_mean_squared_error: 0.6773 - val_output_stddev_root_mean_squared_error: 0.0495 - val_output_samp_root_mean_squared_error: 0.6768
# Epoch 35/100
# 10/10 - 2s - loss: 0.4298 - output_loss: 0.0712 - output_stddev_loss: 0.0095 - output_samp_loss: 0.3491 - output_root_mean_squared_error: 0.2668 - output_stddev_root_mean_squared_error: 0.0976 - output_samp_root_mean_squared_error: 0.5908 - val_loss: 0.9449 - val_output_loss: 0.4923 - val_output_stddev_loss: 0.0026 - val_output_samp_loss: 0.4500 - val_output_root_mean_squared_error: 0.7017 - val_output_stddev_root_mean_squared_error: 0.0508 - val_output_samp_root_mean_squared_error: 0.6708
# Epoch 36/100
# 10/10 - 2s - loss: 0.4400 - output_loss: 0.1285 - output_stddev_loss: 0.0085 - output_samp_loss: 0.3030 - output_root_mean_squared_error: 0.3585 - output_stddev_root_mean_squared_error: 0.0921 - output_samp_root_mean_squared_error: 0.5505 - val_loss: 0.7033 - val_output_loss: 0.3218 - val_output_stddev_loss: 0.0016 - val_output_samp_loss: 0.3799 - val_output_root_mean_squared_error: 0.5673 - val_output_stddev_root_mean_squared_error: 0.0401 - val_output_samp_root_mean_squared_error: 0.6163
# Epoch 37/100
# 10/10 - 2s - loss: 0.4157 - output_loss: 0.0737 - output_stddev_loss: 0.0098 - output_samp_loss: 0.3322 - output_root_mean_squared_error: 0.2715 - output_stddev_root_mean_squared_error: 0.0990 - output_samp_root_mean_squared_error: 0.5764 - val_loss: 0.6469 - val_output_loss: 0.3609 - val_output_stddev_loss: 0.0019 - val_output_samp_loss: 0.2841 - val_output_root_mean_squared_error: 0.6007 - val_output_stddev_root_mean_squared_error: 0.0437 - val_output_samp_root_mean_squared_error: 0.5330
# Epoch 38/100
# 10/10 - 2s - loss: 0.3956 - output_loss: 0.0681 - output_stddev_loss: 0.0101 - output_samp_loss: 0.3174 - output_root_mean_squared_error: 0.2609 - output_stddev_root_mean_squared_error: 0.1006 - output_samp_root_mean_squared_error: 0.5634 - val_loss: 0.7275 - val_output_loss: 0.3471 - val_output_stddev_loss: 0.0020 - val_output_samp_loss: 0.3784 - val_output_root_mean_squared_error: 0.5891 - val_output_stddev_root_mean_squared_error: 0.0446 - val_output_samp_root_mean_squared_error: 0.6152
# Epoch 39/100
# 10/10 - 2s - loss: 0.4408 - output_loss: 0.0854 - output_stddev_loss: 0.0096 - output_samp_loss: 0.3457 - output_root_mean_squared_error: 0.2923 - output_stddev_root_mean_squared_error: 0.0980 - output_samp_root_mean_squared_error: 0.5880 - val_loss: 1.1184 - val_output_loss: 0.4882 - val_output_stddev_loss: 0.0037 - val_output_samp_loss: 0.6265 - val_output_root_mean_squared_error: 0.6987 - val_output_stddev_root_mean_squared_error: 0.0606 - val_output_samp_root_mean_squared_error: 0.7915
# Epoch 40/100
# 10/10 - 2s - loss: 0.4835 - output_loss: 0.1067 - output_stddev_loss: 0.0109 - output_samp_loss: 0.3660 - output_root_mean_squared_error: 0.3266 - output_stddev_root_mean_squared_error: 0.1044 - output_samp_root_mean_squared_error: 0.6049 - val_loss: 0.9447 - val_output_loss: 0.5729 - val_output_stddev_loss: 0.0019 - val_output_samp_loss: 0.3698 - val_output_root_mean_squared_error: 0.7569 - val_output_stddev_root_mean_squared_error: 0.0438 - val_output_samp_root_mean_squared_error: 0.6081
# Epoch 41/100
# 10/10 - 2s - loss: 0.4032 - output_loss: 0.0968 - output_stddev_loss: 0.0107 - output_samp_loss: 0.2957 - output_root_mean_squared_error: 0.3112 - output_stddev_root_mean_squared_error: 0.1034 - output_samp_root_mean_squared_error: 0.5438 - val_loss: 0.5908 - val_output_loss: 0.2765 - val_output_stddev_loss: 0.0025 - val_output_samp_loss: 0.3119 - val_output_root_mean_squared_error: 0.5258 - val_output_stddev_root_mean_squared_error: 0.0498 - val_output_samp_root_mean_squared_error: 0.5585
# Epoch 42/100
# 10/10 - 2s - loss: 0.3620 - output_loss: 0.0678 - output_stddev_loss: 0.0106 - output_samp_loss: 0.2836 - output_root_mean_squared_error: 0.2604 - output_stddev_root_mean_squared_error: 0.1029 - output_samp_root_mean_squared_error: 0.5325 - val_loss: 0.7038 - val_output_loss: 0.3789 - val_output_stddev_loss: 0.0018 - val_output_samp_loss: 0.3231 - val_output_root_mean_squared_error: 0.6156 - val_output_stddev_root_mean_squared_error: 0.0421 - val_output_samp_root_mean_squared_error: 0.5684
# Epoch 43/100
# 10/10 - 2s - loss: 0.3952 - output_loss: 0.0661 - output_stddev_loss: 0.0092 - output_samp_loss: 0.3200 - output_root_mean_squared_error: 0.2571 - output_stddev_root_mean_squared_error: 0.0957 - output_samp_root_mean_squared_error: 0.5657 - val_loss: 0.6755 - val_output_loss: 0.2914 - val_output_stddev_loss: 0.0023 - val_output_samp_loss: 0.3818 - val_output_root_mean_squared_error: 0.5398 - val_output_stddev_root_mean_squared_error: 0.0482 - val_output_samp_root_mean_squared_error: 0.6179
# Epoch 44/100
# 10/10 - 2s - loss: 0.3524 - output_loss: 0.0485 - output_stddev_loss: 0.0098 - output_samp_loss: 0.2942 - output_root_mean_squared_error: 0.2202 - output_stddev_root_mean_squared_error: 0.0988 - output_samp_root_mean_squared_error: 0.5424 - val_loss: 0.6246 - val_output_loss: 0.3150 - val_output_stddev_loss: 0.0022 - val_output_samp_loss: 0.3074 - val_output_root_mean_squared_error: 0.5612 - val_output_stddev_root_mean_squared_error: 0.0468 - val_output_samp_root_mean_squared_error: 0.5545
# Epoch 45/100
# 10/10 - 2s - loss: 0.3650 - output_loss: 0.0631 - output_stddev_loss: 0.0072 - output_samp_loss: 0.2947 - output_root_mean_squared_error: 0.2512 - output_stddev_root_mean_squared_error: 0.0848 - output_samp_root_mean_squared_error: 0.5429 - val_loss: 0.7578 - val_output_loss: 0.4033 - val_output_stddev_loss: 0.0017 - val_output_samp_loss: 0.3529 - val_output_root_mean_squared_error: 0.6350 - val_output_stddev_root_mean_squared_error: 0.0414 - val_output_samp_root_mean_squared_error: 0.5940
# Epoch 46/100
# 10/10 - 2s - loss: 0.3692 - output_loss: 0.0685 - output_stddev_loss: 0.0083 - output_samp_loss: 0.2924 - output_root_mean_squared_error: 0.2617 - output_stddev_root_mean_squared_error: 0.0909 - output_samp_root_mean_squared_error: 0.5408 - val_loss: 0.9541 - val_output_loss: 0.3804 - val_output_stddev_loss: 0.0016 - val_output_samp_loss: 0.5722 - val_output_root_mean_squared_error: 0.6167 - val_output_stddev_root_mean_squared_error: 0.0396 - val_output_samp_root_mean_squared_error: 0.7564
# Epoch 47/100
# 10/10 - 3s - loss: 0.4088 - output_loss: 0.0716 - output_stddev_loss: 0.0107 - output_samp_loss: 0.3266 - output_root_mean_squared_error: 0.2676 - output_stddev_root_mean_squared_error: 0.1032 - output_samp_root_mean_squared_error: 0.5715 - val_loss: 1.0132 - val_output_loss: 0.5101 - val_output_stddev_loss: 0.0014 - val_output_samp_loss: 0.5017 - val_output_root_mean_squared_error: 0.7142 - val_output_stddev_root_mean_squared_error: 0.0376 - val_output_samp_root_mean_squared_error: 0.7083
# Epoch 48/100
# 10/10 - 2s - loss: 0.4574 - output_loss: 0.0993 - output_stddev_loss: 0.0092 - output_samp_loss: 0.3489 - output_root_mean_squared_error: 0.3151 - output_stddev_root_mean_squared_error: 0.0961 - output_samp_root_mean_squared_error: 0.5906 - val_loss: 0.7574 - val_output_loss: 0.3857 - val_output_stddev_loss: 0.0019 - val_output_samp_loss: 0.3698 - val_output_root_mean_squared_error: 0.6210 - val_output_stddev_root_mean_squared_error: 0.0435 - val_output_samp_root_mean_squared_error: 0.6081
# Epoch 49/100
# 10/10 - 2s - loss: 0.3900 - output_loss: 0.0786 - output_stddev_loss: 0.0092 - output_samp_loss: 0.3021 - output_root_mean_squared_error: 0.2804 - output_stddev_root_mean_squared_error: 0.0960 - output_samp_root_mean_squared_error: 0.5497 - val_loss: 0.7355 - val_output_loss: 0.3724 - val_output_stddev_loss: 0.0022 - val_output_samp_loss: 0.3610 - val_output_root_mean_squared_error: 0.6102 - val_output_stddev_root_mean_squared_error: 0.0470 - val_output_samp_root_mean_squared_error: 0.6008
# Epoch 50/100
# 10/10 - 2s - loss: 0.3750 - output_loss: 0.0623 - output_stddev_loss: 0.0071 - output_samp_loss: 0.3057 - output_root_mean_squared_error: 0.2495 - output_stddev_root_mean_squared_error: 0.0840 - output_samp_root_mean_squared_error: 0.5529 - val_loss: 0.5727 - val_output_loss: 0.2943 - val_output_stddev_loss: 0.0032 - val_output_samp_loss: 0.2752 - val_output_root_mean_squared_error: 0.5425 - val_output_stddev_root_mean_squared_error: 0.0562 - val_output_samp_root_mean_squared_error: 0.5246
# Epoch 51/100
# 10/10 - 2s - loss: 0.4046 - output_loss: 0.0948 - output_stddev_loss: 0.0080 - output_samp_loss: 0.3017 - output_root_mean_squared_error: 0.3080 - output_stddev_root_mean_squared_error: 0.0892 - output_samp_root_mean_squared_error: 0.5493 - val_loss: 0.5444 - val_output_loss: 0.2686 - val_output_stddev_loss: 0.0017 - val_output_samp_loss: 0.2741 - val_output_root_mean_squared_error: 0.5183 - val_output_stddev_root_mean_squared_error: 0.0406 - val_output_samp_root_mean_squared_error: 0.5236
# Epoch 52/100
# 10/10 - 2s - loss: 0.4284 - output_loss: 0.0736 - output_stddev_loss: 0.0096 - output_samp_loss: 0.3453 - output_root_mean_squared_error: 0.2712 - output_stddev_root_mean_squared_error: 0.0979 - output_samp_root_mean_squared_error: 0.5876 - val_loss: 0.5835 - val_output_loss: 0.2879 - val_output_stddev_loss: 0.0141 - val_output_samp_loss: 0.2815 - val_output_root_mean_squared_error: 0.5365 - val_output_stddev_root_mean_squared_error: 0.1186 - val_output_samp_root_mean_squared_error: 0.5306
# Epoch 53/100
# 10/10 - 2s - loss: 0.4444 - output_loss: 0.0777 - output_stddev_loss: 0.0122 - output_samp_loss: 0.3545 - output_root_mean_squared_error: 0.2787 - output_stddev_root_mean_squared_error: 0.1104 - output_samp_root_mean_squared_error: 0.5954 - val_loss: 0.6709 - val_output_loss: 0.3516 - val_output_stddev_loss: 0.0043 - val_output_samp_loss: 0.3150 - val_output_root_mean_squared_error: 0.5929 - val_output_stddev_root_mean_squared_error: 0.0658 - val_output_samp_root_mean_squared_error: 0.5612
# Epoch 54/100
# 10/10 - 2s - loss: 0.3574 - output_loss: 0.0501 - output_stddev_loss: 0.0111 - output_samp_loss: 0.2962 - output_root_mean_squared_error: 0.2239 - output_stddev_root_mean_squared_error: 0.1053 - output_samp_root_mean_squared_error: 0.5443 - val_loss: 0.7359 - val_output_loss: 0.3485 - val_output_stddev_loss: 0.0058 - val_output_samp_loss: 0.3816 - val_output_root_mean_squared_error: 0.5903 - val_output_stddev_root_mean_squared_error: 0.0764 - val_output_samp_root_mean_squared_error: 0.6177
# Epoch 55/100
# 10/10 - 2s - loss: 0.3958 - output_loss: 0.0581 - output_stddev_loss: 0.0095 - output_samp_loss: 0.3283 - output_root_mean_squared_error: 0.2411 - output_stddev_root_mean_squared_error: 0.0973 - output_samp_root_mean_squared_error: 0.5729 - val_loss: 0.8619 - val_output_loss: 0.5215 - val_output_stddev_loss: 0.0021 - val_output_samp_loss: 0.3383 - val_output_root_mean_squared_error: 0.7221 - val_output_stddev_root_mean_squared_error: 0.0462 - val_output_samp_root_mean_squared_error: 0.5816
# Epoch 56/100
# 10/10 - 2s - loss: 0.3770 - output_loss: 0.0949 - output_stddev_loss: 0.0091 - output_samp_loss: 0.2730 - output_root_mean_squared_error: 0.3080 - output_stddev_root_mean_squared_error: 0.0954 - output_samp_root_mean_squared_error: 0.5225 - val_loss: 0.5607 - val_output_loss: 0.2757 - val_output_stddev_loss: 0.0017 - val_output_samp_loss: 0.2833 - val_output_root_mean_squared_error: 0.5251 - val_output_stddev_root_mean_squared_error: 0.0413 - val_output_samp_root_mean_squared_error: 0.5323
# Epoch 57/100
# 10/10 - 2s - loss: 0.3807 - output_loss: 0.0711 - output_stddev_loss: 0.0092 - output_samp_loss: 0.3004 - output_root_mean_squared_error: 0.2666 - output_stddev_root_mean_squared_error: 0.0961 - output_samp_root_mean_squared_error: 0.5481 - val_loss: 0.6919 - val_output_loss: 0.3993 - val_output_stddev_loss: 0.0015 - val_output_samp_loss: 0.2911 - val_output_root_mean_squared_error: 0.6319 - val_output_stddev_root_mean_squared_error: 0.0381 - val_output_samp_root_mean_squared_error: 0.5396
# Epoch 58/100
# 10/10 - 2s - loss: 0.3592 - output_loss: 0.0516 - output_stddev_loss: 0.0074 - output_samp_loss: 0.3002 - output_root_mean_squared_error: 0.2271 - output_stddev_root_mean_squared_error: 0.0862 - output_samp_root_mean_squared_error: 0.5479 - val_loss: 0.6469 - val_output_loss: 0.2967 - val_output_stddev_loss: 0.0015 - val_output_samp_loss: 0.3486 - val_output_root_mean_squared_error: 0.5447 - val_output_stddev_root_mean_squared_error: 0.0390 - val_output_samp_root_mean_squared_error: 0.5905
# Epoch 59/100
# 10/10 - 2s - loss: 0.4013 - output_loss: 0.0885 - output_stddev_loss: 0.0074 - output_samp_loss: 0.3054 - output_root_mean_squared_error: 0.2975 - output_stddev_root_mean_squared_error: 0.0861 - output_samp_root_mean_squared_error: 0.5526 - val_loss: 1.0341 - val_output_loss: 0.5554 - val_output_stddev_loss: 0.0033 - val_output_samp_loss: 0.4754 - val_output_root_mean_squared_error: 0.7453 - val_output_stddev_root_mean_squared_error: 0.0578 - val_output_samp_root_mean_squared_error: 0.6895
# Epoch 60/100
# 10/10 - 2s - loss: 0.4058 - output_loss: 0.0662 - output_stddev_loss: 0.0064 - output_samp_loss: 0.3332 - output_root_mean_squared_error: 0.2574 - output_stddev_root_mean_squared_error: 0.0799 - output_samp_root_mean_squared_error: 0.5772 - val_loss: 0.6838 - val_output_loss: 0.3664 - val_output_stddev_loss: 0.0039 - val_output_samp_loss: 0.3135 - val_output_root_mean_squared_error: 0.6053 - val_output_stddev_root_mean_squared_error: 0.0623 - val_output_samp_root_mean_squared_error: 0.5599
# Epoch 61/100
# 10/10 - 2s - loss: 0.3527 - output_loss: 0.0628 - output_stddev_loss: 0.0094 - output_samp_loss: 0.2804 - output_root_mean_squared_error: 0.2507 - output_stddev_root_mean_squared_error: 0.0969 - output_samp_root_mean_squared_error: 0.5296 - val_loss: 0.5966 - val_output_loss: 0.2771 - val_output_stddev_loss: 0.0031 - val_output_samp_loss: 0.3165 - val_output_root_mean_squared_error: 0.5264 - val_output_stddev_root_mean_squared_error: 0.0553 - val_output_samp_root_mean_squared_error: 0.5626
# Epoch 62/100
# 10/10 - 2s - loss: 0.3598 - output_loss: 0.0555 - output_stddev_loss: 0.0068 - output_samp_loss: 0.2975 - output_root_mean_squared_error: 0.2356 - output_stddev_root_mean_squared_error: 0.0823 - output_samp_root_mean_squared_error: 0.5454 - val_loss: 0.8336 - val_output_loss: 0.4508 - val_output_stddev_loss: 0.0015 - val_output_samp_loss: 0.3813 - val_output_root_mean_squared_error: 0.6714 - val_output_stddev_root_mean_squared_error: 0.0383 - val_output_samp_root_mean_squared_error: 0.6175
# Epoch 63/100
# 10/10 - 2s - loss: 0.3920 - output_loss: 0.0503 - output_stddev_loss: 0.0078 - output_samp_loss: 0.3338 - output_root_mean_squared_error: 0.2243 - output_stddev_root_mean_squared_error: 0.0886 - output_samp_root_mean_squared_error: 0.5778 - val_loss: 0.6739 - val_output_loss: 0.3267 - val_output_stddev_loss: 0.0019 - val_output_samp_loss: 0.3453 - val_output_root_mean_squared_error: 0.5716 - val_output_stddev_root_mean_squared_error: 0.0437 - val_output_samp_root_mean_squared_error: 0.5876
# Epoch 64/100
# 10/10 - 2s - loss: 0.3698 - output_loss: 0.0721 - output_stddev_loss: 0.0069 - output_samp_loss: 0.2908 - output_root_mean_squared_error: 0.2685 - output_stddev_root_mean_squared_error: 0.0830 - output_samp_root_mean_squared_error: 0.5393 - val_loss: 0.5897 - val_output_loss: 0.2929 - val_output_stddev_loss: 0.0021 - val_output_samp_loss: 0.2948 - val_output_root_mean_squared_error: 0.5412 - val_output_stddev_root_mean_squared_error: 0.0456 - val_output_samp_root_mean_squared_error: 0.5429
# Epoch 65/100
# 10/10 - 2s - loss: 0.4630 - output_loss: 0.1083 - output_stddev_loss: 0.0082 - output_samp_loss: 0.3466 - output_root_mean_squared_error: 0.3290 - output_stddev_root_mean_squared_error: 0.0904 - output_samp_root_mean_squared_error: 0.5887 - val_loss: 0.8363 - val_output_loss: 0.3845 - val_output_stddev_loss: 0.0055 - val_output_samp_loss: 0.4463 - val_output_root_mean_squared_error: 0.6201 - val_output_stddev_root_mean_squared_error: 0.0743 - val_output_samp_root_mean_squared_error: 0.6680
# Epoch 66/100
# 10/10 - 2s - loss: 0.4246 - output_loss: 0.1022 - output_stddev_loss: 0.0085 - output_samp_loss: 0.3139 - output_root_mean_squared_error: 0.3197 - output_stddev_root_mean_squared_error: 0.0920 - output_samp_root_mean_squared_error: 0.5603 - val_loss: 0.6955 - val_output_loss: 0.3344 - val_output_stddev_loss: 0.0015 - val_output_samp_loss: 0.3597 - val_output_root_mean_squared_error: 0.5783 - val_output_stddev_root_mean_squared_error: 0.0386 - val_output_samp_root_mean_squared_error: 0.5997
# Epoch 67/100
# 10/10 - 2s - loss: 0.3703 - output_loss: 0.0544 - output_stddev_loss: 0.0073 - output_samp_loss: 0.3085 - output_root_mean_squared_error: 0.2333 - output_stddev_root_mean_squared_error: 0.0856 - output_samp_root_mean_squared_error: 0.5554 - val_loss: 0.6475 - val_output_loss: 0.3496 - val_output_stddev_loss: 0.0032 - val_output_samp_loss: 0.2947 - val_output_root_mean_squared_error: 0.5913 - val_output_stddev_root_mean_squared_error: 0.0568 - val_output_samp_root_mean_squared_error: 0.5428
# Epoch 68/100
# 10/10 - 3s - loss: 0.3593 - output_loss: 0.0501 - output_stddev_loss: 0.0077 - output_samp_loss: 0.3015 - output_root_mean_squared_error: 0.2238 - output_stddev_root_mean_squared_error: 0.0880 - output_samp_root_mean_squared_error: 0.5491 - val_loss: 0.6274 - val_output_loss: 0.3190 - val_output_stddev_loss: 0.0041 - val_output_samp_loss: 0.3042 - val_output_root_mean_squared_error: 0.5648 - val_output_stddev_root_mean_squared_error: 0.0640 - val_output_samp_root_mean_squared_error: 0.5516
# Epoch 69/100
# 10/10 - 2s - loss: 0.3640 - output_loss: 0.0596 - output_stddev_loss: 0.0074 - output_samp_loss: 0.2969 - output_root_mean_squared_error: 0.2442 - output_stddev_root_mean_squared_error: 0.0861 - output_samp_root_mean_squared_error: 0.5449 - val_loss: 0.6221 - val_output_loss: 0.3220 - val_output_stddev_loss: 0.0041 - val_output_samp_loss: 0.2960 - val_output_root_mean_squared_error: 0.5675 - val_output_stddev_root_mean_squared_error: 0.0641 - val_output_samp_root_mean_squared_error: 0.5441
# Epoch 70/100
# 10/10 - 2s - loss: 0.3748 - output_loss: 0.0581 - output_stddev_loss: 0.0080 - output_samp_loss: 0.3086 - output_root_mean_squared_error: 0.2411 - output_stddev_root_mean_squared_error: 0.0897 - output_samp_root_mean_squared_error: 0.5555 - val_loss: 0.8103 - val_output_loss: 0.4344 - val_output_stddev_loss: 0.0041 - val_output_samp_loss: 0.3719 - val_output_root_mean_squared_error: 0.6591 - val_output_stddev_root_mean_squared_error: 0.0637 - val_output_samp_root_mean_squared_error: 0.6098
# Epoch 71/100
# 10/10 - 2s - loss: 0.3862 - output_loss: 0.0466 - output_stddev_loss: 0.0077 - output_samp_loss: 0.3319 - output_root_mean_squared_error: 0.2159 - output_stddev_root_mean_squared_error: 0.0877 - output_samp_root_mean_squared_error: 0.5761 - val_loss: 1.0675 - val_output_loss: 0.3869 - val_output_stddev_loss: 0.0039 - val_output_samp_loss: 0.6766 - val_output_root_mean_squared_error: 0.6220 - val_output_stddev_root_mean_squared_error: 0.0624 - val_output_samp_root_mean_squared_error: 0.8226
# Epoch 72/100
# 10/10 - 2s - loss: 0.3639 - output_loss: 0.0628 - output_stddev_loss: 0.0074 - output_samp_loss: 0.2938 - output_root_mean_squared_error: 0.2506 - output_stddev_root_mean_squared_error: 0.0858 - output_samp_root_mean_squared_error: 0.5420 - val_loss: 0.6936 - val_output_loss: 0.3202 - val_output_stddev_loss: 0.0045 - val_output_samp_loss: 0.3689 - val_output_root_mean_squared_error: 0.5659 - val_output_stddev_root_mean_squared_error: 0.0670 - val_output_samp_root_mean_squared_error: 0.6073
# Epoch 73/100
# 10/10 - 2s - loss: 0.3383 - output_loss: 0.0478 - output_stddev_loss: 0.0071 - output_samp_loss: 0.2834 - output_root_mean_squared_error: 0.2187 - output_stddev_root_mean_squared_error: 0.0841 - output_samp_root_mean_squared_error: 0.5324 - val_loss: 0.6872 - val_output_loss: 0.3362 - val_output_stddev_loss: 0.0012 - val_output_samp_loss: 0.3498 - val_output_root_mean_squared_error: 0.5798 - val_output_stddev_root_mean_squared_error: 0.0349 - val_output_samp_root_mean_squared_error: 0.5914
# Epoch 74/100
# 10/10 - 2s - loss: 0.3903 - output_loss: 0.0488 - output_stddev_loss: 0.0053 - output_samp_loss: 0.3363 - output_root_mean_squared_error: 0.2208 - output_stddev_root_mean_squared_error: 0.0726 - output_samp_root_mean_squared_error: 0.5799 - val_loss: 0.8441 - val_output_loss: 0.4238 - val_output_stddev_loss: 0.0025 - val_output_samp_loss: 0.4178 - val_output_root_mean_squared_error: 0.6510 - val_output_stddev_root_mean_squared_error: 0.0503 - val_output_samp_root_mean_squared_error: 0.6464
# Epoch 75/100
# 10/10 - 2s - loss: 0.3740 - output_loss: 0.0610 - output_stddev_loss: 0.0070 - output_samp_loss: 0.3061 - output_root_mean_squared_error: 0.2469 - output_stddev_root_mean_squared_error: 0.0835 - output_samp_root_mean_squared_error: 0.5532 - val_loss: 0.9652 - val_output_loss: 0.4468 - val_output_stddev_loss: 0.0030 - val_output_samp_loss: 0.5154 - val_output_root_mean_squared_error: 0.6684 - val_output_stddev_root_mean_squared_error: 0.0550 - val_output_samp_root_mean_squared_error: 0.7179
# Epoch 76/100
# 10/10 - 2s - loss: 0.3399 - output_loss: 0.0483 - output_stddev_loss: 0.0056 - output_samp_loss: 0.2860 - output_root_mean_squared_error: 0.2199 - output_stddev_root_mean_squared_error: 0.0751 - output_samp_root_mean_squared_error: 0.5347 - val_loss: 0.5955 - val_output_loss: 0.2971 - val_output_stddev_loss: 0.0039 - val_output_samp_loss: 0.2944 - val_output_root_mean_squared_error: 0.5451 - val_output_stddev_root_mean_squared_error: 0.0628 - val_output_samp_root_mean_squared_error: 0.5426
# Epoch 77/100
# 10/10 - 2s - loss: 0.3268 - output_loss: 0.0500 - output_stddev_loss: 0.0061 - output_samp_loss: 0.2706 - output_root_mean_squared_error: 0.2237 - output_stddev_root_mean_squared_error: 0.0782 - output_samp_root_mean_squared_error: 0.5202 - val_loss: 0.6608 - val_output_loss: 0.3180 - val_output_stddev_loss: 0.0029 - val_output_samp_loss: 0.3399 - val_output_root_mean_squared_error: 0.5639 - val_output_stddev_root_mean_squared_error: 0.0534 - val_output_samp_root_mean_squared_error: 0.5830
# Epoch 78/100
# 10/10 - 2s - loss: 0.3285 - output_loss: 0.0407 - output_stddev_loss: 0.0051 - output_samp_loss: 0.2827 - output_root_mean_squared_error: 0.2017 - output_stddev_root_mean_squared_error: 0.0711 - output_samp_root_mean_squared_error: 0.5317 - val_loss: 0.7596 - val_output_loss: 0.3756 - val_output_stddev_loss: 0.0020 - val_output_samp_loss: 0.3821 - val_output_root_mean_squared_error: 0.6129 - val_output_stddev_root_mean_squared_error: 0.0443 - val_output_samp_root_mean_squared_error: 0.6181
# Epoch 79/100
# 10/10 - 2s - loss: 0.3227 - output_loss: 0.0409 - output_stddev_loss: 0.0058 - output_samp_loss: 0.2760 - output_root_mean_squared_error: 0.2021 - output_stddev_root_mean_squared_error: 0.0763 - output_samp_root_mean_squared_error: 0.5253 - val_loss: 0.6512 - val_output_loss: 0.3454 - val_output_stddev_loss: 0.0030 - val_output_samp_loss: 0.3028 - val_output_root_mean_squared_error: 0.5877 - val_output_stddev_root_mean_squared_error: 0.0547 - val_output_samp_root_mean_squared_error: 0.5503
# Epoch 80/100
# 10/10 - 2s - loss: 0.3322 - output_loss: 0.0330 - output_stddev_loss: 0.0072 - output_samp_loss: 0.2920 - output_root_mean_squared_error: 0.1817 - output_stddev_root_mean_squared_error: 0.0846 - output_samp_root_mean_squared_error: 0.5404 - val_loss: 1.0639 - val_output_loss: 0.4219 - val_output_stddev_loss: 0.0064 - val_output_samp_loss: 0.6357 - val_output_root_mean_squared_error: 0.6495 - val_output_stddev_root_mean_squared_error: 0.0798 - val_output_samp_root_mean_squared_error: 0.7973
# Epoch 81/100
# 10/10 - 2s - loss: 0.3820 - output_loss: 0.0614 - output_stddev_loss: 0.0070 - output_samp_loss: 0.3137 - output_root_mean_squared_error: 0.2477 - output_stddev_root_mean_squared_error: 0.0834 - output_samp_root_mean_squared_error: 0.5601 - val_loss: 0.7633 - val_output_loss: 0.3664 - val_output_stddev_loss: 0.0038 - val_output_samp_loss: 0.3932 - val_output_root_mean_squared_error: 0.6053 - val_output_stddev_root_mean_squared_error: 0.0613 - val_output_samp_root_mean_squared_error: 0.6271
# Restoring model weights from the end of the best epoch.
# Epoch 00081: early stopping
# #### FOLD 1 OOF RMSE = 0.5183
# #### FOLD 1 OOF RMSE = 0.5236

# %% [markdown]
# ## Model loss and metrics graph

# %%
for fold, history in enumerate(history_list):
    print(f'\nFOLD: {fold+1}')
    plot_metrics(history)
# Out:
# FOLD: 1

# %% [markdown]
# # Model evaluation
#
# We are evaluating the model on the `OOF` predictions, it stands for `Out Of Fold`, since we are training using `K-Fold` our model will see all the data, and the correct way to evaluate each fold is by looking at the predictions that are not from that fold.
#
# ## OOF metrics

# %%
y_true = np.concatenate(oof_labels)
y_preds = np.concatenate(oof_pred)

for fold, history in enumerate(history_list):
    print(f"FOLD {fold+1} RMSE: {np.min(history['val_output_root_mean_squared_error']):.4f}")
    
print(f'OOF RMSE: {mean_squared_error(y_true, y_preds, squared=False):.4f}')
# Out:
# FOLD 1 RMSE: 0.5183
# OOF RMSE: 0.5183

# %% [markdown]
# ### **Error analysis**, label x prediction distribution
#
# Here we can compare the distribution from the labels and the predicted values, in a perfect scenario they should align.

# %%
preds_df = pd.DataFrame({'Label': y_true, 'Prediction': y_preds[:,0]})

fig, ax = plt.subplots(1, 1, figsize=(20, 6))
sns.distplot(preds_df['Label'], ax=ax, label='Label')
sns.distplot(preds_df['Prediction'], ax=ax, label='Prediction')
ax.legend()
plt.show()

# %%
sns.jointplot(data=preds_df, x='Label', y='Prediction', kind='reg', height=10)
plt.show()
